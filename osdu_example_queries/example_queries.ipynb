# %% [markdown]
# # OSDU search examples
#
# For more documentation and tutorials: https://community.opengroup.org/osdu/platform/system/search-service/-/blob/master/docs/tutorial/SearchService.md

# %% [markdown]
# # Prerequsites
#
# You need to set environment variables before proceeding or change the variables declarations 'os.environ.get("ENVIRONMENT_VARIABLE")' in the config.py file.
#
# Please set environment varibles
# - create a .env file in the root folder
# - set environment variables inside .env
#
# TUTORIAL_DNS=\
# TUTORIAL_BASE_URL=\
# TUTORIAL_DATA_PARTITION=\
# TUTORIAL_CLIENT_ID=\
# TUTORIAL_TENANT_ID=\
# TUTORIAL_SCOPES=
#
# ### NOTE
# OSDU is a work in progress and some of these queries may be out of date due to updates in the MEDS version

# %% [markdown]
# ## Import libraries

# %%
from utils import OsduService
from config import Config
from pprint import pprint
import logging

# %%
# set logging information to print to console
logger = logging.getLogger()
logger.setLevel(logging.INFO)

# %%
# instantiating the osdu query class
config = Config()
osdu_search = OsduService(config)

# %% [markdown]
# ### Query by kind

# %%
payload = {
    # "kind": "osdu:wks:master-data--Field:*", # * is a wildcard
    "kind": "osdu:wks:master-data--Field:1.0.0",
    "limit": 2
}

response = osdu_search.get_payload(payload=payload, cursor=False)
pprint(response)
# Out:
# INFO:root:Start search ...
# INFO:root:Time elapsed: 0.012614917755126954 minutes, Number of records: , 2
# INFO:root:Search finished...
# [{'acl': {'owners': ['data.osdudevops.owners@npequinor-dev.dataservices.energy',
#                      'data.masterdata.owners@npequinor-dev.dataservices.energy'],
#           'viewers': ['data.default.viewers@npequinor-dev.dataservices.energy']},
#   'ancestry': {'parents': ['npequinor-dev:fields:13051661-86f3-44f0-b168-a305291a69de:1692100054780514']},
#   'authority': 'osdu',
#   'createTime': '2023-06-20T04:29:07.353Z',
#   'createUser': '4cdd9a47-c1a2-4211-80ec-4b0af906e453',
#   'data': {'ExistenceKind': None,
#            'FieldDescription': None,
#            'FieldID': '13051661-86f3-44f0-b168-a305291a69de',
#            'FieldName': 'SAFIR/SAFIR NORTH',
#            'ResourceCurationStatus': None,
#            'ResourceHomeRegionID': None,
#            'ResourceLifecycleStatus': None,
#            'ResourceSecurityClassification': None,
#            'Source': 'IHS',
#            'SpatialLocation.CoordinateQualityCheckPerformedBy': None,
#            'SpatialLocation.QualitativeSpatialAccuracyTypeID': None,
#            'SpatialLocation.QuantitativeAccuracyBandID': None,
#            'SpatialLocation.SpatialGeometryTypeID': None,
#            'SpatialLocation.SpatialParameterTypeID': None,
#            'SpatialLocation.Wgs84Coordinates': {'geometries': [{'coordinates': [[[[26.8840245,
#                                                                                    30.59479],
#                                                                                   [26.8984175,
#                                                                                    30.59568],
#                                                                                   [26.90366525,
#                                                                                    30.59359325],
#                                                                                   [26.89976775,
#                                                                                    30.58852975],
#                                                                                   [26.89513525,
#                                                                                    30.5857615],
#                                                                                   [26.88976775,
#                                                                                    30.5852885],
#                                                                                   [26.88452,
#                                                                                    30.58737525],
#                                                                                   [26.879392,
#                                                                                    30.59202175],
#                                                                                   [26.8840245,
#                                                                                    30.59479]]]],
#                                                                 'type': 'multipolygon'}],
#                                                 'type': 'geometrycollection'},
#            'TechnicalAssuranceID': None,
#            'TechnicalAssuranceTypeID': None,
#            'VersionCreationReason': None,
#            'VirtualProperties.DefaultLocation.CoordinateQualityCheckPerformedBy': None,
#            'VirtualProperties.DefaultLocation.QualitativeSpatialAccuracyTypeID': None,
#            'VirtualProperties.DefaultLocation.QuantitativeAccuracyBandID': None,
#            'VirtualProperties.DefaultLocation.SpatialGeometryTypeID': None,
#            'VirtualProperties.DefaultLocation.SpatialParameterTypeID': None,
#            'VirtualProperties.DefaultLocation.Wgs84Coordinates': {'geometries': [{'coordinates': [[[[26.8840245,
#                                                                                                      30.59479],
#                                                                                                     [26.8984175,
#                                                                                                      30.59568],
#                                                                                                     [26.90366525,
#                                                                                                      30.59359325],
#                                                                                                     [26.89976775,
#                                                                                                      30.58852975],
#                                                                                                     [26.89513525,
#                                                                                                      30.5857615],
#                                                                                                     [26.88976775,
#                                                                                                      30.5852885],
#                                                                                                     [26.88452,
#                                                                                                      30.58737525],
#                                                                                                     [26.879392,
#                                                                                                      30.59202175],
#                                                                                                     [26.8840245,
#                                                                                                      30.59479]]]],
#                                                                                   'type': 'multipolygon'}],
#                                                                   'type': 'geometrycollection'},
#            'VirtualProperties.DefaultName': 'SAFIR/SAFIR NORTH'},
#   'id': 'npequinor-dev:master-data--Field:feba5c0a-0f22-11ee-999c-2617b5073fb4',
#   'kind': 'osdu:wks:master-data--Field:1.0.0',
#   'legal': {'legaltags': ['npequinor-dev-equinor-private-default'],
#             'otherRelevantDataCountries': ['NO'],
#             'status': 'compliant'},
#   'modifyTime': '2023-08-15T13:33:04.433Z',
#   'modifyUser': '4cdd9a47-c1a2-4211-80ec-4b0af906e453',
#   'namespace': 'osdu:wks',
#   'source': 'wks',
#   'tags': {'EqnrSource': 'SMDA API',
#            'businessCriticalData': 'Not assessed yet',
#            'commitId': '109458dee75e49040de153558ca9e4a46fe14353',
#            'countryOfOrigin': 'NO',
#            'dataID': '552 556 560 525 548',
#            'exportControl': 'No',
#            'inside': 'No',
#            'intellectualPropertyRight': 'Not assessed yet',
#            'legalOwnership': 'Equinor solely',
#            'personalData': 'Yes, limited personal data',
#            'securityClassification': 'Internal',
#            'sensitivityFlag': 'null',
#            'sourceSystem': 'SMDA',
#            'soxCriticalData': 'No'},
#   'type': 'master-data--Field',
#   'version': 1692106384202265},
#  {'acl': {'owners': ['data.osdudevops.owners@npequinor-dev.dataservices.energy',
#                      'data.masterdata.owners@npequinor-dev.dataservices.energy'],
#           'viewers': ['data.default.viewers@npequinor-dev.dataservices.energy']},
#   'ancestry': {'parents': ['npequinor-dev:fields:13097894-89eb-4e8b-a647-6221f0e145d2:1692100054780514']},
#   'authority': 'osdu',
#   'createTime': '2023-06-20T04:29:07.353Z',
#   'createUser': '4cdd9a47-c1a2-4211-80ec-4b0af906e453',
#   'data': {'ExistenceKind': None,
#            'FieldDescription': None,
#            'FieldID': '13097894-89eb-4e8b-a647-6221f0e145d2',
#            'FieldName': 'XINGHUO (TA) 5',
#            'ResourceCurationStatus': None,
#            'ResourceHomeRegionID': None,
#            'ResourceLifecycleStatus': None,
#            'ResourceSecurityClassification': None,
#            'Source': 'IHS',
#            'SpatialLocation.CoordinateQualityCheckPerformedBy': None,
#            'SpatialLocation.QualitativeSpatialAccuracyTypeID': None,
#            'SpatialLocation.QuantitativeAccuracyBandID': None,
#            'SpatialLocation.SpatialGeometryTypeID': None,
#            'SpatialLocation.SpatialParameterTypeID': None,
#            'SpatialLocation.Wgs84Coordinates': {'geometries': [{'coordinates': [[[82.553333,
#                                                                                   41.593333],
#                                                                                  [82.563333,
#                                                                                   41.593333],
#                                                                                  [82.568333,
#                                                                                   41.588333],
#                                                                                  [82.568333,
#                                                                                   41.578333],
#                                                                                  [82.563333,
#                                                                                   41.573333],
#                                                                                  [82.553333,
#                                                                                   41.573333],
#                                                                                  [82.548333,
#                                                                                   41.578333],
#                                                                                  [82.548333,
#                                                                                   41.588333],
#                                                                                  [82.553333,
#                                                                                   41.593333]]],
#                                                                 'type': 'polygon'}],
#                                                 'type': 'geometrycollection'},
#            'TechnicalAssuranceID': None,
#            'TechnicalAssuranceTypeID': None,
#            'VersionCreationReason': None,
#            'VirtualProperties.DefaultLocation.CoordinateQualityCheckPerformedBy': None,
#            'VirtualProperties.DefaultLocation.QualitativeSpatialAccuracyTypeID': None,
#            'VirtualProperties.DefaultLocation.QuantitativeAccuracyBandID': None,
#            'VirtualProperties.DefaultLocation.SpatialGeometryTypeID': None,
#            'VirtualProperties.DefaultLocation.SpatialParameterTypeID': None,
#            'VirtualProperties.DefaultLocation.Wgs84Coordinates': {'geometries': [{'coordinates': [[[82.553333,
#                                                                                                     41.593333],
#                                                                                                    [82.563333,
#                                                                                                     41.593333],
#                                                                                                    [82.568333,
#                                                                                                     41.588333],
#                                                                                                    [82.568333,
#                                                                                                     41.578333],
#                                                                                                    [82.563333,
#                                                                                                     41.573333],
#                                                                                                    [82.553333,
#                                                                                                     41.573333],
#                                                                                                    [82.548333,
#                                                                                                     41.578333],
#                                                                                                    [82.548333,
#                                                                                                     41.588333],
#                                                                                                    [82.553333,
#                                                                                                     41.593333]]],
#                                                                                   'type': 'polygon'}],
#                                                                   'type': 'geometrycollection'},
#            'VirtualProperties.DefaultName': 'XINGHUO (TA) 5'},
#   'id': 'npequinor-dev:master-data--Field:feba38ec-0f22-11ee-999c-2617b5073fb4',
#   'kind': 'osdu:wks:master-data--Field:1.0.0',
#   'legal': {'legaltags': ['npequinor-dev-equinor-private-default'],
#             'otherRelevantDataCountries': ['NO'],
#             'status': 'compliant'},
#   'modifyTime': '2023-08-15T13:33:04.433Z',
#   'modifyUser': '4cdd9a47-c1a2-4211-80ec-4b0af906e453',
#   'namespace': 'osdu:wks',
#   'source': 'wks',
#   'tags': {'EqnrSource': 'SMDA API',
#            'businessCriticalData': 'Not assessed yet',
#            'commitId': '109458dee75e49040de153558ca9e4a46fe14353',
#            'countryOfOrigin': 'NO',
#            'dataID': '552 556 560 525 548',
#            'exportControl': 'No',
#            'inside': 'No',
#            'intellectualPropertyRight': 'Not assessed yet',
#            'legalOwnership': 'Equinor solely',
#            'personalData': 'Yes, limited personal data',
#            'securityClassification': 'Internal',
#            'sensitivityFlag': 'null',
#            'sourceSystem': 'SMDA',
#            'soxCriticalData': 'No'},
#   'type': 'master-data--Field',
#   'version': 1692106384202265}]

# %% [markdown]
# ### Text Queries

# %%
example_queries = [
    "data.WellboreID:9*",
    "data.WellboreID:93f9b07e",
    "data.WellboreID:93f9b07e-7098-11ed",
    "data.WellboreID:93f9b07e-7098-11ed-97ff-367dda495db0", 
    "data.WellboreID:\"93f9b07e-7098-11ed\"", 
    "data.WellboreID:93f9b07",
    "data.WellboreID:\"93f9b07\"", 
    "data.WellboreID:93f9b07*", 
    "data.WellboreID:93f*07e", 
]

for query in example_queries:
    payload = {
            "kind": "osdu:wks:work-product-component--WellLog:*",
            "query": query,
            "limit": 10
        }

    response = osdu_search.get_payload(payload=payload, cursor=True, max_iterations=10)
    pprint(response)
# Out:
# INFO:root:Start search ...
# INFO:root:Time elapsed: 0.014279480775197346 minutes, Number of records: , 10
# INFO:root:Search finished...
# INFO:root:Start search ...
# [{'acl': {'owners': ['data.osdudevops.owners@npequinor-dev.dataservices.energy',
#                      'data.wle.creators@npequinor-dev.dataservices.energy'],
#           'viewers': ['data.norway.viewers@npequinor-dev.dataservices.energy',
#                       'data.datascientist.viewers@npequinor-dev.dataservices.energy']},
#   'authority': 'osdu',
#   'createTime': '2023-03-09T21:50:59.255Z',
#   'createUser': 'e34bd588-d306-4a26-880e-ae74f0c85fc4',
#   'data': {'ActivityType': None,
#            'BottomMeasuredDepth': 0.0,
#            'CompanyID': None,
#            'Curves': [{'CurveDescription': None,
#                        'CurveID': 'TIME',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': 'npequinor-dev:reference-data--UnitOfMeasure:ms:',
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': 'npequinor-dev:reference-data--LogCurveFamily:Time:',
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': 'Time Index',
#                        'NullValue': None},
#                       {'CurveDescription': None,
#                        'CurveID': 'ETIM',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': 'npequinor-dev:reference-data--UnitOfMeasure:s:',
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': 'npequinor-dev:reference-data--LogCurveFamily:Time-Interval:',
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': 'Elapsed Logging Time',
#                        'NullValue': None},
#                       {'CurveDescription': None,
#                        'CurveID': 'TDEP',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': 'npequinor-dev:reference-data--UnitOfMeasure:0.1%20in:',
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': 'npequinor-dev:reference-data--LogCurveFamily:Measured-Depth:',
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': '6-Inch Frame Depth',
#                        'NullValue': None},
#                       {'CurveDescription': None,
#                        'CurveID': 'HV',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': 'npequinor-dev:reference-data--UnitOfMeasure:V:',
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': 'npequinor-dev:reference-data--LogCurveFamily:Electric-Potential:',
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': 'Head Voltage',
#                        'NullValue': None},
#                       {'CurveDescription': None,
#                        'CurveID': 'CVEL',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': 'npequinor-dev:reference-data--UnitOfMeasure:m%2Fh:',
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': 'npequinor-dev:reference-data--LogCurveFamily:Cable-Velocity:',
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': 'Cable Velocity',
#                        'NullValue': None},
#                       {'CurveDescription': None,
#                        'CurveID': 'TENS',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': 'npequinor-dev:reference-data--UnitOfMeasure:lbf:',
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': 'npequinor-dev:reference-data--LogCurveFamily:Tension:',
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': 'Cable Tension',
#                        'NullValue': None},
#                       {'CurveDescription': None,
#                        'CurveID': 'IDWD',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': 'npequinor-dev:reference-data--UnitOfMeasure:m:',
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': 'npequinor-dev:reference-data--LogCurveFamily:Measured-Depth:',
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': 'Borehole depth as measured by the IDW '
#                                    '(Integrated Depth Wheel)',
#                        'NullValue': None},
#                       {'CurveDescription': None,
#                        'CurveID': 'TVD',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': 'npequinor-dev:reference-data--UnitOfMeasure:m:',
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': 'npequinor-dev:reference-data--LogCurveFamily:True-Vertical-Depth:',
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': 'True Vertical Depth',
#                        'NullValue': None},
#                       {'CurveDescription': None,
#                        'CurveID': 'CS',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': 'npequinor-dev:reference-data--UnitOfMeasure:m%2Fh:',
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': 'npequinor-dev:reference-data--LogCurveFamily:Cable-Velocity:',
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': 'Cable Speed',
#                        'NullValue': None},
#                       {'CurveDescription': None,
#                        'CurveID': 'TVDSS',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': 'npequinor-dev:reference-data--UnitOfMeasure:m:',
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': 'npequinor-dev:reference-data--LogCurveFamily:True-Vertical-Depth-Sub-Sea:',
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': 'Sub-sea TVD: True Vertical Depth measured '
#                                    'from Mean Sea Level',
#                        'NullValue': None},
#                       {'CurveDescription': None,
#                        'CurveID': 'SCD',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': 'npequinor-dev:reference-data--UnitOfMeasure:m:',
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': 'npequinor-dev:reference-data--LogCurveFamily:Measured-Depth:',
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': 'Speed Corrected Depth',
#                        'NullValue': None},
#                       {'CurveDescription': None,
#                        'CurveID': 'DEPTH',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': 'npequinor-dev:reference-data--UnitOfMeasure:m:',
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': 'npequinor-dev:reference-data--LogCurveFamily:Measured-Depth:',
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': 'Depth Index',
#                        'NullValue': None}],
#            'Description': None,
#            'DrillingFluidProperty': None,
#            'ExistenceKind': None,
#            'FrameIdentifier': None,
#            'HoleTypeLogging': None,
#            'IsDiscoverable': None,
#            'IsExtendedLoad': None,
#            'IsRegular': None,
#            'LogActivity': None,
#            'LogRemark': None,
#            'LogRun': None,
#            'LogSource': None,
#            'LogVersion': None,
#            'LoggingDirection': None,
#            'LoggingService': None,
#            'Name': 'https://omniadlseun.dfs.core.windows.net/raw/data/WELL LOG '
#                    'EXTRACTION/NO/v2.2/get_raw_data/7220/NO 7220-11-3 '
#                    'AR/FM_PRESS_RAW_RUN2B_EWL_29.DLIS_5847b16a/2_data.parquet',
#            'ReferenceCurveID': None,
#            'ResourceCurationStatus': None,
#            'ResourceHomeRegionID': None,
#            'ResourceLifecycleStatus': None,
#            'ResourceSecurityClassification': None,
#            'SamplingDomainTypeID': None,
#            'SeismicReferenceElevation.VerticalCRSID': None,
#            'SeismicReferenceElevation.VerticalMeasurementDescription': None,
#            'SeismicReferenceElevation.VerticalMeasurementPathID': None,
#            'SeismicReferenceElevation.VerticalMeasurementSourceID': None,
#            'SeismicReferenceElevation.VerticalMeasurementTypeID': None,
#            'SeismicReferenceElevation.VerticalMeasurementUnitOfMeasureID': None,
#            'SeismicReferenceElevation.VerticalReferenceEntityID': None,
#            'SeismicReferenceElevation.VerticalReferenceID': None,
#            'SeismicReferenceElevation.WellboreTVDTrajectoryID': None,
#            'ServiceCompanyID': None,
#            'Source': 'WLE v2.2',
#            'SpatialArea.CoordinateQualityCheckPerformedBy': None,
#            'SpatialArea.QualitativeSpatialAccuracyTypeID': None,
#            'SpatialArea.QuantitativeAccuracyBandID': None,
#            'SpatialArea.SpatialGeometryTypeID': None,
#            'SpatialArea.SpatialParameterTypeID': None,
#            'SpatialPoint.CoordinateQualityCheckPerformedBy': None,
#            'SpatialPoint.QualitativeSpatialAccuracyTypeID': None,
#            'SpatialPoint.QuantitativeAccuracyBandID': None,
#            'SpatialPoint.SpatialGeometryTypeID': None,
#            'SpatialPoint.SpatialParameterTypeID': None,
#            'SubmitterName': None,
#            'TechnicalAssuranceID': None,
#            'ToolStringDescription': None,
#            'TopMeasuredDepth': 0.0,
#            'VerticalMeasurement.VerticalCRSID': None,
#            'VerticalMeasurement.VerticalMeasurementDescription': None,
#            'VerticalMeasurement.VerticalMeasurementPathID': None,
#            'VerticalMeasurement.VerticalMeasurementSourceID': None,
#            'VerticalMeasurement.VerticalMeasurementTypeID': None,
#            'VerticalMeasurement.VerticalMeasurementUnitOfMeasureID': None,
#            'VerticalMeasurement.VerticalReferenceEntityID': None,
#            'VerticalMeasurement.VerticalReferenceID': None,
#            'VerticalMeasurement.WellboreTVDTrajectoryID': None,
#            'VerticalMeasurementID': None,
#            'WellLogTypeID': None,
#            'WellboreID': 'npequinor-dev:master-data--Wellbore:ec3dee22-7097-11ed-97ff-367dda495db0:'},
#   'id': 'npequinor-dev:work-product-component--WellLog:69233af0d12d4310b8a8685b14e3f44e',
#   'kind': 'osdu:wks:work-product-component--WellLog:1.2.0',
#   'legal': {'legaltags': ['npequinor-dev-equinor-private-default'],
#             'otherRelevantDataCountries': ['NO'],
#             'status': 'compliant'},
#   'modifyTime': '2023-03-09T21:51:16.518Z',
#   'modifyUser': 'e34bd588-d306-4a26-880e-ae74f0c85fc4',
#   'namespace': 'osdu:wks',
#   'source': 'wks',
#   'tags': {'businessCriticalData': 'No',
#            'countryOfOrigin': 'NO',
#            'dataID': '706',
#            'exportControl': 'No',
#            'inside': 'No',
#            'intellectualPropertyRight': 'Not accessed yet',
#            'legalOwnership': 'Joint venture',
#            'lineageComplete': 'False',
#            'personalData': 'No',
#            'securityClassification': 'Internal',
#            'sensitivityFlag': 'No',
#            'sourceSystem': 'WellDB NO',
#            'soxCriticalData': 'No'},
#   'type': 'work-product-component--WellLog',
#   'version': 1678398676505136},
#  {'acl': {'owners': ['data.osdudevops.owners@npequinor-dev.dataservices.energy',
#                      'data.wle.creators@npequinor-dev.dataservices.energy'],
#           'viewers': ['data.norway.viewers@npequinor-dev.dataservices.energy',
#                       'data.datascientist.viewers@npequinor-dev.dataservices.energy']},
#   'authority': 'osdu',
#   'createTime': '2023-03-09T21:51:12.354Z',
#   'createUser': 'e34bd588-d306-4a26-880e-ae74f0c85fc4',
#   'data': {'ActivityType': None,
#            'BottomMeasuredDepth': 0.0,
#            'CompanyID': None,
#            'Curves': [{'CurveDescription': None,
#                        'CurveID': 'TIME',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': 'npequinor-dev:reference-data--UnitOfMeasure:ms:',
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': 'npequinor-dev:reference-data--LogCurveFamily:Time:',
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': 'Time Index',
#                        'NullValue': None},
#                       {'CurveDescription': None,
#                        'CurveID': 'ETIM',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': 'npequinor-dev:reference-data--UnitOfMeasure:s:',
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': 'npequinor-dev:reference-data--LogCurveFamily:Time-Interval:',
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': 'Elapsed Logging Time',
#                        'NullValue': None},
#                       {'CurveDescription': None,
#                        'CurveID': 'TDEP',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': 'npequinor-dev:reference-data--UnitOfMeasure:0.1%20in:',
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': 'npequinor-dev:reference-data--LogCurveFamily:Measured-Depth:',
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': '6-Inch Frame Depth',
#                        'NullValue': None},
#                       {'CurveDescription': None,
#                        'CurveID': 'HV',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': 'npequinor-dev:reference-data--UnitOfMeasure:V:',
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': 'npequinor-dev:reference-data--LogCurveFamily:Electric-Potential:',
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': 'Head Voltage',
#                        'NullValue': None},
#                       {'CurveDescription': None,
#                        'CurveID': 'CVEL',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': 'npequinor-dev:reference-data--UnitOfMeasure:m%2Fh:',
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': 'npequinor-dev:reference-data--LogCurveFamily:Cable-Velocity:',
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': 'Cable Velocity',
#                        'NullValue': None},
#                       {'CurveDescription': None,
#                        'CurveID': 'TENS',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': 'npequinor-dev:reference-data--UnitOfMeasure:lbf:',
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': 'npequinor-dev:reference-data--LogCurveFamily:Tension:',
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': 'Cable Tension',
#                        'NullValue': None},
#                       {'CurveDescription': None,
#                        'CurveID': 'IDWD',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': 'npequinor-dev:reference-data--UnitOfMeasure:m:',
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': 'npequinor-dev:reference-data--LogCurveFamily:Measured-Depth:',
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': 'Borehole depth as measured by the IDW '
#                                    '(Integrated Depth Wheel)',
#                        'NullValue': None},
#                       {'CurveDescription': None,
#                        'CurveID': 'TVD',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': 'npequinor-dev:reference-data--UnitOfMeasure:m:',
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': 'npequinor-dev:reference-data--LogCurveFamily:True-Vertical-Depth:',
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': 'True Vertical Depth',
#                        'NullValue': None},
#                       {'CurveDescription': None,
#                        'CurveID': 'CS',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': 'npequinor-dev:reference-data--UnitOfMeasure:m%2Fh:',
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': 'npequinor-dev:reference-data--LogCurveFamily:Cable-Velocity:',
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': 'Cable Speed',
#                        'NullValue': None},
#                       {'CurveDescription': None,
#                        'CurveID': 'TVDSS',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': 'npequinor-dev:reference-data--UnitOfMeasure:m:',
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': 'npequinor-dev:reference-data--LogCurveFamily:True-Vertical-Depth-Sub-Sea:',
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': 'Sub-sea TVD: True Vertical Depth measured '
#                                    'from Mean Sea Level',
#                        'NullValue': None},
#                       {'CurveDescription': None,
#                        'CurveID': 'SCD',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': 'npequinor-dev:reference-data--UnitOfMeasure:m:',
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': 'npequinor-dev:reference-data--LogCurveFamily:Measured-Depth:',
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': 'Speed Corrected Depth',
#                        'NullValue': None},
#                       {'CurveDescription': None,
#                        'CurveID': 'DEPTH',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': 'npequinor-dev:reference-data--UnitOfMeasure:m:',
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': 'npequinor-dev:reference-data--LogCurveFamily:Measured-Depth:',
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': 'Depth Index',
#                        'NullValue': None}],
#            'Description': None,
#            'DrillingFluidProperty': None,
#            'ExistenceKind': None,
#            'FrameIdentifier': None,
#            'HoleTypeLogging': None,
#            'IsDiscoverable': None,
#            'IsExtendedLoad': None,
#            'IsRegular': None,
#            'LogActivity': None,
#            'LogRemark': None,
#            'LogRun': None,
#            'LogSource': None,
#            'LogVersion': None,
#            'LoggingDirection': None,
#            'LoggingService': None,
#            'Name': 'https://omniadlseun.dfs.core.windows.net/raw/data/WELL LOG '
#                    'EXTRACTION/NO/v2.2/get_raw_data/7220/NO 7220-11-3 '
#                    'AR/FM_PRESS_RAW_RUN2B_EWL_36.DLIS_a198b1b5/1_data.parquet',
#            'ReferenceCurveID': None,
#            'ResourceCurationStatus': None,
#            'ResourceHomeRegionID': None,
#            'ResourceLifecycleStatus': None,
#            'ResourceSecurityClassification': None,
#            'SamplingDomainTypeID': None,
#            'SeismicReferenceElevation.VerticalCRSID': None,
#            'SeismicReferenceElevation.VerticalMeasurementDescription': None,
#            'SeismicReferenceElevation.VerticalMeasurementPathID': None,
#            'SeismicReferenceElevation.VerticalMeasurementSourceID': None,
#            'SeismicReferenceElevation.VerticalMeasurementTypeID': None,
#            'SeismicReferenceElevation.VerticalMeasurementUnitOfMeasureID': None,
#            'SeismicReferenceElevation.VerticalReferenceEntityID': None,
#            'SeismicReferenceElevation.VerticalReferenceID': None,
#            'SeismicReferenceElevation.WellboreTVDTrajectoryID': None,
#            'ServiceCompanyID': None,
#            'Source': 'WLE v2.2',
#            'SpatialArea.CoordinateQualityCheckPerformedBy': None,
#            'SpatialArea.QualitativeSpatialAccuracyTypeID': None,
#            'SpatialArea.QuantitativeAccuracyBandID': None,
#            'SpatialArea.SpatialGeometryTypeID': None,
#            'SpatialArea.SpatialParameterTypeID': None,
#            'SpatialPoint.CoordinateQualityCheckPerformedBy': None,
#            'SpatialPoint.QualitativeSpatialAccuracyTypeID': None,
#            'SpatialPoint.QuantitativeAccuracyBandID': None,
#            'SpatialPoint.SpatialGeometryTypeID': None,
#            'SpatialPoint.SpatialParameterTypeID': None,
#            'SubmitterName': None,
#            'TechnicalAssuranceID': None,
#            'ToolStringDescription': None,
#            'TopMeasuredDepth': 0.0,
#            'VerticalMeasurement.VerticalCRSID': None,
#            'VerticalMeasurement.VerticalMeasurementDescription': None,
#            'VerticalMeasurement.VerticalMeasurementPathID': None,
#            'VerticalMeasurement.VerticalMeasurementSourceID': None,
#            'VerticalMeasurement.VerticalMeasurementTypeID': None,
#            'VerticalMeasurement.VerticalMeasurementUnitOfMeasureID': None,
#            'VerticalMeasurement.VerticalReferenceEntityID': None,
#            'VerticalMeasurement.VerticalReferenceID': None,
#            'VerticalMeasurement.WellboreTVDTrajectoryID': None,
#            'VerticalMeasurementID': None,
#            'WellLogTypeID': None,
#            'WellboreID': 'npequinor-dev:master-data--Wellbore:ec3dee22-7097-11ed-97ff-367dda495db0:'},
#   'id': 'npequinor-dev:work-product-component--WellLog:0ce5c746dbb0447b89ae843d3a56b09d',
#   'kind': 'osdu:wks:work-product-component--WellLog:1.2.0',
#   'legal': {'legaltags': ['npequinor-dev-equinor-private-default'],
#             'otherRelevantDataCountries': ['NO'],
#             'status': 'compliant'},
#   'modifyTime': '2023-03-09T21:51:16.535Z',
#   'modifyUser': 'e34bd588-d306-4a26-880e-ae74f0c85fc4',
#   'namespace': 'osdu:wks',
#   'source': 'wks',
#   'tags': {'businessCriticalData': 'No',
#            'countryOfOrigin': 'NO',
#            'dataID': '706',
#            'exportControl': 'No',
#            'inside': 'No',
#            'intellectualPropertyRight': 'Not accessed yet',
#            'legalOwnership': 'Joint venture',
#            'lineageComplete': 'False',
#            'personalData': 'No',
#            'securityClassification': 'Internal',
#            'sensitivityFlag': 'No',
#            'sourceSystem': 'WellDB NO',
#            'soxCriticalData': 'No'},
#   'type': 'work-product-component--WellLog',
#   'version': 1678398676521565},
#  {'acl': {'owners': ['data.osdudevops.owners@npequinor-dev.dataservices.energy',
#                      'data.wle.creators@npequinor-dev.dataservices.energy'],
#           'viewers': ['data.norway.viewers@npequinor-dev.dataservices.energy',
#                       'data.datascientist.viewers@npequinor-dev.dataservices.energy']},
#   'authority': 'osdu',
#   'createTime': '2023-03-09T21:51:16.805Z',
#   'createUser': 'e34bd588-d306-4a26-880e-ae74f0c85fc4',
#   'data': {'ActivityType': None,
#            'BottomMeasuredDepth': 0.0,
#            'CompanyID': None,
#            'Curves': [{'CurveDescription': None,
#                        'CurveID': 'TIME',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': 'npequinor-dev:reference-data--UnitOfMeasure:ms:',
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': 'npequinor-dev:reference-data--LogCurveFamily:Time:',
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': 'Time Index',
#                        'NullValue': None},
#                       {'CurveDescription': None,
#                        'CurveID': 'ETIM',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': 'npequinor-dev:reference-data--UnitOfMeasure:s:',
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': 'npequinor-dev:reference-data--LogCurveFamily:Time-Interval:',
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': 'Elapsed Logging Time',
#                        'NullValue': None},
#                       {'CurveDescription': None,
#                        'CurveID': 'TDEP',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': 'npequinor-dev:reference-data--UnitOfMeasure:0.1%20in:',
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': 'npequinor-dev:reference-data--LogCurveFamily:Measured-Depth:',
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': '6-Inch Frame Depth',
#                        'NullValue': None},
#                       {'CurveDescription': None,
#                        'CurveID': 'SCBTC1',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': None,
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': None,
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': 'MRSC 1 Bad Telemetry Count',
#                        'NullValue': None},
#                       {'CurveDescription': None,
#                        'CurveID': 'SCSN',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': None,
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': None,
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': 'MRSC Sample Number',
#                        'NullValue': None},
#                       {'CurveDescription': None,
#                        'CurveID': 'SCSS',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': None,
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': None,
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': 'MRSC Seal Status',
#                        'NullValue': None},
#                       {'CurveDescription': None,
#                        'CurveID': 'SCTS',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': None,
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': None,
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': 'MRSC Throttle Status',
#                        'NullValue': None},
#                       {'CurveDescription': None,
#                        'CurveID': 'VP1',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': None,
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': None,
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': 'MRSC 1 Valve Position',
#                        'NullValue': None},
#                       {'CurveDescription': None,
#                        'CurveID': 'POTCV',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': 'npequinor-dev:reference-data--UnitOfMeasure:cm3:',
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': 'npequinor-dev:reference-data--LogCurveFamily:Volume-Pumped:',
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': 'Total Pumpout Volume',
#                        'NullValue': None},
#                       {'CurveDescription': None,
#                        'CurveID': 'POTFR',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': 'npequinor-dev:reference-data--UnitOfMeasure:cm3%2Fs:',
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': 'npequinor-dev:reference-data--LogCurveFamily:Flow-Rate:',
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': 'Total Pumpout Flow Rate',
#                        'NullValue': None},
#                       {'CurveDescription': None,
#                        'CurveID': 'POTMC',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': 'npequinor-dev:reference-data--UnitOfMeasure:A:',
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': 'npequinor-dev:reference-data--LogCurveFamily:Electric-Current:',
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': 'Total Pumpout Current',
#                        'NullValue': None},
#                       {'CurveDescription': None,
#                        'CurveID': 'POUDCV',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': 'npequinor-dev:reference-data--UnitOfMeasure:cm3:',
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': 'npequinor-dev:reference-data--LogCurveFamily:Volume-Pumped:',
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': 'MRPOUD Continuous Volume',
#                        'NullValue': None},
#                       {'CurveDescription': None,
#                        'CurveID': 'POUDDC',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': 'npequinor-dev:reference-data--UnitOfMeasure:%25:',
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': 'npequinor-dev:reference-data--LogCurveFamily:Duty-Cycle:',
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': 'MRPOUD Duty Cycle',
#                        'NullValue': None},
#                       {'CurveDescription': None,
#                        'CurveID': 'POUDET',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': 'npequinor-dev:reference-data--UnitOfMeasure:min:',
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': 'npequinor-dev:reference-data--LogCurveFamily:Pumping-Time:',
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': 'MRPOUD Elapsed Pumping Time',
#                        'NullValue': None},
#                       {'CurveDescription': None,
#                        'CurveID': 'POUDFR',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': 'npequinor-dev:reference-data--UnitOfMeasure:cm3%2Fs:',
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': 'npequinor-dev:reference-data--LogCurveFamily:Flow-Rate:',
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': 'MRPOUD Flow Rate',
#                        'NullValue': None},
#                       {'CurveDescription': None,
#                        'CurveID': 'POUDHP',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': 'npequinor-dev:reference-data--UnitOfMeasure:psi:',
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': 'npequinor-dev:reference-data--LogCurveFamily:Hydraulic-Pressure:',
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': 'MRPOUD Hydraulic Pressure',
#                        'NullValue': None},
#                       {'CurveDescription': None,
#                        'CurveID': 'POUDMC',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': 'npequinor-dev:reference-data--UnitOfMeasure:A:',
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': 'npequinor-dev:reference-data--LogCurveFamily:Electric-Current:',
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': 'MRPOUD Motor Current',
#                        'NullValue': None},
#                       {'CurveDescription': None,
#                        'CurveID': 'POUDMS',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': None,
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': 'npequinor-dev:reference-data--LogCurveFamily:Motor-Speed:',
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': 'MRPOUD Motor Speed',
# ...
#                        'LogCurveTypeID': None,
#                        'Mnemonic': '',
#                        'NullValue': None,
#                        'NumberOfColumns': 1},
#                       {'CurveDescription': None,
#                        'CurveID': 'EWR/DGR',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': None,
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': None,
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': '',
#                        'NullValue': None,
#                        'NumberOfColumns': 1},
#                       {'CurveDescription': None,
#                        'CurveID': 'RUN',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': None,
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': None,
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': '',
#                        'NullValue': None,
#                        'NumberOfColumns': 1},
#                       {'CurveDescription': None,
#                        'CurveID': '500',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': None,
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': None,
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': '',
#                        'NullValue': None,
#                        'NumberOfColumns': 1},
#                       {'CurveDescription': None,
#                        'CurveID': '800-1100',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': None,
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': None,
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': '',
#                        'NullValue': None,
#                        'NumberOfColumns': 1}],
#            'Description': None,
#            'DrillingFluidProperty': None,
#            'ExistenceKind': None,
#            'FrameIdentifier': None,
#            'HoleTypeLogging': None,
#            'IsDiscoverable': None,
#            'IsExtendedLoad': None,
#            'IsRegular': None,
#            'LogActivity': None,
#            'LogRemark': None,
#            'LogRun': None,
#            'LogSource': None,
#            'LogVersion': None,
#            'LoggingDirection': None,
#            'LoggingService': None,
#            'Name': 'https://omniadlseun.dfs.core.windows.net/raw/data/WELL LOG '
#                    'EXTRACTION/NO/v2.2/get_raw_data/0001/NO '
#                    '1-2-2/CONTENT-WLC_PETROPHYSICAL_COMPOSITE_1.LIS.TXT_082efb04/0_data.parquet',
#            'ReferenceCurveID': None,
#            'ResourceCurationStatus': None,
#            'ResourceHomeRegionID': None,
#            'ResourceLifecycleStatus': None,
#            'ResourceSecurityClassification': None,
#            'SamplingDomainTypeID': None,
#            'SeismicReferenceElevation.VerticalCRSID': None,
#            'SeismicReferenceElevation.VerticalMeasurementDescription': None,
#            'SeismicReferenceElevation.VerticalMeasurementPathID': None,
#            'SeismicReferenceElevation.VerticalMeasurementSourceID': None,
#            'SeismicReferenceElevation.VerticalMeasurementTypeID': None,
#            'SeismicReferenceElevation.VerticalMeasurementUnitOfMeasureID': None,
#            'SeismicReferenceElevation.VerticalReferenceEntityID': None,
#            'SeismicReferenceElevation.VerticalReferenceID': None,
#            'SeismicReferenceElevation.WellboreTVDTrajectoryID': None,
#            'ServiceCompanyID': None,
#            'Source': 'WLE v2.2',
#            'SpatialArea.CoordinateQualityCheckPerformedBy': None,
#            'SpatialArea.QualitativeSpatialAccuracyTypeID': None,
#            'SpatialArea.QuantitativeAccuracyBandID': None,
#            'SpatialArea.SpatialGeometryTypeID': None,
#            'SpatialArea.SpatialParameterTypeID': None,
#            'SpatialPoint.CoordinateQualityCheckPerformedBy': None,
#            'SpatialPoint.QualitativeSpatialAccuracyTypeID': None,
#            'SpatialPoint.QuantitativeAccuracyBandID': None,
#            'SpatialPoint.SpatialGeometryTypeID': None,
#            'SpatialPoint.SpatialParameterTypeID': None,
#            'SubmitterName': None,
#            'TechnicalAssuranceID': None,
#            'ToolStringDescription': None,
#            'TopMeasuredDepth': 0.0,
#            'VerticalMeasurement.VerticalCRSID': None,
#            'VerticalMeasurement.VerticalMeasurementDescription': None,
#            'VerticalMeasurement.VerticalMeasurementPathID': None,
#            'VerticalMeasurement.VerticalMeasurementSourceID': None,
#            'VerticalMeasurement.VerticalMeasurementTypeID': None,
#            'VerticalMeasurement.VerticalMeasurementUnitOfMeasureID': None,
#            'VerticalMeasurement.VerticalReferenceEntityID': None,
#            'VerticalMeasurement.VerticalReferenceID': None,
#            'VerticalMeasurement.WellboreTVDTrajectoryID': None,
#            'VerticalMeasurementID': None,
#            'VirtualProperties.DefaultLocation.CoordinateQualityCheckPerformedBy': None,
#            'VirtualProperties.DefaultLocation.QualitativeSpatialAccuracyTypeID': None,
#            'VirtualProperties.DefaultLocation.QuantitativeAccuracyBandID': None,
#            'VirtualProperties.DefaultLocation.SpatialGeometryTypeID': None,
#            'VirtualProperties.DefaultLocation.SpatialParameterTypeID': None,
#            'VirtualProperties.DefaultName': 'https://omniadlseun.dfs.core.windows.net/raw/data/WELL '
#                                             'LOG '
#                                             'EXTRACTION/NO/v2.2/get_raw_data/0001/NO '
#                                             '1-2-2/CONTENT-WLC_PETROPHYSICAL_COMPOSITE_1.LIS.TXT_082efb04/0_data.parquet',
#            'WellLogTypeID': None,
#            'WellboreID': 'npequinor-dev:master-data--Wellbore:93f9b07e-7098-11ed-97ff-367dda495db0:'},
#   'id': 'npequinor-dev:work-product-component--WellLog:cc2a6189bee44c45b28d6cb45782549a',
#   'kind': 'osdu:wks:work-product-component--WellLog:1.2.0',
#   'legal': {'legaltags': ['npequinor-dev-equinor-private-default'],
#             'otherRelevantDataCountries': ['NO'],
#             'status': 'compliant'},
#   'modifyTime': '2023-03-22T08:42:39.174Z',
#   'modifyUser': 'e34bd588-d306-4a26-880e-ae74f0c85fc4',
#   'namespace': 'osdu:wks',
#   'source': 'wks',
#   'tags': {'businessCriticalData': 'No',
#            'countryOfOrigin': 'NO',
#            'dataID': '706',
#            'exportControl': 'No',
#            'inside': 'No',
#            'intellectualPropertyRight': 'Not accessed yet',
#            'legalOwnership': 'Joint venture',
#            'lineageComplete': 'False',
#            'personalData': 'No',
#            'securityClassification': 'Internal',
#            'sensitivityFlag': 'No',
#            'sourceSystem': 'WellDB NO',
#            'soxCriticalData': 'No'},
#   'type': 'work-product-component--WellLog',
#   'version': 1679474559158447},
#  {'acl': {'owners': ['data.osdudevops.owners@npequinor-dev.dataservices.energy',
#                      'data.wle.creators@npequinor-dev.dataservices.energy'],
#           'viewers': ['data.norway.viewers@npequinor-dev.dataservices.energy',
#                       'data.datascientist.viewers@npequinor-dev.dataservices.energy']},
#   'authority': 'osdu',
#   'createTime': '2023-03-22T08:42:40.517Z',
#   'createUser': 'e34bd588-d306-4a26-880e-ae74f0c85fc4',
#   'data': {'ActivityType': None,
#            'BottomMeasuredDepth': 0.0,
#            'CompanyID': None,
#            'Curves': [{'CurveDescription': None,
#                        'CurveID': 'DEPT',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': 'npequinor-dev:reference-data--UnitOfMeasure:m:',
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': 'npequinor-dev:reference-data--LogCurveFamily:Measured-Depth:',
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': '',
#                        'NullValue': None,
#                        'NumberOfColumns': 1},
#                       {'CurveDescription': None,
#                        'CurveID': 'BIO (M) (CENO) MOST DISTAL PALEOBATHYMETRY',
#                        'CurveQuality': None,
#                        'CurveSampleTypeID': None,
#                        'CurveUnit': None,
#                        'CurveVersion': None,
#                        'DepthCoding': None,
#                        'DepthUnit': None,
#                        'Interpolate': None,
#                        'InterpreterName': None,
#                        'IsProcessed': None,
#                        'LogCurveBusinessValueID': None,
#                        'LogCurveFamilyID': None,
#                        'LogCurveMainFamilyID': None,
#                        'LogCurveTypeID': None,
#                        'Mnemonic': 'Bio (M) (Ceno) Most distal paleobathymetry',
#                        'NullValue': None,
#                        'NumberOfColumns': 1}],
#            'Description': None,
#            'DrillingFluidProperty': None,
#            'ExistenceKind': None,
#            'FrameIdentifier': None,
#            'HoleTypeLogging': None,
#            'IsDiscoverable': None,
#            'IsExtendedLoad': None,
#            'IsRegular': None,
#            'LogActivity': None,
#            'LogRemark': None,
#            'LogRun': None,
#            'LogSource': None,
#            'LogVersion': None,
#            'LoggingDirection': None,
#            'LoggingService': None,
#            'Name': 'https://omniadlseun.dfs.core.windows.net/raw/data/WELL LOG '
#                    'EXTRACTION/NO/v2.2/get_raw_data/0001/NO '
#                    '1-2-2/NO__bathymetry_ceno_deepest__NO1_2-2.las_e037c7ce/0_data.parquet',
#            'ReferenceCurveID': None,
#            'ResourceCurationStatus': None,
#            'ResourceHomeRegionID': None,
#            'ResourceLifecycleStatus': None,
#            'ResourceSecurityClassification': None,
#            'SamplingDomainTypeID': None,
#            'SeismicReferenceElevation.VerticalCRSID': None,
#            'SeismicReferenceElevation.VerticalMeasurementDescription': None,
#            'SeismicReferenceElevation.VerticalMeasurementPathID': None,
#            'SeismicReferenceElevation.VerticalMeasurementSourceID': None,
#            'SeismicReferenceElevation.VerticalMeasurementTypeID': None,
#            'SeismicReferenceElevation.VerticalMeasurementUnitOfMeasureID': None,
#            'SeismicReferenceElevation.VerticalReferenceEntityID': None,
#            'SeismicReferenceElevation.VerticalReferenceID': None,
#            'SeismicReferenceElevation.WellboreTVDTrajectoryID': None,
#            'ServiceCompanyID': None,
#            'Source': 'WLE v2.2',
#            'SpatialArea.CoordinateQualityCheckPerformedBy': None,
#            'SpatialArea.QualitativeSpatialAccuracyTypeID': None,
#            'SpatialArea.QuantitativeAccuracyBandID': None,
#            'SpatialArea.SpatialGeometryTypeID': None,
#            'SpatialArea.SpatialParameterTypeID': None,
#            'SpatialPoint.CoordinateQualityCheckPerformedBy': None,
#            'SpatialPoint.QualitativeSpatialAccuracyTypeID': None,
#            'SpatialPoint.QuantitativeAccuracyBandID': None,
#            'SpatialPoint.SpatialGeometryTypeID': None,
#            'SpatialPoint.SpatialParameterTypeID': None,
#            'SubmitterName': None,
#            'TechnicalAssuranceID': None,
#            'ToolStringDescription': None,
#            'TopMeasuredDepth': 0.0,
#            'VerticalMeasurement.VerticalCRSID': None,
#            'VerticalMeasurement.VerticalMeasurementDescription': None,
#            'VerticalMeasurement.VerticalMeasurementPathID': None,
#            'VerticalMeasurement.VerticalMeasurementSourceID': None,
#            'VerticalMeasurement.VerticalMeasurementTypeID': None,
#            'VerticalMeasurement.VerticalMeasurementUnitOfMeasureID': None,
#            'VerticalMeasurement.VerticalReferenceEntityID': None,
#            'VerticalMeasurement.VerticalReferenceID': None,
#            'VerticalMeasurement.WellboreTVDTrajectoryID': None,
#            'VerticalMeasurementID': None,
#            'VirtualProperties.DefaultLocation.CoordinateQualityCheckPerformedBy': None,
#            'VirtualProperties.DefaultLocation.QualitativeSpatialAccuracyTypeID': None,
#            'VirtualProperties.DefaultLocation.QuantitativeAccuracyBandID': None,
#            'VirtualProperties.DefaultLocation.SpatialGeometryTypeID': None,
#            'VirtualProperties.DefaultLocation.SpatialParameterTypeID': None,
#            'VirtualProperties.DefaultName': 'https://omniadlseun.dfs.core.windows.net/raw/data/WELL '
#                                             'LOG '
#                                             'EXTRACTION/NO/v2.2/get_raw_data/0001/NO '
#                                             '1-2-2/NO__bathymetry_ceno_deepest__NO1_2-2.las_e037c7ce/0_data.parquet',
#            'WellLogTypeID': None,
#            'WellboreID': 'npequinor-dev:master-data--Wellbore:93f9b07e-7098-11ed-97ff-367dda495db0:'},
#   'id': 'npequinor-dev:work-product-component--WellLog:38e0983903514c2693fd5f4cda354c9a',
#   'kind': 'osdu:wks:work-product-component--WellLog:1.2.0',
#   'legal': {'legaltags': ['npequinor-dev-equinor-private-default'],
#             'otherRelevantDataCountries': ['NO'],
#             'status': 'compliant'},
#   'modifyTime': '2023-03-22T08:42:41.011Z',
#   'modifyUser': 'e34bd588-d306-4a26-880e-ae74f0c85fc4',
#   'namespace': 'osdu:wks',
#   'source': 'wks',
#   'tags': {'businessCriticalData': 'No',
#            'countryOfOrigin': 'NO',
#            'dataID': '706',
#            'exportControl': 'No',
#            'inside': 'No',
#            'intellectualPropertyRight': 'Not accessed yet',
#            'legalOwnership': 'Joint venture',
#            'lineageComplete': 'False',
#            'personalData': 'No',
#            'securityClassification': 'Internal',
#            'sensitivityFlag': 'No',
#            'sourceSystem': 'WellDB NO',
#            'soxCriticalData': 'No'},
#   'type': 'work-product-component--WellLog',
#   'version': 1679474560999647}]

# %% [markdown]
# ### Wildcards

# %%
# Wildcard *, ?
payload = {
    "kind": "osdu:wks:master-data--Field:*", 
    "query": "data.FieldName:S?FIR*", # the wildcard does not seem to work when spaces and special characters are included such as /, #, %...
    "limit": 1,
}

response = osdu_search.get_payload(payload=payload, cursor=True, max_iterations=10)
pprint(response)
# Out:
# INFO:root:Start search ...
# INFO:root:Time elapsed: 0.01309204896291097 minutes, Number of records: , 1
# INFO:root:Search finished...
# [{'acl': {'owners': ['data.osdudevops.owners@npequinor-dev.dataservices.energy',
#                      'data.masterdata.owners@npequinor-dev.dataservices.energy'],
#           'viewers': ['data.default.viewers@npequinor-dev.dataservices.energy']},
#   'ancestry': {'parents': ['npequinor-dev:fields:13051661-86f3-44f0-b168-a305291a69de:1692100054780514']},
#   'authority': 'osdu',
#   'createTime': '2023-06-20T04:29:07.353Z',
#   'createUser': '4cdd9a47-c1a2-4211-80ec-4b0af906e453',
#   'data': {'ExistenceKind': None,
#            'FieldDescription': None,
#            'FieldID': '13051661-86f3-44f0-b168-a305291a69de',
#            'FieldName': 'SAFIR/SAFIR NORTH',
#            'ResourceCurationStatus': None,
#            'ResourceHomeRegionID': None,
#            'ResourceLifecycleStatus': None,
#            'ResourceSecurityClassification': None,
#            'Source': 'IHS',
#            'SpatialLocation.CoordinateQualityCheckPerformedBy': None,
#            'SpatialLocation.QualitativeSpatialAccuracyTypeID': None,
#            'SpatialLocation.QuantitativeAccuracyBandID': None,
#            'SpatialLocation.SpatialGeometryTypeID': None,
#            'SpatialLocation.SpatialParameterTypeID': None,
#            'SpatialLocation.Wgs84Coordinates': {'geometries': [{'coordinates': [[[[26.8840245,
#                                                                                    30.59479],
#                                                                                   [26.8984175,
#                                                                                    30.59568],
#                                                                                   [26.90366525,
#                                                                                    30.59359325],
#                                                                                   [26.89976775,
#                                                                                    30.58852975],
#                                                                                   [26.89513525,
#                                                                                    30.5857615],
#                                                                                   [26.88976775,
#                                                                                    30.5852885],
#                                                                                   [26.88452,
#                                                                                    30.58737525],
#                                                                                   [26.879392,
#                                                                                    30.59202175],
#                                                                                   [26.8840245,
#                                                                                    30.59479]]]],
#                                                                 'type': 'multipolygon'}],
#                                                 'type': 'geometrycollection'},
#            'TechnicalAssuranceID': None,
#            'TechnicalAssuranceTypeID': None,
#            'VersionCreationReason': None,
#            'VirtualProperties.DefaultLocation.CoordinateQualityCheckPerformedBy': None,
#            'VirtualProperties.DefaultLocation.QualitativeSpatialAccuracyTypeID': None,
#            'VirtualProperties.DefaultLocation.QuantitativeAccuracyBandID': None,
#            'VirtualProperties.DefaultLocation.SpatialGeometryTypeID': None,
#            'VirtualProperties.DefaultLocation.SpatialParameterTypeID': None,
#            'VirtualProperties.DefaultLocation.Wgs84Coordinates': {'geometries': [{'coordinates': [[[[26.8840245,
#                                                                                                      30.59479],
#                                                                                                     [26.8984175,
#                                                                                                      30.59568],
#                                                                                                     [26.90366525,
#                                                                                                      30.59359325],
#                                                                                                     [26.89976775,
#                                                                                                      30.58852975],
#                                                                                                     [26.89513525,
#                                                                                                      30.5857615],
#                                                                                                     [26.88976775,
#                                                                                                      30.5852885],
#                                                                                                     [26.88452,
#                                                                                                      30.58737525],
#                                                                                                     [26.879392,
#                                                                                                      30.59202175],
#                                                                                                     [26.8840245,
#                                                                                                      30.59479]]]],
#                                                                                   'type': 'multipolygon'}],
#                                                                   'type': 'geometrycollection'},
#            'VirtualProperties.DefaultName': 'SAFIR/SAFIR NORTH'},
#   'id': 'npequinor-dev:master-data--Field:feba5c0a-0f22-11ee-999c-2617b5073fb4',
#   'kind': 'osdu:wks:master-data--Field:1.0.0',
#   'legal': {'legaltags': ['npequinor-dev-equinor-private-default'],
#             'otherRelevantDataCountries': ['NO'],
#             'status': 'compliant'},
#   'modifyTime': '2023-08-15T13:33:04.433Z',
#   'modifyUser': '4cdd9a47-c1a2-4211-80ec-4b0af906e453',
#   'namespace': 'osdu:wks',
#   'source': 'wks',
#   'tags': {'EqnrSource': 'SMDA API',
#            'businessCriticalData': 'Not assessed yet',
#            'commitId': '109458dee75e49040de153558ca9e4a46fe14353',
#            'countryOfOrigin': 'NO',
#            'dataID': '552 556 560 525 548',
#            'exportControl': 'No',
#            'inside': 'No',
#            'intellectualPropertyRight': 'Not assessed yet',
#            'legalOwnership': 'Equinor solely',
#            'personalData': 'Yes, limited personal data',
#            'securityClassification': 'Internal',
#            'sensitivityFlag': 'null',
#            'sourceSystem': 'SMDA',
#            'soxCriticalData': 'No'},
#   'type': 'master-data--Field',
#   'version': 1692106384202265}]

# %% [markdown]
# ### Query by date format

# %%
# Date Format
queries = ["createTime:(2023-04-25)", "createTime:(NOT 2023-04-25)", "createTime:(>2023-03-30)"]
for query in queries:
    payload = {
        "kind": "osdu:wks:work-product-component--WellLog:*",
        "query": query, 
        "limit": 10,
        "returnedFields": ["createTime"]
    }

    response = osdu_search.get_payload(payload=payload, cursor=True, max_iterations=10)
    pprint(response)
# Out:
# INFO:root:Start search ...
# INFO:root:Time elapsed: 0.013957198460896809 minutes, Number of records: , 10
# INFO:root:Search finished...
# INFO:root:Start search ...
# [{'createTime': '2023-04-25T12:27:43.051Z'},
#  {'createTime': '2023-04-25T12:27:43.457Z'},
#  {'createTime': '2023-04-25T12:27:43.454Z'},
#  {'createTime': '2023-04-25T12:27:43.933Z'},
#  {'createTime': '2023-04-25T12:27:44.085Z'},
#  {'createTime': '2023-04-25T12:27:44.312Z'},
#  {'createTime': '2023-04-25T12:27:44.505Z'},
#  {'createTime': '2023-04-25T12:27:44.550Z'},
#  {'createTime': '2023-04-25T12:27:44.729Z'},
#  {'createTime': '2023-04-25T12:27:44.936Z'}]
# INFO:root:Time elapsed: 0.01151663064956665 minutes, Number of records: , 10
# INFO:root:Search finished...
# INFO:root:Start search ...
# [{'createTime': '2023-05-30T12:46:09.553Z'},
#  {'createTime': '2023-03-09T21:50:59.255Z'},
#  {'createTime': '2023-03-09T21:51:12.354Z'},
#  {'createTime': '2023-03-09T21:51:16.805Z'},
#  {'createTime': '2023-03-09T21:51:17.390Z'},
#  {'createTime': '2023-03-09T21:50:49.804Z'},
#  {'createTime': '2023-03-09T21:50:44.388Z'},
#  {'createTime': '2023-03-09T21:51:14.178Z'},
#  {'createTime': '2023-03-09T21:50:44.781Z'},
#  {'createTime': '2023-03-09T21:51:02.126Z'}]
# INFO:root:Time elapsed: 0.01122738520304362 minutes, Number of records: , 10
# INFO:root:Search finished...
# [{'createTime': '2023-04-25T12:27:43.051Z'},
#  {'createTime': '2023-05-30T12:46:09.553Z'},
#  {'createTime': '2023-04-25T12:27:43.457Z'},
#  {'createTime': '2023-04-25T12:27:43.454Z'},
#  {'createTime': '2023-04-25T12:27:43.933Z'},
#  {'createTime': '2023-04-25T12:27:44.085Z'},
#  {'createTime': '2023-04-25T12:27:44.312Z'},
#  {'createTime': '2023-04-25T12:27:44.505Z'},
#  {'createTime': '2023-04-25T12:27:44.550Z'},
#  {'createTime': '2023-04-25T12:27:44.729Z'}]

# %% [markdown]
# ### Query by date format with condition

# %%
queries = ["createTime:(>2023-01-01 NOT 2023-03-09)", "createTime:(>2023-01-01 AND 2023-03-09)", "createTime:(2023-04-25 OR 2023-03-09)"]
for query in queries:
    payload = {
        "kind": "osdu:wks:work-product-component--WellLog:*",  
        "query": query,
        "limit": 10,
        "returnedFields": ["createTime"]
    }

    response = osdu_search.get_payload(payload=payload, cursor=True, max_iterations=10)
    pprint(response)
# Out:
# INFO:root:Start search ...
# INFO:root:Time elapsed: 0.011034464836120606 minutes, Number of records: , 10
# INFO:root:Search finished...
# INFO:root:Start search ...
# [{'createTime': '2023-04-25T12:27:43.051Z'},
#  {'createTime': '2023-05-30T12:46:09.553Z'},
#  {'createTime': '2023-04-25T12:27:43.457Z'},
#  {'createTime': '2023-04-25T12:27:43.454Z'},
#  {'createTime': '2023-04-25T12:27:43.933Z'},
#  {'createTime': '2023-04-25T12:27:44.085Z'},
#  {'createTime': '2023-04-25T12:27:44.312Z'},
#  {'createTime': '2023-04-25T12:27:44.505Z'},
#  {'createTime': '2023-04-25T12:27:44.550Z'},
#  {'createTime': '2023-04-25T12:27:44.729Z'}]
# INFO:root:Time elapsed: 0.010924132664998372 minutes, Number of records: , 10
# INFO:root:Search finished...
# INFO:root:Start search ...
# [{'createTime': '2023-03-09T21:50:59.255Z'},
#  {'createTime': '2023-03-09T21:51:12.354Z'},
#  {'createTime': '2023-03-09T21:51:16.805Z'},
#  {'createTime': '2023-03-09T21:51:17.390Z'},
#  {'createTime': '2023-03-09T21:50:49.804Z'},
#  {'createTime': '2023-03-09T21:50:44.388Z'},
#  {'createTime': '2023-03-09T21:51:14.178Z'},
#  {'createTime': '2023-03-09T21:50:44.781Z'},
#  {'createTime': '2023-03-09T21:51:02.126Z'},
#  {'createTime': '2023-03-09T21:50:45.437Z'}]
# INFO:root:Time elapsed: 0.010137546062469482 minutes, Number of records: , 10
# INFO:root:Search finished...
# [{'createTime': '2023-04-25T12:27:43.051Z'},
#  {'createTime': '2023-03-09T21:50:59.255Z'},
#  {'createTime': '2023-04-25T12:27:43.457Z'},
#  {'createTime': '2023-04-25T12:27:43.454Z'},
#  {'createTime': '2023-03-09T21:51:12.354Z'},
#  {'createTime': '2023-04-25T12:27:43.933Z'},
#  {'createTime': '2023-04-25T12:27:44.085Z'},
#  {'createTime': '2023-04-25T12:27:44.312Z'},
#  {'createTime': '2023-04-25T12:27:44.505Z'},
#  {'createTime': '2023-04-25T12:27:44.550Z'}]

# %% [markdown]
# ### Query by nested condition

# %%
# Query by nested condition
payload = {
    "kind": "osdu:wks:master-data--Wellbore:*",
    "query": "nested(data.NameAliases, (AliasName:443)) OR nested(data.NameAliases, (AliasName:\"24/6-1\"))",
    "limit": 10,
    "returnedFields": ["data.NameAliases"]
}

response = osdu_search.get_payload(payload=payload, cursor=True, max_iterations=10)
pprint(response)
# Out:
# INFO:root:Start search ...
# INFO:root:Time elapsed: 0.01060325304667155 minutes, Number of records: , 20
# INFO:root:Search finished...
# [{'data': {'NameAliases': [{'AliasName': 'NO 24-6-1',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': 'NO 24-6-1',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '1',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '443',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '24/6-1',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '100000072383',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '024/06-01',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '443',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '24/6-1',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': 'p7J4e3hIpy',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '24/6-1',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None}]}},
#  {'data': {'NameAliases': [{'AliasName': 'YPF.Ch.B.xp-443',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '443',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '108560.0',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None}]}},
#  {'data': {'NameAliases': [{'AliasName': 'Moloacan-443',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '1B10EB3186C445B196CC54D1DF525127',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': 'MX 205802080000',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '1271112',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '205802080000',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None}]}},
#  {'data': {'NameAliases': [{'AliasName': 'DSDP 0443',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': 'DSDP 58-443',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '443',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '100000215005',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': 'JP DSDP 58-443',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None}]}},
#  {'data': {'NameAliases': [{'AliasName': '7-CP-443-SE',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '7CP  0443  SE',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '100000259993',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '443-SE',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '7CP  0443  SE',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '7-CP-0443-SE',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '901200135700',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': 'BR 7CP  0443  SE',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None}]}},
#  {'data': {'NameAliases': [{'AliasName': 'BR 7CAM 0443  RN',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '7-CAM-443-RN',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '7CAM 0443  RN',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '7-CAM-0443-RN',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '100000262155',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '721000363600',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '443-RN',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '7CAM 0443  RN',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None}]}},
#  {'data': {'NameAliases': [{'AliasName': '7ET  0443  RN',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '7-ET-0443-RN',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '443-RN',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '721000416000',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '100000258569',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '7ET  0443  RN',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '7-ET-443-RN',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': 'BR 7ET  0443  RN',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None}]}},
#  {'data': {'NameAliases': [{'AliasName': 'BR 9MG  0443  BA',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '9-MG-443-BA',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '202400542300',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '443-BA',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '100000270765',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '9MG  0443  BA',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '9MG  0443  BA',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None}]}},
#  {'data': {'NameAliases': [{'AliasName': '3583',
#                             'AliasNameTypeID': 'npequinor-dev:reference-data--AliasNameType:UWI:',
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': 'SCH-443',
#                             'AliasNameTypeID': 'npequinor-dev:reference-data--AliasNameType:BoreholeCode:',
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': 'SCHOONEBEEK-443',
#                             'AliasNameTypeID': 'npequinor-dev:reference-data--AliasNameType:Borehole:',
#                             'DefinitionOrganisationID': None}]}},
#  {'data': {'NameAliases': [{'AliasName': '202400161800',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '7DJ  0443  BA',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '443-BA',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '7-DJ-443-BA',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '100000259035',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '7-DJ-443-BA',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '7DJ  0443  BA',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': 'BR 7DJ  0443  BA',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None}]}},
#  {'data': {'NameAliases': [{'AliasName': '7FZB 0443  CE',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': 'BR 7FZB 0443  CE',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '7-FZB-443-CE',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '301000292400',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '100000262047',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '7-FZB-443-CE',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '443-CE',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '7FZB 0443  CE',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None}]}},
#  {'data': {'NameAliases': [{'AliasName': '7ARG 0443  RN',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '7-ARG-443-RN',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '721000470600',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '100000193165',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '7ARG 0443  RN',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '443-RN',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '7-ARG-443-RN',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': 'BR 7ARG 0443  RN',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None}]}},
#  {'data': {'NameAliases': [{'AliasName': '7-SZ-443-SE',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '7SZ443SE',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '100000542741',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '443-SE',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '90120021389',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '7-SZ-443-SE',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '7-SZ-443-SE',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None}]}},
#  {'data': {'NameAliases': [{'AliasName': 'BR 3-BRSA-443-RJS',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '3-BRSA-443-RJS',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '3CG6RJS',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '3-BRSA-443-RJS',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '100000577878',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '443-RJS',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '3-CG-006-RJS',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '74281021966',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None}]}},
#  {'data': {'NameAliases': [{'AliasName': '3-RJS-443-RJ',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': 'BR 3-RJS-443-RJ',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': 'BR 3RJS 0443  RJ',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': 'BR 3-RJS-443',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '742810203300',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '443-RJ',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '3RJS 0443  RJ',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '3-RJS-443-RJS',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '100000167557',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '3RJS 0443  RJ',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None}]}},
#  {'data': {'NameAliases': [{'AliasName': '5450',
#                             'AliasNameTypeID': 'npequinor-dev:reference-data--AliasNameType:UWI:',
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': 'TWR-443',
#                             'AliasNameTypeID': 'npequinor-dev:reference-data--AliasNameType:BoreholeCode:',
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': 'TWENTE-RIJN-443',
#                             'AliasNameTypeID': 'npequinor-dev:reference-data--AliasNameType:Borehole:',
#                             'DefinitionOrganisationID': None}]}},
#  {'data': {'NameAliases': [{'AliasName': 'US 424433054500',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '042-028676',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '42-443-30545-0000',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': 'CREEK RANCH 10-2',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None}]}},
#  {'data': {'NameAliases': [{'AliasName': '42-443-30317-0000',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': 'Noelke 1',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': 'US 424433031700',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '042-028505',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None}]}},
#  {'data': {'NameAliases': [{'AliasName': '042-028686',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '42-443-30457-0000',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': 'ANNA MCCLUNG 1-1',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': 'US 424433045700',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None}]}},
#  {'data': {'NameAliases': [{'AliasName': 'US 424433031000',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '42-443-30310-0000',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '042-028690',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': 'MC KAY CREEK B-2',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None}]}}]

# %% [markdown]
# ### Query by non-nested and a nested with condition

# %%
# Query by non-nested and nested condition
payload = {
    "kind": "osdu:wks:master-data--Wellbore:*",
    "query": "data.FacilityName:\"NO 24/12-1 R\" AND nested(data.NameAliases, (AliasName:513)) "
}

response = osdu_search.get_payload(payload=payload, cursor=True, max_iterations=10)
pprint(response)
# Out:
# INFO:root:Start search ...
# INFO:root:Time elapsed: 0.13371104796727498 minutes, Number of records: , 6
# INFO:root:Search finished...
# [{'acl': {'owners': ['data.osdudevops.owners@npequinor-dev.dataservices.energy',
#                      'data.masterdata.owners@npequinor-dev.dataservices.energy'],
#           'viewers': ['data.default.viewers@npequinor-dev.dataservices.energy']},
#   'ancestry': {'parents': ['npequinor-dev:wellheaders:ad215042-009b-2b7e-e053-c818a488c79a:1692243353979248']},
#   'authority': 'osdu',
#   'createTime': '2022-11-30T10:13:08.041Z',
#   'createUser': '4cdd9a47-c1a2-4211-80ec-4b0af906e453',
#   'data': {'BusinessIntentionID': 'npequinor-dev:reference-data--WellBusinessIntention:Explore',
#            'ConditionID': None,
#            'CurrentOperatorID': None,
#            'DataSourceOrganisationID': None,
#            'DefaultVerticalMeasurementID': 'Zero_Depth_Reference_Point',
#            'DefinitiveTrajectoryID': None,
#            'ExistenceKind': None,
#            'FacilityID': 'ad215042-009b-2b7e-e053-c818a488c79a',
#            'FacilityName': 'NO 24/12-1 R',
#            'FacilityTypeID': 'npequinor-dev:reference-data--FacilityType:Wellbore:',
#            'FluidDirectionID': None,
#            'GeographicBottomHoleLocation.CoordinateQualityCheckPerformedBy': None,
#            'GeographicBottomHoleLocation.QualitativeSpatialAccuracyTypeID': None,
#            'GeographicBottomHoleLocation.QuantitativeAccuracyBandID': None,
#            'GeographicBottomHoleLocation.SpatialGeometryTypeID': None,
#            'GeographicBottomHoleLocation.SpatialParameterTypeID': None,
#            'InitialOperatorID': None,
#            'InterestTypeID': None,
#            'KickOffWellbore': None,
#            'NameAliases': [{'AliasName': 'NO 24-12-1R',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '513',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '100000798279',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': 'NO 24-12-1 R',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '1 R',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '24/12-1 R',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '024/12-01R',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '513',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '24/12-1 R',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None}],
#            'OperatingEnvironmentID': None,
#            'OutcomeID': None,
#            'PrimaryMaterialID': None,
#            'PrimaryProductTypeID': None,
#            'ProjectedBottomHoleLocation.CoordinateQualityCheckPerformedBy': None,
#            'ProjectedBottomHoleLocation.QualitativeSpatialAccuracyTypeID': None,
#            'ProjectedBottomHoleLocation.QuantitativeAccuracyBandID': None,
#            'ProjectedBottomHoleLocation.SpatialGeometryTypeID': None,
#            'ProjectedBottomHoleLocation.SpatialParameterTypeID': None,
#            'ResourceCurationStatus': None,
#            'ResourceHomeRegionID': None,
#            'ResourceLifecycleStatus': None,
#            'ResourceSecurityClassification': None,
#            'RoleID': None,
#            'SecondaryProductTypeID': None,
#            'ShowProductTypeID': None,
#            'Source': None,
#            'SpatialLocation.CoordinateQualityCheckPerformedBy': None,
#            'SpatialLocation.QualitativeSpatialAccuracyTypeID': None,
#            'SpatialLocation.QuantitativeAccuracyBandID': None,
#            'SpatialLocation.SpatialGeometryTypeID': None,
#            'SpatialLocation.SpatialParameterTypeID': None,
#            'StatusSummaryID': None,
#            'TargetFormation': None,
#            'TechnicalAssuranceID': None,
#            'TechnicalAssuranceTypeID': None,
#            'TertiaryProductTypeID': None,
#            'TrajectoryTypeID': None,
#            'VersionCreationReason': None,
#            'VerticalMeasurements': [{'RigID': None,
#                                      'VerticalCRSID': 'npequinor-dev:reference-data--CoordinateReferenceSystem:Vertical:EPSG::5715:',
#                                      'VerticalMeasurement': 25.0,
#                                      'VerticalMeasurementDescription': None,
#                                      'VerticalMeasurementID': 'Zero_Depth_Reference_Point',
#                                      'VerticalMeasurementPathID': 'npequinor-dev:reference-data--VerticalMeasurementPath:TrueVerticalDepth:',
#                                      'VerticalMeasurementSourceID': None,
#                                      'VerticalMeasurementTypeID': 'npequinor-dev:reference-data--VerticalMeasurementType:KellyBushing:',
#                                      'VerticalMeasurementUnitOfMeasureID': 'npequinor-dev:reference-data--UnitOfMeasure:m:',
#                                      'VerticalReferenceEntityID': None,
#                                      'VerticalReferenceID': None,
#                                      'WellboreTVDTrajectoryID': None}],
#            'VirtualProperties.DefaultLocation.CoordinateQualityCheckPerformedBy': None,
#            'VirtualProperties.DefaultLocation.QualitativeSpatialAccuracyTypeID': None,
#            'VirtualProperties.DefaultLocation.QuantitativeAccuracyBandID': None,
#            'VirtualProperties.DefaultLocation.SpatialGeometryTypeID': None,
#            'VirtualProperties.DefaultLocation.SpatialParameterTypeID': None,
#            'VirtualProperties.DefaultName': 'NO 24/12-1 R',
#            'WasBusinessInterestFinancialNonOperated': None,
#            'WasBusinessInterestFinancialOperated': None,
#            'WasBusinessInterestObligatory': None,
#            'WasBusinessInterestTechnical': None,
#            'WellID': 'npequinor-dev:master-data--Well:df1166aa-6ca7-11ed-9855-367dda495db0',
#            'WellboreTrajectoryTypeID': None},
#   'id': 'npequinor-dev:master-data--Wellbore:95a4a86c-7097-11ed-97ff-367dda495db0',
#   'kind': 'osdu:wks:master-data--Wellbore:1.1.0',
#   'legal': {'legaltags': ['npequinor-dev-equinor-private-default'],
#             'otherRelevantDataCountries': ['NO'],
#             'status': 'compliant'},
#   'modifyTime': '2023-08-19T13:36:49.433Z',
#   'modifyUser': '4cdd9a47-c1a2-4211-80ec-4b0af906e453',
#   'namespace': 'osdu:wks',
#   'source': 'wks',
#   'tags': {'EqnrSource': 'SMDA API',
#            'businessCriticalData': 'Not assessed yet',
#            'commitId': '70ca447faca475b6c00266bbfe43b84f5113f669',
#            'countryOfOrigin': 'NO',
#            'dataID': '552 556 560 525 548',
#            'exportControl': 'No',
#            'inside': 'No',
#            'intellectualPropertyRight': 'Not assessed yet',
#            'legalOwnership': 'Equinor solely',
#            'personalData': 'Yes, limited personal data',
#            'securityClassification': 'Internal',
#            'sensitivityFlag': 'null',
#            'sourceSystem': 'SMDA',
#            'soxCriticalData': 'No'},
#   'type': 'master-data--Wellbore',
#   'version': 1692452208774518},
#  {'acl': {'owners': ['data.osdudevops.owners@npequinor-dev.dataservices.energy',
#                      'data.masterdata.owners@npequinor-dev.dataservices.energy'],
#           'viewers': ['data.default.viewers@npequinor-dev.dataservices.energy']},
#   'ancestry': {'parents': ['npequinor-dev:wellheaders:ad215042-009b-2b7e-e053-c818a488c79a:1692243353979248']},
#   'authority': 'osdu',
#   'createTime': '2022-11-30T10:13:08.041Z',
#   'createUser': '4cdd9a47-c1a2-4211-80ec-4b0af906e453',
#   'data': {'BusinessIntentionID': 'npequinor-dev:reference-data--WellBusinessIntention:Explore',
#            'ConditionID': None,
#            'CurrentOperatorID': None,
#            'DataSourceOrganisationID': None,
#            'DefaultVerticalMeasurementID': 'Zero_Depth_Reference_Point',
#            'DefinitiveTrajectoryID': None,
#            'ExistenceKind': None,
#            'FacilityID': 'ad215042-009b-2b7e-e053-c818a488c79a',
#            'FacilityName': 'NO 24/12-1 R',
#            'FacilityTypeID': 'npequinor-dev:reference-data--FacilityType:Wellbore:',
#            'FluidDirectionID': None,
#            'GeographicBottomHoleLocation.CoordinateQualityCheckPerformedBy': None,
#            'GeographicBottomHoleLocation.QualitativeSpatialAccuracyTypeID': None,
#            'GeographicBottomHoleLocation.QuantitativeAccuracyBandID': None,
#            'GeographicBottomHoleLocation.SpatialGeometryTypeID': None,
#            'GeographicBottomHoleLocation.SpatialParameterTypeID': None,
#            'InitialOperatorID': None,
#            'InterestTypeID': None,
#            'KickOffWellbore': None,
#            'NameAliases': [{'AliasName': 'NO 24-12-1R',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '513',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '100000798279',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': 'NO 24-12-1 R',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '1 R',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '24/12-1 R',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '024/12-01R',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '513',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '24/12-1 R',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None}],
#            'OperatingEnvironmentID': None,
#            'OutcomeID': None,
#            'PrimaryMaterialID': None,
#            'PrimaryProductTypeID': None,
#            'ProjectedBottomHoleLocation.CoordinateQualityCheckPerformedBy': None,
#            'ProjectedBottomHoleLocation.QualitativeSpatialAccuracyTypeID': None,
#            'ProjectedBottomHoleLocation.QuantitativeAccuracyBandID': None,
#            'ProjectedBottomHoleLocation.SpatialGeometryTypeID': None,
#            'ProjectedBottomHoleLocation.SpatialParameterTypeID': None,
#            'ResourceCurationStatus': None,
#            'ResourceHomeRegionID': None,
#            'ResourceLifecycleStatus': None,
#            'ResourceSecurityClassification': None,
#            'RoleID': None,
#            'SecondaryProductTypeID': None,
#            'ShowProductTypeID': None,
#            'Source': None,
#            'SpatialLocation.CoordinateQualityCheckPerformedBy': None,
#            'SpatialLocation.QualitativeSpatialAccuracyTypeID': None,
#            'SpatialLocation.QuantitativeAccuracyBandID': None,
#            'SpatialLocation.SpatialGeometryTypeID': None,
#            'SpatialLocation.SpatialParameterTypeID': None,
#            'StatusSummaryID': None,
#            'TargetFormation': None,
#            'TechnicalAssuranceID': None,
#            'TechnicalAssuranceTypeID': None,
#            'TertiaryProductTypeID': None,
#            'TrajectoryTypeID': None,
#            'VersionCreationReason': None,
#            'VerticalMeasurements': [{'RigID': None,
#                                      'VerticalCRSID': 'npequinor-dev:reference-data--CoordinateReferenceSystem:Vertical:EPSG::5715:',
#                                      'VerticalMeasurement': 25.0,
#                                      'VerticalMeasurementDescription': None,
#                                      'VerticalMeasurementID': 'Zero_Depth_Reference_Point',
#                                      'VerticalMeasurementPathID': 'npequinor-dev:reference-data--VerticalMeasurementPath:TrueVerticalDepth:',
#                                      'VerticalMeasurementSourceID': None,
#                                      'VerticalMeasurementTypeID': 'npequinor-dev:reference-data--VerticalMeasurementType:KellyBushing:',
#                                      'VerticalMeasurementUnitOfMeasureID': 'npequinor-dev:reference-data--UnitOfMeasure:m:',
#                                      'VerticalReferenceEntityID': None,
#                                      'VerticalReferenceID': None,
#                                      'WellboreTVDTrajectoryID': None}],
#            'VirtualProperties.DefaultLocation.CoordinateQualityCheckPerformedBy': None,
#            'VirtualProperties.DefaultLocation.QualitativeSpatialAccuracyTypeID': None,
#            'VirtualProperties.DefaultLocation.QuantitativeAccuracyBandID': None,
#            'VirtualProperties.DefaultLocation.SpatialGeometryTypeID': None,
#            'VirtualProperties.DefaultLocation.SpatialParameterTypeID': None,
#            'VirtualProperties.DefaultName': 'NO 24/12-1 R',
#            'WasBusinessInterestFinancialNonOperated': None,
#            'WasBusinessInterestFinancialOperated': None,
#            'WasBusinessInterestObligatory': None,
#            'WasBusinessInterestTechnical': None,
#            'WellID': 'npequinor-dev:master-data--Well:df1166aa-6ca7-11ed-9855-367dda495db0',
#            'WellboreTrajectoryTypeID': None},
#   'id': 'npequinor-dev:master-data--Wellbore:95a4a86c-7097-11ed-97ff-367dda495db0',
#   'kind': 'osdu:wks:master-data--Wellbore:1.1.0',
#   'legal': {'legaltags': ['npequinor-dev-equinor-private-default'],
#             'otherRelevantDataCountries': ['NO'],
#             'status': 'compliant'},
#   'modifyTime': '2023-08-19T13:36:49.433Z',
#   'modifyUser': '4cdd9a47-c1a2-4211-80ec-4b0af906e453',
#   'namespace': 'osdu:wks',
#   'source': 'wks',
#   'tags': {'EqnrSource': 'SMDA API',
#            'businessCriticalData': 'Not assessed yet',
#            'commitId': '70ca447faca475b6c00266bbfe43b84f5113f669',
#            'countryOfOrigin': 'NO',
#            'dataID': '552 556 560 525 548',
#            'exportControl': 'No',
#            'inside': 'No',
#            'intellectualPropertyRight': 'Not assessed yet',
#            'legalOwnership': 'Equinor solely',
#            'personalData': 'Yes, limited personal data',
#            'securityClassification': 'Internal',
#            'sensitivityFlag': 'null',
#            'sourceSystem': 'SMDA',
#            'soxCriticalData': 'No'},
#   'type': 'master-data--Wellbore',
#   'version': 1692452208774518},
#  {'acl': {'owners': ['data.osdudevops.owners@npequinor-dev.dataservices.energy',
#                      'data.masterdata.owners@npequinor-dev.dataservices.energy'],
#           'viewers': ['data.default.viewers@npequinor-dev.dataservices.energy']},
#   'ancestry': {'parents': ['npequinor-dev:wellheaders:ad215042-009b-2b7e-e053-c818a488c79a:1692243353979248']},
#   'authority': 'osdu',
#   'createTime': '2022-11-30T10:13:08.041Z',
#   'createUser': '4cdd9a47-c1a2-4211-80ec-4b0af906e453',
#   'data': {'BusinessIntentionID': 'npequinor-dev:reference-data--WellBusinessIntention:Explore',
#            'ConditionID': None,
#            'CurrentOperatorID': None,
#            'DataSourceOrganisationID': None,
#            'DefaultVerticalMeasurementID': 'Zero_Depth_Reference_Point',
#            'DefinitiveTrajectoryID': None,
#            'ExistenceKind': None,
#            'FacilityID': 'ad215042-009b-2b7e-e053-c818a488c79a',
#            'FacilityName': 'NO 24/12-1 R',
#            'FacilityTypeID': 'npequinor-dev:reference-data--FacilityType:Wellbore:',
#            'FluidDirectionID': None,
#            'GeographicBottomHoleLocation.CoordinateQualityCheckPerformedBy': None,
#            'GeographicBottomHoleLocation.QualitativeSpatialAccuracyTypeID': None,
#            'GeographicBottomHoleLocation.QuantitativeAccuracyBandID': None,
#            'GeographicBottomHoleLocation.SpatialGeometryTypeID': None,
#            'GeographicBottomHoleLocation.SpatialParameterTypeID': None,
#            'InitialOperatorID': None,
#            'InterestTypeID': None,
#            'KickOffWellbore': None,
#            'NameAliases': [{'AliasName': 'NO 24-12-1R',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '513',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '100000798279',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': 'NO 24-12-1 R',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '1 R',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '24/12-1 R',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '024/12-01R',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '513',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '24/12-1 R',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None}],
#            'OperatingEnvironmentID': None,
#            'OutcomeID': None,
#            'PrimaryMaterialID': None,
#            'PrimaryProductTypeID': None,
#            'ProjectedBottomHoleLocation.CoordinateQualityCheckPerformedBy': None,
#            'ProjectedBottomHoleLocation.QualitativeSpatialAccuracyTypeID': None,
#            'ProjectedBottomHoleLocation.QuantitativeAccuracyBandID': None,
#            'ProjectedBottomHoleLocation.SpatialGeometryTypeID': None,
#            'ProjectedBottomHoleLocation.SpatialParameterTypeID': None,
#            'ResourceCurationStatus': None,
#            'ResourceHomeRegionID': None,
#            'ResourceLifecycleStatus': None,
#            'ResourceSecurityClassification': None,
#            'RoleID': None,
#            'SecondaryProductTypeID': None,
#            'ShowProductTypeID': None,
#            'Source': None,
#            'SpatialLocation.CoordinateQualityCheckPerformedBy': None,
#            'SpatialLocation.QualitativeSpatialAccuracyTypeID': None,
#            'SpatialLocation.QuantitativeAccuracyBandID': None,
#            'SpatialLocation.SpatialGeometryTypeID': None,
#            'SpatialLocation.SpatialParameterTypeID': None,
#            'StatusSummaryID': None,
#            'TargetFormation': None,
#            'TechnicalAssuranceID': None,
#            'TechnicalAssuranceTypeID': None,
#            'TertiaryProductTypeID': None,
#            'TrajectoryTypeID': None,
#            'VersionCreationReason': None,
#            'VerticalMeasurements': [{'RigID': None,
#                                      'VerticalCRSID': 'npequinor-dev:reference-data--CoordinateReferenceSystem:Vertical:EPSG::5715:',
#                                      'VerticalMeasurement': 25.0,
#                                      'VerticalMeasurementDescription': None,
#                                      'VerticalMeasurementID': 'Zero_Depth_Reference_Point',
#                                      'VerticalMeasurementPathID': 'npequinor-dev:reference-data--VerticalMeasurementPath:TrueVerticalDepth:',
#                                      'VerticalMeasurementSourceID': None,
#                                      'VerticalMeasurementTypeID': 'npequinor-dev:reference-data--VerticalMeasurementType:KellyBushing:',
#                                      'VerticalMeasurementUnitOfMeasureID': 'npequinor-dev:reference-data--UnitOfMeasure:m:',
#                                      'VerticalReferenceEntityID': None,
#                                      'VerticalReferenceID': None,
#                                      'WellboreTVDTrajectoryID': None}],
#            'VirtualProperties.DefaultLocation.CoordinateQualityCheckPerformedBy': None,
#            'VirtualProperties.DefaultLocation.QualitativeSpatialAccuracyTypeID': None,
#            'VirtualProperties.DefaultLocation.QuantitativeAccuracyBandID': None,
#            'VirtualProperties.DefaultLocation.SpatialGeometryTypeID': None,
#            'VirtualProperties.DefaultLocation.SpatialParameterTypeID': None,
#            'VirtualProperties.DefaultName': 'NO 24/12-1 R',
#            'WasBusinessInterestFinancialNonOperated': None,
#            'WasBusinessInterestFinancialOperated': None,
#            'WasBusinessInterestObligatory': None,
#            'WasBusinessInterestTechnical': None,
#            'WellID': 'npequinor-dev:master-data--Well:df1166aa-6ca7-11ed-9855-367dda495db0',
#            'WellboreTrajectoryTypeID': None},
#   'id': 'npequinor-dev:master-data--Wellbore:95a4a86c-7097-11ed-97ff-367dda495db0',
#   'kind': 'osdu:wks:master-data--Wellbore:1.1.0',
#   'legal': {'legaltags': ['npequinor-dev-equinor-private-default'],
#             'otherRelevantDataCountries': ['NO'],
#             'status': 'compliant'},
#   'modifyTime': '2023-08-19T13:36:49.433Z',
#   'modifyUser': '4cdd9a47-c1a2-4211-80ec-4b0af906e453',
#   'namespace': 'osdu:wks',
#   'source': 'wks',
#   'tags': {'EqnrSource': 'SMDA API',
#            'businessCriticalData': 'Not assessed yet',
#            'commitId': '70ca447faca475b6c00266bbfe43b84f5113f669',
#            'countryOfOrigin': 'NO',
#            'dataID': '552 556 560 525 548',
#            'exportControl': 'No',
#            'inside': 'No',
#            'intellectualPropertyRight': 'Not assessed yet',
#            'legalOwnership': 'Equinor solely',
#            'personalData': 'Yes, limited personal data',
#            'securityClassification': 'Internal',
#            'sensitivityFlag': 'null',
#            'sourceSystem': 'SMDA',
#            'soxCriticalData': 'No'},
#   'type': 'master-data--Wellbore',
#   'version': 1692452208774518},
#  {'acl': {'owners': ['data.osdudevops.owners@npequinor-dev.dataservices.energy',
#                      'data.masterdata.owners@npequinor-dev.dataservices.energy'],
#           'viewers': ['data.default.viewers@npequinor-dev.dataservices.energy']},
#   'ancestry': {'parents': ['npequinor-dev:wellheaders:ad215042-009b-2b7e-e053-c818a488c79a:1692243353979248']},
#   'authority': 'osdu',
#   'createTime': '2022-11-30T10:13:08.041Z',
#   'createUser': '4cdd9a47-c1a2-4211-80ec-4b0af906e453',
#   'data': {'BusinessIntentionID': 'npequinor-dev:reference-data--WellBusinessIntention:Explore',
#            'ConditionID': None,
#            'CurrentOperatorID': None,
#            'DataSourceOrganisationID': None,
#            'DefaultVerticalMeasurementID': 'Zero_Depth_Reference_Point',
#            'DefinitiveTrajectoryID': None,
#            'ExistenceKind': None,
#            'FacilityID': 'ad215042-009b-2b7e-e053-c818a488c79a',
#            'FacilityName': 'NO 24/12-1 R',
#            'FacilityTypeID': 'npequinor-dev:reference-data--FacilityType:Wellbore:',
#            'FluidDirectionID': None,
#            'GeographicBottomHoleLocation.CoordinateQualityCheckPerformedBy': None,
#            'GeographicBottomHoleLocation.QualitativeSpatialAccuracyTypeID': None,
#            'GeographicBottomHoleLocation.QuantitativeAccuracyBandID': None,
#            'GeographicBottomHoleLocation.SpatialGeometryTypeID': None,
#            'GeographicBottomHoleLocation.SpatialParameterTypeID': None,
#            'InitialOperatorID': None,
#            'InterestTypeID': None,
#            'KickOffWellbore': None,
#            'NameAliases': [{'AliasName': 'NO 24-12-1R',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '513',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '100000798279',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': 'NO 24-12-1 R',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '1 R',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '24/12-1 R',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '024/12-01R',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '513',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '24/12-1 R',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None}],
#            'OperatingEnvironmentID': None,
#            'OutcomeID': None,
#            'PrimaryMaterialID': None,
#            'PrimaryProductTypeID': None,
#            'ProjectedBottomHoleLocation.CoordinateQualityCheckPerformedBy': None,
#            'ProjectedBottomHoleLocation.QualitativeSpatialAccuracyTypeID': None,
#            'ProjectedBottomHoleLocation.QuantitativeAccuracyBandID': None,
#            'ProjectedBottomHoleLocation.SpatialGeometryTypeID': None,
#            'ProjectedBottomHoleLocation.SpatialParameterTypeID': None,
#            'ResourceCurationStatus': None,
#            'ResourceHomeRegionID': None,
#            'ResourceLifecycleStatus': None,
#            'ResourceSecurityClassification': None,
#            'RoleID': None,
#            'SecondaryProductTypeID': None,
#            'ShowProductTypeID': None,
#            'Source': None,
#            'SpatialLocation.CoordinateQualityCheckPerformedBy': None,
#            'SpatialLocation.QualitativeSpatialAccuracyTypeID': None,
#            'SpatialLocation.QuantitativeAccuracyBandID': None,
#            'SpatialLocation.SpatialGeometryTypeID': None,
#            'SpatialLocation.SpatialParameterTypeID': None,
#            'StatusSummaryID': None,
#            'TargetFormation': None,
#            'TechnicalAssuranceID': None,
#            'TechnicalAssuranceTypeID': None,
#            'TertiaryProductTypeID': None,
#            'TrajectoryTypeID': None,
#            'VersionCreationReason': None,
#            'VerticalMeasurements': [{'RigID': None,
#                                      'VerticalCRSID': 'npequinor-dev:reference-data--CoordinateReferenceSystem:Vertical:EPSG::5715:',
#                                      'VerticalMeasurement': 25.0,
#                                      'VerticalMeasurementDescription': None,
#                                      'VerticalMeasurementID': 'Zero_Depth_Reference_Point',
#                                      'VerticalMeasurementPathID': 'npequinor-dev:reference-data--VerticalMeasurementPath:TrueVerticalDepth:',
#                                      'VerticalMeasurementSourceID': None,
#                                      'VerticalMeasurementTypeID': 'npequinor-dev:reference-data--VerticalMeasurementType:KellyBushing:',
#                                      'VerticalMeasurementUnitOfMeasureID': 'npequinor-dev:reference-data--UnitOfMeasure:m:',
#                                      'VerticalReferenceEntityID': None,
#                                      'VerticalReferenceID': None,
#                                      'WellboreTVDTrajectoryID': None}],
#            'VirtualProperties.DefaultLocation.CoordinateQualityCheckPerformedBy': None,
#            'VirtualProperties.DefaultLocation.QualitativeSpatialAccuracyTypeID': None,
#            'VirtualProperties.DefaultLocation.QuantitativeAccuracyBandID': None,
#            'VirtualProperties.DefaultLocation.SpatialGeometryTypeID': None,
#            'VirtualProperties.DefaultLocation.SpatialParameterTypeID': None,
#            'VirtualProperties.DefaultName': 'NO 24/12-1 R',
#            'WasBusinessInterestFinancialNonOperated': None,
#            'WasBusinessInterestFinancialOperated': None,
#            'WasBusinessInterestObligatory': None,
#            'WasBusinessInterestTechnical': None,
#            'WellID': 'npequinor-dev:master-data--Well:df1166aa-6ca7-11ed-9855-367dda495db0',
#            'WellboreTrajectoryTypeID': None},
#   'id': 'npequinor-dev:master-data--Wellbore:95a4a86c-7097-11ed-97ff-367dda495db0',
#   'kind': 'osdu:wks:master-data--Wellbore:1.1.0',
#   'legal': {'legaltags': ['npequinor-dev-equinor-private-default'],
#             'otherRelevantDataCountries': ['NO'],
#             'status': 'compliant'},
#   'modifyTime': '2023-08-19T13:36:49.433Z',
#   'modifyUser': '4cdd9a47-c1a2-4211-80ec-4b0af906e453',
#   'namespace': 'osdu:wks',
#   'source': 'wks',
#   'tags': {'EqnrSource': 'SMDA API',
#            'businessCriticalData': 'Not assessed yet',
#            'commitId': '70ca447faca475b6c00266bbfe43b84f5113f669',
#            'countryOfOrigin': 'NO',
#            'dataID': '552 556 560 525 548',
#            'exportControl': 'No',
#            'inside': 'No',
#            'intellectualPropertyRight': 'Not assessed yet',
#            'legalOwnership': 'Equinor solely',
#            'personalData': 'Yes, limited personal data',
#            'securityClassification': 'Internal',
#            'sensitivityFlag': 'null',
#            'sourceSystem': 'SMDA',
#            'soxCriticalData': 'No'},
#   'type': 'master-data--Wellbore',
#   'version': 1692452208774518},
#  {'acl': {'owners': ['data.osdudevops.owners@npequinor-dev.dataservices.energy',
#                      'data.masterdata.owners@npequinor-dev.dataservices.energy'],
#           'viewers': ['data.default.viewers@npequinor-dev.dataservices.energy']},
#   'ancestry': {'parents': ['npequinor-dev:wellheaders:ad215042-009b-2b7e-e053-c818a488c79a:1692243353979248']},
#   'authority': 'osdu',
#   'createTime': '2022-11-30T10:13:08.041Z',
#   'createUser': '4cdd9a47-c1a2-4211-80ec-4b0af906e453',
#   'data': {'BusinessIntentionID': 'npequinor-dev:reference-data--WellBusinessIntention:Explore',
#            'ConditionID': None,
#            'CurrentOperatorID': None,
#            'DataSourceOrganisationID': None,
#            'DefaultVerticalMeasurementID': 'Zero_Depth_Reference_Point',
#            'DefinitiveTrajectoryID': None,
#            'ExistenceKind': None,
#            'FacilityID': 'ad215042-009b-2b7e-e053-c818a488c79a',
#            'FacilityName': 'NO 24/12-1 R',
#            'FacilityTypeID': 'npequinor-dev:reference-data--FacilityType:Wellbore:',
#            'FluidDirectionID': None,
#            'GeographicBottomHoleLocation.CoordinateQualityCheckPerformedBy': None,
#            'GeographicBottomHoleLocation.QualitativeSpatialAccuracyTypeID': None,
#            'GeographicBottomHoleLocation.QuantitativeAccuracyBandID': None,
#            'GeographicBottomHoleLocation.SpatialGeometryTypeID': None,
#            'GeographicBottomHoleLocation.SpatialParameterTypeID': None,
#            'InitialOperatorID': None,
#            'InterestTypeID': None,
#            'KickOffWellbore': None,
#            'NameAliases': [{'AliasName': 'NO 24-12-1R',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '513',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '100000798279',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': 'NO 24-12-1 R',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '1 R',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '24/12-1 R',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '024/12-01R',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '513',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '24/12-1 R',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None}],
#            'OperatingEnvironmentID': None,
#            'OutcomeID': None,
#            'PrimaryMaterialID': None,
#            'PrimaryProductTypeID': None,
#            'ProjectedBottomHoleLocation.CoordinateQualityCheckPerformedBy': None,
#            'ProjectedBottomHoleLocation.QualitativeSpatialAccuracyTypeID': None,
#            'ProjectedBottomHoleLocation.QuantitativeAccuracyBandID': None,
#            'ProjectedBottomHoleLocation.SpatialGeometryTypeID': None,
#            'ProjectedBottomHoleLocation.SpatialParameterTypeID': None,
#            'ResourceCurationStatus': None,
#            'ResourceHomeRegionID': None,
#            'ResourceLifecycleStatus': None,
#            'ResourceSecurityClassification': None,
#            'RoleID': None,
#            'SecondaryProductTypeID': None,
#            'ShowProductTypeID': None,
#            'Source': None,
#            'SpatialLocation.CoordinateQualityCheckPerformedBy': None,
#            'SpatialLocation.QualitativeSpatialAccuracyTypeID': None,
#            'SpatialLocation.QuantitativeAccuracyBandID': None,
#            'SpatialLocation.SpatialGeometryTypeID': None,
#            'SpatialLocation.SpatialParameterTypeID': None,
#            'StatusSummaryID': None,
#            'TargetFormation': None,
#            'TechnicalAssuranceID': None,
#            'TechnicalAssuranceTypeID': None,
#            'TertiaryProductTypeID': None,
#            'TrajectoryTypeID': None,
#            'VersionCreationReason': None,
#            'VerticalMeasurements': [{'RigID': None,
#                                      'VerticalCRSID': 'npequinor-dev:reference-data--CoordinateReferenceSystem:Vertical:EPSG::5715:',
#                                      'VerticalMeasurement': 25.0,
#                                      'VerticalMeasurementDescription': None,
#                                      'VerticalMeasurementID': 'Zero_Depth_Reference_Point',
#                                      'VerticalMeasurementPathID': 'npequinor-dev:reference-data--VerticalMeasurementPath:TrueVerticalDepth:',
#                                      'VerticalMeasurementSourceID': None,
#                                      'VerticalMeasurementTypeID': 'npequinor-dev:reference-data--VerticalMeasurementType:KellyBushing:',
#                                      'VerticalMeasurementUnitOfMeasureID': 'npequinor-dev:reference-data--UnitOfMeasure:m:',
#                                      'VerticalReferenceEntityID': None,
#                                      'VerticalReferenceID': None,
#                                      'WellboreTVDTrajectoryID': None}],
#            'VirtualProperties.DefaultLocation.CoordinateQualityCheckPerformedBy': None,
#            'VirtualProperties.DefaultLocation.QualitativeSpatialAccuracyTypeID': None,
#            'VirtualProperties.DefaultLocation.QuantitativeAccuracyBandID': None,
#            'VirtualProperties.DefaultLocation.SpatialGeometryTypeID': None,
#            'VirtualProperties.DefaultLocation.SpatialParameterTypeID': None,
#            'VirtualProperties.DefaultName': 'NO 24/12-1 R',
#            'WasBusinessInterestFinancialNonOperated': None,
#            'WasBusinessInterestFinancialOperated': None,
#            'WasBusinessInterestObligatory': None,
#            'WasBusinessInterestTechnical': None,
#            'WellID': 'npequinor-dev:master-data--Well:df1166aa-6ca7-11ed-9855-367dda495db0',
#            'WellboreTrajectoryTypeID': None},
#   'id': 'npequinor-dev:master-data--Wellbore:95a4a86c-7097-11ed-97ff-367dda495db0',
#   'kind': 'osdu:wks:master-data--Wellbore:1.1.0',
#   'legal': {'legaltags': ['npequinor-dev-equinor-private-default'],
#             'otherRelevantDataCountries': ['NO'],
#             'status': 'compliant'},
#   'modifyTime': '2023-08-19T13:36:49.433Z',
#   'modifyUser': '4cdd9a47-c1a2-4211-80ec-4b0af906e453',
#   'namespace': 'osdu:wks',
#   'source': 'wks',
#   'tags': {'EqnrSource': 'SMDA API',
#            'businessCriticalData': 'Not assessed yet',
#            'commitId': '70ca447faca475b6c00266bbfe43b84f5113f669',
#            'countryOfOrigin': 'NO',
#            'dataID': '552 556 560 525 548',
#            'exportControl': 'No',
#            'inside': 'No',
#            'intellectualPropertyRight': 'Not assessed yet',
#            'legalOwnership': 'Equinor solely',
#            'personalData': 'Yes, limited personal data',
#            'securityClassification': 'Internal',
#            'sensitivityFlag': 'null',
#            'sourceSystem': 'SMDA',
#            'soxCriticalData': 'No'},
#   'type': 'master-data--Wellbore',
#   'version': 1692452208774518},
#  {'acl': {'owners': ['data.osdudevops.owners@npequinor-dev.dataservices.energy',
#                      'data.masterdata.owners@npequinor-dev.dataservices.energy'],
#           'viewers': ['data.default.viewers@npequinor-dev.dataservices.energy']},
#   'ancestry': {'parents': ['npequinor-dev:wellheaders:ad215042-009b-2b7e-e053-c818a488c79a:1692243353979248']},
#   'authority': 'osdu',
#   'createTime': '2022-11-30T10:13:08.041Z',
#   'createUser': '4cdd9a47-c1a2-4211-80ec-4b0af906e453',
#   'data': {'BusinessIntentionID': 'npequinor-dev:reference-data--WellBusinessIntention:Explore',
#            'ConditionID': None,
#            'CurrentOperatorID': None,
#            'DataSourceOrganisationID': None,
#            'DefaultVerticalMeasurementID': 'Zero_Depth_Reference_Point',
#            'DefinitiveTrajectoryID': None,
#            'ExistenceKind': None,
#            'FacilityID': 'ad215042-009b-2b7e-e053-c818a488c79a',
#            'FacilityName': 'NO 24/12-1 R',
#            'FacilityTypeID': 'npequinor-dev:reference-data--FacilityType:Wellbore:',
#            'FluidDirectionID': None,
#            'GeographicBottomHoleLocation.CoordinateQualityCheckPerformedBy': None,
#            'GeographicBottomHoleLocation.QualitativeSpatialAccuracyTypeID': None,
#            'GeographicBottomHoleLocation.QuantitativeAccuracyBandID': None,
#            'GeographicBottomHoleLocation.SpatialGeometryTypeID': None,
#            'GeographicBottomHoleLocation.SpatialParameterTypeID': None,
#            'InitialOperatorID': None,
#            'InterestTypeID': None,
#            'KickOffWellbore': None,
#            'NameAliases': [{'AliasName': 'NO 24-12-1R',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '513',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '100000798279',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': 'NO 24-12-1 R',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '1 R',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '24/12-1 R',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '024/12-01R',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '513',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None},
#                            {'AliasName': '24/12-1 R',
#                             'AliasNameTypeID': None,
#                             'DefinitionOrganisationID': None}],
#            'OperatingEnvironmentID': None,
#            'OutcomeID': None,
#            'PrimaryMaterialID': None,
#            'PrimaryProductTypeID': None,
#            'ProjectedBottomHoleLocation.CoordinateQualityCheckPerformedBy': None,
#            'ProjectedBottomHoleLocation.QualitativeSpatialAccuracyTypeID': None,
#            'ProjectedBottomHoleLocation.QuantitativeAccuracyBandID': None,
#            'ProjectedBottomHoleLocation.SpatialGeometryTypeID': None,
#            'ProjectedBottomHoleLocation.SpatialParameterTypeID': None,
#            'ResourceCurationStatus': None,
#            'ResourceHomeRegionID': None,
#            'ResourceLifecycleStatus': None,
#            'ResourceSecurityClassification': None,
#            'RoleID': None,
#            'SecondaryProductTypeID': None,
#            'ShowProductTypeID': None,
#            'Source': None,
#            'SpatialLocation.CoordinateQualityCheckPerformedBy': None,
#            'SpatialLocation.QualitativeSpatialAccuracyTypeID': None,
#            'SpatialLocation.QuantitativeAccuracyBandID': None,
#            'SpatialLocation.SpatialGeometryTypeID': None,
#            'SpatialLocation.SpatialParameterTypeID': None,
#            'StatusSummaryID': None,
#            'TargetFormation': None,
#            'TechnicalAssuranceID': None,
#            'TechnicalAssuranceTypeID': None,
#            'TertiaryProductTypeID': None,
#            'TrajectoryTypeID': None,
#            'VersionCreationReason': None,
#            'VerticalMeasurements': [{'RigID': None,
#                                      'VerticalCRSID': 'npequinor-dev:reference-data--CoordinateReferenceSystem:Vertical:EPSG::5715:',
#                                      'VerticalMeasurement': 25.0,
#                                      'VerticalMeasurementDescription': None,
#                                      'VerticalMeasurementID': 'Zero_Depth_Reference_Point',
#                                      'VerticalMeasurementPathID': 'npequinor-dev:reference-data--VerticalMeasurementPath:TrueVerticalDepth:',
#                                      'VerticalMeasurementSourceID': None,
#                                      'VerticalMeasurementTypeID': 'npequinor-dev:reference-data--VerticalMeasurementType:KellyBushing:',
#                                      'VerticalMeasurementUnitOfMeasureID': 'npequinor-dev:reference-data--UnitOfMeasure:m:',
#                                      'VerticalReferenceEntityID': None,
#                                      'VerticalReferenceID': None,
#                                      'WellboreTVDTrajectoryID': None}],
#            'VirtualProperties.DefaultLocation.CoordinateQualityCheckPerformedBy': None,
#            'VirtualProperties.DefaultLocation.QualitativeSpatialAccuracyTypeID': None,
#            'VirtualProperties.DefaultLocation.QuantitativeAccuracyBandID': None,
#            'VirtualProperties.DefaultLocation.SpatialGeometryTypeID': None,
#            'VirtualProperties.DefaultLocation.SpatialParameterTypeID': None,
#            'VirtualProperties.DefaultName': 'NO 24/12-1 R',
#            'WasBusinessInterestFinancialNonOperated': None,
#            'WasBusinessInterestFinancialOperated': None,
#            'WasBusinessInterestObligatory': None,
#            'WasBusinessInterestTechnical': None,
#            'WellID': 'npequinor-dev:master-data--Well:df1166aa-6ca7-11ed-9855-367dda495db0',
#            'WellboreTrajectoryTypeID': None},
#   'id': 'npequinor-dev:master-data--Wellbore:95a4a86c-7097-11ed-97ff-367dda495db0',
#   'kind': 'osdu:wks:master-data--Wellbore:1.1.0',
#   'legal': {'legaltags': ['npequinor-dev-equinor-private-default'],
#             'otherRelevantDataCountries': ['NO'],
#             'status': 'compliant'},
#   'modifyTime': '2023-08-19T13:36:49.433Z',
#   'modifyUser': '4cdd9a47-c1a2-4211-80ec-4b0af906e453',
#   'namespace': 'osdu:wks',
#   'source': 'wks',
#   'tags': {'EqnrSource': 'SMDA API',
#            'businessCriticalData': 'Not assessed yet',
#            'commitId': '70ca447faca475b6c00266bbfe43b84f5113f669',
#            'countryOfOrigin': 'NO',
#            'dataID': '552 556 560 525 548',
#            'exportControl': 'No',
#            'inside': 'No',
#            'intellectualPropertyRight': 'Not assessed yet',
#            'legalOwnership': 'Equinor solely',
#            'personalData': 'Yes, limited personal data',
#            'securityClassification': 'Internal',
#            'sensitivityFlag': 'null',
#            'sourceSystem': 'SMDA',
#            'soxCriticalData': 'No'},
#   'type': 'master-data--Wellbore',
#   'version': 1692452208774518}]

# %%
# Query by sorting (id feks)
payload = {
    "kind": "osdu:wks:work-product-component--WellLog:1.2.0",
    "sort": {
        "field": ["version"],
        "order": ["DESC"],
    },
    "limit": 10,
    "returnedFields": ["version"]
}

response = osdu_search.get_payload(payload=payload, cursor=True, max_iterations=10)
pprint(response)
# Out:
# INFO:root:Start search ...
# INFO:root:Time elapsed: 0.014083115259806316 minutes, Number of records: , 10
# INFO:root:Search finished...
# [{'version': 1691428800183940},
#  {'version': 1691428799745098},
#  {'version': 1691428799425244},
#  {'version': 1691428798909601},
#  {'version': 1691428798816611},
#  {'version': 1691428798813003},
#  {'version': 1691428798725530},
#  {'version': 1691428798674779},
#  {'version': 1691428798566671},
#  {'version': 1691428798560823}]

# %% [markdown]
# ### Query by sorting multiple fields

# %%
# Query by sorting multi
payload = {
    "kind": "osdu:wks:master-data--Wellbore:*",
    "sort": {
        "field": ["createTime", "version"],
        "order": ["DESC", "ASC"],
    }
}

response = osdu_search.get_payload(payload=payload, cursor=True, max_iterations=10)
pprint(response)
# Out:
# INFO:root:Start search ...
# INFO:root:Time elapsed: 0.018859867254892984 minutes, Number of records: , 10
# INFO:root:Search finished...
# [{'acl': {'owners': ['data.osdudevops.owners@npequinor-dev.dataservices.energy',
#                      'data.masterdata.owners@npequinor-dev.dataservices.energy'],
#           'viewers': ['data.default.viewers@npequinor-dev.dataservices.energy']},
#   'ancestry': {'parents': ['npequinor-dev:wellheaders:ab988b77-eb76-4dfe-a1ae-9aa9d37333e2:1692242837393948']},
#   'authority': 'osdu',
#   'createTime': '2023-08-19T12:03:41.648Z',
#   'createUser': '4cdd9a47-c1a2-4211-80ec-4b0af906e453',
#   'data': {'BusinessIntentionID': 'npequinor-dev:reference-data--WellBusinessIntention:Develop',
#            'ConditionID': None,
#            'CurrentOperatorID': None,
#            'DataSourceOrganisationID': None,
#            'DefaultVerticalMeasurementID': 'Zero_Depth_Reference_Point',
#            'DefinitiveTrajectoryID': None,
#            'ExistenceKind': None,
#            'FacilityID': 'ab988b77-eb76-4dfe-a1ae-9aa9d37333e2',
#            'FacilityName': 'NO 2/8-N-11 A',
#            'FacilityTypeID': 'npequinor-dev:reference-data--FacilityType:Wellbore:',
#            'FluidDirectionID': None,
#            'GeoContexts': [{'BasinID': None,
#                             'FieldID': 'npequinor-dev:master-data--Field:c3be1ad4-708e-11ed-aa24-367dda495db0:',
#                             'GeoPoliticalEntityID': None,
#                             'GeoTypeID': 'Field',
#                             'PlayID': None,
#                             'ProspectID': None}],
#            'GeographicBottomHoleLocation.CoordinateQualityCheckPerformedBy': None,
#            'GeographicBottomHoleLocation.QualitativeSpatialAccuracyTypeID': None,
#            'GeographicBottomHoleLocation.QuantitativeAccuracyBandID': None,
#            'GeographicBottomHoleLocation.SpatialGeometryTypeID': None,
#            'GeographicBottomHoleLocation.SpatialParameterTypeID': None,
#            'InitialOperatorID': None,
#            'InterestTypeID': None,
#            'KickOffWellbore': None,
#            'OperatingEnvironmentID': None,
#            'OutcomeID': None,
#            'PrimaryMaterialID': None,
#            'PrimaryProductTypeID': None,
#            'ProjectedBottomHoleLocation.CoordinateQualityCheckPerformedBy': None,
#            'ProjectedBottomHoleLocation.QualitativeSpatialAccuracyTypeID': None,
#            'ProjectedBottomHoleLocation.QuantitativeAccuracyBandID': None,
#            'ProjectedBottomHoleLocation.SpatialGeometryTypeID': None,
#            'ProjectedBottomHoleLocation.SpatialParameterTypeID': None,
#            'ResourceCurationStatus': None,
#            'ResourceHomeRegionID': None,
#            'ResourceLifecycleStatus': None,
#            'ResourceSecurityClassification': None,
#            'RoleID': None,
#            'SecondaryProductTypeID': None,
#            'ShowProductTypeID': None,
#            'Source': None,
#            'SpatialLocation.CoordinateQualityCheckPerformedBy': None,
#            'SpatialLocation.QualitativeSpatialAccuracyTypeID': None,
#            'SpatialLocation.QuantitativeAccuracyBandID': None,
#            'SpatialLocation.SpatialGeometryTypeID': None,
#            'SpatialLocation.SpatialParameterTypeID': None,
#            'StatusSummaryID': None,
#            'TargetFormation': None,
#            'TechnicalAssuranceID': None,
#            'TechnicalAssuranceTypeID': None,
#            'TertiaryProductTypeID': None,
#            'TrajectoryTypeID': None,
#            'VersionCreationReason': None,
#            'VerticalMeasurements': [{'RigID': 'npequinor-dev:master-data--Rig:24dfe5c4-279d-11ee-aed5-bc6ee27abb91',
#                                      'VerticalCRSID': 'npequinor-dev:reference-data--CoordinateReferenceSystem:Vertical:EPSG::5715:',
#                                      'VerticalMeasurement': 66.82,
#                                      'VerticalMeasurementDescription': None,
#                                      'VerticalMeasurementID': 'Zero_Depth_Reference_Point',
#                                      'VerticalMeasurementPathID': 'npequinor-dev:reference-data--VerticalMeasurementPath:TrueVerticalDepth:',
#                                      'VerticalMeasurementSourceID': None,
#                                      'VerticalMeasurementTypeID': 'npequinor-dev:reference-data--VerticalMeasurementType:KellyBushing:',
#                                      'VerticalMeasurementUnitOfMeasureID': 'npequinor-dev:reference-data--UnitOfMeasure:m:',
#                                      'VerticalReferenceEntityID': None,
#                                      'VerticalReferenceID': None,
#                                      'WellboreTVDTrajectoryID': None}],
#            'VirtualProperties.DefaultLocation.CoordinateQualityCheckPerformedBy': None,
#            'VirtualProperties.DefaultLocation.QualitativeSpatialAccuracyTypeID': None,
#            'VirtualProperties.DefaultLocation.QuantitativeAccuracyBandID': None,
#            'VirtualProperties.DefaultLocation.SpatialGeometryTypeID': None,
#            'VirtualProperties.DefaultLocation.SpatialParameterTypeID': None,
#            'VirtualProperties.DefaultName': 'NO 2/8-N-11 A',
#            'WasBusinessInterestFinancialNonOperated': None,
#            'WasBusinessInterestFinancialOperated': None,
#            'WasBusinessInterestObligatory': None,
#            'WasBusinessInterestTechnical': None,
#            'WellID': 'npequinor-dev:master-data--Well:cfec5cde-6ca7-11ed-9855-367dda495db0',
#            'WellboreTrajectoryTypeID': None},
#   'id': 'npequinor-dev:master-data--Wellbore:63666a1a-3e88-11ee-bcc4-ee31ab6402f4',
#   'kind': 'osdu:wks:master-data--Wellbore:1.1.0',
#   'legal': {'legaltags': ['npequinor-dev-equinor-private-default'],
#             'otherRelevantDataCountries': ['NO'],
#             'status': 'compliant'},
#   'namespace': 'osdu:wks',
#   'source': 'wks',
#   'tags': {'EqnrSource': 'SMDA API',
#            'businessCriticalData': 'Not assessed yet',
#            'commitId': '70ca447faca475b6c00266bbfe43b84f5113f669',
#            'countryOfOrigin': 'NO',
#            'dataID': '552 556 560 525 548',
#            'exportControl': 'No',
#            'inside': 'No',
#            'intellectualPropertyRight': 'Not assessed yet',
#            'legalOwnership': 'Equinor solely',
#            'personalData': 'Yes, limited personal data',
#            'securityClassification': 'Internal',
#            'sensitivityFlag': 'null',
#            'sourceSystem': 'SMDA',
#            'soxCriticalData': 'No'},
#   'type': 'master-data--Wellbore',
#   'version': 1692446621511123},
#  {'acl': {'owners': ['data.osdudevops.owners@npequinor-dev.dataservices.energy',
#                      'data.masterdata.owners@npequinor-dev.dataservices.energy'],
#           'viewers': ['data.default.viewers@npequinor-dev.dataservices.energy']},
#   'ancestry': {'parents': ['npequinor-dev:wellheaders:a96699f8-01e0-4c20-a0c5-130926d1c24c:1692242837393948']},
#   'authority': 'osdu',
#   'createTime': '2023-08-19T12:03:41.648Z',
#   'createUser': '4cdd9a47-c1a2-4211-80ec-4b0af906e453',
#   'data': {'BusinessIntentionID': None,
#            'ConditionID': None,
#            'CurrentOperatorID': None,
#            'DataSourceOrganisationID': None,
#            'DefaultVerticalMeasurementID': 'Zero_Depth_Reference_Point',
#            'DefinitiveTrajectoryID': None,
#            'ExistenceKind': None,
#            'FacilityID': 'a96699f8-01e0-4c20-a0c5-130926d1c24c',
#            'FacilityName': 'NO 1/9-U-14',
#            'FacilityTypeID': 'npequinor-dev:reference-data--FacilityType:Wellbore:',
#            'FluidDirectionID': None,
#            'GeographicBottomHoleLocation.CoordinateQualityCheckPerformedBy': None,
#            'GeographicBottomHoleLocation.QualitativeSpatialAccuracyTypeID': None,
#            'GeographicBottomHoleLocation.QuantitativeAccuracyBandID': None,
#            'GeographicBottomHoleLocation.SpatialGeometryTypeID': None,
#            'GeographicBottomHoleLocation.SpatialParameterTypeID': None,
#            'InitialOperatorID': None,
#            'InterestTypeID': None,
#            'KickOffWellbore': None,
#            'OperatingEnvironmentID': None,
#            'OutcomeID': None,
#            'PrimaryMaterialID': None,
#            'PrimaryProductTypeID': None,
#            'ProjectedBottomHoleLocation.CoordinateQualityCheckPerformedBy': None,
#            'ProjectedBottomHoleLocation.QualitativeSpatialAccuracyTypeID': None,
#            'ProjectedBottomHoleLocation.QuantitativeAccuracyBandID': None,
#            'ProjectedBottomHoleLocation.SpatialGeometryTypeID': None,
#            'ProjectedBottomHoleLocation.SpatialParameterTypeID': None,
#            'ResourceCurationStatus': None,
#            'ResourceHomeRegionID': None,
#            'ResourceLifecycleStatus': None,
#            'ResourceSecurityClassification': None,
#            'RoleID': None,
#            'SecondaryProductTypeID': None,
#            'ShowProductTypeID': None,
#            'Source': None,
#            'SpatialLocation.CoordinateQualityCheckPerformedBy': None,
#            'SpatialLocation.QualitativeSpatialAccuracyTypeID': None,
#            'SpatialLocation.QuantitativeAccuracyBandID': None,
#            'SpatialLocation.SpatialGeometryTypeID': None,
#            'SpatialLocation.SpatialParameterTypeID': None,
#            'StatusSummaryID': None,
#            'TargetFormation': None,
#            'TechnicalAssuranceID': None,
#            'TechnicalAssuranceTypeID': None,
#            'TertiaryProductTypeID': None,
#            'TrajectoryTypeID': None,
#            'VersionCreationReason': None,
#            'VerticalMeasurements': [{'RigID': 'npequinor-dev:master-data--Rig:24e0c6a2-279d-11ee-aacb-bc6ee27abb91',
#                                      'VerticalCRSID': 'npequinor-dev:reference-data--CoordinateReferenceSystem:Vertical:EPSG::5715:',
#                                      'VerticalMeasurement': 0.0,
#                                      'VerticalMeasurementDescription': None,
#                                      'VerticalMeasurementID': 'Zero_Depth_Reference_Point',
#                                      'VerticalMeasurementPathID': 'npequinor-dev:reference-data--VerticalMeasurementPath:TrueVerticalDepth:',
#                                      'VerticalMeasurementSourceID': None,
#                                      'VerticalMeasurementTypeID': 'npequinor-dev:reference-data--VerticalMeasurementType:KellyBushing:',
#                                      'VerticalMeasurementUnitOfMeasureID': 'npequinor-dev:reference-data--UnitOfMeasure:m:',
#                                      'VerticalReferenceEntityID': None,
#                                      'VerticalReferenceID': None,
#                                      'WellboreTVDTrajectoryID': None}],
#            'VirtualProperties.DefaultLocation.CoordinateQualityCheckPerformedBy': None,
#            'VirtualProperties.DefaultLocation.QualitativeSpatialAccuracyTypeID': None,
#            'VirtualProperties.DefaultLocation.QuantitativeAccuracyBandID': None,
#            'VirtualProperties.DefaultLocation.SpatialGeometryTypeID': None,
#            'VirtualProperties.DefaultLocation.SpatialParameterTypeID': None,
#            'VirtualProperties.DefaultName': 'NO 1/9-U-14',
#            'WasBusinessInterestFinancialNonOperated': None,
#            'WasBusinessInterestFinancialOperated': None,
#            'WasBusinessInterestObligatory': None,
#            'WasBusinessInterestTechnical': None,
#            'WellID': 'npequinor-dev:master-data--Well:b883d21e-3bac-11ee-af51-d6aabf56ae2d',
#            'WellboreTrajectoryTypeID': None},
#   'id': 'npequinor-dev:master-data--Wellbore:64910ef4-3e88-11ee-bcc4-ee31ab6402f4',
#   'kind': 'osdu:wks:master-data--Wellbore:1.1.0',
#   'legal': {'legaltags': ['npequinor-dev-equinor-private-default'],
#             'otherRelevantDataCountries': ['NO'],
#             'status': 'compliant'},
#   'namespace': 'osdu:wks',
#   'source': 'wks',
#   'tags': {'EqnrSource': 'SMDA API',
#            'businessCriticalData': 'Not assessed yet',
#            'commitId': '70ca447faca475b6c00266bbfe43b84f5113f669',
#            'countryOfOrigin': 'NO',
#            'dataID': '552 556 560 525 548',
#            'exportControl': 'No',
#            'inside': 'No',
#            'intellectualPropertyRight': 'Not assessed yet',
#            'legalOwnership': 'Equinor solely',
#            'personalData': 'Yes, limited personal data',
#            'securityClassification': 'Internal',
#            'sensitivityFlag': 'null',
#            'sourceSystem': 'SMDA',
#            'soxCriticalData': 'No'},
#   'type': 'master-data--Wellbore',
#   'version': 1692446621511123},
#  {'acl': {'owners': ['data.osdudevops.owners@npequinor-dev.dataservices.energy',
#                      'data.masterdata.owners@npequinor-dev.dataservices.energy'],
#           'viewers': ['data.default.viewers@npequinor-dev.dataservices.energy']},
#   'ancestry': {'parents': ['npequinor-dev:wellheaders:aef097e3-7e18-4071-a6a4-5860a0f01908:1692101687783497']},
#   'authority': 'osdu',
#   'createTime': '2023-08-16T15:34:35.321Z',
#   'createUser': '4cdd9a47-c1a2-4211-80ec-4b0af906e453',
#   'data': {'BusinessIntentionID': None,
#            'ConditionID': None,
#            'CurrentOperatorID': None,
#            'DataSourceOrganisationID': None,
#            'DefaultVerticalMeasurementID': 'Zero_Depth_Reference_Point',
#            'DefinitiveTrajectoryID': None,
#            'ExistenceKind': None,
#            'FacilityID': 'aef097e3-7e18-4071-a6a4-5860a0f01908',
#            'FacilityName': 'NO 1/9-U-10',
#            'FacilityTypeID': 'npequinor-dev:reference-data--FacilityType:Wellbore:',
#            'FluidDirectionID': None,
#            'GeographicBottomHoleLocation.CoordinateQualityCheckPerformedBy': None,
#            'GeographicBottomHoleLocation.QualitativeSpatialAccuracyTypeID': None,
#            'GeographicBottomHoleLocation.QuantitativeAccuracyBandID': None,
#            'GeographicBottomHoleLocation.SpatialGeometryTypeID': None,
#            'GeographicBottomHoleLocation.SpatialParameterTypeID': None,
#            'InitialOperatorID': None,
#            'InterestTypeID': None,
#            'KickOffWellbore': None,
#            'OperatingEnvironmentID': None,
#            'OutcomeID': None,
#            'PrimaryMaterialID': None,
#            'PrimaryProductTypeID': None,
#            'ProjectedBottomHoleLocation.CoordinateQualityCheckPerformedBy': None,
#            'ProjectedBottomHoleLocation.QualitativeSpatialAccuracyTypeID': None,
#            'ProjectedBottomHoleLocation.QuantitativeAccuracyBandID': None,
#            'ProjectedBottomHoleLocation.SpatialGeometryTypeID': None,
#            'ProjectedBottomHoleLocation.SpatialParameterTypeID': None,
#            'ResourceCurationStatus': None,
#            'ResourceHomeRegionID': None,
#            'ResourceLifecycleStatus': None,
#            'ResourceSecurityClassification': None,
#            'RoleID': None,
#            'SecondaryProductTypeID': None,
#            'ShowProductTypeID': None,
#            'Source': None,
#            'SpatialLocation.CoordinateQualityCheckPerformedBy': None,
#            'SpatialLocation.QualitativeSpatialAccuracyTypeID': None,
#            'SpatialLocation.QuantitativeAccuracyBandID': None,
#            'SpatialLocation.SpatialGeometryTypeID': None,
#            'SpatialLocation.SpatialParameterTypeID': None,
#            'StatusSummaryID': None,
#            'TargetFormation': None,
#            'TechnicalAssuranceID': None,
#            'TechnicalAssuranceTypeID': None,
#            'TertiaryProductTypeID': None,
#            'TrajectoryTypeID': None,
#            'VersionCreationReason': None,
#            'VerticalMeasurements': [{'RigID': 'npequinor-dev:master-data--Rig:24e0c6a2-279d-11ee-aacb-bc6ee27abb91',
#                                      'VerticalCRSID': 'npequinor-dev:reference-data--CoordinateReferenceSystem:Vertical:EPSG::5715:',
#                                      'VerticalMeasurement': 0.0,
#                                      'VerticalMeasurementDescription': None,
#                                      'VerticalMeasurementID': 'Zero_Depth_Reference_Point',
#                                      'VerticalMeasurementPathID': 'npequinor-dev:reference-data--VerticalMeasurementPath:TrueVerticalDepth:',
#                                      'VerticalMeasurementSourceID': None,
#                                      'VerticalMeasurementTypeID': 'npequinor-dev:reference-data--VerticalMeasurementType:KellyBushing:',
#                                      'VerticalMeasurementUnitOfMeasureID': 'npequinor-dev:reference-data--UnitOfMeasure:m:',
#                                      'VerticalReferenceEntityID': None,
#                                      'VerticalReferenceID': None,
#                                      'WellboreTVDTrajectoryID': None}],
#            'VirtualProperties.DefaultLocation.CoordinateQualityCheckPerformedBy': None,
#            'VirtualProperties.DefaultLocation.QualitativeSpatialAccuracyTypeID': None,
#            'VirtualProperties.DefaultLocation.QuantitativeAccuracyBandID': None,
#            'VirtualProperties.DefaultLocation.SpatialGeometryTypeID': None,
#            'VirtualProperties.DefaultLocation.SpatialParameterTypeID': None,
#            'VirtualProperties.DefaultName': 'NO 1/9-U-10',
#            'WasBusinessInterestFinancialNonOperated': None,
#            'WasBusinessInterestFinancialOperated': None,
#            'WasBusinessInterestObligatory': None,
#            'WasBusinessInterestTechnical': None,
#            'WellID': 'npequinor-dev:master-data--Well:1bd7e1a0-3b7d-11ee-af51-d6aabf56ae2d',
#            'WellboreTrajectoryTypeID': None},
#   'id': 'npequinor-dev:master-data--Wellbore:64ce5164-3c4a-11ee-8050-d6ba67abf449',
#   'kind': 'osdu:wks:master-data--Wellbore:1.1.0',
#   'legal': {'legaltags': ['npequinor-dev-equinor-private-default'],
#             'otherRelevantDataCountries': ['NO'],
#             'status': 'compliant'},
#   'modifyTime': '2023-08-17T02:13:51.606Z',
#   'modifyUser': '4cdd9a47-c1a2-4211-80ec-4b0af906e453',
#   'namespace': 'osdu:wks',
#   'source': 'wks',
#   'tags': {'EqnrSource': 'SMDA API',
#            'businessCriticalData': 'Not assessed yet',
#            'commitId': '109458dee75e49040de153558ca9e4a46fe14353',
#            'countryOfOrigin': 'NO',
#            'dataID': '552 556 560 525 548',
#            'exportControl': 'No',
#            'inside': 'No',
#            'intellectualPropertyRight': 'Not assessed yet',
#            'legalOwnership': 'Equinor solely',
#            'personalData': 'Yes, limited personal data',
#            'securityClassification': 'Internal',
#            'sensitivityFlag': 'null',
#            'sourceSystem': 'SMDA',
#            'soxCriticalData': 'No'},
#   'type': 'master-data--Wellbore',
#   'version': 1692238431371618},
#  {'acl': {'owners': ['data.osdudevops.owners@npequinor-dev.dataservices.energy',
#                      'data.masterdata.owners@npequinor-dev.dataservices.energy'],
#           'viewers': ['data.default.viewers@npequinor-dev.dataservices.energy']},
#   'ancestry': {'parents': ['npequinor-dev:wellheaders:0a6a98b8-9ff7-4ff5-a41b-5792f03d1824:1692100310235561']},
#   'authority': 'osdu',
#   'createTime': '2023-08-16T14:09:02.759Z',
#   'createUser': '4cdd9a47-c1a2-4211-80ec-4b0af906e453',
#   'data': {'BusinessIntentionID': None,
#            'ConditionID': None,
#            'CurrentOperatorID': None,
#            'DataSourceOrganisationID': None,
#            'DefaultVerticalMeasurementID': 'Zero_Depth_Reference_Point',
#            'DefinitiveTrajectoryID': None,
#            'ExistenceKind': None,
#            'FacilityID': '0a6a98b8-9ff7-4ff5-a41b-5792f03d1824',
#            'FacilityName': 'NO 1/9-U-4',
#            'FacilityTypeID': 'npequinor-dev:reference-data--FacilityType:Wellbore:',
#            'FluidDirectionID': None,
#            'GeographicBottomHoleLocation.CoordinateQualityCheckPerformedBy': None,
#            'GeographicBottomHoleLocation.QualitativeSpatialAccuracyTypeID': None,
#            'GeographicBottomHoleLocation.QuantitativeAccuracyBandID': None,
#            'GeographicBottomHoleLocation.SpatialGeometryTypeID': None,
#            'GeographicBottomHoleLocation.SpatialParameterTypeID': None,
#            'InitialOperatorID': None,
#            'InterestTypeID': None,
#            'KickOffWellbore': None,
#            'OperatingEnvironmentID': None,
#            'OutcomeID': None,
#            'PrimaryMaterialID': None,
#            'PrimaryProductTypeID': None,
#            'ProjectedBottomHoleLocation.CoordinateQualityCheckPerformedBy': None,
#            'ProjectedBottomHoleLocation.QualitativeSpatialAccuracyTypeID': None,
#            'ProjectedBottomHoleLocation.QuantitativeAccuracyBandID': None,
#            'ProjectedBottomHoleLocation.SpatialGeometryTypeID': None,
#            'ProjectedBottomHoleLocation.SpatialParameterTypeID': None,
#            'ResourceCurationStatus': None,
#            'ResourceHomeRegionID': None,
#            'ResourceLifecycleStatus': None,
#            'ResourceSecurityClassification': None,
#            'RoleID': None,
#            'SecondaryProductTypeID': None,
#            'ShowProductTypeID': None,
#            'Source': None,
#            'SpatialLocation.CoordinateQualityCheckPerformedBy': None,
#            'SpatialLocation.QualitativeSpatialAccuracyTypeID': None,
#            'SpatialLocation.QuantitativeAccuracyBandID': None,
#            'SpatialLocation.SpatialGeometryTypeID': None,
#            'SpatialLocation.SpatialParameterTypeID': None,
#            'StatusSummaryID': None,
#            'TargetFormation': None,
#            'TechnicalAssuranceID': None,
#            'TechnicalAssuranceTypeID': None,
#            'TertiaryProductTypeID': None,
#            'TrajectoryTypeID': None,
#            'VersionCreationReason': None,
#            'VerticalMeasurements': [{'RigID': 'npequinor-dev:master-data--Rig:24e0c6a2-279d-11ee-aacb-bc6ee27abb91',
#                                      'VerticalCRSID': 'npequinor-dev:reference-data--CoordinateReferenceSystem:Vertical:EPSG::5715:',
#                                      'VerticalMeasurement': 0.0,
#                                      'VerticalMeasurementDescription': None,
#                                      'VerticalMeasurementID': 'Zero_Depth_Reference_Point',
#                                      'VerticalMeasurementPathID': 'npequinor-dev:reference-data--VerticalMeasurementPath:TrueVerticalDepth:',
#                                      'VerticalMeasurementSourceID': None,
#                                      'VerticalMeasurementTypeID': 'npequinor-dev:reference-data--VerticalMeasurementType:KellyBushing:',
#                                      'VerticalMeasurementUnitOfMeasureID': 'npequinor-dev:reference-data--UnitOfMeasure:m:',
#                                      'VerticalReferenceEntityID': None,
#                                      'VerticalReferenceID': None,
#                                      'WellboreTVDTrajectoryID': None}],
#            'VirtualProperties.DefaultLocation.CoordinateQualityCheckPerformedBy': None,
#            'VirtualProperties.DefaultLocation.QualitativeSpatialAccuracyTypeID': None,
#            'VirtualProperties.DefaultLocation.QuantitativeAccuracyBandID': None,
#            'VirtualProperties.DefaultLocation.SpatialGeometryTypeID': None,
#            'VirtualProperties.DefaultLocation.SpatialParameterTypeID': None,
#            'VirtualProperties.DefaultName': 'NO 1/9-U-4',
#            'WasBusinessInterestFinancialNonOperated': None,
#            'WasBusinessInterestFinancialOperated': None,
#            'WasBusinessInterestObligatory': None,
#            'WasBusinessInterestTechnical': None,
#            'WellID': 'npequinor-dev:master-data--Well:7ef283ca-3b79-11ee-af51-d6aabf56ae2d',
#            'WellboreTrajectoryTypeID': None},
#   'id': 'npequinor-dev:master-data--Wellbore:616402be-3c3e-11ee-8050-d6ba67abf449',
#   'kind': 'osdu:wks:master-data--Wellbore:1.1.0',
#   'legal': {'legaltags': ['npequinor-dev-equinor-private-default'],
#             'otherRelevantDataCountries': ['NO'],
#             'status': 'compliant'},
#   'modifyTime': '2023-08-17T00:46:52.306Z',
#   'modifyUser': '4cdd9a47-c1a2-4211-80ec-4b0af906e453',
#   'namespace': 'osdu:wks',
#   'source': 'wks',
#   'tags': {'EqnrSource': 'SMDA API',
#            'businessCriticalData': 'Not assessed yet',
#            'commitId': '109458dee75e49040de153558ca9e4a46fe14353',
#            'countryOfOrigin': 'NO',
#            'dataID': '552 556 560 525 548',
#            'exportControl': 'No',
#            'inside': 'No',
#            'intellectualPropertyRight': 'Not assessed yet',
#            'legalOwnership': 'Equinor solely',
#            'personalData': 'Yes, limited personal data',
#            'securityClassification': 'Internal',
#            'sensitivityFlag': 'null',
#            'sourceSystem': 'SMDA',
#            'soxCriticalData': 'No'},
#   'type': 'master-data--Wellbore',
#   'version': 1692233211908310},
#  {'acl': {'owners': ['data.osdudevops.owners@npequinor-dev.dataservices.energy',
#                      'data.masterdata.owners@npequinor-dev.dataservices.energy'],
#           'viewers': ['data.default.viewers@npequinor-dev.dataservices.energy']},
#   'ancestry': {'parents': ['npequinor-dev:wellheaders:cd19b006-7273-4264-9633-afd69c6d57b8:1691555862444033']},
#   'authority': 'osdu',
#   'createTime': '2023-08-16T02:21:30.121Z',
#   'createUser': '4cdd9a47-c1a2-4211-80ec-4b0af906e453',
#   'data': {'BusinessIntentionID': 'npequinor-dev:reference-data--WellBusinessIntention:Explore',
#            'ConditionID': None,
#            'CurrentOperatorID': None,
#            'DataSourceOrganisationID': None,
#            'DefaultVerticalMeasurementID': 'Zero_Depth_Reference_Point',
#            'DefinitiveTrajectoryID': None,
#            'ExistenceKind': None,
#            'FacilityID': 'cd19b006-7273-4264-9633-afd69c6d57b8',
#            'FacilityName': 'BR 3-BRSA-1388D-SPS',
#            'FacilityTypeID': 'npequinor-dev:reference-data--FacilityType:Wellbore:',
#            'FluidDirectionID': None,
#            'GeographicBottomHoleLocation.CoordinateQualityCheckPerformedBy': None,
#            'GeographicBottomHoleLocation.QualitativeSpatialAccuracyTypeID': None,
#            'GeographicBottomHoleLocation.QuantitativeAccuracyBandID': None,
#            'GeographicBottomHoleLocation.SpatialGeometryTypeID': None,
#            'GeographicBottomHoleLocation.SpatialParameterTypeID': None,
#            'InitialOperatorID': None,
#            'InterestTypeID': None,
#            'KickOffWellbore': None,
#            'OperatingEnvironmentID': None,
#            'OutcomeID': None,
#            'PrimaryMaterialID': None,
#            'PrimaryProductTypeID': None,
#            'ProjectedBottomHoleLocation.CoordinateQualityCheckPerformedBy': None,
#            'ProjectedBottomHoleLocation.QualitativeSpatialAccuracyTypeID': None,
#            'ProjectedBottomHoleLocation.QuantitativeAccuracyBandID': None,
#            'ProjectedBottomHoleLocation.SpatialGeometryTypeID': None,
#            'ProjectedBottomHoleLocation.SpatialParameterTypeID': None,
#            'ResourceCurationStatus': None,
#            'ResourceHomeRegionID': None,
#            'ResourceLifecycleStatus': None,
#            'ResourceSecurityClassification': None,
#            'RoleID': None,
#            'SecondaryProductTypeID': None,
#            'ShowProductTypeID': None,
#            'Source': None,
#            'SpatialLocation.CoordinateQualityCheckPerformedBy': None,
#            'SpatialLocation.QualitativeSpatialAccuracyTypeID': None,
#            'SpatialLocation.QuantitativeAccuracyBandID': None,
#            'SpatialLocation.SpatialGeometryTypeID': None,
#            'SpatialLocation.SpatialParameterTypeID': None,
#            'StatusSummaryID': None,
#            'TargetFormation': None,
#            'TechnicalAssuranceID': None,
#            'TechnicalAssuranceTypeID': None,
#            'TertiaryProductTypeID': None,
#            'TrajectoryTypeID': None,
#            'VersionCreationReason': None,
#            'VerticalMeasurements': [{'RigID': None,
#                                      'VerticalCRSID': 'npequinor-dev:reference-data--CoordinateReferenceSystem:Vertical:EPSG::5715:',
#                                      'VerticalMeasurement': 32.0,
#                                      'VerticalMeasurementDescription': None,
#                                      'VerticalMeasurementID': 'Zero_Depth_Reference_Point',
#                                      'VerticalMeasurementPathID': 'npequinor-dev:reference-data--VerticalMeasurementPath:TrueVerticalDepth:',
#                                      'VerticalMeasurementSourceID': None,
#                                      'VerticalMeasurementTypeID': 'npequinor-dev:reference-data--VerticalMeasurementType:RotaryTable:',
#                                      'VerticalMeasurementUnitOfMeasureID': 'npequinor-dev:reference-data--UnitOfMeasure:m:',
#                                      'VerticalReferenceEntityID': None,
#                                      'VerticalReferenceID': None,
#                                      'WellboreTVDTrajectoryID': None}],
#            'VirtualProperties.DefaultLocation.CoordinateQualityCheckPerformedBy': None,
#            'VirtualProperties.DefaultLocation.QualitativeSpatialAccuracyTypeID': None,
#            'VirtualProperties.DefaultLocation.QuantitativeAccuracyBandID': None,
#            'VirtualProperties.DefaultLocation.SpatialGeometryTypeID': None,
#            'VirtualProperties.DefaultLocation.SpatialParameterTypeID': None,
#            'VirtualProperties.DefaultName': 'BR 3-BRSA-1388D-SPS',
#            'WasBusinessInterestFinancialNonOperated': None,
#            'WasBusinessInterestFinancialOperated': None,
#            'WasBusinessInterestObligatory': None,
#            'WasBusinessInterestTechnical': None,
#            'WellID': 'npequinor-dev:master-data--Well:e19ef89c-312d-11ee-a93e-8abc6a9a4945',
#            'WellboreTrajectoryTypeID': None},
#   'id': 'npequinor-dev:master-data--Wellbore:7f21b0e8-3bdb-11ee-af51-d6aabf56ae2d',
#   'kind': 'osdu:wks:master-data--Wellbore:1.1.0',
#   'legal': {'legaltags': ['npequinor-dev-equinor-private-default'],
#             'otherRelevantDataCountries': ['NO'],
#             'status': 'compliant'},
#   'modifyTime': '2023-08-18T21:09:35.353Z',
#   'modifyUser': '4cdd9a47-c1a2-4211-80ec-4b0af906e453',
#   'namespace': 'osdu:wks',
#   'source': 'wks',
#   'tags': {'EqnrSource': 'SMDA API',
#            'businessCriticalData': 'Not assessed yet',
#            'commitId': '70ca447faca475b6c00266bbfe43b84f5113f669',
#            'countryOfOrigin': 'NO',
#            'dataID': '552 556 560 525 548',
#            'exportControl': 'No',
#            'inside': 'No',
#            'intellectualPropertyRight': 'Not assessed yet',
#            'legalOwnership': 'Equinor solely',
#            'personalData': 'Yes, limited personal data',
#            'securityClassification': 'Internal',
#            'sensitivityFlag': 'null',
#            'sourceSystem': 'SMDA',
#            'soxCriticalData': 'No'},
#   'type': 'master-data--Wellbore',
#   'version': 1692392975101394},
#  {'acl': {'owners': ['data.osdudevops.owners@npequinor-dev.dataservices.energy',
#                      'data.masterdata.owners@npequinor-dev.dataservices.energy'],
#           'viewers': ['data.default.viewers@npequinor-dev.dataservices.energy']},
#   'ancestry': {'parents': ['npequinor-dev:wellheaders:c992fd5d-3cf7-4847-bf44-8368312a5fa5:1691555839380122']},
#   'authority': 'osdu',
#   'createTime': '2023-08-16T02:21:30.121Z',
#   'createUser': '4cdd9a47-c1a2-4211-80ec-4b0af906e453',
#   'data': {'BusinessIntentionID': 'npequinor-dev:reference-data--WellBusinessIntention:Explore',
#            'ConditionID': None,
#            'CurrentOperatorID': None,
#            'DataSourceOrganisationID': None,
#            'DefaultVerticalMeasurementID': 'Zero_Depth_Reference_Point',
#            'DefinitiveTrajectoryID': None,
#            'ExistenceKind': None,
#            'FacilityID': 'c992fd5d-3cf7-4847-bf44-8368312a5fa5',
#            'FacilityName': 'GB 206/05c- 4',
#            'FacilityTypeID': 'npequinor-dev:reference-data--FacilityType:Wellbore:',
#            'FluidDirectionID': None,
#            'GeographicBottomHoleLocation.CoordinateQualityCheckPerformedBy': None,
#            'GeographicBottomHoleLocation.QualitativeSpatialAccuracyTypeID': None,
#            'GeographicBottomHoleLocation.QuantitativeAccuracyBandID': None,
#            'GeographicBottomHoleLocation.SpatialGeometryTypeID': None,
#            'GeographicBottomHoleLocation.SpatialParameterTypeID': None,
#            'InitialOperatorID': None,
#            'InterestTypeID': None,
#            'KickOffWellbore': None,
#            'OperatingEnvironmentID': None,
#            'OutcomeID': None,
#            'PrimaryMaterialID': None,
#            'PrimaryProductTypeID': None,
#            'ProjectedBottomHoleLocation.CoordinateQualityCheckPerformedBy': None,
#            'ProjectedBottomHoleLocation.QualitativeSpatialAccuracyTypeID': None,
#            'ProjectedBottomHoleLocation.QuantitativeAccuracyBandID': None,
#            'ProjectedBottomHoleLocation.SpatialGeometryTypeID': None,
#            'ProjectedBottomHoleLocation.SpatialParameterTypeID': None,
#            'ResourceCurationStatus': None,
#            'ResourceHomeRegionID': None,
#            'ResourceLifecycleStatus': None,
#            'ResourceSecurityClassification': None,
#            'RoleID': None,
#            'SecondaryProductTypeID': None,
#            'ShowProductTypeID': None,
#            'Source': None,
#            'SpatialLocation.CoordinateQualityCheckPerformedBy': None,
#            'SpatialLocation.QualitativeSpatialAccuracyTypeID': None,
#            'SpatialLocation.QuantitativeAccuracyBandID': None,
#            'SpatialLocation.SpatialGeometryTypeID': None,
#            'SpatialLocation.SpatialParameterTypeID': None,
#            'StatusSummaryID': None,
#            'TargetFormation': None,
#            'TechnicalAssuranceID': None,
#            'TechnicalAssuranceTypeID': None,
#            'TertiaryProductTypeID': None,
#            'TrajectoryTypeID': None,
#            'VersionCreationReason': None,
#            'VerticalMeasurements': [{'RigID': None,
#                                      'VerticalCRSID': 'npequinor-dev:reference-data--CoordinateReferenceSystem:Vertical:EPSG::5715:',
#                                      'VerticalMeasurement': 131.23,
#                                      'VerticalMeasurementDescription': None,
#                                      'VerticalMeasurementID': 'Zero_Depth_Reference_Point',
#                                      'VerticalMeasurementPathID': 'npequinor-dev:reference-data--VerticalMeasurementPath:TrueVerticalDepth:',
#                                      'VerticalMeasurementSourceID': None,
#                                      'VerticalMeasurementTypeID': 'npequinor-dev:reference-data--VerticalMeasurementType:KellyBushing:',
#                                      'VerticalMeasurementUnitOfMeasureID': 'npequinor-dev:reference-data--UnitOfMeasure:ft:',
#                                      'VerticalReferenceEntityID': None,
#                                      'VerticalReferenceID': None,
#                                      'WellboreTVDTrajectoryID': None}],
#            'VirtualProperties.DefaultLocation.CoordinateQualityCheckPerformedBy': None,
#            'VirtualProperties.DefaultLocation.QualitativeSpatialAccuracyTypeID': None,
#            'VirtualProperties.DefaultLocation.QuantitativeAccuracyBandID': None,
#            'VirtualProperties.DefaultLocation.SpatialGeometryTypeID': None,
#            'VirtualProperties.DefaultLocation.SpatialParameterTypeID': None,
#            'VirtualProperties.DefaultName': 'GB 206/05c- 4',
#            'WasBusinessInterestFinancialNonOperated': None,
#            'WasBusinessInterestFinancialOperated': None,
#            'WasBusinessInterestObligatory': None,
#            'WasBusinessInterestTechnical': None,
#            'WellID': 'npequinor-dev:master-data--Well:2fe0831a-2b55-11ee-85cf-becae9590646',
#            'WellboreTrajectoryTypeID': None},
#   'id': 'npequinor-dev:master-data--Wellbore:7ff23524-3bdb-11ee-af51-d6aabf56ae2d',
#   'kind': 'osdu:wks:master-data--Wellbore:1.1.0',
#   'legal': {'legaltags': ['npequinor-dev-equinor-private-default'],
#             'otherRelevantDataCountries': ['NO'],
#             'status': 'compliant'},
#   'modifyTime': '2023-08-18T21:09:35.353Z',
#   'modifyUser': '4cdd9a47-c1a2-4211-80ec-4b0af906e453',
#   'namespace': 'osdu:wks',
#   'source': 'wks',
#   'tags': {'EqnrSource': 'SMDA API',
#            'businessCriticalData': 'Not assessed yet',
#            'commitId': '70ca447faca475b6c00266bbfe43b84f5113f669',
#            'countryOfOrigin': 'NO',
#            'dataID': '552 556 560 525 548',
#            'exportControl': 'No',
#            'inside': 'No',
#            'intellectualPropertyRight': 'Not assessed yet',
#            'legalOwnership': 'Equinor solely',
#            'personalData': 'Yes, limited personal data',
#            'securityClassification': 'Internal',
#            'sensitivityFlag': 'null',
#            'sourceSystem': 'SMDA',
#            'soxCriticalData': 'No'},
#   'type': 'master-data--Wellbore',
#   'version': 1692392975101394},
#  {'acl': {'owners': ['data.osdudevops.owners@npequinor-dev.dataservices.energy',
#                      'data.masterdata.owners@npequinor-dev.dataservices.energy'],
#           'viewers': ['data.default.viewers@npequinor-dev.dataservices.energy']},
#   'ancestry': {'parents': ['npequinor-dev:wellheaders:9fdab2dc-a4c1-4bd3-8ed4-3c1977f0100c:1691551308833354']},
#   'authority': 'osdu',
#   'createTime': '2023-08-10T00:59:16.789Z',
#   'createUser': '4cdd9a47-c1a2-4211-80ec-4b0af906e453',
#   'data': {'BusinessIntentionID': 'npequinor-dev:reference-data--WellBusinessIntention:Explore',
#            'ConditionID': None,
#            'CurrentOperatorID': None,
#            'DataSourceOrganisationID': None,
#            'DefaultVerticalMeasurementID': 'Zero_Depth_Reference_Point',
#            'DefinitiveTrajectoryID': None,
#            'ExistenceKind': None,
#            'FacilityID': '9fdab2dc-a4c1-4bd3-8ed4-3c1977f0100c',
#            'FacilityName': 'NO 30/9 M-12 CHT2',
#            'FacilityTypeID': 'npequinor-dev:reference-data--FacilityType:Wellbore:',
#            'FluidDirectionID': None,
#            'GeoContexts': [{'BasinID': None,
#                             'FieldID': 'npequinor-dev:master-data--Field:c54463cc-708e-11ed-aa24-367dda495db0:',
#                             'GeoPoliticalEntityID': None,
#                             'GeoTypeID': 'Field',
#                             'PlayID': None,
#                             'ProspectID': None}],
#            'GeographicBottomHoleLocation.CoordinateQualityCheckPerformedBy': None,
#            'GeographicBottomHoleLocation.QualitativeSpatialAccuracyTypeID': None,
#            'GeographicBottomHoleLocation.QuantitativeAccuracyBandID': None,
#            'GeographicBottomHoleLocation.SpatialGeometryTypeID': None,
#            'GeographicBottomHoleLocation.SpatialParameterTypeID': None,
#            'InitialOperatorID': None,
#            'InterestTypeID': None,
#            'KickOffWellbore': None,
#            'OperatingEnvironmentID': None,
#            'OutcomeID': None,
#            'PrimaryMaterialID': None,
#            'PrimaryProductTypeID': None,
#            'ProjectedBottomHoleLocation.CoordinateQualityCheckPerformedBy': None,
#            'ProjectedBottomHoleLocation.QualitativeSpatialAccuracyTypeID': None,
#            'ProjectedBottomHoleLocation.QuantitativeAccuracyBandID': None,
#            'ProjectedBottomHoleLocation.SpatialGeometryTypeID': None,
#            'ProjectedBottomHoleLocation.SpatialParameterTypeID': None,
#            'ResourceCurationStatus': None,
#            'ResourceHomeRegionID': None,
#            'ResourceLifecycleStatus': None,
#            'ResourceSecurityClassification': None,
#            'RoleID': None,
#            'SecondaryProductTypeID': None,
#            'ShowProductTypeID': None,
#            'Source': None,
#            'SpatialLocation.CoordinateQualityCheckPerformedBy': None,
#            'SpatialLocation.QualitativeSpatialAccuracyTypeID': None,
#            'SpatialLocation.QuantitativeAccuracyBandID': None,
#            'SpatialLocation.SpatialGeometryTypeID': None,
#            'SpatialLocation.SpatialParameterTypeID': None,
#            'StatusSummaryID': None,
#            'TargetFormation': None,
#            'TechnicalAssuranceID': None,
#            'TechnicalAssuranceTypeID': None,
#            'TertiaryProductTypeID': None,
#            'TrajectoryTypeID': None,
#            'VersionCreationReason': None,
#            'VerticalMeasurements': [{'RigID': 'npequinor-dev:master-data--Rig:24e11596-279d-11ee-886a-bc6ee27abb91',
#                                      'VerticalCRSID': 'npequinor-dev:reference-data--CoordinateReferenceSystem:Vertical:EPSG::5715:',
#                                      'VerticalMeasurement': 56.0,
#                                      'VerticalMeasurementDescription': None,
#                                      'VerticalMeasurementID': 'Zero_Depth_Reference_Point',
#                                      'VerticalMeasurementPathID': 'npequinor-dev:reference-data--VerticalMeasurementPath:TrueVerticalDepth:',
#                                      'VerticalMeasurementSourceID': None,
#                                      'VerticalMeasurementTypeID': 'npequinor-dev:reference-data--VerticalMeasurementType:RotaryTable:',
#                                      'VerticalMeasurementUnitOfMeasureID': 'npequinor-dev:reference-data--UnitOfMeasure:m:',
#                                      'VerticalReferenceEntityID': None,
#                                      'VerticalReferenceID': None,
#                                      'WellboreTVDTrajectoryID': None}],
#            'VirtualProperties.DefaultLocation.CoordinateQualityCheckPerformedBy': None,
#            'VirtualProperties.DefaultLocation.QualitativeSpatialAccuracyTypeID': None,
#            'VirtualProperties.DefaultLocation.QuantitativeAccuracyBandID': None,
#            'VirtualProperties.DefaultLocation.SpatialGeometryTypeID': None,
#            'VirtualProperties.DefaultLocation.SpatialParameterTypeID': None,
#            'VirtualProperties.DefaultName': 'NO 30/9 M-12 CHT2',
#            'WasBusinessInterestFinancialNonOperated': None,
#            'WasBusinessInterestFinancialOperated': None,
#            'WasBusinessInterestObligatory': None,
#            'WasBusinessInterestTechnical': None,
#            'WellID': 'npequinor-dev:master-data--Well:e3586628-6ca7-11ed-9855-367dda495db0',
#            'WellboreTrajectoryTypeID': None},
#   'id': 'npequinor-dev:master-data--Wellbore:ff493006-3718-11ee-8346-8abc6a9a4945',
#   'kind': 'osdu:wks:master-data--Wellbore:1.1.0',
#   'legal': {'legaltags': ['npequinor-dev-equinor-private-default'],
#             'otherRelevantDataCountries': ['NO'],
#             'status': 'compliant'},
#   'modifyTime': '2023-08-16T02:40:20.214Z',
#   'modifyUser': '4cdd9a47-c1a2-4211-80ec-4b0af906e453',
#   'namespace': 'osdu:wks',
#   'source': 'wks',
#   'tags': {'EqnrSource': 'SMDA API',
#            'businessCriticalData': 'Not assessed yet',
#            'commitId': '109458dee75e49040de153558ca9e4a46fe14353',
#            'countryOfOrigin': 'NO',
#            'dataID': '552 556 560 525 548',
#            'exportControl': 'No',
#            'inside': 'No',
#            'intellectualPropertyRight': 'Not assessed yet',
#            'legalOwnership': 'Equinor solely',
#            'personalData': 'Yes, limited personal data',
#            'securityClassification': 'Internal',
#            'sensitivityFlag': 'null',
#            'sourceSystem': 'SMDA',
#            'soxCriticalData': 'No'},
#   'type': 'master-data--Wellbore',
#   'version': 1692153619957580},
#  {'acl': {'owners': ['data.osdudevops.owners@npequinor-dev.dataservices.energy',
#                      'data.masterdata.owners@npequinor-dev.dataservices.energy'],
#           'viewers': ['data.default.viewers@npequinor-dev.dataservices.energy']},
#   'ancestry': {'parents': ['npequinor-dev:wellheaders:54c6ee4e-8df9-46c5-80de-5a07814df658:1691551288761555']},
#   'authority': 'osdu',
#   'createTime': '2023-08-09T17:41:06.377Z',
#   'createUser': '4cdd9a47-c1a2-4211-80ec-4b0af906e453',
#   'data': {'BusinessIntentionID': 'npequinor-dev:reference-data--WellBusinessIntention:Develop',
#            'ConditionID': None,
#            'CurrentOperatorID': None,
#            'DataSourceOrganisationID': None,
#            'DefaultVerticalMeasurementID': 'Zero_Depth_Reference_Point',
#            'DefinitiveTrajectoryID': None,
#            'ExistenceKind': None,
#            'FacilityID': '54c6ee4e-8df9-46c5-80de-5a07814df658',
#            'FacilityName': 'NO 30/9-M-12 CHT3',
#            'FacilityTypeID': 'npequinor-dev:reference-data--FacilityType:Wellbore:',
#            'FluidDirectionID': None,
#            'GeoContexts': [{'BasinID': None,
#                             'FieldID': 'npequinor-dev:master-data--Field:c54463cc-708e-11ed-aa24-367dda495db0:',
#                             'GeoPoliticalEntityID': None,
#                             'GeoTypeID': 'Field',
#                             'PlayID': None,
#                             'ProspectID': None}],
#            'GeographicBottomHoleLocation.CoordinateQualityCheckPerformedBy': None,
#            'GeographicBottomHoleLocation.QualitativeSpatialAccuracyTypeID': None,
#            'GeographicBottomHoleLocation.QuantitativeAccuracyBandID': None,
#            'GeographicBottomHoleLocation.SpatialGeometryTypeID': None,
#            'GeographicBottomHoleLocation.SpatialParameterTypeID': None,
#            'InitialOperatorID': None,
#            'InterestTypeID': None,
#            'KickOffWellbore': None,
#            'OperatingEnvironmentID': None,
#            'OutcomeID': None,
#            'PrimaryMaterialID': None,
#            'PrimaryProductTypeID': None,
#            'ProjectedBottomHoleLocation.CoordinateQualityCheckPerformedBy': None,
#            'ProjectedBottomHoleLocation.QualitativeSpatialAccuracyTypeID': None,
#            'ProjectedBottomHoleLocation.QuantitativeAccuracyBandID': None,
#            'ProjectedBottomHoleLocation.SpatialGeometryTypeID': None,
#            'ProjectedBottomHoleLocation.SpatialParameterTypeID': None,
#            'ResourceCurationStatus': None,
#            'ResourceHomeRegionID': None,
#            'ResourceLifecycleStatus': None,
#            'ResourceSecurityClassification': None,
#            'RoleID': None,
#            'SecondaryProductTypeID': None,
#            'ShowProductTypeID': None,
#            'Source': None,
#            'SpatialLocation.CoordinateQualityCheckPerformedBy': None,
#            'SpatialLocation.QualitativeSpatialAccuracyTypeID': None,
#            'SpatialLocation.QuantitativeAccuracyBandID': None,
#            'SpatialLocation.SpatialGeometryTypeID': None,
#            'SpatialLocation.SpatialParameterTypeID': None,
#            'StatusSummaryID': None,
#            'TargetFormation': None,
#            'TechnicalAssuranceID': None,
#            'TechnicalAssuranceTypeID': None,
#            'TertiaryProductTypeID': None,
#            'TrajectoryTypeID': None,
#            'VersionCreationReason': None,
#            'VerticalMeasurements': [{'RigID': 'npequinor-dev:master-data--Rig:24e11596-279d-11ee-886a-bc6ee27abb91',
#                                      'VerticalCRSID': 'npequinor-dev:reference-data--CoordinateReferenceSystem:Vertical:EPSG::5715:',
#                                      'VerticalMeasurement': 56.0,
#                                      'VerticalMeasurementDescription': None,
#                                      'VerticalMeasurementID': 'Zero_Depth_Reference_Point',
#                                      'VerticalMeasurementPathID': 'npequinor-dev:reference-data--VerticalMeasurementPath:TrueVerticalDepth:',
#                                      'VerticalMeasurementSourceID': None,
#                                      'VerticalMeasurementTypeID': 'npequinor-dev:reference-data--VerticalMeasurementType:RotaryTable:',
#                                      'VerticalMeasurementUnitOfMeasureID': 'npequinor-dev:reference-data--UnitOfMeasure:m:',
#                                      'VerticalReferenceEntityID': None,
#                                      'VerticalReferenceID': None,
#                                      'WellboreTVDTrajectoryID': None}],
#            'VirtualProperties.DefaultLocation.CoordinateQualityCheckPerformedBy': None,
#            'VirtualProperties.DefaultLocation.QualitativeSpatialAccuracyTypeID': None,
#            'VirtualProperties.DefaultLocation.QuantitativeAccuracyBandID': None,
#            'VirtualProperties.DefaultLocation.SpatialGeometryTypeID': None,
#            'VirtualProperties.DefaultLocation.SpatialParameterTypeID': None,
#            'VirtualProperties.DefaultName': 'NO 30/9-M-12 CHT3',
#            'WasBusinessInterestFinancialNonOperated': None,
#            'WasBusinessInterestFinancialOperated': None,
#            'WasBusinessInterestObligatory': None,
#            'WasBusinessInterestTechnical': None,
#            'WellID': 'npequinor-dev:master-data--Well:e3586628-6ca7-11ed-9855-367dda495db0',
#            'WellboreTrajectoryTypeID': None},
#   'id': 'npequinor-dev:master-data--Wellbore:c9ef6728-36db-11ee-8346-8abc6a9a4945',
#   'kind': 'osdu:wks:master-data--Wellbore:1.1.0',
#   'legal': {'legaltags': ['npequinor-dev-equinor-private-default'],
#             'otherRelevantDataCountries': ['NO'],
#             'status': 'compliant'},
#   'modifyTime': '2023-08-16T02:41:50.521Z',
#   'modifyUser': '4cdd9a47-c1a2-4211-80ec-4b0af906e453',
#   'namespace': 'osdu:wks',
#   'source': 'wks',
#   'tags': {'EqnrSource': 'SMDA API',
#            'businessCriticalData': 'Not assessed yet',
#            'commitId': '109458dee75e49040de153558ca9e4a46fe14353',
#            'countryOfOrigin': 'NO',
#            'dataID': '552 556 560 525 548',
#            'exportControl': 'No',
#            'inside': 'No',
#            'intellectualPropertyRight': 'Not assessed yet',
#            'legalOwnership': 'Equinor solely',
#            'personalData': 'Yes, limited personal data',
#            'securityClassification': 'Internal',
#            'sensitivityFlag': 'null',
#            'sourceSystem': 'SMDA',
#            'soxCriticalData': 'No'},
#   'type': 'master-data--Wellbore',
#   'version': 1692153710166527},
#  {'acl': {'owners': ['data.osdudevops.owners@npequinor-dev.dataservices.energy',
#                      'data.masterdata.owners@npequinor-dev.dataservices.energy'],
#           'viewers': ['data.default.viewers@npequinor-dev.dataservices.energy']},
#   'ancestry': {'parents': ['npequinor-dev:wellheaders:442d3873-1081-4488-ba95-2da87d2b7b64:1691551037487273']},
#   'authority': 'osdu',
#   'createTime': '2023-08-09T13:06:32.599Z',
#   'createUser': '4cdd9a47-c1a2-4211-80ec-4b0af906e453',
#   'data': {'BusinessIntentionID': None,
#            'ConditionID': None,
#            'CurrentOperatorID': None,
#            'DataSourceOrganisationID': None,
#            'DefaultVerticalMeasurementID': 'Zero_Depth_Reference_Point',
#            'DefinitiveTrajectoryID': None,
#            'ExistenceKind': None,
#            'FacilityID': '442d3873-1081-4488-ba95-2da87d2b7b64',
#            'FacilityName': 'US 341112498400',
#            'FacilityTypeID': 'npequinor-dev:reference-data--FacilityType:Wellbore:',
#            'FluidDirectionID': None,
#            'GeographicBottomHoleLocation.CoordinateQualityCheckPerformedBy': None,
#            'GeographicBottomHoleLocation.QualitativeSpatialAccuracyTypeID': None,
#            'GeographicBottomHoleLocation.QuantitativeAccuracyBandID': None,
#            'GeographicBottomHoleLocation.SpatialGeometryTypeID': None,
#            'GeographicBottomHoleLocation.SpatialParameterTypeID': None,
#            'InitialOperatorID': None,
#            'InterestTypeID': None,
#            'KickOffWellbore': None,
#            'OperatingEnvironmentID': None,
#            'OutcomeID': None,
#            'PrimaryMaterialID': None,
#            'PrimaryProductTypeID': None,
#            'ProjectedBottomHoleLocation.CoordinateQualityCheckPerformedBy': None,
#            'ProjectedBottomHoleLocation.QualitativeSpatialAccuracyTypeID': None,
#            'ProjectedBottomHoleLocation.QuantitativeAccuracyBandID': None,
#            'ProjectedBottomHoleLocation.SpatialGeometryTypeID': None,
#            'ProjectedBottomHoleLocation.SpatialParameterTypeID': None,
#            'ResourceCurationStatus': None,
#            'ResourceHomeRegionID': None,
#            'ResourceLifecycleStatus': None,
#            'ResourceSecurityClassification': None,
#            'RoleID': None,
#            'SecondaryProductTypeID': None,
#            'ShowProductTypeID': None,
#            'Source': None,
#            'SpatialLocation.CoordinateQualityCheckPerformedBy': None,
#            'SpatialLocation.QualitativeSpatialAccuracyTypeID': None,
#            'SpatialLocation.QuantitativeAccuracyBandID': None,
#            'SpatialLocation.SpatialGeometryTypeID': None,
#            'SpatialLocation.SpatialParameterTypeID': None,
#            'StatusSummaryID': None,
#            'TargetFormation': None,
#            'TechnicalAssuranceID': None,
#            'TechnicalAssuranceTypeID': None,
#            'TertiaryProductTypeID': None,
#            'TrajectoryTypeID': None,
#            'VersionCreationReason': None,
#            'VerticalMeasurements': [{'RigID': None,
#                                      'VerticalCRSID': 'npequinor-dev:reference-data--CoordinateReferenceSystem:Vertical:EPSG::5715:',
#                                      'VerticalMeasurement': 1304.4,
#                                      'VerticalMeasurementDescription': None,
#                                      'VerticalMeasurementID': 'Zero_Depth_Reference_Point',
#                                      'VerticalMeasurementPathID': 'npequinor-dev:reference-data--VerticalMeasurementPath:TrueVerticalDepth:',
#                                      'VerticalMeasurementSourceID': None,
#                                      'VerticalMeasurementTypeID': 'npequinor-dev:reference-data--VerticalMeasurementType:KellyBushing:',
#                                      'VerticalMeasurementUnitOfMeasureID': 'npequinor-dev:reference-data--UnitOfMeasure:ft:',
#                                      'VerticalReferenceEntityID': None,
#                                      'VerticalReferenceID': None,
#                                      'WellboreTVDTrajectoryID': None}],
#            'VirtualProperties.DefaultLocation.CoordinateQualityCheckPerformedBy': None,
#            'VirtualProperties.DefaultLocation.QualitativeSpatialAccuracyTypeID': None,
#            'VirtualProperties.DefaultLocation.QuantitativeAccuracyBandID': None,
#            'VirtualProperties.DefaultLocation.SpatialGeometryTypeID': None,
#            'VirtualProperties.DefaultLocation.SpatialParameterTypeID': None,
#            'VirtualProperties.DefaultName': 'US 341112498400',
#            'WasBusinessInterestFinancialNonOperated': None,
#            'WasBusinessInterestFinancialOperated': None,
#            'WasBusinessInterestObligatory': None,
#            'WasBusinessInterestTechnical': None,
#            'WellID': 'npequinor-dev:master-data--Well:2f722cce-367e-11ee-8346-8abc6a9a4945',
#            'WellboreTrajectoryTypeID': None},
#   'id': 'npequinor-dev:master-data--Wellbore:83f0b1b2-36b5-11ee-8346-8abc6a9a4945',
#   'kind': 'osdu:wks:master-data--Wellbore:1.1.0',
#   'legal': {'legaltags': ['npequinor-dev-equinor-private-default'],
#             'otherRelevantDataCountries': ['NO'],
#             'status': 'compliant'},
#   'modifyTime': '2023-08-15T19:53:19.267Z',
#   'modifyUser': '4cdd9a47-c1a2-4211-80ec-4b0af906e453',
#   'namespace': 'osdu:wks',
#   'source': 'wks',
#   'tags': {'EqnrSource': 'SMDA API',
#            'businessCriticalData': 'Not assessed yet',
#            'commitId': '109458dee75e49040de153558ca9e4a46fe14353',
#            'countryOfOrigin': 'NO',
#            'dataID': '552 556 560 525 548',
#            'exportControl': 'No',
#            'inside': 'No',
#            'intellectualPropertyRight': 'Not assessed yet',
#            'legalOwnership': 'Equinor solely',
#            'personalData': 'Yes, limited personal data',
#            'securityClassification': 'Internal',
#            'sensitivityFlag': 'null',
#            'sourceSystem': 'SMDA',
#            'soxCriticalData': 'No'},
#   'type': 'master-data--Wellbore',
#   'version': 1692129198878939},
#  {'acl': {'owners': ['data.osdudevops.owners@npequinor-dev.dataservices.energy',
#                      'data.masterdata.owners@npequinor-dev.dataservices.energy'],
#           'viewers': ['data.default.viewers@npequinor-dev.dataservices.energy']},
#   'ancestry': {'parents': ['npequinor-dev:wellheaders:ae1f5bb3-c62b-417e-96e4-441675687df3:1691553821892540']},
#   'authority': 'osdu',
#   'createTime': '2023-08-03T09:42:34.689Z',
#   'createUser': '4cdd9a47-c1a2-4211-80ec-4b0af906e453',
#   'data': {'BusinessIntentionID': None,
#            'ConditionID': None,
#            'CurrentOperatorID': None,
#            'DataSourceOrganisationID': None,
#            'DefaultVerticalMeasurementID': 'Zero_Depth_Reference_Point',
#            'DefinitiveTrajectoryID': None,
#            'ExistenceKind': None,
#            'FacilityID': 'ae1f5bb3-c62b-417e-96e4-441675687df3',
#            'FacilityName': 'US 370152385100',
#            'FacilityTypeID': 'npequinor-dev:reference-data--FacilityType:Wellbore:',
#            'FluidDirectionID': None,
#            'GeographicBottomHoleLocation.CoordinateQualityCheckPerformedBy': None,
#            'GeographicBottomHoleLocation.QualitativeSpatialAccuracyTypeID': None,
#            'GeographicBottomHoleLocation.QuantitativeAccuracyBandID': None,
#            'GeographicBottomHoleLocation.SpatialGeometryTypeID': None,
#            'GeographicBottomHoleLocation.SpatialParameterTypeID': None,
#            'InitialOperatorID': None,
#            'InterestTypeID': None,
#            'KickOffWellbore': None,
#            'OperatingEnvironmentID': None,
#            'OutcomeID': None,
#            'PrimaryMaterialID': None,
#            'PrimaryProductTypeID': None,
#            'ProjectedBottomHoleLocation.CoordinateQualityCheckPerformedBy': None,
#            'ProjectedBottomHoleLocation.QualitativeSpatialAccuracyTypeID': None,
#            'ProjectedBottomHoleLocation.QuantitativeAccuracyBandID': None,
#            'ProjectedBottomHoleLocation.SpatialGeometryTypeID': None,
#            'ProjectedBottomHoleLocation.SpatialParameterTypeID': None,
#            'ResourceCurationStatus': None,
#            'ResourceHomeRegionID': None,
#            'ResourceLifecycleStatus': None,
#            'ResourceSecurityClassification': None,
#            'RoleID': None,
#            'SecondaryProductTypeID': None,
#            'ShowProductTypeID': None,
#            'Source': None,
#            'SpatialLocation.CoordinateQualityCheckPerformedBy': None,
#            'SpatialLocation.QualitativeSpatialAccuracyTypeID': None,
#            'SpatialLocation.QuantitativeAccuracyBandID': None,
#            'SpatialLocation.SpatialGeometryTypeID': None,
#            'SpatialLocation.SpatialParameterTypeID': None,
#            'StatusSummaryID': None,
#            'TargetFormation': None,
#            'TechnicalAssuranceID': None,
#            'TechnicalAssuranceTypeID': None,
#            'TertiaryProductTypeID': None,
#            'TrajectoryTypeID': None,
#            'VersionCreationReason': None,
#            'VerticalMeasurements': [{'RigID': None,
#                                      'VerticalCRSID': 'npequinor-dev:reference-data--CoordinateReferenceSystem:Vertical:EPSG::5715:',
#                                      'VerticalMeasurement': 953.0,
#                                      'VerticalMeasurementDescription': None,
#                                      'VerticalMeasurementID': 'Zero_Depth_Reference_Point',
#                                      'VerticalMeasurementPathID': 'npequinor-dev:reference-data--VerticalMeasurementPath:TrueVerticalDepth:',
#                                      'VerticalMeasurementSourceID': None,
#                                      'VerticalMeasurementTypeID': 'npequinor-dev:reference-data--VerticalMeasurementType:KellyBushing:',
#                                      'VerticalMeasurementUnitOfMeasureID': 'npequinor-dev:reference-data--UnitOfMeasure:ft:',
#                                      'VerticalReferenceEntityID': None,
#                                      'VerticalReferenceID': None,
#                                      'WellboreTVDTrajectoryID': None}],
#            'VirtualProperties.DefaultLocation.CoordinateQualityCheckPerformedBy': None,
#            'VirtualProperties.DefaultLocation.QualitativeSpatialAccuracyTypeID': None,
#            'VirtualProperties.DefaultLocation.QuantitativeAccuracyBandID': None,
#            'VirtualProperties.DefaultLocation.SpatialGeometryTypeID': None,
#            'VirtualProperties.DefaultLocation.SpatialParameterTypeID': None,
#            'VirtualProperties.DefaultName': 'US 370152385100',
#            'WasBusinessInterestFinancialNonOperated': None,
#            'WasBusinessInterestFinancialOperated': None,
#            'WasBusinessInterestObligatory': None,
#            'WasBusinessInterestTechnical': None,
#            'WellID': 'npequinor-dev:master-data--Well:8dd2be8e-3122-11ee-a93e-8abc6a9a4945',
#            'WellboreTrajectoryTypeID': None},
#   'id': 'npequinor-dev:master-data--Wellbore:0081b75e-31e2-11ee-a93e-8abc6a9a4945',
#   'kind': 'osdu:wks:master-data--Wellbore:1.1.0',
#   'legal': {'legaltags': ['npequinor-dev-equinor-private-default'],
#             'otherRelevantDataCountries': ['NO'],
#             'status': 'compliant'},
#   'modifyTime': '2023-08-10T06:24:27.475Z',
#   'modifyUser': '4cdd9a47-c1a2-4211-80ec-4b0af906e453',
#   'namespace': 'osdu:wks',
#   'source': 'wks',
#   'tags': {'EqnrSource': 'SMDA API',
#            'businessCriticalData': 'Not assessed yet',
#            'commitId': 'd9ab551f3190e8824b4b565704283840d7701d42',
#            'countryOfOrigin': 'NO',
#            'dataID': '552 556 560 525 548',
#            'exportControl': 'No',
#            'inside': 'No',
#            'intellectualPropertyRight': 'Not assessed yet',
#            'legalOwnership': 'Equinor solely',
#            'personalData': 'Yes, limited personal data',
#            'securityClassification': 'Internal',
#            'sensitivityFlag': 'null',
#            'sourceSystem': 'SMDA',
#            'soxCriticalData': 'No'},
#   'type': 'master-data--Wellbore',
#   'version': 1691648667382408}]
