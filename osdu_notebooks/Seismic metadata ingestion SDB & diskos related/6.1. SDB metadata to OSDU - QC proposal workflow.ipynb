# %%
"""
The ingestion has been done in two steps:
    1. SDB metadata into custom schemas to OSDU
    2. Osdu  custom schemas into OSDU well known schemas

Therefore, we must address any record incosistency (missing) encounter in these stpes versus what there is in SDB.

QC WORKFLOW:

    1. Request records from SDB
        1.1. Make visible inconsitencies in SDB like ids uniqueness/duplicates so that we know which many recors we must expect
        to be ingested into custom schemas. 
        ** --> If any inconsistency here we report to SDB/DISKOS
        
    2. Compare which unique records have been ingested into OSDU to custom schemas.
        ** --> If any inconsistency here we address it into the custom schema ingestion pipeline.
        
    3. Compare which recoirds from custom schemas have been transformed succesfully into wks records and which ones have not.
        Take custom (sdb original) records relationships here.
        ** --> If any inconsistency here we address it into the custom schema ingestion pipeline.
"""

## Maybe resquest all ids and connect them in power bi to see inconsistencies??
# Out:
# '\nThe ingestion has been done in two steps:\n    1. SDB metadata into custom schemas to OSDU\n    2. Osdu  custom schemas into OSDU well known schemas\n\nTherefore, we must address any record incosistency (missing) encounter in these stpes versus what there is in SDB.\n\nQC WORKFLOW:\n\n    1. Request records from SDB\n        1.1. Make visible inconsitencies in SDB like ids uniqueness/duplicates so that we know which many recors we must expect\n        to be ingested into custom schemas. \n        ** --> If any inconsistency here we report to SDB/DISKOS\n        \n    2. Compare which unique records have been ingested into OSDU to custom schemas.\n        ** --> If any inconsistency here we address it into the custom schema ingestion pipeline.\n        \n    3. Compare which recoirds from custom schemas have been transformed succesfully into wks records and which ones have not.\n        Take custom (sdb original) records relationships here.\n        ** --> If any inconsistency here we address it into the custom schema ingestion pipeline.\n'

# %%
"""Uncomment if running in Azure ML"""
import sys
sys.path.append(r'/mnt/batch/tasks/shared/LS_root/mounts/clusters/jopm/code/Users/JOPM/osdu_jopm_rottation')
sys.path

from utils.sdb_diskos_service import LandmarkService
from src.libs.osdu_service.osdu_http_client import OsduHttpClient
from dotenv import load_dotenv
import json
import os

load_dotenv()
# Out:
# True

# %%
"""
Utilities
"""

def unique_ids_counts(records, dimension):
    return list(set([record[dimension] for record in records]))

def get_non_unique_values(records, dimension):
    duplicates = []
    value_counts = {} 

    for record in records:
        value = record[dimension]
        value_counts[value] = value_counts.get(value, 0) + 1

    for value, count in value_counts.items():
        if count > 1:
            duplicates.append(value)

    return duplicates

def derive_osdu_id_from_source_record(record, entity_name):
    """
    Funtion intended to convert sdb/diskos unique ids into osdu unique ids to later compare them and
    check which are missing or have been removed.
    """

    schema_kind = entities.get(entity_name).get('relativePath')    
    id = f"{osdu_env}:{schema_kind}:{record[entities.get(entity_name).get('enitity_unique_identifier')]}"

    return id

def compare_dictionaries(dict1, dict2, path=""):
    
    diff = {}

    for key in dict1:
        new_path = f"{path}.{key}" if path else key
        if key not in dict2:
            diff[new_path] = {
                "record1_value": dict1[key],
                "record2_value": None
            }
        elif dict1[key] != dict2[key]:
            if isinstance(dict1[key], dict) and isinstance(dict2[key], dict):
                sub_diff = compare_dictionaries(dict1[key], dict2[key], new_path)
                diff.update(sub_diff)
            else:
                diff[new_path] = {
                    "record1_value": dict1[key],
                    "record2_value": dict2[key]
                }

    for key in dict2:
        new_path = f"{path}.{key}" if path else key
        if key not in dict1:
            diff[new_path] = {
                "record1_value": None,
                "record2_value": dict2[key]
            }

    return diff

# %% [markdown]
# #### 1. Get records from SDB

# %%
last_run_date_time = "2023-07-25T09:10:16.945Z"
last_run_date_time = None
query_records_created_prior_latsrundate = True

osdu_env = "npequinor-dev"
source = "sdb"
# source = "diskos"

osdu_client = OsduHttpClient(osdu_env, client_type="token-client")

# %%
entities = {
    "seismicsurveys": {
        # Attibutes to make the sourse API request
        "relativePath": "seismicsurveys",
        "filters_dict": {"surveyDimension": ["eq", "'3D'"]},
        "return_cols": ["surveyId"],
        "expand_on": None,
        "lastrundatetime": last_run_date_time,
        "before_rundate": query_records_created_prior_latsrundate,
        "enitity_unique_identifier": "surveyId",
        
        # Attributes to connect to osdu
        "custom_schema": f"eqnr:iEnergy-{source}:seismicsurveys:1.0.0",
        "osdu_well_known_schema": [
            "osdu:wks:master-data--SeismicAcquisitionSurvey:1.2.0"
        ]
    },
    "seismicpoststackdatasets": {
        # Attibutes to make the sourse API request
        "relativePath": "seismicpoststackdatasets",
        "filters_dict": {"surveyDimension": ["eq", "'3D'"]},
        "return_cols": ["seismicPoststackDatasetId"],
        "expand_on": None,
        "lastrundatetime": last_run_date_time,
        "before_rundate": query_records_created_prior_latsrundate,
        "enitity_unique_identifier": "seismicPoststackDatasetId",
        
        # Attributes to connect to osdu
        "custom_schema": f"eqnr:iEnergy-{source}:seismicpoststackdatasets:1.0.0",
        "osdu_well_known_schema": [
            "osdu:wks:dataset--FileCollection.SEGY:1.0.0",                    # --->> missing in ingestion workflow - to be fixed
            "osdu:wks:work-product-component--SeismicTraceData:1.3.0"
        ]
    },
    "poststackcubes": {
        # Attibutes to make the sourse API request
        "relativePath": "poststackcubes",
        "filters_dict": None,
        "return_cols": ["poststackCubeId"],
        "expand_on": None,
        "lastrundatetime": last_run_date_time,
        "before_rundate": query_records_created_prior_latsrundate,
        "enitity_unique_identifier": "poststackCubeId",
        
        # Attributes to connect to osdu
        "custom_schema": f"eqnr:iEnergy-{source}:poststackcubes:1.0.0",
        "osdu_well_known_schema": [
            "osdu:wks:work-product-component--SeismicTraceData:1.3.0"
        ]
    },
    "poststackcubegeometries": {
        # Attibutes to make the sourse API request
        "relativePath": "poststackcubegeometries",
        "filters_dict": None,
        "return_cols": ["poststackCubeId"],
        "expand_on": None,
        "lastrundatetime": last_run_date_time,
        "before_rundate": query_records_created_prior_latsrundate,
        "enitity_unique_identifier": "poststackCubeId",
        
        # Attributes to connect to osdu
        "custom_schema": f"eqnr:iEnergy-{source}:poststackcubegeometries:1.0.0",
        "osdu_well_known_schema": [
            "osdu:wks:work-product-component--SeismicTraceData:1.3.0",
            "osdu:wks:dataset--FileCollection.SEGY:1.0.0"
        ]
    },
    "seismicprojects": {
        # Attibutes to make the sourse API request
        "relativePath": "seismicprojects",
        "filters_dict": {"seismicDimension": ["eq", "'3D'"]},
        "return_cols": ["projectId"],
        "expand_on": None,
        "lastrundatetime": last_run_date_time,
        "before_rundate": query_records_created_prior_latsrundate,
        "enitity_unique_identifier": "projectId",
        
        # Attributes to connect to osdu
        "custom_schema": f"eqnr:iEnergy-{source}:seismicprojects:1.0.0",
        "osdu_well_known_schema": [
            "osdu:wks:master-data--SeismicProcessingProject:1.2.0"
        ],
    },
    "navigationsets": {
        # Attibutes to make the sourse API request
        "relativePath": "navigationsets",
        "filters_dict": {"surveyDimension": ["eq", "'3D'"]},
        "return_cols": ["navigationSetId"],
        "expand_on": None,
        "lastrundatetime": last_run_date_time,
        "before_rundate": query_records_created_prior_latsrundate,
        "enitity_unique_identifier": "navigationSetId",
        
        # Attributes to connect to osdu
        "custom_schema": f"eqnr:iEnergy-{source}:navigationsets:1.0.0",
        "osdu_well_known_schema": [
            "osdu:wks:dataset--FileCollection.Generic:1.0.0"                      # --->> Issue they do not have ancestry custom records in DEV - Uncomment if running in test
        ]
    },
    "binsetgrids": {
        # Attibutes to make the sourse API request
        "relativePath": "binsetgrids",
        "filters_dict": None,
        "return_cols": ["binsetGrid3dId"],
        "expand_on": None,
        "lastrundatetime": last_run_date_time,
        "before_rundate": query_records_created_prior_latsrundate,
        "enitity_unique_identifier": "binsetGrid3dId",
        
        # Attributes to connect to osdu
        "custom_schema": f"eqnr:iEnergy-{source}:binsetgrids:1.0.0",
        "osdu_well_known_schema": [
            "osdu:wks:work-product-component--SeismicBinGrid:1.0.0"               # --->> Issue they do not have ancestry custom records in DEV - Uncomment if running in test
        ]
    }
}

# %%
"""
Requesting records from source system.
"""

sdb_records = dict()

with LandmarkService(os.environ[f"{source}_metadata_url"], os.environ[f"{source}_ds_security_url"], os.environ[f"{source}_refresh_token"]) as landmark:
    
    for entity_name in entities:
        records = landmark.get_records(**entities.get(entity_name))
        sdb_records[entity_name] = records

    ## TODO: Leave the query by batch option commented out as it might be needed when we switch into requesting data from DISKOS (larger data)
# Out:
# WARNING:root:Sending request to: https://ndrapi.dsif.dazlmkeqnprd04.ienergycloud.solutions/dsdataserver/dsl.svc/NDRAPI/1/NDR-SDM/ALL_PROJECTS/seismicsurveys?$format=json&$filter=surveyDimension eq '3D'&$select=surveyId&$inlinecount=allpages
# WARNING:root:Sending request to: https://ndrapi.dsif.dazlmkeqnprd04.ienergycloud.solutions/dsdataserver/dsl.svc/NDRAPI/1/NDR-SDM/ALL_PROJECTS/seismicpoststackdatasets?$format=json&$filter=surveyDimension eq '3D'&$select=seismicPoststackDatasetId&$inlinecount=allpages
# WARNING:root:Sending request to: https://ndrapi.dsif.dazlmkeqnprd04.ienergycloud.solutions/dsdataserver/dsl.svc/NDRAPI/1/NDR-SDM/ALL_PROJECTS/poststackcubes?$format=json&$select=poststackCubeId&$inlinecount=allpages
# WARNING:root:Sending request to: https://ndrapi.dsif.dazlmkeqnprd04.ienergycloud.solutions/dsdataserver/dsl.svc/NDRAPI/1/NDR-SDM/ALL_PROJECTS/poststackcubegeometries?$format=json&$select=poststackCubeId&$inlinecount=allpages
# WARNING:root:Sending request to: https://ndrapi.dsif.dazlmkeqnprd04.ienergycloud.solutions/dsdataserver/dsl.svc/NDRAPI/1/NDR-SDM/ALL_PROJECTS/seismicprojects?$format=json&$filter=seismicDimension eq '3D'&$select=projectId&$inlinecount=allpages
# WARNING:root:Sending request to: https://ndrapi.dsif.dazlmkeqnprd04.ienergycloud.solutions/dsdataserver/dsl.svc/NDRAPI/1/NDR-SDM/ALL_PROJECTS/navigationsets?$format=json&$filter=surveyDimension eq '3D'&$select=navigationSetId&$inlinecount=allpages
# WARNING:root:Sending request to: https://ndrapi.dsif.dazlmkeqnprd04.ienergycloud.solutions/dsdataserver/dsl.svc/NDRAPI/1/NDR-SDM/ALL_PROJECTS/binsetgrids?$format=json&$select=binsetGrid3dId&$inlinecount=allpages

# %%
"""2. Records ids uniqueness"""

entities_names = list(entities.keys())
entities_unique_identifiers = list([entity.get('enitity_unique_identifier') for entity in entities.values()])

ids_counts = dict()
for pair in list(zip(entities_names, entities_unique_identifiers)):
    ids_counts[pair[0]] = len(unique_ids_counts(sdb_records[pair[0]], pair[1]))
    
for key in ids_counts.keys():
    print(f"Entity: {key} has {len(sdb_records[key])} records, from which {ids_counts[key]} are have unique identifiers (ids)")
# Out:
# Entity: seismicsurveys has 1975 records, from which 1975 are have unique identifiers (ids)
# Entity: seismicpoststackdatasets has 19464 records, from which 19452 are have unique identifiers (ids)
# Entity: poststackcubes has 19383 records, from which 19371 are have unique identifiers (ids)
# Entity: poststackcubegeometries has 19383 records, from which 19371 are have unique identifiers (ids)
# Entity: seismicprojects has 2403 records, from which 2403 are have unique identifiers (ids)
# Entity: navigationsets has 3248 records, from which 3248 are have unique identifiers (ids)
# Entity: binsetgrids has 2143 records, from which 2143 are have unique identifiers (ids)

# %%
"""
2. Records ids uniqueness.
Let's find the non-unique ids for each entity.
"""

def get_non_unique_values(records, dimension):
    duplicates = []
    value_counts = {} 

    for record in records:
        value = record[dimension]
        value_counts[value] = value_counts.get(value, 0) + 1

    for value, count in value_counts.items():
        if count > 1:
            duplicates.append(value)

    return duplicates

ids_duplicates = dict()
for pair in list(zip(entities_names, entities_unique_identifiers)):
    ids_duplicates[pair[0]] = get_non_unique_values(sdb_records[pair[0]], pair[1])
    
for key in ids_duplicates.keys():
    print(f"Entity: {key} - Duplicated ids: {ids_duplicates[key]}")
# Out:
# Entity: seismicsurveys - Duplicated ids: []
# Entity: seismicpoststackdatasets - Duplicated ids: ['31361036', '31361032', '31361024', '31361022', '31361018', '31361016', '31361037', '31361033', '31361025', '31361023', '31361019', '31361017']
# Entity: poststackcubes - Duplicated ids: ['1657858064', '1657858063', '1657858062', '1657858061', '1657858070', '1657858069', '1657858068', '1657858067', '1657858082', '1657858081', '1657858078', '1657858077']
# Entity: poststackcubegeometries - Duplicated ids: ['1657858064', '1657858063', '1657858062', '1657858061', '1657858070', '1657858069', '1657858068', '1657858067', '1657858082', '1657858081', '1657858078', '1657858077']
# Entity: seismicprojects - Duplicated ids: []
# Entity: navigationsets - Duplicated ids: []
# Entity: binsetgrids - Duplicated ids: []

# %% [markdown]
# #### 2. Get records from OSDU - custom schemas

# %%
"""
Let's first request the custom records from OSDU and store them in a dictionary.
"""

osdu_ingested_custom_records = dict()

for entity in entities.keys():
    
    schema_kind = entities.get(entity).get("custom_schema")
    print(f"---- Working on entity: {entity} of custom schema kind: {schema_kind} ----")
    
    search_payload =  {
        "kind": schema_kind,
        "returnedFields": ["id"]
    }
    osdu_cutom_records = osdu_client.app_query_returning_json("search/v2/query_with_cursor", search_payload)
    osdu_ingested_custom_records[entity] = osdu_cutom_records

    print(f"> Retrieved {len(osdu_cutom_records)} records from OSDU of kind {schema_kind} \n")
# Out:
# ---- Working on entity: seismicsurveys of custom schema kind: eqnr:iEnergy-sdb:seismicsurveys:1.0.0 ----
# > Retrieved 1971 records from OSDU of kind eqnr:iEnergy-sdb:seismicsurveys:1.0.0
#
# ---- Working on entity: seismicpoststackdatasets of custom schema kind: eqnr:iEnergy-sdb:seismicpoststackdatasets:1.0.0 ----
# > Retrieved 18886 records from OSDU of kind eqnr:iEnergy-sdb:seismicpoststackdatasets:1.0.0
#
# ---- Working on entity: poststackcubes of custom schema kind: eqnr:iEnergy-sdb:poststackcubes:1.0.0 ----
# > Retrieved 18828 records from OSDU of kind eqnr:iEnergy-sdb:poststackcubes:1.0.0
#
# ---- Working on entity: poststackcubegeometries of custom schema kind: eqnr:iEnergy-sdb:poststackcubegeometries:1.0.0 ----
# > Retrieved 18824 records from OSDU of kind eqnr:iEnergy-sdb:poststackcubegeometries:1.0.0
#
# ---- Working on entity: seismicprojects of custom schema kind: eqnr:iEnergy-sdb:seismicprojects:1.0.0 ----
# > Retrieved 2401 records from OSDU of kind eqnr:iEnergy-sdb:seismicprojects:1.0.0
#
# ---- Working on entity: navigationsets of custom schema kind: eqnr:iEnergy-sdb:navigationsets:1.0.0 ----
# > Retrieved 3245 records from OSDU of kind eqnr:iEnergy-sdb:navigationsets:1.0.0
#
# ---- Working on entity: binsetgrids of custom schema kind: eqnr:iEnergy-sdb:binsetgrids:1.0.0 ----
# > Retrieved 2142 records from OSDU of kind eqnr:iEnergy-sdb:binsetgrids:1.0.0
# Bad pipe message: %s [b'\xdd\xba*\x1d\x13rF&\xfaD8w ]}\xcff\xa7 h\xf0n\xdf\xab\xe5\x04\x06\x86\xbb\n\xc9E\xc2\x9fz\x82\xde25\x07Bn\x8c\x90Tz\x08\x9c\xf3\xb1\x1d\x00\x08\x13\x02\x13\x03\x13\x01\x00\xff\x01\x00\x00\x8f\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x00\x1e\x00\x1c\x04\x03\x05\x03\x06\x03\x08\x07\x08\x08\x08\t\x08\n\x08\x0b\x08\x04\x08\x05\x08\x06\x04\x01\x05\x01\x06\x01\x00+\x00\x03\x02\x03\x04\x00-\x00\x02\x01\x01\x003\x00&\x00$\x00\x1d\x00 \x98\x99\xad\x9b']
# Bad pipe message: %s [b'\xd2\xc0\xa2H\x88m]\ny\xc8\xa5-q\xec\x93!\x13\xcd\x00\x00\xa6\xc0,\xc00\x00\xa3\x00\x9f\xcc\xa9\xcc\xa8\xcc\xaa\xc0\xaf\xc0\xad', b"\xc0\x9f\xc0]\xc0a\xc0W\xc0S\xc0+\xc0/\x00\xa2\x00\x9e\xc0\xae\xc0\xac\xc0\xa2\xc0\x9e\xc0\\\xc0`\xc0V\xc0R\xc0$\xc0(\x00k\x00j\xc0s\xc0w\x00\xc4\x00\xc3\xc0#\xc0'\x00g\x00@\xc0r\xc0v\x00\xbe\x00\xbd\xc0\n\xc0\x14\x009\x008\x00\x88\x00\x87\xc0\t\xc0\x13\x003\x002\x00\x9a\x00\x99\x00E\x00D\xc0\x07\xc0\x11\xc0\x08\xc0\x12\x00\x16\x00\x13\x00\x9d\xc0\xa1\xc0\x9d\xc0Q\x00\x9c\xc0\xa0\xc0\x9c\xc0P\x00=\x00\xc0\x00<\x00\xba\x005\x00\x84\x00/\x00\x96\x00A\x00\x05\x00\n\x00\xff\x01\x00\x00j\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00", b'#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x000\x00.\x04\x03\x05\x03\x06\x03']
# Bad pipe message: %s [b'\x08\x08\x08\t\x08\n\x08', b'\x04\x08\x05\x08\x06\x04\x01\x05\x01\x06']
# Bad pipe message: %s [b'', b'\x03\x03']
# Bad pipe message: %s [b'']
# Bad pipe message: %s [b'', b'\x02']
# Bad pipe message: %s [b'\x05\x02\x06']
# Bad pipe message: %s [b'~H\xa3\xc1\x83\x87\x10[o']
# Bad pipe message: %s [b'\x1d\xb6\n\x98\x1c\xb5\xbe\x00\x00>\xc0\x14\xc0\n\x009\x008\x007\x006\xc0\x0f\xc0\x05\x005\xc0\x13\xc0\t\x003\x002\x001\x000\xc0\x0e\xc0\x04\x00/\x00\x9a\x00\x99\x00\x98\x00\x97\x00\x96\x00\x07\xc0\x11\xc0\x07\xc0\x0c\xc0\x02\x00\x05\x00\x04\x00\xff\x02\x01\x00\x00C\x00\x00\x00\x0e\x00\x0c\x00\x00\t12']
# Bad pipe message: %s [b'0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x1c\x00\x1a\x00\x17\x00\x19\x00\x1c\x00\x1b\x00\x18\x00\x1a\x00\x16\x00\x0e\x00\r\x00\x0b\x00\x0c\x00\t\x00\n\x00#\x00\x00\x00\x0f\x00\x01\x01']
# Bad pipe message: %s [b'#\x14L\x8aq8\x89.\xb2qd\x98\x14\x053M8q\x00\x00>\xc0\x14\xc0\n\x009\x008\x007\x006\xc0\x0f\xc0\x05\x005\xc0\x13\xc0\t\x003\x002\x001\x000\xc0\x0e\xc0\x04\x00/\x00\x9a\x00\x99\x00\x98\x00\x97\x00\x96\x00\x07\xc0\x11\xc0\x07\xc0\x0c\xc0\x02\x00\x05\x00\x04\x00\xff\x02\x01\x00\x00C\x00\x00\x00\x0e\x00\x0c\x00\x00']
# Bad pipe message: %s [b'\x11\x0c\xcf\xbb\xbd\xa1\x86\xd6\x94\xafw\xe6\x83\xa88\x95\xfeS\x00\x00\xa2\xc0\x14\xc0\n\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00:\x00\x89\xc0\x0f\xc0\x05\x005\x00\x84\xc0\x13\xc0\t\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0']
# Bad pipe message: %s [b'4\x00\x9b\x00F\xc0\x0e\xc0\x04\x00/\x00\x96\x00A\x00\x07\xc0\x11\xc0\x07\xc0\x16']
# Bad pipe message: %s [b'\xdbo\xcdr', b"\x1d\x14\x1f\x1c\xa3g\xe4\xff\x9c\xecOK\x00\x00\x86\xc00\xc0,\xc0(\xc0$\xc0\x14\xc0\n\x00\xa5\x00\xa3\x00\xa1\x00\x9f\x00k\x00j\x00i\x00h\x009\x008\x007\x006\xc02\xc0.\xc0*\xc0&\xc0\x0f\xc0\x05\x00\x9d\x00=\x005\xc0/\xc0+\xc0'\xc0#\xc0\x13\xc0\t\x00\xa4\x00\xa2\x00\xa0\x00\x9e\x00g\x00@\x00?\x00>\x003\x002\x001\x000\xc01\xc0-\xc0)\xc0%\xc0\x0e\xc0\x04\x00\x9c\x00<\x00/\x00\x9a\x00\x99\x00\x98\x00\x97\x00\x96\x00\x07\xc0\x11\xc0\x07\xc0\x0c\xc0\x02\x00\x05\x00\x04\x00\xff\x02\x01\x00\x00g\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x1c\x00\x1a\x00\x17\x00\x19\x00\x1c\x00\x1b\x00\x18\x00\x1a\x00\x16\x00\x0e\x00\r\x00\x0b\x00\x0c\x00\t\x00\n\x00#\x00\x00\x00\r\x00 \x00\x1e\x06\x01\x06\x02\x06\x03\x05\x01\x05\x02\x05\x03\x04\x01\x04"]
# Bad pipe message: %s [b'\x03']
# Bad pipe message: %s [b'\x03\x02', b'\x02\x01', b'\x02']
# Bad pipe message: %s [b'\x0f\x00']
# Bad pipe message: %s [b"\xd8y\x13o \xaeu\x8a\xcc\x16I\x8b\x15\x19w\\\x9d2\x00\x00\xf4\xc00\xc0,\xc0(\xc0$\xc0\x14\xc0\n\x00\xa5\x00\xa3\x00\xa1\x00\x9f\x00k\x00j\x00i\x00h\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00\xa7\x00m\x00:\x00\x89\xc02\xc0.\xc0*\xc0&\xc0\x0f\xc0\x05\x00\x9d\x00=\x005\x00\x84\xc0/\xc0+\xc0'\xc0#\xc0\x13\xc0\t\x00\xa4\x00\xa2\x00\xa0\x00\x9e\x00g\x00@\x00?\x00>\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x00\xa6\x00l\x004\x00\x9b\x00F\xc01\xc0-\xc0)\xc0%\xc0\x0e\xc0\x04\x00\x9c\x00<\x00/\x00\x96\x00A\x00\x07\xc0\x11\xc0\x07\xc0\x16\x00\x18\xc0\x0c\xc0\x02\x00\x05\x00\x04\xc0\x12\xc0\x08\x00\x16\x00\x13\x00\x10\x00\r\xc0\x17\x00\x1b\xc0\r\xc0\x03\x00\n\x00\x15\x00"]
# Bad pipe message: %s [b'\x0f\x00\x0c\x00\x1a\x00\t\x00\x14\x00\x11\x00\x19\x00\x08\x00\x06']

# %%
"""
Let's find out which record ids from the source (SDB or DISKOS) are missing in the OSDU custom schemas and the other way around.
"""

sdb_osdu_unique_ids_custom_records = dict()

for pair in list(zip(entities_names, entities_unique_identifiers)):
    entity_name = pair[0]
    entities_unique_identifier = pair[1]

    print(f"Comparing {entity_name} entity {source.upper()} source records versus OSDU cutom records")
    
    original_records_source = sdb_records.get(entity_name)
    original_records_source_unique = list(set([record.get(entities_unique_identifier) for record in original_records_source]))
    osdu_records_derived_from_source = list(set([derive_osdu_id_from_source_record(record, entity_name) for record in original_records_source]))

    ingested_records_osdu = [record.get('id') for record in osdu_ingested_custom_records.get(entity_name)]
    common_record_ids = list(set(osdu_records_derived_from_source).intersection(ingested_records_osdu))

    missing_in_osdu = [record for record in osdu_records_derived_from_source if record not in ingested_records_osdu]
    missing_in_source = [record for record in ingested_records_osdu if record not in osdu_records_derived_from_source]
    
    sdb_osdu_unique_ids_custom_records[entity_name] = {
        "Source records count": len(original_records_source),
        "Source unique records ids count": len(original_records_source_unique),
        "OSDU custom ingested unique ids count": len(ingested_records_osdu),
        "Common records count (source-custom)": len(common_record_ids),
        "Ingeted into OSDU (custom) but missing in source": {
            "count": len(missing_in_source),
            "ids": missing_in_source
        },
        "Present in source but missing in OSDU (custom)": {
            "count": len(missing_in_osdu),
            "ids": missing_in_osdu
        }
    }
# Out:
# Comparing seismicsurveys entity SDB source records versus OSDU cutom records
# Comparing seismicpoststackdatasets entity SDB source records versus OSDU cutom records
# Comparing poststackcubes entity SDB source records versus OSDU cutom records
# Comparing poststackcubegeometries entity SDB source records versus OSDU cutom records
# Comparing seismicprojects entity SDB source records versus OSDU cutom records
# Comparing navigationsets entity SDB source records versus OSDU cutom records
# Comparing binsetgrids entity SDB source records versus OSDU cutom records

# %%
print(json.dumps(sdb_osdu_unique_ids_custom_records, indent=4))
# Out:
# {
#     "seismicsurveys": {
#         "Source records count": 1975,
#         "Source unique records ids count": 1975,
#         "OSDU custom ingested unique ids count": 1971,
#         "Common records count (source-custom)": 1971,
#         "Ingeted into OSDU (custom) but missing in source": {
#             "count": 0,
#             "ids": []
#         },
#         "Present in source but missing in OSDU (custom)": {
#             "count": 4,
#             "ids": [
#                 "npequinor-dev:seismicsurveys:1518672454",
#                 "npequinor-dev:seismicsurveys:1518355860",
#                 "npequinor-dev:seismicsurveys:1518607427",
#                 "npequinor-dev:seismicsurveys:1518815961"
#             ]
#         }
#     },
#     "seismicpoststackdatasets": {
#         "Source records count": 19464,
#         "Source unique records ids count": 19452,
#         "OSDU custom ingested unique ids count": 18886,
#         "Common records count (source-custom)": 18875,
#         "Ingeted into OSDU (custom) but missing in source": {
#             "count": 11,
#             "ids": [
#                 "npequinor-dev:seismicpoststackdatasets:1507739908",
#                 "npequinor-dev:seismicpoststackdatasets:1512424188",
#                 "npequinor-dev:seismicpoststackdatasets:1513243199",
#                 "npequinor-dev:seismicpoststackdatasets:1509101910",
#                 "npequinor-dev:seismicpoststackdatasets:1509706310",
#                 "npequinor-dev:seismicpoststackdatasets:1509347977",
#                 "npequinor-dev:seismicpoststackdatasets:1510915519",
#                 "npequinor-dev:seismicpoststackdatasets:1509279074",
#                 "npequinor-dev:seismicpoststackdatasets:1510915524",
#                 "npequinor-dev:seismicpoststackdatasets:1511110884",
#                 "npequinor-dev:seismicpoststackdatasets:1510264906"
#             ]
#         },
#         "Present in source but missing in OSDU (custom)": {
#             "count": 577,
#             "ids": [
#                 "npequinor-dev:seismicpoststackdatasets:1521150705",
#                 "npequinor-dev:seismicpoststackdatasets:1521585262",
#                 "npequinor-dev:seismicpoststackdatasets:1520450638",
#                 "npequinor-dev:seismicpoststackdatasets:1521944440",
#                 "npequinor-dev:seismicpoststackdatasets:1519040620",
#                 "npequinor-dev:seismicpoststackdatasets:1518434210",
#                 "npequinor-dev:seismicpoststackdatasets:1519141832",
#                 "npequinor-dev:seismicpoststackdatasets:1518560012",
#                 "npequinor-dev:seismicpoststackdatasets:1520262785",
#                 "npequinor-dev:seismicpoststackdatasets:1521284432",
#                 "npequinor-dev:seismicpoststackdatasets:1519714663",
#                 "npequinor-dev:seismicpoststackdatasets:1521396149",
#                 "npequinor-dev:seismicpoststackdatasets:1518459005",
#                 "npequinor-dev:seismicpoststackdatasets:1520815240",
#                 "npequinor-dev:seismicpoststackdatasets:1520328883",
#                 "npequinor-dev:seismicpoststackdatasets:1518441018",
#                 "npequinor-dev:seismicpoststackdatasets:1521223491",
#                 "npequinor-dev:seismicpoststackdatasets:1520890576",
#                 "npequinor-dev:seismicpoststackdatasets:1519990064",
#                 "npequinor-dev:seismicpoststackdatasets:1522086670",
#                 "npequinor-dev:seismicpoststackdatasets:1519988244",
#                 "npequinor-dev:seismicpoststackdatasets:1519099851",
#                 "npequinor-dev:seismicpoststackdatasets:1519197037",
#                 "npequinor-dev:seismicpoststackdatasets:1520366625",
#                 "npequinor-dev:seismicpoststackdatasets:1520910252",
#                 "npequinor-dev:seismicpoststackdatasets:1520966500",
#                 "npequinor-dev:seismicpoststackdatasets:1520804272",
#                 "npequinor-dev:seismicpoststackdatasets:1518327261",
#                 "npequinor-dev:seismicpoststackdatasets:1519857037",
#                 "npequinor-dev:seismicpoststackdatasets:1521706462",
#                 "npequinor-dev:seismicpoststackdatasets:1519330703",
#                 "npequinor-dev:seismicpoststackdatasets:1519878820",
#                 "npequinor-dev:seismicpoststackdatasets:1520350469",
#                 "npequinor-dev:seismicpoststackdatasets:1519286606",
#                 "npequinor-dev:seismicpoststackdatasets:1520033469",
#                 "npequinor-dev:seismicpoststackdatasets:1520172069",
#                 "npequinor-dev:seismicpoststackdatasets:1521167200",
#                 "npequinor-dev:seismicpoststackdatasets:1518823894",
#                 "npequinor-dev:seismicpoststackdatasets:1518512199",
#                 "npequinor-dev:seismicpoststackdatasets:1520518511",
#                 "npequinor-dev:seismicpoststackdatasets:1521566419",
#                 "npequinor-dev:seismicpoststackdatasets:1520486325",
#                 "npequinor-dev:seismicpoststackdatasets:1519787920",
#                 "npequinor-dev:seismicpoststackdatasets:1521490574",
#                 "npequinor-dev:seismicpoststackdatasets:1519481249",
#                 "npequinor-dev:seismicpoststackdatasets:1518904068",
#                 "npequinor-dev:seismicpoststackdatasets:1519025092",
#                 "npequinor-dev:seismicpoststackdatasets:1520851259",
#                 "npequinor-dev:seismicpoststackdatasets:1521199882",
#                 "npequinor-dev:seismicpoststackdatasets:1518577927",
#                 "npequinor-dev:seismicpoststackdatasets:1520324160",
#                 "npequinor-dev:seismicpoststackdatasets:1521314498",
#                 "npequinor-dev:seismicpoststackdatasets:1518215897",
#                 "npequinor-dev:seismicpoststackdatasets:1519701620",
#                 "npequinor-dev:seismicpoststackdatasets:1521698734",
#                 "npequinor-dev:seismicpoststackdatasets:1518331843",
#                 "npequinor-dev:seismicpoststackdatasets:1521700495",
#                 "npequinor-dev:seismicpoststackdatasets:1520808536",
#                 "npequinor-dev:seismicpoststackdatasets:1521788198",
#                 "npequinor-dev:seismicpoststackdatasets:1521827775",
#                 "npequinor-dev:seismicpoststackdatasets:1519863383",
#                 "npequinor-dev:seismicpoststackdatasets:1521461540",
#                 "npequinor-dev:seismicpoststackdatasets:1520946416",
#                 "npequinor-dev:seismicpoststackdatasets:1521338592",
#                 "npequinor-dev:seismicpoststackdatasets:1519308108",
#                 "npequinor-dev:seismicpoststackdatasets:1518623117",
#                 "npequinor-dev:seismicpoststackdatasets:1519926655",
#                 "npequinor-dev:seismicpoststackdatasets:1521524211",
#                 "npequinor-dev:seismicpoststackdatasets:1518249082",
#                 "npequinor-dev:seismicpoststackdatasets:1520122869",
#                 "npequinor-dev:seismicpoststackdatasets:1521345439",
#                 "npequinor-dev:seismicpoststackdatasets:1518219589",
#                 "npequinor-dev:seismicpoststackdatasets:1520555461",
#                 "npequinor-dev:seismicpoststackdatasets:1519211664",
#                 "npequinor-dev:seismicpoststackdatasets:1521078867",
#                 "npequinor-dev:seismicpoststackdatasets:1519624527",
#                 "npequinor-dev:seismicpoststackdatasets:1521784406",
#                 "npequinor-dev:seismicpoststackdatasets:1520672166",
#                 "npequinor-dev:seismicpoststackdatasets:1519558363",
#                 "npequinor-dev:seismicpoststackdatasets:1519047008",
#                 "npequinor-dev:seismicpoststackdatasets:1522024790",
#                 "npequinor-dev:seismicpoststackdatasets:1519019916",
#                 "npequinor-dev:seismicpoststackdatasets:1522014745",
#                 "npequinor-dev:seismicpoststackdatasets:1521052211",
#                 "npequinor-dev:seismicpoststackdatasets:1521234455",
#                 "npequinor-dev:seismicpoststackdatasets:1521074349",
#                 "npequinor-dev:seismicpoststackdatasets:1522319655",
#                 "npequinor-dev:seismicpoststackdatasets:1521179718",
#                 "npequinor-dev:seismicpoststackdatasets:1521786302",
#                 "npequinor-dev:seismicpoststackdatasets:1519930295",
#                 "npequinor-dev:seismicpoststackdatasets:1518981264",
#                 "npequinor-dev:seismicpoststackdatasets:1520432181",
#                 "npequinor-dev:seismicpoststackdatasets:1521684284",
#                 "npequinor-dev:seismicpoststackdatasets:1522028588",
#                 "npequinor-dev:seismicpoststackdatasets:1521593726",
#                 "npequinor-dev:seismicpoststackdatasets:1518252774",
#                 "npequinor-dev:seismicpoststackdatasets:1518286216",
#                 "npequinor-dev:seismicpoststackdatasets:1520357229",
#                 "npequinor-dev:seismicpoststackdatasets:1521869148",
#                 "npequinor-dev:seismicpoststackdatasets:1519933935",
#                 "npequinor-dev:seismicpoststackdatasets:1520499782",
#                 "npequinor-dev:seismicpoststackdatasets:1518485240",
#                 "npequinor-dev:seismicpoststackdatasets:1518437614",
#                 "npequinor-dev:seismicpoststackdatasets:1518933758",
#                 "npequinor-dev:seismicpoststackdatasets:1521809299",
#                 "npequinor-dev:seismicpoststackdatasets:1521872522",
#                 "npequinor-dev:seismicpoststackdatasets:1518553547",
#                 "npequinor-dev:seismicpoststackdatasets:1521497261",
#                 "npequinor-dev:seismicpoststackdatasets:1519848869",
#                 "npequinor-dev:seismicpoststackdatasets:1521171064",
#                 "npequinor-dev:seismicpoststackdatasets:1518290154",
#                 "npequinor-dev:seismicpoststackdatasets:1521277688",
#                 "npequinor-dev:seismicpoststackdatasets:1521086128",
#                 "npequinor-dev:seismicpoststackdatasets:1519877000",
#                 "npequinor-dev:seismicpoststackdatasets:1520744927",
#                 "npequinor-dev:seismicpoststackdatasets:1519322474",
#                 "npequinor-dev:seismicpoststackdatasets:1520896866",
#                 "npequinor-dev:seismicpoststackdatasets:1518556210",
#                 "npequinor-dev:seismicpoststackdatasets:1520279843",
#                 "npequinor-dev:seismicpoststackdatasets:1521289667",
#                 "npequinor-dev:seismicpoststackdatasets:1519256873",
#                 "npequinor-dev:seismicpoststackdatasets:1521757737",
#                 "npequinor-dev:seismicpoststackdatasets:1519027522",
#                 "npequinor-dev:seismicpoststackdatasets:1520122911",
#                 "npequinor-dev:seismicpoststackdatasets:1522279577",
#                 "npequinor-dev:seismicpoststackdatasets:1519948660",
#                 "npequinor-dev:seismicpoststackdatasets:1520680710",
#                 "npequinor-dev:seismicpoststackdatasets:1519768948",
#                 "npequinor-dev:seismicpoststackdatasets:1518962416",
#                 "npequinor-dev:seismicpoststackdatasets:1521145117",
#                 "npequinor-dev:seismicpoststackdatasets:1519932115",
#                 "npequinor-dev:seismicpoststackdatasets:1518827580",
#                 "npequinor-dev:seismicpoststackdatasets:1521807439",
#                 "npequinor-dev:seismicpoststackdatasets:1520843376",
#                 "npequinor-dev:seismicpoststackdatasets:1520175574",
#                 "npequinor-dev:seismicpoststackdatasets:1521107163",
#                 "npequinor-dev:seismicpoststackdatasets:1519855215",
#                 "npequinor-dev:seismicpoststackdatasets:1521042534",
#                 "npequinor-dev:seismicpoststackdatasets:1520991355",
#                 "npequinor-dev:seismicpoststackdatasets:1520984609",
#                 "npequinor-dev:seismicpoststackdatasets:1519844327",
#                 "npequinor-dev:seismicpoststackdatasets:1520112656",
#                 "npequinor-dev:seismicpoststackdatasets:1518846382",
#                 "npequinor-dev:seismicpoststackdatasets:1519672835",
#                 "npequinor-dev:seismicpoststackdatasets:1519014740",
#                 "npequinor-dev:seismicpoststackdatasets:1522046653",
#                 "npequinor-dev:seismicpoststackdatasets:1521374317",
#                 "npequinor-dev:seismicpoststackdatasets:1519503475",
#                 "npequinor-dev:seismicpoststackdatasets:1521540832",
#                 "npequinor-dev:seismicpoststackdatasets:1519990207",
#                 "npequinor-dev:seismicpoststackdatasets:1518486253",
#                 "npequinor-dev:seismicpoststackdatasets:1521332812",
#                 "npequinor-dev:seismicpoststackdatasets:1520461513",
#                 "npequinor-dev:seismicpoststackdatasets:1520144645",
#                 "npequinor-dev:seismicpoststackdatasets:1518664820",
#                 "npequinor-dev:seismicpoststackdatasets:1520521359",
#                 "npequinor-dev:seismicpoststackdatasets:1519350031",
#                 "npequinor-dev:seismicpoststackdatasets:1520265633",
#                 "npequinor-dev:seismicpoststackdatasets:1519090985",
#                 "npequinor-dev:seismicpoststackdatasets:1519764299",
#                 "npequinor-dev:seismicpoststackdatasets:1521858969",
#                 "npequinor-dev:seismicpoststackdatasets:1521165268",
#                 "npequinor-dev:seismicpoststackdatasets:1518984255",
#                 "npequinor-dev:seismicpoststackdatasets:1519429936",
#                 "npequinor-dev:seismicpoststackdatasets:1520050153",
#                 "npequinor-dev:seismicpoststackdatasets:1521853919",
#                 "npequinor-dev:seismicpoststackdatasets:1520824184",
#                 "npequinor-dev:seismicpoststackdatasets:1520413011",
#                 "npequinor-dev:seismicpoststackdatasets:1519288450",
#                 "npequinor-dev:seismicpoststackdatasets:1521802813",
#                 "npequinor-dev:seismicpoststackdatasets:1520316799",
#                 "npequinor-dev:seismicpoststackdatasets:1518499837",
#                 "npequinor-dev:seismicpoststackdatasets:1518539127",
#                 "npequinor-dev:seismicpoststackdatasets:1519092771",
#                 "npequinor-dev:seismicpoststackdatasets:1518481146",
#                 "npequinor-dev:seismicpoststackdatasets:1520551414",
#                 "npequinor-dev:seismicpoststackdatasets:1521021038",
#                 "npequinor-dev:seismicpoststackdatasets:1520941412",
#                 "npequinor-dev:seismicpoststackdatasets:1521023005",
#                 "npequinor-dev:seismicpoststackdatasets:1521463258",
#                 "npequinor-dev:seismicpoststackdatasets:1519738492",
#                 "npequinor-dev:seismicpoststackdatasets:1521537181",
#                 "npequinor-dev:seismicpoststackdatasets:1519784464",
#                 "npequinor-dev:seismicpoststackdatasets:1518499841",
#                 "npequinor-dev:seismicpoststackdatasets:1520281555",
#                 "npequinor-dev:seismicpoststackdatasets:1521221093",
#                 "npequinor-dev:seismicpoststackdatasets:1521177786",
#                 "npequinor-dev:seismicpoststackdatasets:1521712226",
#                 "npequinor-dev:seismicpoststackdatasets:1518508940",
#                 "npequinor-dev:seismicpoststackdatasets:1522058395",
#                 "npequinor-dev:seismicpoststackdatasets:1521493948",
#                 "npequinor-dev:seismicpoststackdatasets:1520019753",
#                 "npequinor-dev:seismicpoststackdatasets:1519269342",
#                 "npequinor-dev:seismicpoststackdatasets:1522080292",
#                 "npequinor-dev:seismicpoststackdatasets:1521560012",
#                 "npequinor-dev:seismicpoststackdatasets:1521419148",
#                 "npequinor-dev:seismicpoststackdatasets:1520408013",
#                 "npequinor-dev:seismicpoststackdatasets:1520575740",
#                 "npequinor-dev:seismicpoststackdatasets:1521562065",
#                 "npequinor-dev:seismicpoststackdatasets:1522273267",
#                 "npequinor-dev:seismicpoststackdatasets:1519865208",
#                 "npequinor-dev:seismicpoststackdatasets:1520786301",
#                 "npequinor-dev:seismicpoststackdatasets:1521181650",
#                 "npequinor-dev:seismicpoststackdatasets:1519865203",
#                 "npequinor-dev:seismicpoststackdatasets:1518222819",
#                 "npequinor-dev:seismicpoststackdatasets:1521142311",
#                 "npequinor-dev:seismicpoststackdatasets:1519871554",
#                 "npequinor-dev:seismicpoststackdatasets:1518296803",
#                 "npequinor-dev:seismicpoststackdatasets:1519760660",
#                 "npequinor-dev:seismicpoststackdatasets:1519794834",
#                 "npequinor-dev:seismicpoststackdatasets:1521800953",
#                 "npequinor-dev:seismicpoststackdatasets:1521813019",
#                 "npequinor-dev:seismicpoststackdatasets:1521782447",
#                 "npequinor-dev:seismicpoststackdatasets:1522063214",
#                 "npequinor-dev:seismicpoststackdatasets:1520950888",
#                 "npequinor-dev:seismicpoststackdatasets:1520133757",
#                 "npequinor-dev:seismicpoststackdatasets:1519684410",
#                 "npequinor-dev:seismicpoststackdatasets:1522282838",
#                 "npequinor-dev:seismicpoststackdatasets:1521842141",
#                 "npequinor-dev:seismicpoststackdatasets:1521704530",
#                 "npequinor-dev:seismicpoststackdatasets:1518465989",
#                 "npequinor-dev:seismicpoststackdatasets:1518447826",
#                 "npequinor-dev:seismicpoststackdatasets:1521399062",
#                 "npequinor-dev:seismicpoststackdatasets:1520675014",
#                 "npequinor-dev:seismicpoststackdatasets:1522254217",
#                 "npequinor-dev:seismicpoststackdatasets:1519742828",
#                 "npequinor-dev:seismicpoststackdatasets:1518456328",
#                 "npequinor-dev:seismicpoststackdatasets:1521811159",
#                 "npequinor-dev:seismicpoststackdatasets:1522066300",
#                 "npequinor-dev:seismicpoststackdatasets:1521499523",
#                 "npequinor-dev:seismicpoststackdatasets:1521320294",
#                 "npequinor-dev:seismicpoststackdatasets:1519915767",
#                 "npequinor-dev:seismicpoststackdatasets:1518230670",
#                 "npequinor-dev:seismicpoststackdatasets:1520527055",
#                 "npequinor-dev:seismicpoststackdatasets:1519982638",
#                 "npequinor-dev:seismicpoststackdatasets:1519794832",
#                 "npequinor-dev:seismicpoststackdatasets:1520677862",
#                 "npequinor-dev:seismicpoststackdatasets:1519917587",
#                 "npequinor-dev:seismicpoststackdatasets:1521248960",
#                 "npequinor-dev:seismicpoststackdatasets:1521572560",
#                 "npequinor-dev:seismicpoststackdatasets:1520518509",
#                 "npequinor-dev:seismicpoststackdatasets:1518610176",
#                 "npequinor-dev:seismicpoststackdatasets:1519204949",
#                 "npequinor-dev:seismicpoststackdatasets:1518323634",
#                 "npequinor-dev:seismicpoststackdatasets:1521371616",
#                 "npequinor-dev:seismicpoststackdatasets:1520369755",
#                 "npequinor-dev:seismicpoststackdatasets:1521521302",
#                 "npequinor-dev:seismicpoststackdatasets:1521524676",
#                 "npequinor-dev:seismicpoststackdatasets:1521845513",
#                 "npequinor-dev:seismicpoststackdatasets:1521590535",
#                 "npequinor-dev:seismicpoststackdatasets:1520669318",
#                 "npequinor-dev:seismicpoststackdatasets:1520484138",
#                 "npequinor-dev:seismicpoststackdatasets:1519250032",
#                 "npequinor-dev:seismicpoststackdatasets:1519791183",
#                 "npequinor-dev:seismicpoststackdatasets:1518527259",
#                 "npequinor-dev:seismicpoststackdatasets:1522010872",
#                 "npequinor-dev:seismicpoststackdatasets:1521874384",
#                 "npequinor-dev:seismicpoststackdatasets:1519997312",
#                 "npequinor-dev:seismicpoststackdatasets:1521110535",
#                 "npequinor-dev:seismicpoststackdatasets:1518502732",
#                 "npequinor-dev:seismicpoststackdatasets:1521818567",
#                 "npequinor-dev:seismicpoststackdatasets:1521692012",
#                 "npequinor-dev:seismicpoststackdatasets:1519670601",
#                 "npequinor-dev:seismicpoststackdatasets:1520566180",
#                 "npequinor-dev:seismicpoststackdatasets:1521452886",
#                 "npequinor-dev:seismicpoststackdatasets:1519889779",
#                 "npequinor-dev:seismicpoststackdatasets:1519175259",
#                 "npequinor-dev:seismicpoststackdatasets:1521047842",
#                 "npequinor-dev:seismicpoststackdatasets:1519177470",
#                 "npequinor-dev:seismicpoststackdatasets:1521547330",
#                 "npequinor-dev:seismicpoststackdatasets:1520142825",
#                 "npequinor-dev:seismicpoststackdatasets:1521543896",
#                 "npequinor-dev:seismicpoststackdatasets:1521380725",
#                 "npequinor-dev:seismicpoststackdatasets:1519154067",
#                 "npequinor-dev:seismicpoststackdatasets:1521318362",
#                 "npequinor-dev:seismicpoststackdatasets:1521199884",
#                 "npequinor-dev:seismicpoststackdatasets:1520231846",
#                 "npequinor-dev:seismicpoststackdatasets:1521393898",
#                 "npequinor-dev:seismicpoststackdatasets:1519230691",
#                 "npequinor-dev:seismicpoststackdatasets:1520933000",
#                 "npequinor-dev:seismicpoststackdatasets:1520270902",
#                 "npequinor-dev:seismicpoststackdatasets:1520910250",
#                 "npequinor-dev:seismicpoststackdatasets:1520239494",
#                 "npequinor-dev:seismicpoststackdatasets:1518596883",
#                 "npequinor-dev:seismicpoststackdatasets:1519420111",
#                 "npequinor-dev:seismicpoststackdatasets:1521755652",
#                 "npequinor-dev:seismicpoststackdatasets:1520846886",
#                 "npequinor-dev:seismicpoststackdatasets:1519489303",
#                 "npequinor-dev:seismicpoststackdatasets:1518479443",
#                 "npequinor-dev:seismicpoststackdatasets:1519777568",
#                 "npequinor-dev:seismicpoststackdatasets:1520887922",
#                 "npequinor-dev:seismicpoststackdatasets:1520185899",
#                 "npequinor-dev:seismicpoststackdatasets:1519895239",
#                 "npequinor-dev:seismicpoststackdatasets:1521717048",
#                 "npequinor-dev:seismicpoststackdatasets:1520502871",
#                 "npequinor-dev:seismicpoststackdatasets:1518917896",
#                 "npequinor-dev:seismicpoststackdatasets:1521514558",
#                 "npequinor-dev:seismicpoststackdatasets:1520599366",
#                 "npequinor-dev:seismicpoststackdatasets:1519222768",
#                 "npequinor-dev:seismicpoststackdatasets:1521045532",
#                 "npequinor-dev:seismicpoststackdatasets:1520244897",
#                 "npequinor-dev:seismicpoststackdatasets:1519858857",
#                 "npequinor-dev:seismicpoststackdatasets:1519681054",
#                 "npequinor-dev:seismicpoststackdatasets:1518430806",
#                 "npequinor-dev:seismicpoststackdatasets:1521308734",
#                 "npequinor-dev:seismicpoststackdatasets:1522016605",
#                 "npequinor-dev:seismicpoststackdatasets:1520390842",
#                 "npequinor-dev:seismicpoststackdatasets:1520153714",
#                 "npequinor-dev:seismicpoststackdatasets:1519758584",
#                 "npequinor-dev:seismicpoststackdatasets:1521927818",
#                 "npequinor-dev:seismicpoststackdatasets:1521302938",
#                 "npequinor-dev:seismicpoststackdatasets:1519677011",
#                 "npequinor-dev:seismicpoststackdatasets:1522257031",
#                 "npequinor-dev:seismicpoststackdatasets:1521794052",
#                 "npequinor-dev:seismicpoststackdatasets:1520184272",
#                 "npequinor-dev:seismicpoststackdatasets:1520580415",
#                 "npequinor-dev:seismicpoststackdatasets:1522038832",
#                 "npequinor-dev:seismicpoststackdatasets:1519945938",
#                 "npequinor-dev:seismicpoststackdatasets:1521799093",
#                 "npequinor-dev:seismicpoststackdatasets:1519283150",
#                 "npequinor-dev:seismicpoststackdatasets:1519031037",
#                 "npequinor-dev:seismicpoststackdatasets:1521534762",
#                 "npequinor-dev:seismicpoststackdatasets:1519189125",
#                 "npequinor-dev:seismicpoststackdatasets:1518225198",
#                 "npequinor-dev:seismicpoststackdatasets:1520135577",
#                 "npequinor-dev:seismicpoststackdatasets:1519167347",
#                 "npequinor-dev:seismicpoststackdatasets:1522321800",
#                 "npequinor-dev:seismicpoststackdatasets:1521196018",
#                 "npequinor-dev:seismicpoststackdatasets:1519307465",
#                 "npequinor-dev:seismicpoststackdatasets:1521304870",
#                 "npequinor-dev:seismicpoststackdatasets:1521447090",
#                 "npequinor-dev:seismicpoststackdatasets:1520164129",
#                 "npequinor-dev:seismicpoststackdatasets:1520466293",
#                 "npequinor-dev:seismicpoststackdatasets:1519051914",
#                 "npequinor-dev:seismicpoststackdatasets:1521421080",
#                 "npequinor-dev:seismicpoststackdatasets:1519004854",
#                 "npequinor-dev:seismicpoststackdatasets:1520354941",
#                 "npequinor-dev:seismicpoststackdatasets:1522245617",
#                 "npequinor-dev:seismicpoststackdatasets:1522043066",
#                 "npequinor-dev:seismicpoststackdatasets:1519157510",
#                 "npequinor-dev:seismicpoststackdatasets:1518576491",
#                 "npequinor-dev:seismicpoststackdatasets:1519208913",
#                 "npequinor-dev:seismicpoststackdatasets:1520235871",
#                 "npequinor-dev:seismicpoststackdatasets:1519103725",
#                 "npequinor-dev:seismicpoststackdatasets:1519119273",
#                 "npequinor-dev:seismicpoststackdatasets:1521039544",
#                 "npequinor-dev:seismicpoststackdatasets:1520112101",
#                 "npequinor-dev:seismicpoststackdatasets:1519880640",
#                 "npequinor-dev:seismicpoststackdatasets:1519919407",
#                 "npequinor-dev:seismicpoststackdatasets:1519732704",
#                 "npequinor-dev:seismicpoststackdatasets:1521454818",
#                 "npequinor-dev:seismicpoststackdatasets:1521516119",
#                 "npequinor-dev:seismicpoststackdatasets:1519096108",
#                 "npequinor-dev:seismicpoststackdatasets:1518307847",
#                 "npequinor-dev:seismicpoststackdatasets:1518905821",
#                 "npequinor-dev:seismicpoststackdatasets:1521440368",
#                 "npequinor-dev:seismicpoststackdatasets:1519458897",
#                 "npequinor-dev:seismicpoststackdatasets:1518966090",
#                 "npequinor-dev:seismicpoststackdatasets:1520607115",
#                 "npequinor-dev:seismicpoststackdatasets:1520605729",
#                 "npequinor-dev:seismicpoststackdatasets:1520612037",
#                 "npequinor-dev:seismicpoststackdatasets:1521686216",
#                 "npequinor-dev:seismicpoststackdatasets:1520137397",
#                 "npequinor-dev:seismicpoststackdatasets:1521568935",
#                 "npequinor-dev:seismicpoststackdatasets:1519567538",
#                 "npequinor-dev:seismicpoststackdatasets:1521493320",
#                 "npequinor-dev:seismicpoststackdatasets:1519928475",
#                 "npequinor-dev:seismicpoststackdatasets:1519048245",
#                 "npequinor-dev:seismicpoststackdatasets:1519664663",
#                 "npequinor-dev:seismicpoststackdatasets:1521226671",
#                 "npequinor-dev:seismicpoststackdatasets:1521470819",
#                 "npequinor-dev:seismicpoststackdatasets:1520288198",
#                 "npequinor-dev:seismicpoststackdatasets:1520037265",
#                 "npequinor-dev:seismicpoststackdatasets:1521403307",
#                 "npequinor-dev:seismicpoststackdatasets:1519151507",
#                 "npequinor-dev:seismicpoststackdatasets:1519700291",
#                 "npequinor-dev:seismicpoststackdatasets:1521267584",
#                 "npequinor-dev:seismicpoststackdatasets:1519867028",
#                 "npequinor-dev:seismicpoststackdatasets:1519885166",
#                 "npequinor-dev:seismicpoststackdatasets:1519857035",
#                 "npequinor-dev:seismicpoststackdatasets:1521081531",
#                 "npequinor-dev:seismicpoststackdatasets:1521838767",
#                 "npequinor-dev:seismicpoststackdatasets:1520571309",
#                 "npequinor-dev:seismicpoststackdatasets:1521330880",
#                 "npequinor-dev:seismicpoststackdatasets:1518839718",
#                 "npequinor-dev:seismicpoststackdatasets:1522030496",
#                 "npequinor-dev:seismicpoststackdatasets:1519533986",
#                 "npequinor-dev:seismicpoststackdatasets:1520267773",
#                 "npequinor-dev:seismicpoststackdatasets:1521688148",
#                 "npequinor-dev:seismicpoststackdatasets:1519893419",
#                 "npequinor-dev:seismicpoststackdatasets:1521838769",
#                 "npequinor-dev:seismicpoststackdatasets:1521334744",
#                 "npequinor-dev:seismicpoststackdatasets:1521467183",
#                 "npequinor-dev:seismicpoststackdatasets:1518223283",
#                 "npequinor-dev:seismicpoststackdatasets:1521720915",
#                 "npequinor-dev:seismicpoststackdatasets:1521343398",
#                 "npequinor-dev:seismicpoststackdatasets:1518254888",
#                 "npequinor-dev:seismicpoststackdatasets:1520435029",
#                 "npequinor-dev:seismicpoststackdatasets:1518957517",
#                 "npequinor-dev:seismicpoststackdatasets:1522260473",
#                 "npequinor-dev:seismicpoststackdatasets:1520423637",
#                 "npequinor-dev:seismicpoststackdatasets:1518909825",
#                 "npequinor-dev:seismicpoststackdatasets:1522026683",
#                 "npequinor-dev:seismicpoststackdatasets:1519416147",
#                 "npequinor-dev:seismicpoststackdatasets:1520041533",
#                 "npequinor-dev:seismicpoststackdatasets:1520111968",
#                 "npequinor-dev:seismicpoststackdatasets:1522036680",
#                 "npequinor-dev:seismicpoststackdatasets:1518488514",
#                 "npequinor-dev:seismicpoststackdatasets:1522334423",
#                 "npequinor-dev:seismicpoststackdatasets:1518815962",
#                 "npequinor-dev:seismicpoststackdatasets:1521017332",
#                 "npequinor-dev:seismicpoststackdatasets:1521163336",
#                 "npequinor-dev:seismicpoststackdatasets:1519222763",
#                 "npequinor-dev:seismicpoststackdatasets:1518914640",
#                 "npequinor-dev:seismicpoststackdatasets:1519876998",
#                 "npequinor-dev:seismicpoststackdatasets:1519279694",
#                 "npequinor-dev:seismicpoststackdatasets:1519250037",
#                 "npequinor-dev:seismicpoststackdatasets:1518282862",
#                 "npequinor-dev:seismicpoststackdatasets:1520616522",
#                 "npequinor-dev:seismicpoststackdatasets:1519710032",
#                 "npequinor-dev:seismicpoststackdatasets:1521185514",
#                 "npequinor-dev:seismicpoststackdatasets:1521722847",
#                 "npequinor-dev:seismicpoststackdatasets:1519139631",
#                 "npequinor-dev:seismicpoststackdatasets:1518662222",
#                 "npequinor-dev:seismicpoststackdatasets:1520555463",
#                 "npequinor-dev:seismicpoststackdatasets:1520404807",
#                 "npequinor-dev:seismicpoststackdatasets:1520648040",
#                 "npequinor-dev:seismicpoststackdatasets:1522326395",
#                 "npequinor-dev:seismicpoststackdatasets:1520856258",
#                 "npequinor-dev:seismicpoststackdatasets:1518951574",
#                 "npequinor-dev:seismicpoststackdatasets:1521931569",
#                 "npequinor-dev:seismicpoststackdatasets:1519313351",
#                 "npequinor-dev:seismicpoststackdatasets:1521169132",
#                 "npequinor-dev:seismicpoststackdatasets:1519891599",
#                 "npequinor-dev:seismicpoststackdatasets:1520493082",
#                 "npequinor-dev:seismicpoststackdatasets:1520410861",
#                 "npequinor-dev:seismicpoststackdatasets:1518530862",
#                 "npequinor-dev:seismicpoststackdatasets:1521270136",
#                 "npequinor-dev:seismicpoststackdatasets:1521405549",
#                 "npequinor-dev:seismicpoststackdatasets:1521824565",
#                 "npequinor-dev:seismicpoststackdatasets:1518243552",
#                 "npequinor-dev:seismicpoststackdatasets:1520201344",
#                 "npequinor-dev:seismicpoststackdatasets:1519416145",
#                 "npequinor-dev:seismicpoststackdatasets:1521281060",
#                 "npequinor-dev:seismicpoststackdatasets:1518451230",
#                 "npequinor-dev:seismicpoststackdatasets:1518280197",
#                 "npequinor-dev:seismicpoststackdatasets:1521286463",
#                 "npequinor-dev:seismicpoststackdatasets:1520110148",
#                 "npequinor-dev:seismicpoststackdatasets:1520984604",
#                 "npequinor-dev:seismicpoststackdatasets:1520818368",
#                 "npequinor-dev:seismicpoststackdatasets:1521115964",
#                 "npequinor-dev:seismicpoststackdatasets:1519705683",
#                 "npequinor-dev:seismicpoststackdatasets:1519746528",
#                 "npequinor-dev:seismicpoststackdatasets:1522275213",
#                 "npequinor-dev:seismicpoststackdatasets:1520046448",
#                 "npequinor-dev:seismicpoststackdatasets:1522080278",
#                 "npequinor-dev:seismicpoststackdatasets:1521474801",
#                 "npequinor-dev:seismicpoststackdatasets:1520320715",
#                 "npequinor-dev:seismicpoststackdatasets:1518581668",
#                 "npequinor-dev:seismicpoststackdatasets:1520642344",
#                 "npequinor-dev:seismicpoststackdatasets:1520402317",
#                 "npequinor-dev:seismicpoststackdatasets:1521306802",
#                 "npequinor-dev:seismicpoststackdatasets:1520994158",
#                 "npequinor-dev:seismicpoststackdatasets:1518525511",
#                 "npequinor-dev:seismicpoststackdatasets:1520457961",
#                 "npequinor-dev:seismicpoststackdatasets:1520265635",
#                 "npequinor-dev:seismicpoststackdatasets:1520452661",
#                 "npequinor-dev:seismicpoststackdatasets:1520131937",
#                 "npequinor-dev:seismicpoststackdatasets:1519847049",
#                 "npequinor-dev:seismicpoststackdatasets:1520639496",
#                 "npequinor-dev:seismicpoststackdatasets:1520121049",
#                 "npequinor-dev:seismicpoststackdatasets:1518942830",
#                 "npequinor-dev:seismicpoststackdatasets:1521183582",
#                 "npequinor-dev:seismicpoststackdatasets:1521377278",
#                 "npequinor-dev:seismicpoststackdatasets:1519133693",
#                 "npequinor-dev:seismicpoststackdatasets:1519536878",
#                 "npequinor-dev:seismicpoststackdatasets:1520636648",
#                 "npequinor-dev:seismicpoststackdatasets:1518563494",
#                 "npequinor-dev:seismicpoststackdatasets:1518992332",
#                 "npequinor-dev:seismicpoststackdatasets:1518260160",
#                 "npequinor-dev:seismicpoststackdatasets:1520645192",
#                 "npequinor-dev:seismicpoststackdatasets:1518534333",
#                 "npequinor-dev:seismicpoststackdatasets:1518499839",
#                 "npequinor-dev:seismicpoststackdatasets:1521432640",
#                 "npequinor-dev:seismicpoststackdatasets:1520426484",
#                 "npequinor-dev:seismicpoststackdatasets:1522081934",
#                 "npequinor-dev:seismicpoststackdatasets:1520293121",
#                 "npequinor-dev:seismicpoststackdatasets:1518939698",
#                 "npequinor-dev:seismicpoststackdatasets:1519272798",
#                 "npequinor-dev:seismicpoststackdatasets:1521356366",
#                 "npequinor-dev:seismicpoststackdatasets:1518996942",
#                 "npequinor-dev:seismicpoststackdatasets:1521424944",
#                 "npequinor-dev:seismicpoststackdatasets:1521267586",
#                 "npequinor-dev:seismicpoststackdatasets:1522012807",
#                 "npequinor-dev:seismicpoststackdatasets:1520148285",
#                 "npequinor-dev:seismicpoststackdatasets:1520563975",
#                 "npequinor-dev:seismicpoststackdatasets:1518819926",
#                 "npequinor-dev:seismicpoststackdatasets:1521598750",
#                 "npequinor-dev:seismicpoststackdatasets:1519116865",
#                 "npequinor-dev:seismicpoststackdatasets:1522061034",
#                 "npequinor-dev:seismicpoststackdatasets:1518256468",
#                 "npequinor-dev:seismicpoststackdatasets:1520125906",
#                 "npequinor-dev:seismicpoststackdatasets:1522284345",
#                 "npequinor-dev:seismicpoststackdatasets:1520984611",
#                 "npequinor-dev:seismicpoststackdatasets:1521316430",
#                 "npequinor-dev:seismicpoststackdatasets:1520546917",
#                 "npequinor-dev:seismicpoststackdatasets:1521322226",
#                 "npequinor-dev:seismicpoststackdatasets:1519598082",
#                 "npequinor-dev:seismicpoststackdatasets:1521423012",
#                 "npequinor-dev:seismicpoststackdatasets:1520429333",
#                 "npequinor-dev:seismicpoststackdatasets:1521136195",
#                 "npequinor-dev:seismicpoststackdatasets:1521438436",
#                 "npequinor-dev:seismicpoststackdatasets:1518823892",
#                 "npequinor-dev:seismicpoststackdatasets:1521690080",
#                 "npequinor-dev:seismicpoststackdatasets:1521436504",
#                 "npequinor-dev:seismicpoststackdatasets:1519310925",
#                 "npequinor-dev:seismicpoststackdatasets:1518320767",
#                 "npequinor-dev:seismicpoststackdatasets:1521702598",
#                 "npequinor-dev:seismicpoststackdatasets:1519298849",
#                 "npequinor-dev:seismicpoststackdatasets:1522329836",
#                 "npequinor-dev:seismicpoststackdatasets:1521718983",
#                 "npequinor-dev:seismicpoststackdatasets:1520883450",
#                 "npequinor-dev:seismicpoststackdatasets:1518936231",
#                 "npequinor-dev:seismicpoststackdatasets:1521368648",
#                 "npequinor-dev:seismicpoststackdatasets:1518342887",
#                 "npequinor-dev:seismicpoststackdatasets:1519042607",
#                 "npequinor-dev:seismicpoststackdatasets:1518585539",
#                 "npequinor-dev:seismicpoststackdatasets:1520334789",
#                 "npequinor-dev:seismicpoststackdatasets:1520229285",
#                 "npequinor-dev:seismicpoststackdatasets:1521137862",
#                 "npequinor-dev:seismicpoststackdatasets:1518823890",
#                 "npequinor-dev:seismicpoststackdatasets:1520146465",
#                 "npequinor-dev:seismicpoststackdatasets:1521348829",
#                 "npequinor-dev:seismicpoststackdatasets:1518842400",
#                 "npequinor-dev:seismicpoststackdatasets:1518462350",
#                 "npequinor-dev:seismicpoststackdatasets:1521120651",
#                 "npequinor-dev:seismicpoststackdatasets:1520549765",
#                 "npequinor-dev:seismicpoststackdatasets:1520730654",
#                 "npequinor-dev:seismicpoststackdatasets:1520191344",
#                 "npequinor-dev:seismicpoststackdatasets:1519736160",
#                 "npequinor-dev:seismicpoststackdatasets:1520987983",
#                 "npequinor-dev:seismicpoststackdatasets:1519850689",
#                 "npequinor-dev:seismicpoststackdatasets:1522251147",
#                 "npequinor-dev:seismicpoststackdatasets:1520198587",
#                 "npequinor-dev:seismicpoststackdatasets:1520937315",
#                 "npequinor-dev:seismicpoststackdatasets:1521450954",
#                 "npequinor-dev:seismicpoststackdatasets:1518443077",
#                 "npequinor-dev:seismicpoststackdatasets:1521328948",
#                 "npequinor-dev:seismicpoststackdatasets:1520285539",
#                 "npequinor-dev:seismicpoststackdatasets:1519874276",
#                 "npequinor-dev:seismicpoststackdatasets:1521026808",
#                 "npequinor-dev:seismicpoststackdatasets:1518551001",
#                 "npequinor-dev:seismicpoststackdatasets:1521588513",
#                 "npequinor-dev:seismicpoststackdatasets:1519371082",
#                 "npequinor-dev:seismicpoststackdatasets:1519181399",
#                 "npequinor-dev:seismicpoststackdatasets:1521937886",
#                 "npequinor-dev:seismicpoststackdatasets:1521088759",
#                 "npequinor-dev:seismicpoststackdatasets:1522180570",
#                 "npequinor-dev:seismicpoststackdatasets:1521201816",
#                 "npequinor-dev:seismicpoststackdatasets:1518953554",
#                 "npequinor-dev:seismicpoststackdatasets:1521821008",
#                 "npequinor-dev:seismicpoststackdatasets:1519124794",
#                 "npequinor-dev:seismicpoststackdatasets:1521434572",
#                 "npequinor-dev:seismicpoststackdatasets:1521197950",
#                 "npequinor-dev:seismicpoststackdatasets:1521449022",
#                 "npequinor-dev:seismicpoststackdatasets:1521715116",
#                 "npequinor-dev:seismicpoststackdatasets:1521112126",
#                 "npequinor-dev:seismicpoststackdatasets:1520524207",
#                 "npequinor-dev:seismicpoststackdatasets:1521274330",
#                 "npequinor-dev:seismicpoststackdatasets:1519921227",
#                 "npequinor-dev:seismicpoststackdatasets:1518505498",
#                 "npequinor-dev:seismicpoststackdatasets:1520160165",
#                 "npequinor-dev:seismicpoststackdatasets:1521426876",
#                 "npequinor-dev:seismicpoststackdatasets:1521352026",
#                 "npequinor-dev:seismicpoststackdatasets:1521014294",
#                 "npequinor-dev:seismicpoststackdatasets:1518849549",
#                 "npequinor-dev:seismicpoststackdatasets:1520910254"
#             ]
#         }
#     },
#     "poststackcubes": {
#         "Source records count": 19383,
#         "Source unique records ids count": 19371,
#         "OSDU custom ingested unique ids count": 18828,
#         "Common records count (source-custom)": 18824,
#         "Ingeted into OSDU (custom) but missing in source": {
#             "count": 4,
#             "ids": [
#                 "npequinor-dev:poststackcubes:1509347982",
#                 "npequinor-dev:poststackcubes:1510997351",
#                 "npequinor-dev:poststackcubes:1510991048",
#                 "npequinor-dev:poststackcubes:1512424193"
#             ]
#         },
#         "Present in source but missing in OSDU (custom)": {
#             "count": 547,
#             "ids": [
#                 "npequinor-dev:poststackcubes:1519505921",
#                 "npequinor-dev:poststackcubes:1520730659",
#                 "npequinor-dev:poststackcubes:1518579900",
#                 "npequinor-dev:poststackcubes:1522334428",
#                 "npequinor-dev:poststackcubes:1518827863",
#                 "npequinor-dev:poststackcubes:1520563980",
#                 "npequinor-dev:poststackcubes:1519458902",
#                 "npequinor-dev:poststackcubes:1521110540",
#                 "npequinor-dev:poststackcubes:1521281065",
#                 "npequinor-dev:poststackcubes:1521308739",
#                 "npequinor-dev:poststackcubes:1520359420",
#                 "npequinor-dev:poststackcubes:1519179228",
#                 "npequinor-dev:poststackcubes:1521375397",
#                 "npequinor-dev:poststackcubes:1521524681",
#                 "npequinor-dev:poststackcubes:1521091624",
#                 "npequinor-dev:poststackcubes:1519094446",
#                 "npequinor-dev:poststackcubes:1522061838",
#                 "npequinor-dev:poststackcubes:1522276964",
#                 "npequinor-dev:poststackcubes:1519997319",
#                 "npequinor-dev:poststackcubes:1519564581",
#                 "npequinor-dev:poststackcubes:1518819931",
#                 "npequinor-dev:poststackcubes:1521086361",
#                 "npequinor-dev:poststackcubes:1520121054",
#                 "npequinor-dev:poststackcubes:1521493953",
#                 "npequinor-dev:poststackcubes:1520521364",
#                 "npequinor-dev:poststackcubes:1518451235",
#                 "npequinor-dev:poststackcubes:1521438441",
#                 "npequinor-dev:poststackcubes:1521828688",
#                 "npequinor-dev:poststackcubes:1521585267",
#                 "npequinor-dev:poststackcubes:1518535728",
#                 "npequinor-dev:poststackcubes:1519226732",
#                 "npequinor-dev:poststackcubes:1520808541",
#                 "npequinor-dev:poststackcubes:1521419153",
#                 "npequinor-dev:poststackcubes:1518904073",
#                 "npequinor-dev:poststackcubes:1521514563",
#                 "npequinor-dev:poststackcubes:1521818572",
#                 "npequinor-dev:poststackcubes:1519758589",
#                 "npequinor-dev:poststackcubes:1518489662",
#                 "npequinor-dev:poststackcubes:1519716152",
#                 "npequinor-dev:poststackcubes:1521024415",
#                 "npequinor-dev:poststackcubes:1521500697",
#                 "npequinor-dev:poststackcubes:1518996947",
#                 "npequinor-dev:poststackcubes:1522040066",
#                 "npequinor-dev:poststackcubes:1518434215",
#                 "npequinor-dev:poststackcubes:1519047537",
#                 "npequinor-dev:poststackcubes:1521074354",
#                 "npequinor-dev:poststackcubes:1520786306",
#                 "npequinor-dev:poststackcubes:1522068612",
#                 "npequinor-dev:poststackcubes:1520172080",
#                 "npequinor-dev:poststackcubes:1520819717",
#                 "npequinor-dev:poststackcubes:1521807444",
#                 "npequinor-dev:poststackcubes:1521338597",
#                 "npequinor-dev:poststackcubes:1519048892",
#                 "npequinor-dev:poststackcubes:1520204222",
#                 "npequinor-dev:poststackcubes:1519325936",
#                 "npequinor-dev:poststackcubes:1522323352",
#                 "npequinor-dev:poststackcubes:1521146316",
#                 "npequinor-dev:poststackcubes:1522046819",
#                 "npequinor-dev:poststackcubes:1519014745",
#                 "npequinor-dev:poststackcubes:1522319660",
#                 "npequinor-dev:poststackcubes:1520435034",
#                 "npequinor-dev:poststackcubes:1521825316",
#                 "npequinor-dev:poststackcubes:1519183192",
#                 "npequinor-dev:poststackcubes:1522262228",
#                 "npequinor-dev:poststackcubes:1518963471",
#                 "npequinor-dev:poststackcubes:1521199889",
#                 "npequinor-dev:poststackcubes:1519736165",
#                 "npequinor-dev:poststackcubes:1519787925",
#                 "npequinor-dev:poststackcubes:1521684289",
#                 "npequinor-dev:poststackcubes:1521799098",
#                 "npequinor-dev:poststackcubes:1518459737",
#                 "npequinor-dev:poststackcubes:1520568452",
#                 "npequinor-dev:poststackcubes:1522327044",
#                 "npequinor-dev:poststackcubes:1518576496",
#                 "npequinor-dev:poststackcubes:1520271336",
#                 "npequinor-dev:poststackcubes:1519682498",
#                 "npequinor-dev:poststackcubes:1521320299",
#                 "npequinor-dev:poststackcubes:1519895244",
#                 "npequinor-dev:poststackcubes:1521838774",
#                 "npequinor-dev:poststackcubes:1519286611",
#                 "npequinor-dev:poststackcubes:1521432645",
#                 "npequinor-dev:poststackcubes:1521927823",
#                 "npequinor-dev:poststackcubes:1521382141",
#                 "npequinor-dev:poststackcubes:1522016610",
#                 "npequinor-dev:poststackcubes:1519040625",
#                 "npequinor-dev:poststackcubes:1521566761",
#                 "npequinor-dev:poststackcubes:1519090990",
#                 "npequinor-dev:poststackcubes:1518320772",
#                 "npequinor-dev:poststackcubes:1520577396",
#                 "npequinor-dev:poststackcubes:1518951579",
#                 "npequinor-dev:poststackcubes:1518815967",
#                 "npequinor-dev:poststackcubes:1522010898",
#                 "npequinor-dev:poststackcubes:1521393903",
# ...
#                 "npequinor-dev:poststackcubegeometries:1518665631",
#                 "npequinor-dev:poststackcubegeometries:1519664668",
#                 "npequinor-dev:poststackcubegeometries:1521450959",
#                 "npequinor-dev:poststackcubegeometries:1519505921",
#                 "npequinor-dev:poststackcubegeometries:1520350474",
#                 "npequinor-dev:poststackcubegeometries:1518596888",
#                 "npequinor-dev:poststackcubegeometries:1520815245",
#                 "npequinor-dev:poststackcubegeometries:1519984534",
#                 "npequinor-dev:poststackcubegeometries:1518981269",
#                 "npequinor-dev:poststackcubegeometries:1519686462",
#                 "npequinor-dev:poststackcubegeometries:1520856797",
#                 "npequinor-dev:poststackcubegeometries:1521592011",
#                 "npequinor-dev:poststackcubegeometries:1520669323",
#                 "npequinor-dev:poststackcubegeometries:1521440373",
#                 "npequinor-dev:poststackcubegeometries:1519736165",
#                 "npequinor-dev:poststackcubegeometries:1519286611",
#                 "npequinor-dev:poststackcubegeometries:1518463141",
#                 "npequinor-dev:poststackcubegeometries:1518291278",
#                 "npequinor-dev:poststackcubegeometries:1519053258",
#                 "npequinor-dev:poststackcubegeometries:1518623122",
#                 "npequinor-dev:poststackcubegeometries:1520019977",
#                 "npequinor-dev:poststackcubegeometries:1520408018",
#                 "npequinor-dev:poststackcubegeometries:1521541511",
#                 "npequinor-dev:poststackcubegeometries:1522016610",
#                 "npequinor-dev:poststackcubegeometries:1521353519",
#                 "npequinor-dev:poststackcubegeometries:1519885171",
#                 "npequinor-dev:poststackcubegeometries:1522280656",
#                 "npequinor-dev:poststackcubegeometries:1521704535",
#                 "npequinor-dev:poststackcubegeometries:1520262790",
#                 "npequinor-dev:poststackcubegeometries:1520933005",
#                 "npequinor-dev:poststackcubegeometries:1521794057",
#                 "npequinor-dev:poststackcubegeometries:1520405170",
#                 "npequinor-dev:poststackcubegeometries:1521436509",
#                 "npequinor-dev:poststackcubegeometries:1522058436",
#                 "npequinor-dev:poststackcubegeometries:1518823899",
#                 "npequinor-dev:poststackcubegeometries:1521185519",
#                 "npequinor-dev:poststackcubegeometries:1521375397",
#                 "npequinor-dev:poststackcubegeometries:1521944448",
#                 "npequinor-dev:poststackcubegeometries:1520555468",
#                 "npequinor-dev:poststackcubegeometries:1519858862",
#                 "npequinor-dev:poststackcubegeometries:1522080300",
#                 "npequinor-dev:poststackcubegeometries:1519848874",
#                 "npequinor-dev:poststackcubegeometries:1521821944",
#                 "npequinor-dev:poststackcubegeometries:1518908037",
#                 "npequinor-dev:poststackcubegeometries:1520991360",
#                 "npequinor-dev:poststackcubegeometries:1520164134",
#                 "npequinor-dev:poststackcubegeometries:1520279848",
#                 "npequinor-dev:poststackcubegeometries:1518466545",
#                 "npequinor-dev:poststackcubegeometries:1522254844",
#                 "npequinor-dev:poststackcubegeometries:1520987988",
#                 "npequinor-dev:poststackcubegeometries:1520950893",
#                 "npequinor-dev:poststackcubegeometries:1521107168",
#                 "npequinor-dev:poststackcubegeometries:1519222773",
#                 "npequinor-dev:poststackcubegeometries:1518437619",
#                 "npequinor-dev:poststackcubegeometries:1521270963",
#                 "npequinor-dev:poststackcubegeometries:1521053037",
#                 "npequinor-dev:poststackcubegeometries:1521165273",
#                 "npequinor-dev:poststackcubegeometries:1519784469",
#                 "npequinor-dev:poststackcubegeometries:1521201821",
#                 "npequinor-dev:poststackcubegeometries:1521346775",
#                 "npequinor-dev:poststackcubegeometries:1521566761",
#                 "npequinor-dev:poststackcubegeometries:1518328156",
#                 "npequinor-dev:poststackcubegeometries:1519895244",
#                 "npequinor-dev:poststackcubegeometries:1520546922",
#                 "npequinor-dev:poststackcubegeometries:1518554410",
#                 "npequinor-dev:poststackcubegeometries:1519133698",
#                 "npequinor-dev:poststackcubegeometries:1520577396",
#                 "npequinor-dev:poststackcubegeometries:1522010898",
#                 "npequinor-dev:poststackcubegeometries:1520144650",
#                 "npequinor-dev:poststackcubegeometries:1522026706",
#                 "npequinor-dev:poststackcubegeometries:1520330220",
#                 "npequinor-dev:poststackcubegeometries:1519855220",
#                 "npequinor-dev:poststackcubegeometries:1518904073",
#                 "npequinor-dev:poststackcubegeometries:1520049998",
#                 "npequinor-dev:poststackcubegeometries:1520599371",
#                 "npequinor-dev:poststackcubegeometries:1521179723",
#                 "npequinor-dev:poststackcubegeometries:1521560017",
#                 "npequinor-dev:poststackcubegeometries:1521404019",
#                 "npequinor-dev:poststackcubegeometries:1518510130",
#                 "npequinor-dev:poststackcubegeometries:1520524212",
#                 "npequinor-dev:poststackcubegeometries:1521497325",
#                 "npequinor-dev:poststackcubegeometries:1520122874",
#                 "npequinor-dev:poststackcubegeometries:1518456333",
#                 "npequinor-dev:poststackcubegeometries:1522030522",
#                 "npequinor-dev:poststackcubegeometries:1520614671",
#                 "npequinor-dev:poststackcubegeometries:1518933763",
#                 "npequinor-dev:poststackcubegeometries:1519307470",
#                 "npequinor-dev:poststackcubegeometries:1521548255",
#                 "npequinor-dev:poststackcubegeometries:1519678534",
#                 "npequinor-dev:poststackcubegeometries:1522276964",
#                 "npequinor-dev:poststackcubegeometries:1518525516",
#                 "npequinor-dev:poststackcubegeometries:1519019921",
#                 "npequinor-dev:poststackcubegeometries:1520435034",
#                 "npequinor-dev:poststackcubegeometries:1520413714",
#                 "npequinor-dev:poststackcubegeometries:1519120834",
#                 "npequinor-dev:poststackcubegeometries:1518479448",
#                 "npequinor-dev:poststackcubegeometries:1521454823",
#                 "npequinor-dev:poststackcubegeometries:1519997319",
#                 "npequinor-dev:poststackcubegeometries:1521248965",
#                 "npequinor-dev:poststackcubegeometries:1519670606",
#                 "npequinor-dev:poststackcubegeometries:1521082989",
#                 "npequinor-dev:poststackcubegeometries:1521755675",
#                 "npequinor-dev:poststackcubegeometries:1518249087",
#                 "npequinor-dev:poststackcubegeometries:1521356891",
#                 "npequinor-dev:poststackcubegeometries:1520645197",
#                 "npequinor-dev:poststackcubegeometries:1521802818",
#                 "npequinor-dev:poststackcubegeometries:1520677867",
#                 "npequinor-dev:poststackcubegeometries:1521475033",
#                 "npequinor-dev:poststackcubegeometries:1519047537",
#                 "npequinor-dev:poststackcubegeometries:1518283894",
#                 "npequinor-dev:poststackcubegeometries:1518506702",
#                 "npequinor-dev:poststackcubegeometries:1518528920",
#                 "npequinor-dev:poststackcubegeometries:1521322231",
#                 "npequinor-dev:poststackcubegeometries:1519458902",
#                 "npequinor-dev:poststackcubegeometries:1521281065",
#                 "npequinor-dev:poststackcubegeometries:1521393903",
#                 "npequinor-dev:poststackcubegeometries:1519988249",
#                 "npequinor-dev:poststackcubegeometries:1518430811",
#                 "npequinor-dev:poststackcubegeometries:1518662227",
#                 "npequinor-dev:poststackcubegeometries:1521842146",
#                 "npequinor-dev:poststackcubegeometries:1520423642",
#                 "npequinor-dev:poststackcubegeometries:1520133762",
#                 "npequinor-dev:poststackcubegeometries:1519915772",
#                 "npequinor-dev:poststackcubegeometries:1519919412",
#                 "npequinor-dev:poststackcubegeometries:1519376267",
#                 "npequinor-dev:poststackcubegeometries:1519004859",
#                 "npequinor-dev:poststackcubegeometries:1519889784",
#                 "npequinor-dev:poststackcubegeometries:1520199750",
#                 "npequinor-dev:poststackcubegeometries:1521171069",
#                 "npequinor-dev:poststackcubegeometries:1518532324",
#                 "npequinor-dev:poststackcubegeometries:1519935831",
#                 "npequinor-dev:poststackcubegeometries:1520325748",
#                 "npequinor-dev:poststackcubegeometries:1520887927",
#                 "npequinor-dev:poststackcubegeometries:1519564581",
#                 "npequinor-dev:poststackcubegeometries:1519682498",
#                 "npequinor-dev:poststackcubegeometries:1519850694",
#                 "npequinor-dev:poststackcubegeometries:1521500697",
#                 "npequinor-dev:poststackcubegeometries:1518847652",
#                 "npequinor-dev:poststackcubegeometries:1519032009",
#                 "npequinor-dev:poststackcubegeometries:1521017671",
#                 "npequinor-dev:poststackcubegeometries:1521079617",
#                 "npequinor-dev:poststackcubegeometries:1518535728",
#                 "npequinor-dev:poststackcubegeometries:1521471661",
#                 "npequinor-dev:poststackcubegeometries:1518561218",
#                 "npequinor-dev:poststackcubegeometries:1521588639",
#                 "npequinor-dev:poststackcubegeometries:1520271336",
#                 "npequinor-dev:poststackcubegeometries:1520135582",
#                 "npequinor-dev:poststackcubegeometries:1520488615",
#                 "npequinor-dev:poststackcubegeometries:1521234997",
#                 "npequinor-dev:poststackcubegeometries:1519844332",
#                 "npequinor-dev:poststackcubegeometries:1518342892",
#                 "npequinor-dev:poststackcubegeometries:1521139572",
#                 "npequinor-dev:poststackcubegeometries:1520184277",
#                 "npequinor-dev:poststackcubegeometries:1520354946",
#                 "npequinor-dev:poststackcubegeometries:1520113227",
#                 "npequinor-dev:poststackcubegeometries:1519921232",
#                 "npequinor-dev:poststackcubegeometries:1520552618",
#                 "npequinor-dev:poststackcubegeometries:1518434215",
#                 "npequinor-dev:poststackcubegeometries:1521074354",
#                 "npequinor-dev:poststackcubegeometries:1518513558",
#                 "npequinor-dev:poststackcubegeometries:1518444427",
#                 "npequinor-dev:poststackcubegeometries:1519704260",
#                 "npequinor-dev:poststackcubegeometries:1520730659",
#                 "npequinor-dev:poststackcubegeometries:1521534767",
#                 "npequinor-dev:poststackcubegeometries:1520426490",
#                 "npequinor-dev:poststackcubegeometries:1519891604",
#                 "npequinor-dev:poststackcubegeometries:1521700671",
#                 "npequinor-dev:poststackcubegeometries:1522036691",
#                 "npequinor-dev:poststackcubegeometries:1520819717",
#                 "npequinor-dev:poststackcubegeometries:1520432186",
#                 "npequinor-dev:poststackcubegeometries:1522024813",
#                 "npequinor-dev:poststackcubegeometries:1520172080",
#                 "npequinor-dev:poststackcubegeometries:1522028614",
#                 "npequinor-dev:poststackcubegeometries:1519787925",
#                 "npequinor-dev:poststackcubegeometries:1518503274",
#                 "npequinor-dev:poststackcubegeometries:1519230696",
#                 "npequinor-dev:poststackcubegeometries:1520268488",
#                 "npequinor-dev:poststackcubegeometries:1519765501",
#                 "npequinor-dev:poststackcubegeometries:1519857042",
#                 "npequinor-dev:poststackcubegeometries:1519298854",
#                 "npequinor-dev:poststackcubegeometries:1518296808",
#                 "npequinor-dev:poststackcubegeometries:1518843687",
#                 "npequinor-dev:poststackcubegeometries:1521372025",
#                 "npequinor-dev:poststackcubegeometries:1520549770",
#                 "npequinor-dev:poststackcubegeometries:1518226980",
#                 "npequinor-dev:poststackcubegeometries:1520366630",
#                 "npequinor-dev:poststackcubegeometries:1518447831",
#                 "npequinor-dev:poststackcubegeometries:1519865213",
#                 "npequinor-dev:poststackcubegeometries:1520847853",
#                 "npequinor-dev:poststackcubegeometries:1521570133",
#                 "npequinor-dev:poststackcubegeometries:1518489662",
#                 "npequinor-dev:poststackcubegeometries:1521784426",
#                 "npequinor-dev:poststackcubegeometries:1521698739",
#                 "npequinor-dev:poststackcubegeometries:1521686221",
#                 "npequinor-dev:poststackcubegeometries:1520518516",
#                 "npequinor-dev:poststackcubegeometries:1518280202",
#                 "npequinor-dev:poststackcubegeometries:1518324464",
#                 "npequinor-dev:poststackcubegeometries:1521049665",
#                 "npequinor-dev:poststackcubegeometries:1521825316",
#                 "npequinor-dev:poststackcubegeometries:1520429338",
#                 "npequinor-dev:poststackcubegeometries:1520937477",
#                 "npequinor-dev:poststackcubegeometries:1518287586",
#                 "npequinor-dev:poststackcubegeometries:1520946421"
#             ]
#         }
#     },
#     "seismicprojects": {
#         "Source records count": 2403,
#         "Source unique records ids count": 2403,
#         "OSDU custom ingested unique ids count": 2401,
#         "Common records count (source-custom)": 2400,
#         "Ingeted into OSDU (custom) but missing in source": {
#             "count": 1,
#             "ids": [
#                 "npequinor-dev:seismicprojects:1502387784"
#             ]
#         },
#         "Present in source but missing in OSDU (custom)": {
#             "count": 3,
#             "ids": [
#                 "npequinor-dev:seismicprojects:1519805172",
#                 "npequinor-dev:seismicprojects:1518607430",
#                 "npequinor-dev:seismicprojects:1518672457"
#             ]
#         }
#     },
#     "navigationsets": {
#         "Source records count": 3248,
#         "Source unique records ids count": 3248,
#         "OSDU custom ingested unique ids count": 3245,
#         "Common records count (source-custom)": 3245,
#         "Ingeted into OSDU (custom) but missing in source": {
#             "count": 0,
#             "ids": []
#         },
#         "Present in source but missing in OSDU (custom)": {
#             "count": 3,
#             "ids": [
#                 "npequinor-dev:navigationsets:1519805170",
#                 "npequinor-dev:navigationsets:1518607428",
#                 "npequinor-dev:navigationsets:1518672455"
#             ]
#         }
#     },
#     "binsetgrids": {
#         "Source records count": 2143,
#         "Source unique records ids count": 2143,
#         "OSDU custom ingested unique ids count": 2142,
#         "Common records count (source-custom)": 2140,
#         "Ingeted into OSDU (custom) but missing in source": {
#             "count": 2,
#             "ids": [
#                 "npequinor-dev:binsetgrids:1507739908",
#                 "npequinor-dev:binsetgrids:1502387784"
#             ]
#         },
#         "Present in source but missing in OSDU (custom)": {
#             "count": 3,
#             "ids": [
#                 "npequinor-dev:binsetgrids:1518610157",
#                 "npequinor-dev:binsetgrids:1518672461",
#                 "npequinor-dev:binsetgrids:1519805176"
#             ]
#         }
#     }
# }

# %% [markdown]
# #### 3. Get records from OSDU - well known schemas

# %%
"""
Let's first request the well-known-records (ids and ancestry attributes) from OSDU and store them in a dictionary.
"""

wks_osdu = []
for entity in entities.keys():
    wks_osdu.extend(entities.get(entity).get('osdu_well_known_schema'))

osdu_ingested_wks_records = dict()
columns = ["tags.sourceSystem", "tags.EqnrSource", "data.Source"]  # Three possible columns to query to match the source

for wks_kind in list(set(wks_osdu)):
    print(f"\n--- Working in wks: {wks_kind} ---")

    for column in columns:
        search_payload =  {
            "kind": wks_kind,
            "query": f"{column}:\"{source.upper()}\"",
            "returnedFields": ["id", "ancestry"]
        }

        osdu_wks_records = osdu_client.app_query_returning_json("search/v2/query_with_cursor", search_payload)

        if wks_kind not in osdu_ingested_wks_records.keys():
            osdu_ingested_wks_records[wks_kind] = osdu_wks_records
            print(f"> Retrieved {len(osdu_wks_records)} records from OSDU of kind {wks_kind}")
        else:
            if len(osdu_wks_records) > len(osdu_ingested_wks_records.get(wks_kind)):
                osdu_ingested_wks_records[wks_kind] = osdu_wks_records
                print(f"> Retrieved {len(osdu_wks_records)} records from OSDU of kind {wks_kind}")
# Out:
# --- Working in wks: osdu:wks:dataset--FileCollection.SEGY:1.0.0 ---
# > Retrieved 18885 records from OSDU of kind osdu:wks:dataset--FileCollection.SEGY:1.0.0
#
# --- Working in wks: osdu:wks:dataset--FileCollection.Generic:1.0.0 ---
# > Retrieved 3245 records from OSDU of kind osdu:wks:dataset--FileCollection.Generic:1.0.0
#
# --- Working in wks: osdu:wks:master-data--SeismicProcessingProject:1.2.0 ---
# > Retrieved 2400 records from OSDU of kind osdu:wks:master-data--SeismicProcessingProject:1.2.0
#
# --- Working in wks: osdu:wks:work-product-component--SeismicBinGrid:1.0.0 ---
# > Retrieved 2072 records from OSDU of kind osdu:wks:work-product-component--SeismicBinGrid:1.0.0
#
# --- Working in wks: osdu:wks:master-data--SeismicAcquisitionSurvey:1.2.0 ---
# > Retrieved 1971 records from OSDU of kind osdu:wks:master-data--SeismicAcquisitionSurvey:1.2.0
#
# --- Working in wks: osdu:wks:work-product-component--SeismicTraceData:1.3.0 ---
# > Retrieved 18832 records from OSDU of kind osdu:wks:work-product-component--SeismicTraceData:1.3.0

# %%
"""
Let's now find out which custom records are actually referenced by the well known records and let's check for their relationship.

    - X number of custom records/total of this custom kind found in ancestry of this wks kind.
    - Custom records by kind that are not found in any ancestry of their respective wks.
"""

def get_ancestry_unique_ids(osdu_wks_kind):

    osdu_wks_records = osdu_ingested_wks_records.get(osdu_wks_kind)
    osdu_wks_record_ids = [record.get('id') for record in osdu_wks_records]                                                                                     # records should contain the ancestry attribute within eahc of them
    osdu_ancestry_ids = [record.rsplit(":", maxsplit=1)[0] for wks_record in osdu_wks_records for record in wks_record.get('ancestry').get('parents')]          # this is potentially going to give issues as MAYBE not all custom records have a version appended to the id
    osdu_ancestry_unique_ids = list(set(osdu_ancestry_ids))
    
    return osdu_wks_record_ids, osdu_ancestry_unique_ids

def contrast_custom_to_wks_records(osdu_wks_name, entity_name):
    
    osdu_wks_total_record_ids, ancestry_ids = get_ancestry_unique_ids(osdu_wks_name)
    osdu_custom_records_ids = [record.get('id') for record in osdu_ingested_custom_records.get(entity_name)]

    custom_ids_found_wks_ancestry = list(set(osdu_custom_records_ids).intersection(ancestry_ids))

    custom_ids_missing_in_wks_ansestry = list(set([record for record in osdu_custom_records_ids if record not in ancestry_ids]))

    return osdu_custom_records_ids, osdu_wks_total_record_ids, custom_ids_found_wks_ancestry, custom_ids_missing_in_wks_ansestry

# %%
# NOTE: Most likely these datasets do not have a wks record because they do not have a related cube/cubegeometry (filepath), therefore no SEGY file generic can be created
# this means that we can create the seismic trace wks records but they wont have a cubegeometry and therefore filepath and therefore SEGY file to be referenced.

osdu_custom_to_wks_summary = dict()

for entity_name in entities.keys():

    entity_summary = []

    print(f"----- Working in entity: {entity_name} -----")

    osdu_related_wks = entities.get(entity_name).get('osdu_well_known_schema')

    print(f"Schemas that should be analysed: {osdu_related_wks}")

    for wks_i in osdu_related_wks:
        print(f"> Working in wks: {wks_i} -----")

        osdu_custom_records_ids, osdu_wks_total_record_ids, custom_ids_found_wks_ancestry, custom_ids_missing_in_wks_ansestry = contrast_custom_to_wks_records(wks_i, entity_name)

        summary_i = {
            "Osdu related WKS": wks_i,
            "Osdu custom records ids (ingested)": len(osdu_custom_records_ids),
            "Osdu wks records ids (total)": len(osdu_wks_total_record_ids),
            "Osdu custom ids found in wks ancestry (mapped properly)": len(custom_ids_found_wks_ancestry),
            "Osdu custom ids NOT found in wks ancestry (poptential issues during mapping)": custom_ids_missing_in_wks_ansestry
        }

        entity_summary.append(summary_i)

    
    osdu_custom_to_wks_summary[entity_name] = entity_summary
# Out:
# ----- Working in entity: seismicsurveys -----
# Schemas that should be analysed: ['osdu:wks:master-data--SeismicAcquisitionSurvey:1.2.0']
# > Working in wks: osdu:wks:master-data--SeismicAcquisitionSurvey:1.2.0 -----
# ----- Working in entity: seismicpoststackdatasets -----
# Schemas that should be analysed: ['osdu:wks:dataset--FileCollection.SEGY:1.0.0', 'osdu:wks:work-product-component--SeismicTraceData:1.3.0']
# > Working in wks: osdu:wks:dataset--FileCollection.SEGY:1.0.0 -----
# > Working in wks: osdu:wks:work-product-component--SeismicTraceData:1.3.0 -----
# ----- Working in entity: poststackcubes -----
# Schemas that should be analysed: ['osdu:wks:work-product-component--SeismicTraceData:1.3.0']
# > Working in wks: osdu:wks:work-product-component--SeismicTraceData:1.3.0 -----
# ----- Working in entity: poststackcubegeometries -----
# Schemas that should be analysed: ['osdu:wks:work-product-component--SeismicTraceData:1.3.0', 'osdu:wks:dataset--FileCollection.SEGY:1.0.0']
# > Working in wks: osdu:wks:work-product-component--SeismicTraceData:1.3.0 -----
# > Working in wks: osdu:wks:dataset--FileCollection.SEGY:1.0.0 -----
# ----- Working in entity: seismicprojects -----
# Schemas that should be analysed: ['osdu:wks:master-data--SeismicProcessingProject:1.2.0']
# > Working in wks: osdu:wks:master-data--SeismicProcessingProject:1.2.0 -----
# ----- Working in entity: navigationsets -----
# Schemas that should be analysed: ['osdu:wks:dataset--FileCollection.Generic:1.0.0']
# > Working in wks: osdu:wks:dataset--FileCollection.Generic:1.0.0 -----
# ----- Working in entity: binsetgrids -----
# Schemas that should be analysed: ['osdu:wks:work-product-component--SeismicBinGrid:1.0.0']
# > Working in wks: osdu:wks:work-product-component--SeismicBinGrid:1.0.0 -----

# %%
print(json.dumps(osdu_custom_to_wks_summary, indent=4))
# Out:
# {
#     "seismicsurveys": [
#         {
#             "Osdu related WKS": "osdu:wks:master-data--SeismicAcquisitionSurvey:1.2.0",
#             "Osdu custom records ids (ingested)": 1971,
#             "Osdu wks records ids (total)": 1971,
#             "Osdu custom ids found in wks ancestry (mapped properly)": 1971,
#             "Osdu custom ids NOT found in wks ancestry (poptential issues during mapping)": []
#         }
#     ],
#     "seismicpoststackdatasets": [
#         {
#             "Osdu related WKS": "osdu:wks:dataset--FileCollection.SEGY:1.0.0",
#             "Osdu custom records ids (ingested)": 18886,
#             "Osdu wks records ids (total)": 18885,
#             "Osdu custom ids found in wks ancestry (mapped properly)": 18885,
#             "Osdu custom ids NOT found in wks ancestry (poptential issues during mapping)": [
#                 "npequinor-dev:seismicpoststackdatasets:1507739908"
#             ]
#         },
#         {
#             "Osdu related WKS": "osdu:wks:work-product-component--SeismicTraceData:1.3.0",
#             "Osdu custom records ids (ingested)": 18886,
#             "Osdu wks records ids (total)": 18832,
#             "Osdu custom ids found in wks ancestry (mapped properly)": 18832,
#             "Osdu custom ids NOT found in wks ancestry (poptential issues during mapping)": [
#                 "npequinor-dev:seismicpoststackdatasets:1091186784",
#                 "npequinor-dev:seismicpoststackdatasets:1506483286",
#                 "npequinor-dev:seismicpoststackdatasets:1506870508",
#                 "npequinor-dev:seismicpoststackdatasets:1506410700",
#                 "npequinor-dev:seismicpoststackdatasets:1091604943",
#                 "npequinor-dev:seismicpoststackdatasets:1507074278",
#                 "npequinor-dev:seismicpoststackdatasets:1507137221",
#                 "npequinor-dev:seismicpoststackdatasets:1505802201",
#                 "npequinor-dev:seismicpoststackdatasets:1091326480",
#                 "npequinor-dev:seismicpoststackdatasets:1506596537",
#                 "npequinor-dev:seismicpoststackdatasets:1506593126",
#                 "npequinor-dev:seismicpoststackdatasets:1167115772",
#                 "npequinor-dev:seismicpoststackdatasets:1506536288",
#                 "npequinor-dev:seismicpoststackdatasets:1507086793",
#                 "npequinor-dev:seismicpoststackdatasets:1506463067",
#                 "npequinor-dev:seismicpoststackdatasets:1506972262",
#                 "npequinor-dev:seismicpoststackdatasets:1506539098",
#                 "npequinor-dev:seismicpoststackdatasets:1507739908",
#                 "npequinor-dev:seismicpoststackdatasets:1507154705",
#                 "npequinor-dev:seismicpoststackdatasets:1091297630",
#                 "npequinor-dev:seismicpoststackdatasets:1505897236",
#                 "npequinor-dev:seismicpoststackdatasets:1091617359",
#                 "npequinor-dev:seismicpoststackdatasets:1163174618",
#                 "npequinor-dev:seismicpoststackdatasets:1507119737",
#                 "npequinor-dev:seismicpoststackdatasets:1506599068",
#                 "npequinor-dev:seismicpoststackdatasets:1506933566",
#                 "npequinor-dev:seismicpoststackdatasets:1506015972",
#                 "npequinor-dev:seismicpoststackdatasets:1506120586",
#                 "npequinor-dev:seismicpoststackdatasets:1506681992",
#                 "npequinor-dev:seismicpoststackdatasets:1507061347",
#                 "npequinor-dev:seismicpoststackdatasets:1160732427",
#                 "npequinor-dev:seismicpoststackdatasets:1506516158",
#                 "npequinor-dev:seismicpoststackdatasets:1506622488",
#                 "npequinor-dev:seismicpoststackdatasets:1168224684",
#                 "npequinor-dev:seismicpoststackdatasets:1506661615",
#                 "npequinor-dev:seismicpoststackdatasets:1506698922",
#                 "npequinor-dev:seismicpoststackdatasets:1506945232",
#                 "npequinor-dev:seismicpoststackdatasets:1506805210",
#                 "npequinor-dev:seismicpoststackdatasets:1168218743",
#                 "npequinor-dev:seismicpoststackdatasets:1168246664",
#                 "npequinor-dev:seismicpoststackdatasets:1506716406",
#                 "npequinor-dev:seismicpoststackdatasets:1507064964",
#                 "npequinor-dev:seismicpoststackdatasets:1506512183",
#                 "npequinor-dev:seismicpoststackdatasets:1506912118",
#                 "npequinor-dev:seismicpoststackdatasets:1506174781",
#                 "npequinor-dev:seismicpoststackdatasets:1506929602",
#                 "npequinor-dev:seismicpoststackdatasets:31367077",
#                 "npequinor-dev:seismicpoststackdatasets:1506557763",
#                 "npequinor-dev:seismicpoststackdatasets:1505844130",
#                 "npequinor-dev:seismicpoststackdatasets:1506755524",
#                 "npequinor-dev:seismicpoststackdatasets:1506062181",
#                 "npequinor-dev:seismicpoststackdatasets:1506419866",
#                 "npequinor-dev:seismicpoststackdatasets:1507010693",
#                 "npequinor-dev:seismicpoststackdatasets:1168394308"
#             ]
#         }
#     ],
#     "poststackcubes": [
#         {
#             "Osdu related WKS": "osdu:wks:work-product-component--SeismicTraceData:1.3.0",
#             "Osdu custom records ids (ingested)": 18828,
#             "Osdu wks records ids (total)": 18832,
#             "Osdu custom ids found in wks ancestry (mapped properly)": 18771,
#             "Osdu custom ids NOT found in wks ancestry (poptential issues during mapping)": [
#                 "npequinor-dev:poststackcubes:1507119744",
#                 "npequinor-dev:poststackcubes:1506474669",
#                 "npequinor-dev:poststackcubes:1506661620",
#                 "npequinor-dev:poststackcubes:1506122973",
#                 "npequinor-dev:poststackcubes:1506062186",
#                 "npequinor-dev:poststackcubes:1506912125",
#                 "npequinor-dev:poststackcubes:1510991048",
#                 "npequinor-dev:poststackcubes:1507015526",
#                 "npequinor-dev:poststackcubes:1506755531",
#                 "npequinor-dev:poststackcubes:1506681997",
#                 "npequinor-dev:poststackcubes:1512424193",
#                 "npequinor-dev:poststackcubes:1657851604",
#                 "npequinor-dev:poststackcubes:1657851549",
#                 "npequinor-dev:poststackcubes:1506716831",
#                 "npequinor-dev:poststackcubes:1505844135",
#                 "npequinor-dev:poststackcubes:1506516163",
#                 "npequinor-dev:poststackcubes:1657851600",
#                 "npequinor-dev:poststackcubes:1657850515",
#                 "npequinor-dev:poststackcubes:1505913336",
#                 "npequinor-dev:poststackcubes:1657851585",
#                 "npequinor-dev:poststackcubes:1506933573",
#                 "npequinor-dev:poststackcubes:1509347982",
#                 "npequinor-dev:poststackcubes:1506698929",
#                 "npequinor-dev:poststackcubes:1506599073",
#                 "npequinor-dev:poststackcubes:1506425503",
#                 "npequinor-dev:poststackcubes:1657851536",
#                 "npequinor-dev:poststackcubes:1506603035",
#                 "npequinor-dev:poststackcubes:1657850512",
#                 "npequinor-dev:poststackcubes:1506483291",
#                 "npequinor-dev:poststackcubes:1506567460",
#                 "npequinor-dev:poststackcubes:1510997351",
#                 "npequinor-dev:poststackcubes:1507078954",
#                 "npequinor-dev:poststackcubes:1506929607",
#                 "npequinor-dev:poststackcubes:1657851596",
#                 "npequinor-dev:poststackcubes:1505802206",
#                 "npequinor-dev:poststackcubes:1506972269",
#                 "npequinor-dev:poststackcubes:1506495859",
#                 "npequinor-dev:poststackcubes:1506623685",
#                 "npequinor-dev:poststackcubes:1506540257",
#                 "npequinor-dev:poststackcubes:1506512188",
#                 "npequinor-dev:poststackcubes:1657850526",
#                 "npequinor-dev:poststackcubes:1507137228",
#                 "npequinor-dev:poststackcubes:1506805217",
#                 "npequinor-dev:poststackcubes:1506950999",
#                 "npequinor-dev:poststackcubes:1506175367",
#                 "npequinor-dev:poststackcubes:1506870515",
#                 "npequinor-dev:poststackcubes:1506536293",
#                 "npequinor-dev:poststackcubes:1657851610",
#                 "npequinor-dev:poststackcubes:1657863747",
#                 "npequinor-dev:poststackcubes:1657850530",
#                 "npequinor-dev:poststackcubes:1657850522",
#                 "npequinor-dev:poststackcubes:1507061352",
#                 "npequinor-dev:poststackcubes:1507154712",
#                 "npequinor-dev:poststackcubes:1506593131",
#                 "npequinor-dev:poststackcubes:1507065318",
#                 "npequinor-dev:poststackcubes:1506413987",
#                 "npequinor-dev:poststackcubes:1507090509"
#             ]
#         }
#     ],
#     "poststackcubegeometries": [
#         {
#             "Osdu related WKS": "osdu:wks:work-product-component--SeismicTraceData:1.3.0",
#             "Osdu custom records ids (ingested)": 18824,
#             "Osdu wks records ids (total)": 18832,
#             "Osdu custom ids found in wks ancestry (mapped properly)": 18771,
#             "Osdu custom ids NOT found in wks ancestry (poptential issues during mapping)": [
#                 "npequinor-dev:poststackcubegeometries:1657850522",
#                 "npequinor-dev:poststackcubegeometries:1505802206",
#                 "npequinor-dev:poststackcubegeometries:1506474669",
#                 "npequinor-dev:poststackcubegeometries:1506122973",
#                 "npequinor-dev:poststackcubegeometries:1657850512",
#                 "npequinor-dev:poststackcubegeometries:1657863747",
#                 "npequinor-dev:poststackcubegeometries:1505844135",
#                 "npequinor-dev:poststackcubegeometries:1657851596",
#                 "npequinor-dev:poststackcubegeometries:1507015526",
#                 "npequinor-dev:poststackcubegeometries:1506870515",
#                 "npequinor-dev:poststackcubegeometries:1657850515",
#                 "npequinor-dev:poststackcubegeometries:1657850530",
#                 "npequinor-dev:poststackcubegeometries:1507154712",
#                 "npequinor-dev:poststackcubegeometries:1506681997",
#                 "npequinor-dev:poststackcubegeometries:1657851604",
#                 "npequinor-dev:poststackcubegeometries:1506425503",
#                 "npequinor-dev:poststackcubegeometries:1657851610",
#                 "npequinor-dev:poststackcubegeometries:1506593131",
#                 "npequinor-dev:poststackcubegeometries:1506567460",
#                 "npequinor-dev:poststackcubegeometries:1506516163",
#                 "npequinor-dev:poststackcubegeometries:1506540257",
#                 "npequinor-dev:poststackcubegeometries:1507078954",
#                 "npequinor-dev:poststackcubegeometries:1506495859",
#                 "npequinor-dev:poststackcubegeometries:1506175367",
#                 "npequinor-dev:poststackcubegeometries:1507061352",
#                 "npequinor-dev:poststackcubegeometries:1506512188",
#                 "npequinor-dev:poststackcubegeometries:1506536293",
#                 "npequinor-dev:poststackcubegeometries:1506698929",
#                 "npequinor-dev:poststackcubegeometries:1506950999",
#                 "npequinor-dev:poststackcubegeometries:1506483291",
#                 "npequinor-dev:poststackcubegeometries:1506912125",
#                 "npequinor-dev:poststackcubegeometries:1506805217",
#                 "npequinor-dev:poststackcubegeometries:1506661620",
#                 "npequinor-dev:poststackcubegeometries:1657851600",
#                 "npequinor-dev:poststackcubegeometries:1507065318",
#                 "npequinor-dev:poststackcubegeometries:1657851585",
#                 "npequinor-dev:poststackcubegeometries:1506599073",
#                 "npequinor-dev:poststackcubegeometries:1505913336",
#                 "npequinor-dev:poststackcubegeometries:1506062186",
#                 "npequinor-dev:poststackcubegeometries:1657850526",
#                 "npequinor-dev:poststackcubegeometries:1506603035",
#                 "npequinor-dev:poststackcubegeometries:1506716831",
#                 "npequinor-dev:poststackcubegeometries:1507090509",
#                 "npequinor-dev:poststackcubegeometries:1506933573",
#                 "npequinor-dev:poststackcubegeometries:1506755531",
#                 "npequinor-dev:poststackcubegeometries:1507137228",
#                 "npequinor-dev:poststackcubegeometries:1506972269",
#                 "npequinor-dev:poststackcubegeometries:1506929607",
#                 "npequinor-dev:poststackcubegeometries:1506623685",
#                 "npequinor-dev:poststackcubegeometries:1507119744",
#                 "npequinor-dev:poststackcubegeometries:1506413987",
#                 "npequinor-dev:poststackcubegeometries:1657851536",
#                 "npequinor-dev:poststackcubegeometries:1657851549"
#             ]
#         },
#         {
#             "Osdu related WKS": "osdu:wks:dataset--FileCollection.SEGY:1.0.0",
#             "Osdu custom records ids (ingested)": 18824,
#             "Osdu wks records ids (total)": 18885,
#             "Osdu custom ids found in wks ancestry (mapped properly)": 18824,
#             "Osdu custom ids NOT found in wks ancestry (poptential issues during mapping)": []
#         }
#     ],
#     "seismicprojects": [
#         {
#             "Osdu related WKS": "osdu:wks:master-data--SeismicProcessingProject:1.2.0",
#             "Osdu custom records ids (ingested)": 2401,
#             "Osdu wks records ids (total)": 2400,
#             "Osdu custom ids found in wks ancestry (mapped properly)": 2400,
#             "Osdu custom ids NOT found in wks ancestry (poptential issues during mapping)": [
#                 "npequinor-dev:seismicprojects:1502387784"
#             ]
#         }
#     ],
#     "navigationsets": [
#         {
#             "Osdu related WKS": "osdu:wks:dataset--FileCollection.Generic:1.0.0",
#             "Osdu custom records ids (ingested)": 3245,
#             "Osdu wks records ids (total)": 3245,
#             "Osdu custom ids found in wks ancestry (mapped properly)": 3245,
#             "Osdu custom ids NOT found in wks ancestry (poptential issues during mapping)": []
#         }
#     ],
#     "binsetgrids": [
#         {
#             "Osdu related WKS": "osdu:wks:work-product-component--SeismicBinGrid:1.0.0",
#             "Osdu custom records ids (ingested)": 2142,
#             "Osdu wks records ids (total)": 2072,
#             "Osdu custom ids found in wks ancestry (mapped properly)": 2072,
#             "Osdu custom ids NOT found in wks ancestry (poptential issues during mapping)": [
#                 "npequinor-dev:binsetgrids:200586815",
#                 "npequinor-dev:binsetgrids:200586820",
#                 "npequinor-dev:binsetgrids:200587409",
#                 "npequinor-dev:binsetgrids:200586841",
#                 "npequinor-dev:binsetgrids:1502387784",
#                 "npequinor-dev:binsetgrids:200586805",
#                 "npequinor-dev:binsetgrids:200586810",
#                 "npequinor-dev:binsetgrids:200586843",
#                 "npequinor-dev:binsetgrids:200586829",
#                 "npequinor-dev:binsetgrids:200587992",
#                 "npequinor-dev:binsetgrids:200586594",
#                 "npequinor-dev:binsetgrids:200586796",
#                 "npequinor-dev:binsetgrids:200586811",
#                 "npequinor-dev:binsetgrids:200588380",
#                 "npequinor-dev:binsetgrids:200586787",
#                 "npequinor-dev:binsetgrids:200586834",
#                 "npequinor-dev:binsetgrids:200586830",
#                 "npequinor-dev:binsetgrids:200586840",
#                 "npequinor-dev:binsetgrids:200586806",
#                 "npequinor-dev:binsetgrids:200586836",
#                 "npequinor-dev:binsetgrids:200586828",
#                 "npequinor-dev:binsetgrids:200586827",
#                 "npequinor-dev:binsetgrids:200586823",
#                 "npequinor-dev:binsetgrids:200586826",
#                 "npequinor-dev:binsetgrids:200586802",
#                 "npequinor-dev:binsetgrids:200586833",
#                 "npequinor-dev:binsetgrids:200586835",
#                 "npequinor-dev:binsetgrids:200586846",
#                 "npequinor-dev:binsetgrids:200586831",
#                 "npequinor-dev:binsetgrids:200588882",
#                 "npequinor-dev:binsetgrids:200586803",
#                 "npequinor-dev:binsetgrids:200586832",
#                 "npequinor-dev:binsetgrids:200586801",
#                 "npequinor-dev:binsetgrids:200586842",
#                 "npequinor-dev:binsetgrids:200586795",
#                 "npequinor-dev:binsetgrids:200586791",
#                 "npequinor-dev:binsetgrids:1507739908",
#                 "npequinor-dev:binsetgrids:200586822",
#                 "npequinor-dev:binsetgrids:200586825",
#                 "npequinor-dev:binsetgrids:200588833",
#                 "npequinor-dev:binsetgrids:200586807",
#                 "npequinor-dev:binsetgrids:200586839",
#                 "npequinor-dev:binsetgrids:200586792",
#                 "npequinor-dev:binsetgrids:200586809",
#                 "npequinor-dev:binsetgrids:200588129",
#                 "npequinor-dev:binsetgrids:200586799",
#                 "npequinor-dev:binsetgrids:200586800",
#                 "npequinor-dev:binsetgrids:200586797",
#                 "npequinor-dev:binsetgrids:200589089",
#                 "npequinor-dev:binsetgrids:200586569",
#                 "npequinor-dev:binsetgrids:200586793",
#                 "npequinor-dev:binsetgrids:200586837",
#                 "npequinor-dev:binsetgrids:200586845",
#                 "npequinor-dev:binsetgrids:200586794",
#                 "npequinor-dev:binsetgrids:200586790",
#                 "npequinor-dev:binsetgrids:200586838",
#                 "npequinor-dev:binsetgrids:200586819",
#                 "npequinor-dev:binsetgrids:200589086",
#                 "npequinor-dev:binsetgrids:200586812",
#                 "npequinor-dev:binsetgrids:200586798",
#                 "npequinor-dev:binsetgrids:200586808",
#                 "npequinor-dev:binsetgrids:200586821",
#                 "npequinor-dev:binsetgrids:200586818",
#                 "npequinor-dev:binsetgrids:200586817",
#                 "npequinor-dev:binsetgrids:200586804",
#                 "npequinor-dev:binsetgrids:200586591",
#                 "npequinor-dev:binsetgrids:200586844",
#                 "npequinor-dev:binsetgrids:200586824",
#                 "npequinor-dev:binsetgrids:200586593",
#                 "npequinor-dev:binsetgrids:200586590"
#             ]
#         }
#     ]
# }

# %%
"""
Let's combine both summaries, source to custom AND cutom to wks.
"""

full_summary = dict()

for entity_name in entities.keys():
    full_summary[entity_name] = {
        "Source to custom summary": sdb_osdu_unique_ids_custom_records.get(entity_name),
        "Custom to WKS summary": osdu_custom_to_wks_summary.get(entity_name)
    }

print(json.dumps(full_summary, indent=4))
# Out:
# {
#     "seismicsurveys": {
#         "Source to custom summary": {
#             "Source records count": 1975,
#             "Source unique records ids count": 1975,
#             "OSDU custom ingested unique ids count": 1971,
#             "Common records count (source-custom)": 1971,
#             "Ingeted into OSDU (custom) but missing in source": {
#                 "count": 0,
#                 "ids": []
#             },
#             "Present in source but missing in OSDU (custom)": {
#                 "count": 4,
#                 "ids": [
#                     "npequinor-dev:seismicsurveys:1518672454",
#                     "npequinor-dev:seismicsurveys:1518355860",
#                     "npequinor-dev:seismicsurveys:1518607427",
#                     "npequinor-dev:seismicsurveys:1518815961"
#                 ]
#             }
#         },
#         "Custom to WKS summary": [
#             {
#                 "Osdu related WKS": "osdu:wks:master-data--SeismicAcquisitionSurvey:1.2.0",
#                 "Osdu custom records ids (ingested)": 1971,
#                 "Osdu wks records ids (total)": 1971,
#                 "Osdu custom ids found in wks ancestry (mapped properly)": 1971,
#                 "Osdu custom ids NOT found in wks ancestry (poptential issues during mapping)": []
#             }
#         ]
#     },
#     "seismicpoststackdatasets": {
#         "Source to custom summary": {
#             "Source records count": 19464,
#             "Source unique records ids count": 19452,
#             "OSDU custom ingested unique ids count": 18886,
#             "Common records count (source-custom)": 18875,
#             "Ingeted into OSDU (custom) but missing in source": {
#                 "count": 11,
#                 "ids": [
#                     "npequinor-dev:seismicpoststackdatasets:1507739908",
#                     "npequinor-dev:seismicpoststackdatasets:1512424188",
#                     "npequinor-dev:seismicpoststackdatasets:1513243199",
#                     "npequinor-dev:seismicpoststackdatasets:1509101910",
#                     "npequinor-dev:seismicpoststackdatasets:1509706310",
#                     "npequinor-dev:seismicpoststackdatasets:1509347977",
#                     "npequinor-dev:seismicpoststackdatasets:1510915519",
#                     "npequinor-dev:seismicpoststackdatasets:1509279074",
#                     "npequinor-dev:seismicpoststackdatasets:1510915524",
#                     "npequinor-dev:seismicpoststackdatasets:1511110884",
#                     "npequinor-dev:seismicpoststackdatasets:1510264906"
#                 ]
#             },
#             "Present in source but missing in OSDU (custom)": {
#                 "count": 577,
#                 "ids": [
#                     "npequinor-dev:seismicpoststackdatasets:1521150705",
#                     "npequinor-dev:seismicpoststackdatasets:1521585262",
#                     "npequinor-dev:seismicpoststackdatasets:1520450638",
#                     "npequinor-dev:seismicpoststackdatasets:1521944440",
#                     "npequinor-dev:seismicpoststackdatasets:1519040620",
#                     "npequinor-dev:seismicpoststackdatasets:1518434210",
#                     "npequinor-dev:seismicpoststackdatasets:1519141832",
#                     "npequinor-dev:seismicpoststackdatasets:1518560012",
#                     "npequinor-dev:seismicpoststackdatasets:1520262785",
#                     "npequinor-dev:seismicpoststackdatasets:1521284432",
#                     "npequinor-dev:seismicpoststackdatasets:1519714663",
#                     "npequinor-dev:seismicpoststackdatasets:1521396149",
#                     "npequinor-dev:seismicpoststackdatasets:1518459005",
#                     "npequinor-dev:seismicpoststackdatasets:1520815240",
#                     "npequinor-dev:seismicpoststackdatasets:1520328883",
#                     "npequinor-dev:seismicpoststackdatasets:1518441018",
#                     "npequinor-dev:seismicpoststackdatasets:1521223491",
#                     "npequinor-dev:seismicpoststackdatasets:1520890576",
#                     "npequinor-dev:seismicpoststackdatasets:1519990064",
#                     "npequinor-dev:seismicpoststackdatasets:1522086670",
#                     "npequinor-dev:seismicpoststackdatasets:1519988244",
#                     "npequinor-dev:seismicpoststackdatasets:1519099851",
#                     "npequinor-dev:seismicpoststackdatasets:1519197037",
#                     "npequinor-dev:seismicpoststackdatasets:1520366625",
#                     "npequinor-dev:seismicpoststackdatasets:1520910252",
#                     "npequinor-dev:seismicpoststackdatasets:1520966500",
#                     "npequinor-dev:seismicpoststackdatasets:1520804272",
#                     "npequinor-dev:seismicpoststackdatasets:1518327261",
#                     "npequinor-dev:seismicpoststackdatasets:1519857037",
#                     "npequinor-dev:seismicpoststackdatasets:1521706462",
#                     "npequinor-dev:seismicpoststackdatasets:1519330703",
#                     "npequinor-dev:seismicpoststackdatasets:1519878820",
#                     "npequinor-dev:seismicpoststackdatasets:1520350469",
#                     "npequinor-dev:seismicpoststackdatasets:1519286606",
#                     "npequinor-dev:seismicpoststackdatasets:1520033469",
#                     "npequinor-dev:seismicpoststackdatasets:1520172069",
#                     "npequinor-dev:seismicpoststackdatasets:1521167200",
#                     "npequinor-dev:seismicpoststackdatasets:1518823894",
#                     "npequinor-dev:seismicpoststackdatasets:1518512199",
#                     "npequinor-dev:seismicpoststackdatasets:1520518511",
#                     "npequinor-dev:seismicpoststackdatasets:1521566419",
#                     "npequinor-dev:seismicpoststackdatasets:1520486325",
#                     "npequinor-dev:seismicpoststackdatasets:1519787920",
#                     "npequinor-dev:seismicpoststackdatasets:1521490574",
#                     "npequinor-dev:seismicpoststackdatasets:1519481249",
#                     "npequinor-dev:seismicpoststackdatasets:1518904068",
#                     "npequinor-dev:seismicpoststackdatasets:1519025092",
#                     "npequinor-dev:seismicpoststackdatasets:1520851259",
#                     "npequinor-dev:seismicpoststackdatasets:1521199882",
#                     "npequinor-dev:seismicpoststackdatasets:1518577927",
#                     "npequinor-dev:seismicpoststackdatasets:1520324160",
#                     "npequinor-dev:seismicpoststackdatasets:1521314498",
#                     "npequinor-dev:seismicpoststackdatasets:1518215897",
#                     "npequinor-dev:seismicpoststackdatasets:1519701620",
#                     "npequinor-dev:seismicpoststackdatasets:1521698734",
#                     "npequinor-dev:seismicpoststackdatasets:1518331843",
#                     "npequinor-dev:seismicpoststackdatasets:1521700495",
#                     "npequinor-dev:seismicpoststackdatasets:1520808536",
#                     "npequinor-dev:seismicpoststackdatasets:1521788198",
#                     "npequinor-dev:seismicpoststackdatasets:1521827775",
#                     "npequinor-dev:seismicpoststackdatasets:1519863383",
#                     "npequinor-dev:seismicpoststackdatasets:1521461540",
#                     "npequinor-dev:seismicpoststackdatasets:1520946416",
#                     "npequinor-dev:seismicpoststackdatasets:1521338592",
#                     "npequinor-dev:seismicpoststackdatasets:1519308108",
#                     "npequinor-dev:seismicpoststackdatasets:1518623117",
#                     "npequinor-dev:seismicpoststackdatasets:1519926655",
#                     "npequinor-dev:seismicpoststackdatasets:1521524211",
#                     "npequinor-dev:seismicpoststackdatasets:1518249082",
#                     "npequinor-dev:seismicpoststackdatasets:1520122869",
#                     "npequinor-dev:seismicpoststackdatasets:1521345439",
#                     "npequinor-dev:seismicpoststackdatasets:1518219589",
#                     "npequinor-dev:seismicpoststackdatasets:1520555461",
#                     "npequinor-dev:seismicpoststackdatasets:1519211664",
#                     "npequinor-dev:seismicpoststackdatasets:1521078867",
#                     "npequinor-dev:seismicpoststackdatasets:1519624527",
#                     "npequinor-dev:seismicpoststackdatasets:1521784406",
#                     "npequinor-dev:seismicpoststackdatasets:1520672166",
#                     "npequinor-dev:seismicpoststackdatasets:1519558363",
#                     "npequinor-dev:seismicpoststackdatasets:1519047008",
#                     "npequinor-dev:seismicpoststackdatasets:1522024790",
#                     "npequinor-dev:seismicpoststackdatasets:1519019916",
#                     "npequinor-dev:seismicpoststackdatasets:1522014745",
#                     "npequinor-dev:seismicpoststackdatasets:1521052211",
#                     "npequinor-dev:seismicpoststackdatasets:1521234455",
#                     "npequinor-dev:seismicpoststackdatasets:1521074349",
#                     "npequinor-dev:seismicpoststackdatasets:1522319655",
#                     "npequinor-dev:seismicpoststackdatasets:1521179718",
#                     "npequinor-dev:seismicpoststackdatasets:1521786302",
#                     "npequinor-dev:seismicpoststackdatasets:1519930295",
#                     "npequinor-dev:seismicpoststackdatasets:1518981264",
#                     "npequinor-dev:seismicpoststackdatasets:1520432181",
#                     "npequinor-dev:seismicpoststackdatasets:1521684284",
#                     "npequinor-dev:seismicpoststackdatasets:1522028588",
#                     "npequinor-dev:seismicpoststackdatasets:1521593726",
#                     "npequinor-dev:seismicpoststackdatasets:1518252774",
#                     "npequinor-dev:seismicpoststackdatasets:1518286216",
#                     "npequinor-dev:seismicpoststackdatasets:1520357229",
#                     "npequinor-dev:seismicpoststackdatasets:1521869148",
#                     "npequinor-dev:seismicpoststackdatasets:1519933935",
#                     "npequinor-dev:seismicpoststackdatasets:1520499782",
#                     "npequinor-dev:seismicpoststackdatasets:1518485240",
#                     "npequinor-dev:seismicpoststackdatasets:1518437614",
#                     "npequinor-dev:seismicpoststackdatasets:1518933758",
#                     "npequinor-dev:seismicpoststackdatasets:1521809299",
#                     "npequinor-dev:seismicpoststackdatasets:1521872522",
#                     "npequinor-dev:seismicpoststackdatasets:1518553547",
#                     "npequinor-dev:seismicpoststackdatasets:1521497261",
#                     "npequinor-dev:seismicpoststackdatasets:1519848869",
#                     "npequinor-dev:seismicpoststackdatasets:1521171064",
#                     "npequinor-dev:seismicpoststackdatasets:1518290154",
#                     "npequinor-dev:seismicpoststackdatasets:1521277688",
#                     "npequinor-dev:seismicpoststackdatasets:1521086128",
#                     "npequinor-dev:seismicpoststackdatasets:1519877000",
#                     "npequinor-dev:seismicpoststackdatasets:1520744927",
#                     "npequinor-dev:seismicpoststackdatasets:1519322474",
#                     "npequinor-dev:seismicpoststackdatasets:1520896866",
#                     "npequinor-dev:seismicpoststackdatasets:1518556210",
#                     "npequinor-dev:seismicpoststackdatasets:1520279843",
#                     "npequinor-dev:seismicpoststackdatasets:1521289667",
#                     "npequinor-dev:seismicpoststackdatasets:1519256873",
#                     "npequinor-dev:seismicpoststackdatasets:1521757737",
#                     "npequinor-dev:seismicpoststackdatasets:1519027522",
#                     "npequinor-dev:seismicpoststackdatasets:1520122911",
#                     "npequinor-dev:seismicpoststackdatasets:1522279577",
#                     "npequinor-dev:seismicpoststackdatasets:1519948660",
#                     "npequinor-dev:seismicpoststackdatasets:1520680710",
#                     "npequinor-dev:seismicpoststackdatasets:1519768948",
#                     "npequinor-dev:seismicpoststackdatasets:1518962416",
#                     "npequinor-dev:seismicpoststackdatasets:1521145117",
#                     "npequinor-dev:seismicpoststackdatasets:1519932115",
#                     "npequinor-dev:seismicpoststackdatasets:1518827580",
#                     "npequinor-dev:seismicpoststackdatasets:1521807439",
#                     "npequinor-dev:seismicpoststackdatasets:1520843376",
#                     "npequinor-dev:seismicpoststackdatasets:1520175574",
#                     "npequinor-dev:seismicpoststackdatasets:1521107163",
#                     "npequinor-dev:seismicpoststackdatasets:1519855215",
#                     "npequinor-dev:seismicpoststackdatasets:1521042534",
#                     "npequinor-dev:seismicpoststackdatasets:1520991355",
#                     "npequinor-dev:seismicpoststackdatasets:1520984609",
#                     "npequinor-dev:seismicpoststackdatasets:1519844327",
#                     "npequinor-dev:seismicpoststackdatasets:1520112656",
#                     "npequinor-dev:seismicpoststackdatasets:1518846382",
#                     "npequinor-dev:seismicpoststackdatasets:1519672835",
#                     "npequinor-dev:seismicpoststackdatasets:1519014740",
#                     "npequinor-dev:seismicpoststackdatasets:1522046653",
#                     "npequinor-dev:seismicpoststackdatasets:1521374317",
#                     "npequinor-dev:seismicpoststackdatasets:1519503475",
#                     "npequinor-dev:seismicpoststackdatasets:1521540832",
#                     "npequinor-dev:seismicpoststackdatasets:1519990207",
#                     "npequinor-dev:seismicpoststackdatasets:1518486253",
#                     "npequinor-dev:seismicpoststackdatasets:1521332812",
#                     "npequinor-dev:seismicpoststackdatasets:1520461513",
#                     "npequinor-dev:seismicpoststackdatasets:1520144645",
#                     "npequinor-dev:seismicpoststackdatasets:1518664820",
#                     "npequinor-dev:seismicpoststackdatasets:1520521359",
#                     "npequinor-dev:seismicpoststackdatasets:1519350031",
#                     "npequinor-dev:seismicpoststackdatasets:1520265633",
#                     "npequinor-dev:seismicpoststackdatasets:1519090985",
#                     "npequinor-dev:seismicpoststackdatasets:1519764299",
#                     "npequinor-dev:seismicpoststackdatasets:1521858969",
#                     "npequinor-dev:seismicpoststackdatasets:1521165268",
#                     "npequinor-dev:seismicpoststackdatasets:1518984255",
#                     "npequinor-dev:seismicpoststackdatasets:1519429936",
#                     "npequinor-dev:seismicpoststackdatasets:1520050153",
#                     "npequinor-dev:seismicpoststackdatasets:1521853919",
#                     "npequinor-dev:seismicpoststackdatasets:1520824184",
#                     "npequinor-dev:seismicpoststackdatasets:1520413011",
#                     "npequinor-dev:seismicpoststackdatasets:1519288450",
#                     "npequinor-dev:seismicpoststackdatasets:1521802813",
#                     "npequinor-dev:seismicpoststackdatasets:1520316799",
#                     "npequinor-dev:seismicpoststackdatasets:1518499837",
#                     "npequinor-dev:seismicpoststackdatasets:1518539127",
#                     "npequinor-dev:seismicpoststackdatasets:1519092771",
#                     "npequinor-dev:seismicpoststackdatasets:1518481146",
#                     "npequinor-dev:seismicpoststackdatasets:1520551414",
#                     "npequinor-dev:seismicpoststackdatasets:1521021038",
#                     "npequinor-dev:seismicpoststackdatasets:1520941412",
#                     "npequinor-dev:seismicpoststackdatasets:1521023005",
#                     "npequinor-dev:seismicpoststackdatasets:1521463258",
#                     "npequinor-dev:seismicpoststackdatasets:1519738492",
#                     "npequinor-dev:seismicpoststackdatasets:1521537181",
#                     "npequinor-dev:seismicpoststackdatasets:1519784464",
#                     "npequinor-dev:seismicpoststackdatasets:1518499841",
#                     "npequinor-dev:seismicpoststackdatasets:1520281555",
#                     "npequinor-dev:seismicpoststackdatasets:1521221093",
#                     "npequinor-dev:seismicpoststackdatasets:1521177786",
#                     "npequinor-dev:seismicpoststackdatasets:1521712226",
#                     "npequinor-dev:seismicpoststackdatasets:1518508940",
#                     "npequinor-dev:seismicpoststackdatasets:1522058395",
#                     "npequinor-dev:seismicpoststackdatasets:1521493948",
#                     "npequinor-dev:seismicpoststackdatasets:1520019753",
#                     "npequinor-dev:seismicpoststackdatasets:1519269342",
#                     "npequinor-dev:seismicpoststackdatasets:1522080292",
#                     "npequinor-dev:seismicpoststackdatasets:1521560012",
#                     "npequinor-dev:seismicpoststackdatasets:1521419148",
#                     "npequinor-dev:seismicpoststackdatasets:1520408013",
#                     "npequinor-dev:seismicpoststackdatasets:1520575740",
#                     "npequinor-dev:seismicpoststackdatasets:1521562065",
#                     "npequinor-dev:seismicpoststackdatasets:1522273267",
#                     "npequinor-dev:seismicpoststackdatasets:1519865208",
#                     "npequinor-dev:seismicpoststackdatasets:1520786301",
#                     "npequinor-dev:seismicpoststackdatasets:1521181650",
#                     "npequinor-dev:seismicpoststackdatasets:1519865203",
#                     "npequinor-dev:seismicpoststackdatasets:1518222819",
#                     "npequinor-dev:seismicpoststackdatasets:1521142311",
#                     "npequinor-dev:seismicpoststackdatasets:1519871554",
#                     "npequinor-dev:seismicpoststackdatasets:1518296803",
#                     "npequinor-dev:seismicpoststackdatasets:1519760660",
#                     "npequinor-dev:seismicpoststackdatasets:1519794834",
#                     "npequinor-dev:seismicpoststackdatasets:1521800953",
#                     "npequinor-dev:seismicpoststackdatasets:1521813019",
#                     "npequinor-dev:seismicpoststackdatasets:1521782447",
#                     "npequinor-dev:seismicpoststackdatasets:1522063214",
#                     "npequinor-dev:seismicpoststackdatasets:1520950888",
#                     "npequinor-dev:seismicpoststackdatasets:1520133757",
#                     "npequinor-dev:seismicpoststackdatasets:1519684410",
#                     "npequinor-dev:seismicpoststackdatasets:1522282838",
#                     "npequinor-dev:seismicpoststackdatasets:1521842141",
#                     "npequinor-dev:seismicpoststackdatasets:1521704530",
#                     "npequinor-dev:seismicpoststackdatasets:1518465989",
#                     "npequinor-dev:seismicpoststackdatasets:1518447826",
#                     "npequinor-dev:seismicpoststackdatasets:1521399062",
#                     "npequinor-dev:seismicpoststackdatasets:1520675014",
#                     "npequinor-dev:seismicpoststackdatasets:1522254217",
#                     "npequinor-dev:seismicpoststackdatasets:1519742828",
#                     "npequinor-dev:seismicpoststackdatasets:1518456328",
#                     "npequinor-dev:seismicpoststackdatasets:1521811159",
#                     "npequinor-dev:seismicpoststackdatasets:1522066300",
#                     "npequinor-dev:seismicpoststackdatasets:1521499523",
#                     "npequinor-dev:seismicpoststackdatasets:1521320294",
#                     "npequinor-dev:seismicpoststackdatasets:1519915767",
#                     "npequinor-dev:seismicpoststackdatasets:1518230670",
#                     "npequinor-dev:seismicpoststackdatasets:1520527055",
#                     "npequinor-dev:seismicpoststackdatasets:1519982638",
#                     "npequinor-dev:seismicpoststackdatasets:1519794832",
#                     "npequinor-dev:seismicpoststackdatasets:1520677862",
#                     "npequinor-dev:seismicpoststackdatasets:1519917587",
#                     "npequinor-dev:seismicpoststackdatasets:1521248960",
#                     "npequinor-dev:seismicpoststackdatasets:1521572560",
#                     "npequinor-dev:seismicpoststackdatasets:1520518509",
#                     "npequinor-dev:seismicpoststackdatasets:1518610176",
#                     "npequinor-dev:seismicpoststackdatasets:1519204949",
#                     "npequinor-dev:seismicpoststackdatasets:1518323634",
#                     "npequinor-dev:seismicpoststackdatasets:1521371616",
#                     "npequinor-dev:seismicpoststackdatasets:1520369755",
#                     "npequinor-dev:seismicpoststackdatasets:1521521302",
#                     "npequinor-dev:seismicpoststackdatasets:1521524676",
#                     "npequinor-dev:seismicpoststackdatasets:1521845513",
#                     "npequinor-dev:seismicpoststackdatasets:1521590535",
#                     "npequinor-dev:seismicpoststackdatasets:1520669318",
#                     "npequinor-dev:seismicpoststackdatasets:1520484138",
#                     "npequinor-dev:seismicpoststackdatasets:1519250032",
#                     "npequinor-dev:seismicpoststackdatasets:1519791183",
#                     "npequinor-dev:seismicpoststackdatasets:1518527259",
#                     "npequinor-dev:seismicpoststackdatasets:1522010872",
#                     "npequinor-dev:seismicpoststackdatasets:1521874384",
#                     "npequinor-dev:seismicpoststackdatasets:1519997312",
#                     "npequinor-dev:seismicpoststackdatasets:1521110535",
#                     "npequinor-dev:seismicpoststackdatasets:1518502732",
#                     "npequinor-dev:seismicpoststackdatasets:1521818567",
#                     "npequinor-dev:seismicpoststackdatasets:1521692012",
#                     "npequinor-dev:seismicpoststackdatasets:1519670601",
#                     "npequinor-dev:seismicpoststackdatasets:1520566180",
#                     "npequinor-dev:seismicpoststackdatasets:1521452886",
#                     "npequinor-dev:seismicpoststackdatasets:1519889779",
#                     "npequinor-dev:seismicpoststackdatasets:1519175259",
#                     "npequinor-dev:seismicpoststackdatasets:1521047842",
#                     "npequinor-dev:seismicpoststackdatasets:1519177470",
#                     "npequinor-dev:seismicpoststackdatasets:1521547330",
#                     "npequinor-dev:seismicpoststackdatasets:1520142825",
#                     "npequinor-dev:seismicpoststackdatasets:1521543896",
#                     "npequinor-dev:seismicpoststackdatasets:1521380725",
#                     "npequinor-dev:seismicpoststackdatasets:1519154067",
#                     "npequinor-dev:seismicpoststackdatasets:1521318362",
#                     "npequinor-dev:seismicpoststackdatasets:1521199884",
#                     "npequinor-dev:seismicpoststackdatasets:1520231846",
#                     "npequinor-dev:seismicpoststackdatasets:1521393898",
#                     "npequinor-dev:seismicpoststackdatasets:1519230691",
#                     "npequinor-dev:seismicpoststackdatasets:1520933000",
#                     "npequinor-dev:seismicpoststackdatasets:1520270902",
#                     "npequinor-dev:seismicpoststackdatasets:1520910250",
#                     "npequinor-dev:seismicpoststackdatasets:1520239494",
#                     "npequinor-dev:seismicpoststackdatasets:1518596883",
#                     "npequinor-dev:seismicpoststackdatasets:1519420111",
#                     "npequinor-dev:seismicpoststackdatasets:1521755652",
#                     "npequinor-dev:seismicpoststackdatasets:1520846886",
#                     "npequinor-dev:seismicpoststackdatasets:1519489303",
#                     "npequinor-dev:seismicpoststackdatasets:1518479443",
#                     "npequinor-dev:seismicpoststackdatasets:1519777568",
#                     "npequinor-dev:seismicpoststackdatasets:1520887922",
#                     "npequinor-dev:seismicpoststackdatasets:1520185899",
#                     "npequinor-dev:seismicpoststackdatasets:1519895239",
#                     "npequinor-dev:seismicpoststackdatasets:1521717048",
#                     "npequinor-dev:seismicpoststackdatasets:1520502871",
#                     "npequinor-dev:seismicpoststackdatasets:1518917896",
#                     "npequinor-dev:seismicpoststackdatasets:1521514558",
#                     "npequinor-dev:seismicpoststackdatasets:1520599366",
#                     "npequinor-dev:seismicpoststackdatasets:1519222768",
#                     "npequinor-dev:seismicpoststackdatasets:1521045532",
#                     "npequinor-dev:seismicpoststackdatasets:1520244897",
#                     "npequinor-dev:seismicpoststackdatasets:1519858857",
#                     "npequinor-dev:seismicpoststackdatasets:1519681054",
#                     "npequinor-dev:seismicpoststackdatasets:1518430806",
#                     "npequinor-dev:seismicpoststackdatasets:1521308734",
#                     "npequinor-dev:seismicpoststackdatasets:1522016605",
#                     "npequinor-dev:seismicpoststackdatasets:1520390842",
#                     "npequinor-dev:seismicpoststackdatasets:1520153714",
#                     "npequinor-dev:seismicpoststackdatasets:1519758584",
#                     "npequinor-dev:seismicpoststackdatasets:1521927818",
#                     "npequinor-dev:seismicpoststackdatasets:1521302938",
#                     "npequinor-dev:seismicpoststackdatasets:1519677011",
#                     "npequinor-dev:seismicpoststackdatasets:1522257031",
#                     "npequinor-dev:seismicpoststackdatasets:1521794052",
#                     "npequinor-dev:seismicpoststackdatasets:1520184272",
#                     "npequinor-dev:seismicpoststackdatasets:1520580415",
#                     "npequinor-dev:seismicpoststackdatasets:1522038832",
#                     "npequinor-dev:seismicpoststackdatasets:1519945938",
#                     "npequinor-dev:seismicpoststackdatasets:1521799093",
#                     "npequinor-dev:seismicpoststackdatasets:1519283150",
#                     "npequinor-dev:seismicpoststackdatasets:1519031037",
#                     "npequinor-dev:seismicpoststackdatasets:1521534762",
#                     "npequinor-dev:seismicpoststackdatasets:1519189125",
#                     "npequinor-dev:seismicpoststackdatasets:1518225198",
#                     "npequinor-dev:seismicpoststackdatasets:1520135577",
#                     "npequinor-dev:seismicpoststackdatasets:1519167347",
#                     "npequinor-dev:seismicpoststackdatasets:1522321800",
#                     "npequinor-dev:seismicpoststackdatasets:1521196018",
#                     "npequinor-dev:seismicpoststackdatasets:1519307465",
#                     "npequinor-dev:seismicpoststackdatasets:1521304870",
#                     "npequinor-dev:seismicpoststackdatasets:1521447090",
#                     "npequinor-dev:seismicpoststackdatasets:1520164129",
#                     "npequinor-dev:seismicpoststackdatasets:1520466293",
#                     "npequinor-dev:seismicpoststackdatasets:1519051914",
#                     "npequinor-dev:seismicpoststackdatasets:1521421080",
#                     "npequinor-dev:seismicpoststackdatasets:1519004854",
#                     "npequinor-dev:seismicpoststackdatasets:1520354941",
#                     "npequinor-dev:seismicpoststackdatasets:1522245617",
#                     "npequinor-dev:seismicpoststackdatasets:1522043066",
#                     "npequinor-dev:seismicpoststackdatasets:1519157510",
#                     "npequinor-dev:seismicpoststackdatasets:1518576491",
#                     "npequinor-dev:seismicpoststackdatasets:1519208913",
#                     "npequinor-dev:seismicpoststackdatasets:1520235871",
#                     "npequinor-dev:seismicpoststackdatasets:1519103725",
#                     "npequinor-dev:seismicpoststackdatasets:1519119273",
#                     "npequinor-dev:seismicpoststackdatasets:1521039544",
#                     "npequinor-dev:seismicpoststackdatasets:1520112101",
#                     "npequinor-dev:seismicpoststackdatasets:1519880640",
#                     "npequinor-dev:seismicpoststackdatasets:1519919407",
#                     "npequinor-dev:seismicpoststackdatasets:1519732704",
#                     "npequinor-dev:seismicpoststackdatasets:1521454818",
#                     "npequinor-dev:seismicpoststackdatasets:1521516119",
#                     "npequinor-dev:seismicpoststackdatasets:1519096108",
#                     "npequinor-dev:seismicpoststackdatasets:1518307847",
#                     "npequinor-dev:seismicpoststackdatasets:1518905821",
#                     "npequinor-dev:seismicpoststackdatasets:1521440368",
#                     "npequinor-dev:seismicpoststackdatasets:1519458897",
#                     "npequinor-dev:seismicpoststackdatasets:1518966090",
#                     "npequinor-dev:seismicpoststackdatasets:1520607115",
#                     "npequinor-dev:seismicpoststackdatasets:1520605729",
#                     "npequinor-dev:seismicpoststackdatasets:1520612037",
#                     "npequinor-dev:seismicpoststackdatasets:1521686216",
#                     "npequinor-dev:seismicpoststackdatasets:1520137397",
#                     "npequinor-dev:seismicpoststackdatasets:1521568935",
#                     "npequinor-dev:seismicpoststackdatasets:1519567538",
#                     "npequinor-dev:seismicpoststackdatasets:1521493320",
#                     "npequinor-dev:seismicpoststackdatasets:1519928475",
#                     "npequinor-dev:seismicpoststackdatasets:1519048245",
#                     "npequinor-dev:seismicpoststackdatasets:1519664663",
#                     "npequinor-dev:seismicpoststackdatasets:1521226671",
#                     "npequinor-dev:seismicpoststackdatasets:1521470819",
#                     "npequinor-dev:seismicpoststackdatasets:1520288198",
#                     "npequinor-dev:seismicpoststackdatasets:1520037265",
#                     "npequinor-dev:seismicpoststackdatasets:1521403307",
#                     "npequinor-dev:seismicpoststackdatasets:1519151507",
#                     "npequinor-dev:seismicpoststackdatasets:1519700291",
#                     "npequinor-dev:seismicpoststackdatasets:1521267584",
#                     "npequinor-dev:seismicpoststackdatasets:1519867028",
#                     "npequinor-dev:seismicpoststackdatasets:1519885166",
#                     "npequinor-dev:seismicpoststackdatasets:1519857035",
#                     "npequinor-dev:seismicpoststackdatasets:1521081531",
#                     "npequinor-dev:seismicpoststackdatasets:1521838767",
#                     "npequinor-dev:seismicpoststackdatasets:1520571309",
#                     "npequinor-dev:seismicpoststackdatasets:1521330880",
#                     "npequinor-dev:seismicpoststackdatasets:1518839718",
#                     "npequinor-dev:seismicpoststackdatasets:1522030496",
#                     "npequinor-dev:seismicpoststackdatasets:1519533986",
#                     "npequinor-dev:seismicpoststackdatasets:1520267773",
#                     "npequinor-dev:seismicpoststackdatasets:1521688148",
#                     "npequinor-dev:seismicpoststackdatasets:1519893419",
#                     "npequinor-dev:seismicpoststackdatasets:1521838769",
#                     "npequinor-dev:seismicpoststackdatasets:1521334744",
#                     "npequinor-dev:seismicpoststackdatasets:1521467183",
#                     "npequinor-dev:seismicpoststackdatasets:1518223283",
#                     "npequinor-dev:seismicpoststackdatasets:1521720915",
#                     "npequinor-dev:seismicpoststackdatasets:1521343398",
#                     "npequinor-dev:seismicpoststackdatasets:1518254888",
#                     "npequinor-dev:seismicpoststackdatasets:1520435029",
#                     "npequinor-dev:seismicpoststackdatasets:1518957517",
#                     "npequinor-dev:seismicpoststackdatasets:1522260473",
#                     "npequinor-dev:seismicpoststackdatasets:1520423637",
#                     "npequinor-dev:seismicpoststackdatasets:1518909825",
#                     "npequinor-dev:seismicpoststackdatasets:1522026683",
#                     "npequinor-dev:seismicpoststackdatasets:1519416147",
#                     "npequinor-dev:seismicpoststackdatasets:1520041533",
#                     "npequinor-dev:seismicpoststackdatasets:1520111968",
#                     "npequinor-dev:seismicpoststackdatasets:1522036680",
#                     "npequinor-dev:seismicpoststackdatasets:1518488514",
#                     "npequinor-dev:seismicpoststackdatasets:1522334423",
#                     "npequinor-dev:seismicpoststackdatasets:1518815962",
#                     "npequinor-dev:seismicpoststackdatasets:1521017332",
#                     "npequinor-dev:seismicpoststackdatasets:1521163336",
#                     "npequinor-dev:seismicpoststackdatasets:1519222763",
#                     "npequinor-dev:seismicpoststackdatasets:1518914640",
#                     "npequinor-dev:seismicpoststackdatasets:1519876998",
#                     "npequinor-dev:seismicpoststackdatasets:1519279694",
#                     "npequinor-dev:seismicpoststackdatasets:1519250037",
#                     "npequinor-dev:seismicpoststackdatasets:1518282862",
#                     "npequinor-dev:seismicpoststackdatasets:1520616522",
#                     "npequinor-dev:seismicpoststackdatasets:1519710032",
#                     "npequinor-dev:seismicpoststackdatasets:1521185514",
#                     "npequinor-dev:seismicpoststackdatasets:1521722847",
#                     "npequinor-dev:seismicpoststackdatasets:1519139631",
#                     "npequinor-dev:seismicpoststackdatasets:1518662222",
#                     "npequinor-dev:seismicpoststackdatasets:1520555463",
#                     "npequinor-dev:seismicpoststackdatasets:1520404807",
#                     "npequinor-dev:seismicpoststackdatasets:1520648040",
#                     "npequinor-dev:seismicpoststackdatasets:1522326395",
#                     "npequinor-dev:seismicpoststackdatasets:1520856258",
#                     "npequinor-dev:seismicpoststackdatasets:1518951574",
#                     "npequinor-dev:seismicpoststackdatasets:1521931569",
#                     "npequinor-dev:seismicpoststackdatasets:1519313351",
#                     "npequinor-dev:seismicpoststackdatasets:1521169132",
#                     "npequinor-dev:seismicpoststackdatasets:1519891599",
#                     "npequinor-dev:seismicpoststackdatasets:1520493082",
#                     "npequinor-dev:seismicpoststackdatasets:1520410861",
#                     "npequinor-dev:seismicpoststackdatasets:1518530862",
#                     "npequinor-dev:seismicpoststackdatasets:1521270136",
#                     "npequinor-dev:seismicpoststackdatasets:1521405549",
#                     "npequinor-dev:seismicpoststackdatasets:1521824565",
#                     "npequinor-dev:seismicpoststackdatasets:1518243552",
#                     "npequinor-dev:seismicpoststackdatasets:1520201344",
#                     "npequinor-dev:seismicpoststackdatasets:1519416145",
#                     "npequinor-dev:seismicpoststackdatasets:1521281060",
#                     "npequinor-dev:seismicpoststackdatasets:1518451230",
#                     "npequinor-dev:seismicpoststackdatasets:1518280197",
#                     "npequinor-dev:seismicpoststackdatasets:1521286463",
#                     "npequinor-dev:seismicpoststackdatasets:1520110148",
#                     "npequinor-dev:seismicpoststackdatasets:1520984604",
#                     "npequinor-dev:seismicpoststackdatasets:1520818368",
#                     "npequinor-dev:seismicpoststackdatasets:1521115964",
#                     "npequinor-dev:seismicpoststackdatasets:1519705683",
#                     "npequinor-dev:seismicpoststackdatasets:1519746528",
#                     "npequinor-dev:seismicpoststackdatasets:1522275213",
#                     "npequinor-dev:seismicpoststackdatasets:1520046448",
#                     "npequinor-dev:seismicpoststackdatasets:1522080278",
#                     "npequinor-dev:seismicpoststackdatasets:1521474801",
#                     "npequinor-dev:seismicpoststackdatasets:1520320715",
#                     "npequinor-dev:seismicpoststackdatasets:1518581668",
#                     "npequinor-dev:seismicpoststackdatasets:1520642344",
#                     "npequinor-dev:seismicpoststackdatasets:1520402317",
#                     "npequinor-dev:seismicpoststackdatasets:1521306802",
#                     "npequinor-dev:seismicpoststackdatasets:1520994158",
#                     "npequinor-dev:seismicpoststackdatasets:1518525511",
#                     "npequinor-dev:seismicpoststackdatasets:1520457961",
#                     "npequinor-dev:seismicpoststackdatasets:1520265635",
#                     "npequinor-dev:seismicpoststackdatasets:1520452661",
#                     "npequinor-dev:seismicpoststackdatasets:1520131937",
#                     "npequinor-dev:seismicpoststackdatasets:1519847049",
#                     "npequinor-dev:seismicpoststackdatasets:1520639496",
#                     "npequinor-dev:seismicpoststackdatasets:1520121049",
#                     "npequinor-dev:seismicpoststackdatasets:1518942830",
#                     "npequinor-dev:seismicpoststackdatasets:1521183582",
#                     "npequinor-dev:seismicpoststackdatasets:1521377278",
#                     "npequinor-dev:seismicpoststackdatasets:1519133693",
#                     "npequinor-dev:seismicpoststackdatasets:1519536878",
#                     "npequinor-dev:seismicpoststackdatasets:1520636648",
#                     "npequinor-dev:seismicpoststackdatasets:1518563494",
#                     "npequinor-dev:seismicpoststackdatasets:1518992332",
#                     "npequinor-dev:seismicpoststackdatasets:1518260160",
#                     "npequinor-dev:seismicpoststackdatasets:1520645192",
#                     "npequinor-dev:seismicpoststackdatasets:1518534333",
#                     "npequinor-dev:seismicpoststackdatasets:1518499839",
#                     "npequinor-dev:seismicpoststackdatasets:1521432640",
#                     "npequinor-dev:seismicpoststackdatasets:1520426484",
#                     "npequinor-dev:seismicpoststackdatasets:1522081934",
#                     "npequinor-dev:seismicpoststackdatasets:1520293121",
#                     "npequinor-dev:seismicpoststackdatasets:1518939698",
#                     "npequinor-dev:seismicpoststackdatasets:1519272798",
#                     "npequinor-dev:seismicpoststackdatasets:1521356366",
#                     "npequinor-dev:seismicpoststackdatasets:1518996942",
#                     "npequinor-dev:seismicpoststackdatasets:1521424944",
#                     "npequinor-dev:seismicpoststackdatasets:1521267586",
#                     "npequinor-dev:seismicpoststackdatasets:1522012807",
#                     "npequinor-dev:seismicpoststackdatasets:1520148285",
#                     "npequinor-dev:seismicpoststackdatasets:1520563975",
#                     "npequinor-dev:seismicpoststackdatasets:1518819926",
#                     "npequinor-dev:seismicpoststackdatasets:1521598750",
#                     "npequinor-dev:seismicpoststackdatasets:1519116865",
#                     "npequinor-dev:seismicpoststackdatasets:1522061034",
#                     "npequinor-dev:seismicpoststackdatasets:1518256468",
#                     "npequinor-dev:seismicpoststackdatasets:1520125906",
#                     "npequinor-dev:seismicpoststackdatasets:1522284345",
#                     "npequinor-dev:seismicpoststackdatasets:1520984611",
#                     "npequinor-dev:seismicpoststackdatasets:1521316430",
#                     "npequinor-dev:seismicpoststackdatasets:1520546917",
#                     "npequinor-dev:seismicpoststackdatasets:1521322226",
#                     "npequinor-dev:seismicpoststackdatasets:1519598082",
#                     "npequinor-dev:seismicpoststackdatasets:1521423012",
#                     "npequinor-dev:seismicpoststackdatasets:1520429333",
#                     "npequinor-dev:seismicpoststackdatasets:1521136195",
#                     "npequinor-dev:seismicpoststackdatasets:1521438436",
#                     "npequinor-dev:seismicpoststackdatasets:1518823892",
#                     "npequinor-dev:seismicpoststackdatasets:1521690080",
#                     "npequinor-dev:seismicpoststackdatasets:1521436504",
#                     "npequinor-dev:seismicpoststackdatasets:1519310925",
#                     "npequinor-dev:seismicpoststackdatasets:1518320767",
#                     "npequinor-dev:seismicpoststackdatasets:1521702598",
#                     "npequinor-dev:seismicpoststackdatasets:1519298849",
#                     "npequinor-dev:seismicpoststackdatasets:1522329836",
#                     "npequinor-dev:seismicpoststackdatasets:1521718983",
#                     "npequinor-dev:seismicpoststackdatasets:1520883450",
#                     "npequinor-dev:seismicpoststackdatasets:1518936231",
#                     "npequinor-dev:seismicpoststackdatasets:1521368648",
#                     "npequinor-dev:seismicpoststackdatasets:1518342887",
#                     "npequinor-dev:seismicpoststackdatasets:1519042607",
#                     "npequinor-dev:seismicpoststackdatasets:1518585539",
#                     "npequinor-dev:seismicpoststackdatasets:1520334789",
#                     "npequinor-dev:seismicpoststackdatasets:1520229285",
#                     "npequinor-dev:seismicpoststackdatasets:1521137862",
#                     "npequinor-dev:seismicpoststackdatasets:1518823890",
#                     "npequinor-dev:seismicpoststackdatasets:1520146465",
#                     "npequinor-dev:seismicpoststackdatasets:1521348829",
#                     "npequinor-dev:seismicpoststackdatasets:1518842400",
#                     "npequinor-dev:seismicpoststackdatasets:1518462350",
#                     "npequinor-dev:seismicpoststackdatasets:1521120651",
#                     "npequinor-dev:seismicpoststackdatasets:1520549765",
#                     "npequinor-dev:seismicpoststackdatasets:1520730654",
#                     "npequinor-dev:seismicpoststackdatasets:1520191344",
#                     "npequinor-dev:seismicpoststackdatasets:1519736160",
#                     "npequinor-dev:seismicpoststackdatasets:1520987983",
#                     "npequinor-dev:seismicpoststackdatasets:1519850689",
#                     "npequinor-dev:seismicpoststackdatasets:1522251147",
#                     "npequinor-dev:seismicpoststackdatasets:1520198587",
#                     "npequinor-dev:seismicpoststackdatasets:1520937315",
#                     "npequinor-dev:seismicpoststackdatasets:1521450954",
#                     "npequinor-dev:seismicpoststackdatasets:1518443077",
#                     "npequinor-dev:seismicpoststackdatasets:1521328948",
#                     "npequinor-dev:seismicpoststackdatasets:1520285539",
#                     "npequinor-dev:seismicpoststackdatasets:1519874276",
#                     "npequinor-dev:seismicpoststackdatasets:1521026808",
#                     "npequinor-dev:seismicpoststackdatasets:1518551001",
#                     "npequinor-dev:seismicpoststackdatasets:1521588513",
#                     "npequinor-dev:seismicpoststackdatasets:1519371082",
#                     "npequinor-dev:seismicpoststackdatasets:1519181399",
#                     "npequinor-dev:seismicpoststackdatasets:1521937886",
#                     "npequinor-dev:seismicpoststackdatasets:1521088759",
#                     "npequinor-dev:seismicpoststackdatasets:1522180570",
#                     "npequinor-dev:seismicpoststackdatasets:1521201816",
#                     "npequinor-dev:seismicpoststackdatasets:1518953554",
#                     "npequinor-dev:seismicpoststackdatasets:1521821008",
#                     "npequinor-dev:seismicpoststackdatasets:1519124794",
#                     "npequinor-dev:seismicpoststackdatasets:1521434572",
#                     "npequinor-dev:seismicpoststackdatasets:1521197950",
#                     "npequinor-dev:seismicpoststackdatasets:1521449022",
#                     "npequinor-dev:seismicpoststackdatasets:1521715116",
#                     "npequinor-dev:seismicpoststackdatasets:1521112126",
#                     "npequinor-dev:seismicpoststackdatasets:1520524207",
#                     "npequinor-dev:seismicpoststackdatasets:1521274330",
#                     "npequinor-dev:seismicpoststackdatasets:1519921227",
#                     "npequinor-dev:seismicpoststackdatasets:1518505498",
#                     "npequinor-dev:seismicpoststackdatasets:1520160165",
#                     "npequinor-dev:seismicpoststackdatasets:1521426876",
#                     "npequinor-dev:seismicpoststackdatasets:1521352026",
#                     "npequinor-dev:seismicpoststackdatasets:1521014294",
#                     "npequinor-dev:seismicpoststackdatasets:1518849549",
#                     "npequinor-dev:seismicpoststackdatasets:1520910254"
#                 ]
#             }
#         },
#         "Custom to WKS summary": [
#             {
#                 "Osdu related WKS": "osdu:wks:dataset--FileCollection.SEGY:1.0.0",
#                 "Osdu custom records ids (ingested)": 18886,
#                 "Osdu wks records ids (total)": 18885,
#                 "Osdu custom ids found in wks ancestry (mapped properly)": 18885,
#                 "Osdu custom ids NOT found in wks ancestry (poptential issues during mapping)": [
#                     "npequinor-dev:seismicpoststackdatasets:1507739908"
#                 ]
#             },
#             {
#                 "Osdu related WKS": "osdu:wks:work-product-component--SeismicTraceData:1.3.0",
#                 "Osdu custom records ids (ingested)": 18886,
#                 "Osdu wks records ids (total)": 18832,
#                 "Osdu custom ids found in wks ancestry (mapped properly)": 18832,
#                 "Osdu custom ids NOT found in wks ancestry (poptential issues during mapping)": [
#                     "npequinor-dev:seismicpoststackdatasets:1091186784",
#                     "npequinor-dev:seismicpoststackdatasets:1506483286",
#                     "npequinor-dev:seismicpoststackdatasets:1506870508",
#                     "npequinor-dev:seismicpoststackdatasets:1506410700",
#                     "npequinor-dev:seismicpoststackdatasets:1091604943",
#                     "npequinor-dev:seismicpoststackdatasets:1507074278",
#                     "npequinor-dev:seismicpoststackdatasets:1507137221",
#                     "npequinor-dev:seismicpoststackdatasets:1505802201",
#                     "npequinor-dev:seismicpoststackdatasets:1091326480",
#                     "npequinor-dev:seismicpoststackdatasets:1506596537",
#                     "npequinor-dev:seismicpoststackdatasets:1506593126",
#                     "npequinor-dev:seismicpoststackdatasets:1167115772",
#                     "npequinor-dev:seismicpoststackdatasets:1506536288",
#                     "npequinor-dev:seismicpoststackdatasets:1507086793",
#                     "npequinor-dev:seismicpoststackdatasets:1506463067",
#                     "npequinor-dev:seismicpoststackdatasets:1506972262",
#                     "npequinor-dev:seismicpoststackdatasets:1506539098",
#                     "npequinor-dev:seismicpoststackdatasets:1507739908",
#                     "npequinor-dev:seismicpoststackdatasets:1507154705",
#                     "npequinor-dev:seismicpoststackdatasets:1091297630",
#                     "npequinor-dev:seismicpoststackdatasets:1505897236",
#                     "npequinor-dev:seismicpoststackdatasets:1091617359",
#                     "npequinor-dev:seismicpoststackdatasets:1163174618",
#                     "npequinor-dev:seismicpoststackdatasets:1507119737",
#                     "npequinor-dev:seismicpoststackdatasets:1506599068",
#                     "npequinor-dev:seismicpoststackdatasets:1506933566",
#                     "npequinor-dev:seismicpoststackdatasets:1506015972",
#                     "npequinor-dev:seismicpoststackdatasets:1506120586",
#                     "npequinor-dev:seismicpoststackdatasets:1506681992",
#                     "npequinor-dev:seismicpoststackdatasets:1507061347",
# ...
#                     "npequinor-dev:poststackcubegeometries:1518444427",
#                     "npequinor-dev:poststackcubegeometries:1519704260",
#                     "npequinor-dev:poststackcubegeometries:1520730659",
#                     "npequinor-dev:poststackcubegeometries:1521534767",
#                     "npequinor-dev:poststackcubegeometries:1520426490",
#                     "npequinor-dev:poststackcubegeometries:1519891604",
#                     "npequinor-dev:poststackcubegeometries:1521700671",
#                     "npequinor-dev:poststackcubegeometries:1522036691",
#                     "npequinor-dev:poststackcubegeometries:1520819717",
#                     "npequinor-dev:poststackcubegeometries:1520432186",
#                     "npequinor-dev:poststackcubegeometries:1522024813",
#                     "npequinor-dev:poststackcubegeometries:1520172080",
#                     "npequinor-dev:poststackcubegeometries:1522028614",
#                     "npequinor-dev:poststackcubegeometries:1519787925",
#                     "npequinor-dev:poststackcubegeometries:1518503274",
#                     "npequinor-dev:poststackcubegeometries:1519230696",
#                     "npequinor-dev:poststackcubegeometries:1520268488",
#                     "npequinor-dev:poststackcubegeometries:1519765501",
#                     "npequinor-dev:poststackcubegeometries:1519857042",
#                     "npequinor-dev:poststackcubegeometries:1519298854",
#                     "npequinor-dev:poststackcubegeometries:1518296808",
#                     "npequinor-dev:poststackcubegeometries:1518843687",
#                     "npequinor-dev:poststackcubegeometries:1521372025",
#                     "npequinor-dev:poststackcubegeometries:1520549770",
#                     "npequinor-dev:poststackcubegeometries:1518226980",
#                     "npequinor-dev:poststackcubegeometries:1520366630",
#                     "npequinor-dev:poststackcubegeometries:1518447831",
#                     "npequinor-dev:poststackcubegeometries:1519865213",
#                     "npequinor-dev:poststackcubegeometries:1520847853",
#                     "npequinor-dev:poststackcubegeometries:1521570133",
#                     "npequinor-dev:poststackcubegeometries:1518489662",
#                     "npequinor-dev:poststackcubegeometries:1521784426",
#                     "npequinor-dev:poststackcubegeometries:1521698739",
#                     "npequinor-dev:poststackcubegeometries:1521686221",
#                     "npequinor-dev:poststackcubegeometries:1520518516",
#                     "npequinor-dev:poststackcubegeometries:1518280202",
#                     "npequinor-dev:poststackcubegeometries:1518324464",
#                     "npequinor-dev:poststackcubegeometries:1521049665",
#                     "npequinor-dev:poststackcubegeometries:1521825316",
#                     "npequinor-dev:poststackcubegeometries:1520429338",
#                     "npequinor-dev:poststackcubegeometries:1520937477",
#                     "npequinor-dev:poststackcubegeometries:1518287586",
#                     "npequinor-dev:poststackcubegeometries:1520946421"
#                 ]
#             }
#         },
#         "Custom to WKS summary": [
#             {
#                 "Osdu related WKS": "osdu:wks:work-product-component--SeismicTraceData:1.3.0",
#                 "Osdu custom records ids (ingested)": 18824,
#                 "Osdu wks records ids (total)": 18832,
#                 "Osdu custom ids found in wks ancestry (mapped properly)": 18771,
#                 "Osdu custom ids NOT found in wks ancestry (poptential issues during mapping)": [
#                     "npequinor-dev:poststackcubegeometries:1657850522",
#                     "npequinor-dev:poststackcubegeometries:1505802206",
#                     "npequinor-dev:poststackcubegeometries:1506474669",
#                     "npequinor-dev:poststackcubegeometries:1506122973",
#                     "npequinor-dev:poststackcubegeometries:1657850512",
#                     "npequinor-dev:poststackcubegeometries:1657863747",
#                     "npequinor-dev:poststackcubegeometries:1505844135",
#                     "npequinor-dev:poststackcubegeometries:1657851596",
#                     "npequinor-dev:poststackcubegeometries:1507015526",
#                     "npequinor-dev:poststackcubegeometries:1506870515",
#                     "npequinor-dev:poststackcubegeometries:1657850515",
#                     "npequinor-dev:poststackcubegeometries:1657850530",
#                     "npequinor-dev:poststackcubegeometries:1507154712",
#                     "npequinor-dev:poststackcubegeometries:1506681997",
#                     "npequinor-dev:poststackcubegeometries:1657851604",
#                     "npequinor-dev:poststackcubegeometries:1506425503",
#                     "npequinor-dev:poststackcubegeometries:1657851610",
#                     "npequinor-dev:poststackcubegeometries:1506593131",
#                     "npequinor-dev:poststackcubegeometries:1506567460",
#                     "npequinor-dev:poststackcubegeometries:1506516163",
#                     "npequinor-dev:poststackcubegeometries:1506540257",
#                     "npequinor-dev:poststackcubegeometries:1507078954",
#                     "npequinor-dev:poststackcubegeometries:1506495859",
#                     "npequinor-dev:poststackcubegeometries:1506175367",
#                     "npequinor-dev:poststackcubegeometries:1507061352",
#                     "npequinor-dev:poststackcubegeometries:1506512188",
#                     "npequinor-dev:poststackcubegeometries:1506536293",
#                     "npequinor-dev:poststackcubegeometries:1506698929",
#                     "npequinor-dev:poststackcubegeometries:1506950999",
#                     "npequinor-dev:poststackcubegeometries:1506483291",
#                     "npequinor-dev:poststackcubegeometries:1506912125",
#                     "npequinor-dev:poststackcubegeometries:1506805217",
#                     "npequinor-dev:poststackcubegeometries:1506661620",
#                     "npequinor-dev:poststackcubegeometries:1657851600",
#                     "npequinor-dev:poststackcubegeometries:1507065318",
#                     "npequinor-dev:poststackcubegeometries:1657851585",
#                     "npequinor-dev:poststackcubegeometries:1506599073",
#                     "npequinor-dev:poststackcubegeometries:1505913336",
#                     "npequinor-dev:poststackcubegeometries:1506062186",
#                     "npequinor-dev:poststackcubegeometries:1657850526",
#                     "npequinor-dev:poststackcubegeometries:1506603035",
#                     "npequinor-dev:poststackcubegeometries:1506716831",
#                     "npequinor-dev:poststackcubegeometries:1507090509",
#                     "npequinor-dev:poststackcubegeometries:1506933573",
#                     "npequinor-dev:poststackcubegeometries:1506755531",
#                     "npequinor-dev:poststackcubegeometries:1507137228",
#                     "npequinor-dev:poststackcubegeometries:1506972269",
#                     "npequinor-dev:poststackcubegeometries:1506929607",
#                     "npequinor-dev:poststackcubegeometries:1506623685",
#                     "npequinor-dev:poststackcubegeometries:1507119744",
#                     "npequinor-dev:poststackcubegeometries:1506413987",
#                     "npequinor-dev:poststackcubegeometries:1657851536",
#                     "npequinor-dev:poststackcubegeometries:1657851549"
#                 ]
#             },
#             {
#                 "Osdu related WKS": "osdu:wks:dataset--FileCollection.SEGY:1.0.0",
#                 "Osdu custom records ids (ingested)": 18824,
#                 "Osdu wks records ids (total)": 18885,
#                 "Osdu custom ids found in wks ancestry (mapped properly)": 18824,
#                 "Osdu custom ids NOT found in wks ancestry (poptential issues during mapping)": []
#             }
#         ]
#     },
#     "seismicprojects": {
#         "Source to custom summary": {
#             "Source records count": 2403,
#             "Source unique records ids count": 2403,
#             "OSDU custom ingested unique ids count": 2401,
#             "Common records count (source-custom)": 2400,
#             "Ingeted into OSDU (custom) but missing in source": {
#                 "count": 1,
#                 "ids": [
#                     "npequinor-dev:seismicprojects:1502387784"
#                 ]
#             },
#             "Present in source but missing in OSDU (custom)": {
#                 "count": 3,
#                 "ids": [
#                     "npequinor-dev:seismicprojects:1519805172",
#                     "npequinor-dev:seismicprojects:1518607430",
#                     "npequinor-dev:seismicprojects:1518672457"
#                 ]
#             }
#         },
#         "Custom to WKS summary": [
#             {
#                 "Osdu related WKS": "osdu:wks:master-data--SeismicProcessingProject:1.2.0",
#                 "Osdu custom records ids (ingested)": 2401,
#                 "Osdu wks records ids (total)": 2400,
#                 "Osdu custom ids found in wks ancestry (mapped properly)": 2400,
#                 "Osdu custom ids NOT found in wks ancestry (poptential issues during mapping)": [
#                     "npequinor-dev:seismicprojects:1502387784"
#                 ]
#             }
#         ]
#     },
#     "navigationsets": {
#         "Source to custom summary": {
#             "Source records count": 3248,
#             "Source unique records ids count": 3248,
#             "OSDU custom ingested unique ids count": 3245,
#             "Common records count (source-custom)": 3245,
#             "Ingeted into OSDU (custom) but missing in source": {
#                 "count": 0,
#                 "ids": []
#             },
#             "Present in source but missing in OSDU (custom)": {
#                 "count": 3,
#                 "ids": [
#                     "npequinor-dev:navigationsets:1519805170",
#                     "npequinor-dev:navigationsets:1518607428",
#                     "npequinor-dev:navigationsets:1518672455"
#                 ]
#             }
#         },
#         "Custom to WKS summary": [
#             {
#                 "Osdu related WKS": "osdu:wks:dataset--FileCollection.Generic:1.0.0",
#                 "Osdu custom records ids (ingested)": 3245,
#                 "Osdu wks records ids (total)": 3245,
#                 "Osdu custom ids found in wks ancestry (mapped properly)": 3245,
#                 "Osdu custom ids NOT found in wks ancestry (poptential issues during mapping)": []
#             }
#         ]
#     },
#     "binsetgrids": {
#         "Source to custom summary": {
#             "Source records count": 2143,
#             "Source unique records ids count": 2143,
#             "OSDU custom ingested unique ids count": 2142,
#             "Common records count (source-custom)": 2140,
#             "Ingeted into OSDU (custom) but missing in source": {
#                 "count": 2,
#                 "ids": [
#                     "npequinor-dev:binsetgrids:1507739908",
#                     "npequinor-dev:binsetgrids:1502387784"
#                 ]
#             },
#             "Present in source but missing in OSDU (custom)": {
#                 "count": 3,
#                 "ids": [
#                     "npequinor-dev:binsetgrids:1518610157",
#                     "npequinor-dev:binsetgrids:1518672461",
#                     "npequinor-dev:binsetgrids:1519805176"
#                 ]
#             }
#         },
#         "Custom to WKS summary": [
#             {
#                 "Osdu related WKS": "osdu:wks:work-product-component--SeismicBinGrid:1.0.0",
#                 "Osdu custom records ids (ingested)": 2142,
#                 "Osdu wks records ids (total)": 2072,
#                 "Osdu custom ids found in wks ancestry (mapped properly)": 2072,
#                 "Osdu custom ids NOT found in wks ancestry (poptential issues during mapping)": [
#                     "npequinor-dev:binsetgrids:200586815",
#                     "npequinor-dev:binsetgrids:200586820",
#                     "npequinor-dev:binsetgrids:200587409",
#                     "npequinor-dev:binsetgrids:200586841",
#                     "npequinor-dev:binsetgrids:1502387784",
#                     "npequinor-dev:binsetgrids:200586805",
#                     "npequinor-dev:binsetgrids:200586810",
#                     "npequinor-dev:binsetgrids:200586843",
#                     "npequinor-dev:binsetgrids:200586829",
#                     "npequinor-dev:binsetgrids:200587992",
#                     "npequinor-dev:binsetgrids:200586594",
#                     "npequinor-dev:binsetgrids:200586796",
#                     "npequinor-dev:binsetgrids:200586811",
#                     "npequinor-dev:binsetgrids:200588380",
#                     "npequinor-dev:binsetgrids:200586787",
#                     "npequinor-dev:binsetgrids:200586834",
#                     "npequinor-dev:binsetgrids:200586830",
#                     "npequinor-dev:binsetgrids:200586840",
#                     "npequinor-dev:binsetgrids:200586806",
#                     "npequinor-dev:binsetgrids:200586836",
#                     "npequinor-dev:binsetgrids:200586828",
#                     "npequinor-dev:binsetgrids:200586827",
#                     "npequinor-dev:binsetgrids:200586823",
#                     "npequinor-dev:binsetgrids:200586826",
#                     "npequinor-dev:binsetgrids:200586802",
#                     "npequinor-dev:binsetgrids:200586833",
#                     "npequinor-dev:binsetgrids:200586835",
#                     "npequinor-dev:binsetgrids:200586846",
#                     "npequinor-dev:binsetgrids:200586831",
#                     "npequinor-dev:binsetgrids:200588882",
#                     "npequinor-dev:binsetgrids:200586803",
#                     "npequinor-dev:binsetgrids:200586832",
#                     "npequinor-dev:binsetgrids:200586801",
#                     "npequinor-dev:binsetgrids:200586842",
#                     "npequinor-dev:binsetgrids:200586795",
#                     "npequinor-dev:binsetgrids:200586791",
#                     "npequinor-dev:binsetgrids:1507739908",
#                     "npequinor-dev:binsetgrids:200586822",
#                     "npequinor-dev:binsetgrids:200586825",
#                     "npequinor-dev:binsetgrids:200588833",
#                     "npequinor-dev:binsetgrids:200586807",
#                     "npequinor-dev:binsetgrids:200586839",
#                     "npequinor-dev:binsetgrids:200586792",
#                     "npequinor-dev:binsetgrids:200586809",
#                     "npequinor-dev:binsetgrids:200588129",
#                     "npequinor-dev:binsetgrids:200586799",
#                     "npequinor-dev:binsetgrids:200586800",
#                     "npequinor-dev:binsetgrids:200586797",
#                     "npequinor-dev:binsetgrids:200589089",
#                     "npequinor-dev:binsetgrids:200586569",
#                     "npequinor-dev:binsetgrids:200586793",
#                     "npequinor-dev:binsetgrids:200586837",
#                     "npequinor-dev:binsetgrids:200586845",
#                     "npequinor-dev:binsetgrids:200586794",
#                     "npequinor-dev:binsetgrids:200586790",
#                     "npequinor-dev:binsetgrids:200586838",
#                     "npequinor-dev:binsetgrids:200586819",
#                     "npequinor-dev:binsetgrids:200589086",
#                     "npequinor-dev:binsetgrids:200586812",
#                     "npequinor-dev:binsetgrids:200586798",
#                     "npequinor-dev:binsetgrids:200586808",
#                     "npequinor-dev:binsetgrids:200586821",
#                     "npequinor-dev:binsetgrids:200586818",
#                     "npequinor-dev:binsetgrids:200586817",
#                     "npequinor-dev:binsetgrids:200586804",
#                     "npequinor-dev:binsetgrids:200586591",
#                     "npequinor-dev:binsetgrids:200586844",
#                     "npequinor-dev:binsetgrids:200586824",
#                     "npequinor-dev:binsetgrids:200586593",
#                     "npequinor-dev:binsetgrids:200586590"
#                 ]
#             }
#         ]
#     }
# }

# %%
"""

NOTE for myself for later: 

By seeing the poststackcubegeometries I can guess that some of the datasets have been created but the tarce record failed for these 8 records.
Potential explanations:
    - The reason could be that some the datasets failed first and that caused the trace records to fail too.
    - OR the trace records thenselves failed although the datasets were created properly.

    #TODO: Try ingesting these records in DEV

"""
# Out:
# '\n\nNOTE for myself for later: \n\nBy seeing the poststackcubegeometries I can guess that some of the datasets have been created but the tarce record failed for these 8 records.\nPotential explanations:\n    - The reason could be that some the datasets failed first and that caused the trace records to fail too.\n    - OR the trace records thenselves failed although the datasets were created properly.\n\n    #TODO: Try ingesting these records in DEV\n\n'
