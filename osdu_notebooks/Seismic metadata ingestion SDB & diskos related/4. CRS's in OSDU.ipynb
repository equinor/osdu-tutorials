# %% [markdown]
# ## Check CRS's from SDB in OSDU
#
# Simple QC notebook to check which CRS's found in SDB can be found in OSDU.

# %%
"""Uncomment if running in Azure ML"""
# import sys
# sys.path.append(r'/mnt/batch/tasks/shared/LS_root/mounts/clusters/jopm/code/Users/JOPM/osdu_jopm_rottation')
# sys.path

# %%
import os
import re
from urllib.parse import urljoin
from fuzzywuzzy import fuzz
from libs.ladmark_service.landmark_client import LandmarkService
from libs.osdu_service.osdu_http_client import OsduHttpClient

# Adding .env file variables as environment variables
from dotenv import load_dotenv
load_dotenv()
# Out:
# c:\Users\JOPM\Documents\OSDU - DevOps\Respos\OSDU DevOps\osdu-tutorials\venv\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# True

# %% [markdown]
# ### Additional Utilities

# %%
"""
OSDU search utilities.
"""

def search_cursor(osdu_client: OsduHttpClient, search_url_cursor, search_payload):
    results = []
    cursor = ""

    search_payload["limit"] = 1

    while True:
        search_payload["cursor"] = cursor
        source_data = osdu_client.osdu_client.post_returning_json(
            search_url_cursor, search_payload)
        if source_data["results"]:
            results.extend(source_data['results'])
        cursor = source_data.get('cursor')
        if cursor is None:
            break
    return results


"""
Search for CRS in OSDU utilities.
"""

def search_reference(osdu_client: OsduHttpClient, schema_kind, query_criteria, query_criteria_equals, returned_fields):
    
    osdu_base_url = osdu_client.env_variables["url"]
    search_url = urljoin(osdu_base_url, "api/search/v2/query")
    query = '{}:"\{}\"'.format(query_criteria, query_criteria_equals)

    payload = {
        "kind": schema_kind,
        "returnedFields": returned_fields,
        "limit": 1000,
        "query": query
    }

    resp = osdu_client.osdu_client.post_returning_json(
        search_url,
        payload,
    )
    return resp["results"]


def find_best_match(value, match_on, possible_options, start_prob=50):
    return_index = None
    highest_prob = start_prob
    
    if len(possible_options) == 0:
        return dict(), None
    else:
        for i in range(len(possible_options)):
            prob_cal = fuzz.ratio(possible_options[i].get("data").get(match_on), value)
            if prob_cal >= highest_prob:  # Check for a higher probability
                highest_prob = prob_cal
                return_index = i
                
        if return_index is not None:
            return possible_options[return_index], highest_prob
        else:
            return dict(), None
        
        
def process_crs_string(input_string) -> str:
    processed_string = re.findall(r'\b[A-Za-z]+\b', input_string)
    if isinstance(processed_string, list):
        if len(processed_string) != 0:
            return processed_string[0]
    return input_string
        
        
def remove_spaces(value):
    return re.sub(r'\s+', ' ', value)


def format_for_search(value):
    value = re.sub(r'\s+', ' ', value)
    value_list = value.split(" ")
    formated_string = "(" + " OR ".join(['"' + item + '"' for item in value_list]) + ")"
    return formated_string

# %%
last_run_date_time = "2023-07-26T09:10:16.945Z"
last_run_date_time = None
query_records_created_prior_latsrundate = True

osdu_env = "npequinor-dev"
source = "sdb"

entities = {
    "poststackcubegeometries": {
        "relativePath": "poststackcubegeometries",
        "filters_dict": None,
        "lastrundatetime": last_run_date_time,
        "expand_on": None,
        "id_key": "poststackCubeId",
        "mini_batch_size": 500,
        "return_cols": None
    }
}

# %% [markdown]
# #### 1. CRS's from post stack cube geometries

# %%
"""
Let's get all the poststack geametry cubes records.
Note: We loop by using the seismic surveys id's ONLY because the endpoint geometry cubes endpoint
fails for some reason when requesting all the geometry cubes all at one.
"""

source_records = []
with LandmarkService(
    os.environ[f"{source}_metadata_url"],
    os.environ[f"{source}_ds_security_url"],
    os.environ[f"{source}_refresh_token"]
    ) as landmark:
    
    # generator = landmark.get_records_by_batch_server_pagination(**entities.get("poststackcubegeometries"))
    # generator = landmark.get_records_by_mini_batch(**entities.get("poststackcubegeometries"))
    generator = landmark.get_records_by_batch_client_pagination(**entities.get("poststackcubegeometries"))
    
    try:
        while True:
            records = next(generator)
            source_records.extend(records)
            break                           # remove break statement to request all batches
    except StopIteration:
        pass
# Out:
# WARNING:root:Sending request to: https://ndrapi.dsif.dazlmkeqnprd04.ienergycloud.solutions/dsdataserver/dsl.svc/NDRAPI/1/NDR-SDM/ALL_PROJECTS/poststackcubegeometries?$format=json&$inlinecount=allpages
# WARNING:root:poststackcubegeometries --- Retrieving new token for batch: 0
# WARNING:root:poststackcubegeometries --- Requesting batch from Diskos: 0
# WARNING:root:poststackcubegeometries --- Offset that succeded: 0

# %%
"""
Let's now check for the geometries to see what how many records have all m and z elements being == 0.0
"""

poststackCubeId = [cube["poststackCubeId"] for cube in source_records]
# m = cube_geometries[0]["geometry"].get("linestringzm")[0].get("m")
# z = cube_geometries[0]["geometry"].get("linestringzm")[0].get("z")

all_zeros_m = 0; all_zeros_z = 0
for cube_geom in source_records:
    try:
        m = cube_geom["geometry"].get("linestringzm")[0].get("m")
        z = cube_geom["geometry"].get("linestringzm")[0].get("z")
        
        if all (float(x) == 0.0 for x in m):
            all_zeros_m += 1
        if all (float(x) == 0.0 for x in z):
            all_zeros_z += 1
    except:
        continue

print(
    f"""
    Total records: {len(source_records)}
    Total unique records: {len(list(set(poststackCubeId)))}
    Records with all z values equal to zeros: {all_zeros_z}
    Records with all m values equal to zeros:: {all_zeros_m}
    """
)
# Out:
#     Total records: 500
#     Total unique records: 500
#     Records with all z values equal to zeros: 500
#     Records with all m values equal to zeros:: 500

# %%
"""
Let's now check for th crs to se if we can find a good way to mapp them:
"""

unique_crs = list(set([i["coordinateSystem"] for i in source_records]))

print(
    f"Unique crs in SDB post stack cube geometry data: {len(unique_crs)}"
)
# Out:
# Unique crs in SDB post stack cube geometry data: 16

# %%
"""
Let's bring in all the CoordinateReferenceSystem reference data currently in OSDU DEV.
Note: We will use the OSDU CLI (public client) for this.
"""

osdu_client = OsduHttpClient("npequinor-dev", client_type="public-client")

"""
Example: Finding best match for CRS = "SAD69          T1867"
Note that the start_prob parameter can be used as threshold
for the minimun matching probability to return results.
"""
original_sdb_crs = "SAD69          T1867"

osdu_matched_crs, match_probabilty = find_best_match(
    remove_spaces(original_sdb_crs),
    match_on="Name",
    possible_options=search_reference(
                osdu_client=osdu_client,
                schema_kind="osdu:wks:reference-data--CoordinateReferenceSystem:*",
                query_criteria="data.\\*", query_criteria_equals=format_for_search(original_sdb_crs),
                returned_fields=["id", "data.Name"]
            ),
    start_prob=70
    )

print(f"""
      Sdb crs searched for: {original_sdb_crs},
      OSDU match crs: {osdu_matched_crs},
      Matching probability: {match_probabilty}
      """)
# Out:
#       Sdb crs searched for: SAD69          T1867,
#       OSDU match crs: {'data': {'Name': 'ST_SAD69_T1877'}, 'id': 'npequinor-dev:reference-data--CoordinateReferenceSystem:BoundGeographic2D:EPSG::4618_EPSG::1877'},
#       Matching probability: 72

# %%
"""
Let's check which SDB unique CRS's can be found in OSDU.
"""

crs_mapping_list = []
match_count = 0

for original_crs in unique_crs:
    osdu_crs = {}
    osdu_matched_crs, match_probabilty = find_best_match(
    remove_spaces(original_crs),
    match_on="Name",
    possible_options=search_reference(
                osdu_client=osdu_client,
                schema_kind="osdu:wks:reference-data--CoordinateReferenceSystem:*",
                query_criteria="data.\\*", query_criteria_equals=format_for_search(original_crs),
                returned_fields=["id", "data.Name"]
            ),
    start_prob=70
    )

    record_crs = {
        "SDB CRS": original_crs,
        "OSDU CRS": {
            "Name": osdu_matched_crs.get("data", {}).get("Name"),
            "id": osdu_matched_crs.get("id"),
            "Matching prob": match_probabilty
        }
    }
    
    crs_mapping_list.append(record_crs)
    match_count += 1
    
    print(f"""
        SDB crs name: {original_crs},
        MATCH-PROB: {match_probabilty},
        OSDU crs id: {osdu_matched_crs.get("id")},
        OSDU CRS NAME: {osdu_matched_crs.get("data").get("Name") if len(osdu_matched_crs) != 0 else None}
        """
        )
# Out:
#         SDB crs name: Pulkovo1942    T1808,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: ED50           T1311,
#         MATCH-PROB: 78,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:BoundGeographic2D:EPSG::4230_EPSG::1311,
#         OSDU CRS NAME: ST_ED50_T1311
#
#
#         SDB crs name: Camacupa       T1327,
#         MATCH-PROB: 74,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:BoundGeographic2D:EPSG::4220_EPSG::1327,
#         OSDU CRS NAME: ST_Camacupa1948_T1327
#
#
#         SDB crs name: Camacupa       T1324,
#         MATCH-PROB: 81,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:Geographic2D:EPSG::4220,
#         OSDU CRS NAME: Camacupa 1948
#
#
#         SDB crs name: ED50_N62       T1612,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: ST_Camacupa_T1327,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: NAD27          T1173,
#         MATCH-PROB: 80,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:BoundGeographic2D:EPSG::4267_EPSG::1173,
#         OSDU CRS NAME: ST_NAD27_T1173
#
#
#         SDB crs name: Bogota1975     T1125,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: GDA94          T1150,
#         MATCH-PROB: 80,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:BoundGeographic2D:EPSG::4283_EPSG::1150,
#         OSDU CRS NAME: ST_GDA94_T1150
#
#
#         SDB crs name: WGS84,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: ED50_S62       T1613,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: GDA94          T3000020,
#         MATCH-PROB: 84,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:BoundGeographic2D:EPSG::4283_EQUINOR::3000020,
#         OSDU CRS NAME: ST_GDA94_T3000020
#
#
#         SDB crs name: MAGNA-SIRGAS   T15738,
#         MATCH-PROB: 88,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:BoundGeographic2D:EPSG::4686_EPSG::15738,
#         OSDU CRS NAME: ST_MAGNA-SIRGAS_T15738
#
#
#         SDB crs name: SAD69          T1877,
#         MATCH-PROB: 80,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:BoundGeographic2D:EPSG::4618_EPSG::1877,
#         OSDU CRS NAME: ST_SAD69_T1877
#
#
#         SDB crs name: ED50           T1133,
#         MATCH-PROB: 78,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:BoundGeographic2D:EPSG::4230_EPSG::1133,
#         OSDU CRS NAME: ST_ED50_T1133
#
#
#         SDB crs name: NordSahara1959 T1815,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None

# %%
"""
Let's have a look on how the mapping crs looks like for further QC.
"""
import json

print(json.dumps(crs_mapping_list, indent = 4))
# Out:
# [
#     {
#         "SDB CRS": "Pulkovo1942    T1808",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "ED50           T1311",
#         "OSDU CRS": {
#             "Name": "ST_ED50_T1311",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:BoundGeographic2D:EPSG::4230_EPSG::1311",
#             "Matching prob": 78
#         }
#     },
#     {
#         "SDB CRS": "Camacupa       T1327",
#         "OSDU CRS": {
#             "Name": "ST_Camacupa1948_T1327",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:BoundGeographic2D:EPSG::4220_EPSG::1327",
#             "Matching prob": 74
#         }
#     },
#     {
#         "SDB CRS": "Camacupa       T1324",
#         "OSDU CRS": {
#             "Name": "Camacupa 1948",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:Geographic2D:EPSG::4220",
#             "Matching prob": 81
#         }
#     },
#     {
#         "SDB CRS": "ED50_N62       T1612",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "ST_Camacupa_T1327",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "NAD27          T1173",
#         "OSDU CRS": {
#             "Name": "ST_NAD27_T1173",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:BoundGeographic2D:EPSG::4267_EPSG::1173",
#             "Matching prob": 80
#         }
#     },
#     {
#         "SDB CRS": "Bogota1975     T1125",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "GDA94          T1150",
#         "OSDU CRS": {
#             "Name": "ST_GDA94_T1150",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:BoundGeographic2D:EPSG::4283_EPSG::1150",
#             "Matching prob": 80
#         }
#     },
#     {
#         "SDB CRS": "WGS84",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "ED50_S62       T1613",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "GDA94          T3000020",
#         "OSDU CRS": {
#             "Name": "ST_GDA94_T3000020",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:BoundGeographic2D:EPSG::4283_EQUINOR::3000020",
#             "Matching prob": 84
#         }
#     },
#     {
#         "SDB CRS": "MAGNA-SIRGAS   T15738",
#         "OSDU CRS": {
#             "Name": "ST_MAGNA-SIRGAS_T15738",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:BoundGeographic2D:EPSG::4686_EPSG::15738",
#             "Matching prob": 88
#         }
#     },
#     {
#         "SDB CRS": "SAD69          T1877",
#         "OSDU CRS": {
#             "Name": "ST_SAD69_T1877",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:BoundGeographic2D:EPSG::4618_EPSG::1877",
#             "Matching prob": 80
#         }
#     },
#     {
#         "SDB CRS": "ED50           T1133",
#         "OSDU CRS": {
#             "Name": "ST_ED50_T1133",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:BoundGeographic2D:EPSG::4230_EPSG::1133",
#             "Matching prob": 78
#         }
#     },
#     {
#         "SDB CRS": "NordSahara1959 T1815",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     }
# ]

# %%
"""
Let's see which are the found and non-found crs's within OSDU.
"""
crs_found = [i for i in crs_mapping_list if i.get("OSDU CRS").get("Name") != None]
crs_non_found = [i for i in crs_mapping_list if i.get("OSDU CRS").get("Name") == None]

print(f"""
      Total unique crs's: {len(unique_crs)}
      Crs's found in OSDU: {len(crs_found)}
      Crs's not found in OSDU: {len(crs_non_found)}
      """)
# Out:
#       Total unique crs's: 16
#       Crs's found in OSDU: 9
#       Crs's not found in OSDU: 7

# %%
"""
Let's see how many post stack cube geometries,
crs of which can be referenced based on current osdu crs data.
"""

geo_cubes_with_ref_crs = 0
geo_cubes_with_no_ref_crs = 0
for cube in source_records:
    if cube["coordinateSystem"] in [i.get('SDB CRS') for i in crs_mapping_list if i.get("OSDU CRS").get("Name") != None]:
        geo_cubes_with_ref_crs += 1
    else:
        geo_cubes_with_no_ref_crs += 1
        
print(f"""
      Total post stack cube geometries: {len(source_records)}
      Records with referenced crs in osdu: {geo_cubes_with_ref_crs}
      Records with NO referenced crs in osdu: {geo_cubes_with_no_ref_crs}
      """)
# Out:
#       Total post stack cube geometries: 500
#       Records with referenced crs in osdu: 403
#       Records with NO referenced crs in osdu: 97

# %% [markdown]
# #### 2. CRS's from binsetgrids

# %%
entities = {
    "binsetgrids": {
        # Attibutes to make the sourse API request
        "relativePath": "binsetgrids",
        "filters_dict": None,
        "lastrundatetime": last_run_date_time,
        "expand_on": None,
        "id_key": "binsetGrid3dId",
        "mini_batch_size": 500,
        "return_cols": None
    }
}

# %%
source_records = []
with LandmarkService(
    os.environ[f"{source}_metadata_url"],
    os.environ[f"{source}_ds_security_url"],
    os.environ[f"{source}_refresh_token"]
    ) as landmark:
    
    # generator = landmark.get_records_by_batch_server_pagination(**entities.get("poststackcubegeometries"))
    # generator = landmark.get_records_by_mini_batch(**entities.get("poststackcubegeometries"))
    generator = landmark.get_records_by_batch_client_pagination(**entities.get("binsetgrids"))
    
    try:
        while True:
            records = next(generator)
            source_records.extend(records)
            break                           # remove break statement to request all batches
        
        print(f"Total Binsetgrids retrieved: {len(source_records)}")
        
    except StopIteration:
        pass
# Out:
# WARNING:root:Sending request to: https://ndrapi.dsif.dazlmkeqnprd04.ienergycloud.solutions/dsdataserver/dsl.svc/NDRAPI/1/NDR-SDM/ALL_PROJECTS/binsetgrids?$format=json&$inlinecount=allpages
# WARNING:root:binsetgrids --- Retrieving new token for batch: 0
# WARNING:root:binsetgrids --- Requesting batch from Diskos: 0
# WARNING:root:binsetgrids --- Offset that succeded: 0
# Total Binsetgrids retrieved: 500

# %%
"""
Let's now check for th crs to se if we can find a good way to mapp them:
"""

unique_crs2 = list(set([i["originalCRS"] for i in source_records]))

print(
    f"Unique crs in SDB binsetgrids: {len(unique_crs2)}"
)
# Out:
# Unique crs in SDB binsetgrids: 105

# %%
"""
Example: Finding best match for CRS = "ST_NZGD2000_NZTM_P2193_T1565"
Note that the start_prob parameter can be used as threshold
for the minimun matching probability to return results.
"""
original_sdb_crs = "ST_NZGD2000_NZTM_P2193_T1565"

osdu_matched_crs, match_probabilty = find_best_match(
    original_sdb_crs,
    match_on="Name",
    possible_options=search_reference(
                osdu_client=osdu_client,
                schema_kind="osdu:wks:reference-data--CoordinateReferenceSystem:*",
                query_criteria="data.\\*", query_criteria_equals=original_sdb_crs,
                returned_fields=["id", "data.Name"]
            ),
    start_prob=50
    )

print(f"""
      Sdb crs searched for: {original_sdb_crs},
      OSDU match crs: {osdu_matched_crs},
      Matching probability: {match_probabilty}
      """)
# Out:
#       Sdb crs searched for: ST_NZGD2000_NZTM_P2193_T1565,
#       OSDU match crs: {'data': {'Name': 'ST_NZGD2000_NZTM_P2193_T1565'}, 'id': 'npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::2193_EPSG::1565'},
#       Matching probability: 100

# %%
"""
Let's check which SDB unique CRS's can be found in OSDU.
"""

crs_mapping_list2 = []
match_count = 0

for original_crs in unique_crs2:
    osdu_crs = {}
    osdu_matched_crs, match_probabilty = find_best_match(
    original_crs,
    match_on="Name",
    possible_options=search_reference(
                osdu_client=osdu_client,
                schema_kind="osdu:wks:reference-data--CoordinateReferenceSystem:*",
                query_criteria="data.\\*", query_criteria_equals=original_crs,
                returned_fields=["id", "data.Name"]
            ),
    start_prob=50
    )

    record_crs = {
        "SDB CRS": original_crs,
        "OSDU CRS": {
            "Name": osdu_matched_crs.get("data", {}).get("Name"),
            "id": osdu_matched_crs.get("id"),
            "Matching prob": match_probabilty
        }
    }
    
    crs_mapping_list2.append(record_crs)
    match_count += 1
    
    print(f"""
        SDB crs name: {original_crs},
        MATCH-PROB: {match_probabilty},
        OSDU crs id: {osdu_matched_crs.get("id")},
        OSDU CRS NAME: {osdu_matched_crs.get("data").get("Name") if len(osdu_matched_crs) != 0 else None}
        """
        )
# Out:
#         SDB crs name: SAD69_UTM24S_P29194_T1864,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: ST_WGS84_UTM34N_P32634,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32634,
#         OSDU CRS NAME: ST_WGS84_UTM34N_P32634
#
#
#         SDB crs name: ST_Pulkovo1942_3GK51E_P2592_T1808_Depr,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: Aratu_UTM23S_P20823_T1549,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: ST_CampoInchauspe_Argentina_P22192_T1127,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: ST_WGS84_UTM37S_P32737,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32737,
#         OSDU CRS NAME: ST_WGS84_UTM37S_P32737
#
#
#         SDB crs name: ST_ELD79_UTM33N_P2078_T1861,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::2078_EPSG::1861,
#         OSDU CRS NAME: ST_ELD79_UTM33N_P2078_T1861
#
#
#         SDB crs name: ST_WGS84_UTM49S_P32749,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32749,
#         OSDU CRS NAME: ST_WGS84_UTM49S_P32749
#
#
#         SDB crs name: Pulkovo1942_3GK69E_P2598_T1254,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: ST_SAD69_BrazilPolyconic_P29101_T1877,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::29101_EPSG::1877,
#         OSDU CRS NAME: ST_SAD69_BrazilPolyconic_P29101_T1877
#
#
#         SDB crs name: ST_WGS84_UTM29N_P32629,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32629,
#         OSDU CRS NAME: ST_WGS84_UTM29N_P32629
#
#
#         SDB crs name: NAD27_UTM22N_P26722_T1173,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: ST_SIRGAS2000_UTM24S_P31984_T15894,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::31984_EPSG::15894,
#         OSDU CRS NAME: ST_SIRGAS2000_UTM24S_P31984_T15894
#
#
#         SDB crs name: ST_MAGNA-SIRGAS_ColomBogata_P3116_T15738,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: NAD27_UTM15N_P26715_T208002,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: NAD27_UTM15N_P26715_T1173,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: ST_WGS84_UTM35N_P32635,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32635,
#         OSDU CRS NAME: ST_WGS84_UTM35N_P32635
#
#
#         SDB crs name: ST_WGS84_UTM15N_P32615,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32615,
#         OSDU CRS NAME: ST_WGS84_UTM15N_P32615
#
#
#         SDB crs name: ST_ED50_UTM31N_P23031_T1311,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::23031_EPSG::1311,
#         OSDU CRS NAME: ST_ED50_UTM31N_P23031_T1311
#
#
#         SDB crs name: ST_Camacupa_UTM32S_P22032_T1321,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: ST_SAD69_UTM22N_P29172_T1877,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::29172_EPSG::1877,
#         OSDU CRS NAME: ST_SAD69_UTM22N_P29172_T1877
#
#
#         SDB crs name: ST_WGS84_UTM53S_P32753,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32753,
#         OSDU CRS NAME: ST_WGS84_UTM53S_P32753
#
#
#         SDB crs name: ST_NAD27_UTM17N_P26717_T1185,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::26717_EPSG::1185,
#         OSDU CRS NAME: ST_NAD27_UTM17N_P26717_T1185
#
#
#         SDB crs name: ST_WGS84_UTM32N_P32632,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32632,
#         OSDU CRS NAME: ST_WGS84_UTM32N_P32632
#
#
#         SDB crs name: WGS84_TM8_30NE_P202014,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: NAD27_UTM16N_P26716_T1173,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: Camacupa_TM12SE_P22092_T1321,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: ST_ED50_TM0N_P23090_T1311,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::23090_EPSG::1311,
#         OSDU CRS NAME: ST_ED50_TM0N_P23090_T1311
#
#
#         SDB crs name: WGS84_BLM15N_ftUS_P32665,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: ST_Camacupa_TM11.30SE_P22091_T1324,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: ST_WGS84_UTM30N_P32630,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32630,
#         OSDU CRS NAME: ST_WGS84_UTM30N_P32630
#
#
#         SDB crs name: ST_Camacupa_TM12SE_P22092_T1321,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: WGS84_Lambert_66W_P202122,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: ST_NAD83_UTM20N_P26920_T1188,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::26920_EPSG::1188,
#         OSDU CRS NAME: ST_NAD83_UTM20N_P26920_T1188
#
#
#         SDB crs name: NAD27_UTM15N_P26715_T208003,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: Naparima1972_UTM20N_P27120_T1192,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: ED50_UTM20N_P202012_T1133,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: ST_NAD83_UTM22N_P26922_T1188,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::26922_EPSG::1188,
#         OSDU CRS NAME: ST_NAD83_UTM22N_P26922_T1188
#
#
#         SDB crs name: ST_WGS84_UTM23S_P32723,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32723,
#         OSDU CRS NAME: ST_WGS84_UTM23S_P32723
#
#
#         SDB crs name: ST_CampoInchauspe_Arg2_P22192_T3000029,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: ST_WGS84_UTM54S_P32754,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32754,
#         OSDU CRS NAME: ST_WGS84_UTM54S_P32754
#
#
#         SDB crs name: Aratu_UTM24S_P20824_T1549,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: ST_WGS84_UTM38S_P32738,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32738,
#         OSDU CRS NAME: ST_WGS84_UTM38S_P32738
#
#
#         SDB crs name: ST_ED50_UTM29N_P23029_T1133,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::23029_EPSG::1133,
#         OSDU CRS NAME: ST_ED50_UTM29N_P23029_T1133
#
#
#         SDB crs name: ST_ELD79_TM12NE_P2087_T1859,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::2087_EPSG::1859,
#         OSDU CRS NAME: ST_ELD79_TM12NE_P2087_T1859
#
#
#         SDB crs name: ST_Camacupa_UTM32S_P22032_T1327,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: ST_GDA94_MGA54_P28354_T1150,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::28354_EPSG::1150,
#         OSDU CRS NAME: ST_GDA94_MGA54_P28354_T1150
#
#
#         SDB crs name: SAD69_UTM24S_P29194_T208018,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: NAD27_Cuba_Norte_P2085_T1185,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: ST_Camacupa_TM11.30SE_P22091_T1327,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: ST_ED50_UTM31N_P23031_T1133,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::23031_EPSG::1133,
#         OSDU CRS NAME: ST_ED50_UTM31N_P23031_T1133
#
#
#         SDB crs name: AGD84_AMG50_P20350_T15789,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: ST_SAD69_UTM24S_P29194_T1877,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::29194_EPSG::1877,
#         OSDU CRS NAME: ST_SAD69_UTM24S_P29194_T1877
#
#
#         SDB crs name: WGS84_TM12SE_P202001,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: ST_WGS84_UTM55S_P32755,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32755,
#         OSDU CRS NAME: ST_WGS84_UTM55S_P32755
#
#
#         SDB crs name: ST_ED50_UTM34N_P23034_T1612,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::23034_EPSG::1612,
#         OSDU CRS NAME: ST_ED50_UTM34N_P23034_T1612
#
#
#         SDB crs name: ST_WGS84_UTM51S_P32751,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32751,
#         OSDU CRS NAME: ST_WGS84_UTM51S_P32751
#
#
#         SDB crs name: ST_WGS84_UTM20N_P32620,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32620,
#         OSDU CRS NAME: ST_WGS84_UTM20N_P32620
#
#
#         SDB crs name: ST_WGS84_UTM36N_P32636,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32636,
#         OSDU CRS NAME: ST_WGS84_UTM36N_P32636
#
#
#         SDB crs name: ST_WGS84_UTM44N_P32644,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32644,
#         OSDU CRS NAME: ST_WGS84_UTM44N_P32644
#
#
#         SDB crs name: SAD69_UTM24S_P29194_T1867,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: ST_LaCanoa_UTM20N_P24720_T1516,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::24720_EPSG::1516,
#         OSDU CRS NAME: ST_LaCanoa_UTM20N_P24720_T1516
#
#
#         SDB crs name: ST_Mporaloko_UTM32S_P26692_T1532,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::26692_EPSG::1532,
#         OSDU CRS NAME: ST_Mporaloko_UTM32S_P26692_T1532
#
#
#         SDB crs name: ST_WGS84_UTM22N_P32622,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32622,
#         OSDU CRS NAME: ST_WGS84_UTM22N_P32622
#
#
#         SDB crs name: Egypt1907_RedBelt_P22992_T208005,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: ST_SIRGAS2000_UTM23S_P31983_T15894,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::31983_EPSG::15894,
#         OSDU CRS NAME: ST_SIRGAS2000_UTM23S_P31983_T15894
#
#
#         SDB crs name: ST_WGS84_UTM24S_P32724,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32724,
#         OSDU CRS NAME: ST_WGS84_UTM24S_P32724
#
#
#         SDB crs name: ST_ED50_UTM31N_P23031_T1613,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::23031_EPSG::1613,
#         OSDU CRS NAME: ST_ED50_UTM31N_P23031_T1613
#
#
#         SDB crs name: ST_NAD83_UTM12N_P26912_T1188,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::26912_EPSG::1188,
#         OSDU CRS NAME: ST_NAD83_UTM12N_P26912_T1188
#
#
#         SDB crs name: WGS84_TM60SW_P202009,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: ST_Camacupa_TM12SE_P22092_T1327,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: ST_WGS84_UTM23N_P32623,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32623,
#         OSDU CRS NAME: ST_WGS84_UTM23N_P32623
#
#
#         SDB crs name: ED50_UTM31N_P23031_T1146,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: ST_Camacupa_UTM33S_P22033_T1321,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: ST_ED50_UTM30N_P23030_T1133,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::23030_EPSG::1133,
#         OSDU CRS NAME: ST_ED50_UTM30N_P23030_T1133
#
#
#         SDB crs name: ST_WGS84_UTM50S_P32750,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32750,
#         OSDU CRS NAME: ST_WGS84_UTM50S_P32750
#
#
#         SDB crs name: Camacupa_UTM33S_P22033_T1324,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: AGD84_AMG50_P20350_T1669,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: ST_ED50_UTM28N_P23028_T1311,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::23028_EPSG::1311,
#         OSDU CRS NAME: ST_ED50_UTM28N_P23028_T1311
#
#
#         SDB crs name: ST_WGS84_UTM28N_P32628,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32628,
#         OSDU CRS NAME: ST_WGS84_UTM28N_P32628
#
#
#         SDB crs name: ST_WGS84_UTM39N_P32639,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32639,
#         OSDU CRS NAME: ST_WGS84_UTM39N_P32639
#
#
#         SDB crs name: ST_NordSahara1959_UTM31N_P30731_T1815,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::30731_EPSG::1815,
#         OSDU CRS NAME: ST_NordSahara1959_UTM31N_P30731_T1815
#
#
#         SDB crs name: NAD27_BLM16N_P32066_T1173,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: ST_SAD69_UTM22S_P29192_T1877,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::29192_EPSG::1877,
#         OSDU CRS NAME: ST_SAD69_UTM22S_P29192_T1877
#
#
#         SDB crs name: ST_Pulkovo1942_6GK51E_P2499_T1808,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::2499_EPSG::1808,
#         OSDU CRS NAME: ST_Pulkovo1942_6GK51E_P2499_T1808
#
#
#         SDB crs name: ST_ETRS89_UTM30N_P25830_T1149,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::25830_EPSG::1149,
#         OSDU CRS NAME: ST_ETRS89_UTM30N_P25830_T1149
#
#
#         SDB crs name: ST_GDA94_MGA50_P28350_T1150,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::28350_EPSG::1150,
#         OSDU CRS NAME: ST_GDA94_MGA50_P28350_T1150
#
#
#         SDB crs name: ST_ED50_UTM29N_P23029_T1311,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::23029_EPSG::1311,
#         OSDU CRS NAME: ST_ED50_UTM29N_P23029_T1311
#
#
#         SDB crs name: ST_Minna_UTM31N_P26331_T1823,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::26331_EPSG::1823,
#         OSDU CRS NAME: ST_Minna_UTM31N_P26331_T1823
#
#
#         SDB crs name: ST_NZGD2000_NZTM_P2193_T1565,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::2193_EPSG::1565,
#         OSDU CRS NAME: ST_NZGD2000_NZTM_P2193_T1565
#
#
#         SDB crs name: ST_WGS84_UTM33S_P32733,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32733,
#         OSDU CRS NAME: ST_WGS84_UTM33S_P32733
#
#
#         SDB crs name: ST_Camacupa_UTM33S_P22033_T1327,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: Minna_UTM31N_P26331_T208015,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: ST_SAD69_UTM23S_P29193_T1877,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::29193_EPSG::1877,
#         OSDU CRS NAME: ST_SAD69_UTM23S_P29193_T1877
#
#
#         SDB crs name: ST_GDA94_MGA52_P28352_T1150,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::28352_EPSG::1150,
#         OSDU CRS NAME: ST_GDA94_MGA52_P28352_T1150
#
#
#         SDB crs name: Pulkovo1942_3GK75E_P2601_T1254,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: ST_ED50_UTM30N_P23030_T1311,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::23030_EPSG::1311,
#         OSDU CRS NAME: ST_ED50_UTM30N_P23030_T1311
#
#
#         SDB crs name: Nahrwan1967_UTM39N_P27039_T208000,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: ST_WGS84_UTM32S_P32732,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32732,
#         OSDU CRS NAME: ST_WGS84_UTM32S_P32732
#
#
#         SDB crs name: ST_NordSahara1959_UTM32N_P30732_T1816,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::30732_EPSG::1816,
#         OSDU CRS NAME: ST_NordSahara1959_UTM32N_P30732_T1816
#
#
#         SDB crs name: NAD27_UTM08N_P26708_T1172,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: ST_WGS84_UTM21N_P32621,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32621,
#         OSDU CRS NAME: ST_WGS84_UTM21N_P32621
#
#
#         SDB crs name: ST_WGS84_UTM36S_P32736,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32736,
#         OSDU CRS NAME: ST_WGS84_UTM36S_P32736
#
#
#         SDB crs name: AGD84_AMG51_P20351_T1669,
#         MATCH-PROB: None,
#         OSDU crs id: None,
#         OSDU CRS NAME: None
#
#
#         SDB crs name: ST_WGS84_UTM31N_P32631,
#         MATCH-PROB: 100,
#         OSDU crs id: npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32631,
#         OSDU CRS NAME: ST_WGS84_UTM31N_P32631

# %%
"""
Let's have a look on how the mapping crs looks like for further QC.
"""
import json

print(json.dumps(crs_mapping_list2, indent = 4))
# Out:
# [
#     {
#         "SDB CRS": "SAD69_UTM24S_P29194_T1864",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "ST_WGS84_UTM34N_P32634",
#         "OSDU CRS": {
#             "Name": "ST_WGS84_UTM34N_P32634",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32634",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "ST_Pulkovo1942_3GK51E_P2592_T1808_Depr",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "Aratu_UTM23S_P20823_T1549",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "ST_CampoInchauspe_Argentina_P22192_T1127",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "ST_WGS84_UTM37S_P32737",
#         "OSDU CRS": {
#             "Name": "ST_WGS84_UTM37S_P32737",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32737",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "ST_ELD79_UTM33N_P2078_T1861",
#         "OSDU CRS": {
#             "Name": "ST_ELD79_UTM33N_P2078_T1861",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::2078_EPSG::1861",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "ST_WGS84_UTM49S_P32749",
#         "OSDU CRS": {
#             "Name": "ST_WGS84_UTM49S_P32749",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32749",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "Pulkovo1942_3GK69E_P2598_T1254",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "ST_SAD69_BrazilPolyconic_P29101_T1877",
#         "OSDU CRS": {
#             "Name": "ST_SAD69_BrazilPolyconic_P29101_T1877",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::29101_EPSG::1877",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "ST_WGS84_UTM29N_P32629",
#         "OSDU CRS": {
#             "Name": "ST_WGS84_UTM29N_P32629",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32629",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "NAD27_UTM22N_P26722_T1173",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "ST_SIRGAS2000_UTM24S_P31984_T15894",
#         "OSDU CRS": {
#             "Name": "ST_SIRGAS2000_UTM24S_P31984_T15894",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::31984_EPSG::15894",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "ST_MAGNA-SIRGAS_ColomBogata_P3116_T15738",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "NAD27_UTM15N_P26715_T208002",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "NAD27_UTM15N_P26715_T1173",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "ST_WGS84_UTM35N_P32635",
#         "OSDU CRS": {
#             "Name": "ST_WGS84_UTM35N_P32635",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32635",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "ST_WGS84_UTM15N_P32615",
#         "OSDU CRS": {
#             "Name": "ST_WGS84_UTM15N_P32615",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32615",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "ST_ED50_UTM31N_P23031_T1311",
#         "OSDU CRS": {
#             "Name": "ST_ED50_UTM31N_P23031_T1311",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::23031_EPSG::1311",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "ST_Camacupa_UTM32S_P22032_T1321",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "ST_SAD69_UTM22N_P29172_T1877",
#         "OSDU CRS": {
#             "Name": "ST_SAD69_UTM22N_P29172_T1877",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::29172_EPSG::1877",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "ST_WGS84_UTM53S_P32753",
#         "OSDU CRS": {
#             "Name": "ST_WGS84_UTM53S_P32753",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32753",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "ST_NAD27_UTM17N_P26717_T1185",
#         "OSDU CRS": {
#             "Name": "ST_NAD27_UTM17N_P26717_T1185",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::26717_EPSG::1185",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "ST_WGS84_UTM32N_P32632",
#         "OSDU CRS": {
#             "Name": "ST_WGS84_UTM32N_P32632",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32632",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "WGS84_TM8_30NE_P202014",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "NAD27_UTM16N_P26716_T1173",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "Camacupa_TM12SE_P22092_T1321",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "ST_ED50_TM0N_P23090_T1311",
#         "OSDU CRS": {
#             "Name": "ST_ED50_TM0N_P23090_T1311",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::23090_EPSG::1311",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "WGS84_BLM15N_ftUS_P32665",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "ST_Camacupa_TM11.30SE_P22091_T1324",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "ST_WGS84_UTM30N_P32630",
#         "OSDU CRS": {
#             "Name": "ST_WGS84_UTM30N_P32630",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32630",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "ST_Camacupa_TM12SE_P22092_T1321",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "WGS84_Lambert_66W_P202122",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "ST_NAD83_UTM20N_P26920_T1188",
#         "OSDU CRS": {
#             "Name": "ST_NAD83_UTM20N_P26920_T1188",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::26920_EPSG::1188",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "NAD27_UTM15N_P26715_T208003",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "Naparima1972_UTM20N_P27120_T1192",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "ED50_UTM20N_P202012_T1133",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "ST_NAD83_UTM22N_P26922_T1188",
#         "OSDU CRS": {
#             "Name": "ST_NAD83_UTM22N_P26922_T1188",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::26922_EPSG::1188",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "ST_WGS84_UTM23S_P32723",
#         "OSDU CRS": {
#             "Name": "ST_WGS84_UTM23S_P32723",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32723",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "ST_CampoInchauspe_Arg2_P22192_T3000029",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "ST_WGS84_UTM54S_P32754",
#         "OSDU CRS": {
#             "Name": "ST_WGS84_UTM54S_P32754",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32754",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "Aratu_UTM24S_P20824_T1549",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "ST_WGS84_UTM38S_P32738",
#         "OSDU CRS": {
#             "Name": "ST_WGS84_UTM38S_P32738",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32738",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "ST_ED50_UTM29N_P23029_T1133",
#         "OSDU CRS": {
#             "Name": "ST_ED50_UTM29N_P23029_T1133",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::23029_EPSG::1133",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "ST_ELD79_TM12NE_P2087_T1859",
#         "OSDU CRS": {
#             "Name": "ST_ELD79_TM12NE_P2087_T1859",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::2087_EPSG::1859",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "ST_Camacupa_UTM32S_P22032_T1327",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "ST_GDA94_MGA54_P28354_T1150",
#         "OSDU CRS": {
#             "Name": "ST_GDA94_MGA54_P28354_T1150",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::28354_EPSG::1150",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "SAD69_UTM24S_P29194_T208018",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "NAD27_Cuba_Norte_P2085_T1185",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "ST_Camacupa_TM11.30SE_P22091_T1327",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "ST_ED50_UTM31N_P23031_T1133",
#         "OSDU CRS": {
#             "Name": "ST_ED50_UTM31N_P23031_T1133",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::23031_EPSG::1133",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "AGD84_AMG50_P20350_T15789",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "ST_SAD69_UTM24S_P29194_T1877",
#         "OSDU CRS": {
#             "Name": "ST_SAD69_UTM24S_P29194_T1877",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::29194_EPSG::1877",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "WGS84_TM12SE_P202001",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "ST_WGS84_UTM55S_P32755",
#         "OSDU CRS": {
#             "Name": "ST_WGS84_UTM55S_P32755",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32755",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "ST_ED50_UTM34N_P23034_T1612",
#         "OSDU CRS": {
#             "Name": "ST_ED50_UTM34N_P23034_T1612",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::23034_EPSG::1612",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "ST_WGS84_UTM51S_P32751",
#         "OSDU CRS": {
#             "Name": "ST_WGS84_UTM51S_P32751",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32751",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "ST_WGS84_UTM20N_P32620",
#         "OSDU CRS": {
#             "Name": "ST_WGS84_UTM20N_P32620",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32620",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "ST_WGS84_UTM36N_P32636",
#         "OSDU CRS": {
#             "Name": "ST_WGS84_UTM36N_P32636",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32636",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "ST_WGS84_UTM44N_P32644",
#         "OSDU CRS": {
#             "Name": "ST_WGS84_UTM44N_P32644",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32644",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "SAD69_UTM24S_P29194_T1867",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "ST_LaCanoa_UTM20N_P24720_T1516",
#         "OSDU CRS": {
#             "Name": "ST_LaCanoa_UTM20N_P24720_T1516",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::24720_EPSG::1516",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "ST_Mporaloko_UTM32S_P26692_T1532",
#         "OSDU CRS": {
#             "Name": "ST_Mporaloko_UTM32S_P26692_T1532",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::26692_EPSG::1532",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "ST_WGS84_UTM22N_P32622",
#         "OSDU CRS": {
#             "Name": "ST_WGS84_UTM22N_P32622",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32622",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "Egypt1907_RedBelt_P22992_T208005",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "ST_SIRGAS2000_UTM23S_P31983_T15894",
#         "OSDU CRS": {
#             "Name": "ST_SIRGAS2000_UTM23S_P31983_T15894",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::31983_EPSG::15894",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "ST_WGS84_UTM24S_P32724",
#         "OSDU CRS": {
#             "Name": "ST_WGS84_UTM24S_P32724",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32724",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "ST_ED50_UTM31N_P23031_T1613",
#         "OSDU CRS": {
#             "Name": "ST_ED50_UTM31N_P23031_T1613",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::23031_EPSG::1613",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "ST_NAD83_UTM12N_P26912_T1188",
#         "OSDU CRS": {
#             "Name": "ST_NAD83_UTM12N_P26912_T1188",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::26912_EPSG::1188",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "WGS84_TM60SW_P202009",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "ST_Camacupa_TM12SE_P22092_T1327",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "ST_WGS84_UTM23N_P32623",
#         "OSDU CRS": {
#             "Name": "ST_WGS84_UTM23N_P32623",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32623",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "ED50_UTM31N_P23031_T1146",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "ST_Camacupa_UTM33S_P22033_T1321",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "ST_ED50_UTM30N_P23030_T1133",
#         "OSDU CRS": {
#             "Name": "ST_ED50_UTM30N_P23030_T1133",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::23030_EPSG::1133",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "ST_WGS84_UTM50S_P32750",
#         "OSDU CRS": {
#             "Name": "ST_WGS84_UTM50S_P32750",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32750",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "Camacupa_UTM33S_P22033_T1324",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "AGD84_AMG50_P20350_T1669",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "ST_ED50_UTM28N_P23028_T1311",
#         "OSDU CRS": {
#             "Name": "ST_ED50_UTM28N_P23028_T1311",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::23028_EPSG::1311",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "ST_WGS84_UTM28N_P32628",
#         "OSDU CRS": {
#             "Name": "ST_WGS84_UTM28N_P32628",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32628",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "ST_WGS84_UTM39N_P32639",
#         "OSDU CRS": {
#             "Name": "ST_WGS84_UTM39N_P32639",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32639",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "ST_NordSahara1959_UTM31N_P30731_T1815",
#         "OSDU CRS": {
#             "Name": "ST_NordSahara1959_UTM31N_P30731_T1815",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::30731_EPSG::1815",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "NAD27_BLM16N_P32066_T1173",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "ST_SAD69_UTM22S_P29192_T1877",
#         "OSDU CRS": {
#             "Name": "ST_SAD69_UTM22S_P29192_T1877",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::29192_EPSG::1877",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "ST_Pulkovo1942_6GK51E_P2499_T1808",
#         "OSDU CRS": {
#             "Name": "ST_Pulkovo1942_6GK51E_P2499_T1808",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::2499_EPSG::1808",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "ST_ETRS89_UTM30N_P25830_T1149",
#         "OSDU CRS": {
#             "Name": "ST_ETRS89_UTM30N_P25830_T1149",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::25830_EPSG::1149",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "ST_GDA94_MGA50_P28350_T1150",
#         "OSDU CRS": {
#             "Name": "ST_GDA94_MGA50_P28350_T1150",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::28350_EPSG::1150",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "ST_ED50_UTM29N_P23029_T1311",
#         "OSDU CRS": {
#             "Name": "ST_ED50_UTM29N_P23029_T1311",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::23029_EPSG::1311",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "ST_Minna_UTM31N_P26331_T1823",
#         "OSDU CRS": {
#             "Name": "ST_Minna_UTM31N_P26331_T1823",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::26331_EPSG::1823",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "ST_NZGD2000_NZTM_P2193_T1565",
#         "OSDU CRS": {
#             "Name": "ST_NZGD2000_NZTM_P2193_T1565",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::2193_EPSG::1565",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "ST_WGS84_UTM33S_P32733",
#         "OSDU CRS": {
#             "Name": "ST_WGS84_UTM33S_P32733",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32733",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "ST_Camacupa_UTM33S_P22033_T1327",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "Minna_UTM31N_P26331_T208015",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "ST_SAD69_UTM23S_P29193_T1877",
#         "OSDU CRS": {
#             "Name": "ST_SAD69_UTM23S_P29193_T1877",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::29193_EPSG::1877",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "ST_GDA94_MGA52_P28352_T1150",
#         "OSDU CRS": {
#             "Name": "ST_GDA94_MGA52_P28352_T1150",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::28352_EPSG::1150",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "Pulkovo1942_3GK75E_P2601_T1254",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "ST_ED50_UTM30N_P23030_T1311",
#         "OSDU CRS": {
#             "Name": "ST_ED50_UTM30N_P23030_T1311",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::23030_EPSG::1311",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "Nahrwan1967_UTM39N_P27039_T208000",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "ST_WGS84_UTM32S_P32732",
#         "OSDU CRS": {
#             "Name": "ST_WGS84_UTM32S_P32732",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32732",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "ST_NordSahara1959_UTM32N_P30732_T1816",
#         "OSDU CRS": {
#             "Name": "ST_NordSahara1959_UTM32N_P30732_T1816",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:BoundProjected:EPSG::30732_EPSG::1816",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "NAD27_UTM08N_P26708_T1172",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "ST_WGS84_UTM21N_P32621",
#         "OSDU CRS": {
#             "Name": "ST_WGS84_UTM21N_P32621",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32621",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "ST_WGS84_UTM36S_P32736",
#         "OSDU CRS": {
#             "Name": "ST_WGS84_UTM36S_P32736",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32736",
#             "Matching prob": 100
#         }
#     },
#     {
#         "SDB CRS": "AGD84_AMG51_P20351_T1669",
#         "OSDU CRS": {
#             "Name": null,
#             "id": null,
#             "Matching prob": null
#         }
#     },
#     {
#         "SDB CRS": "ST_WGS84_UTM31N_P32631",
#         "OSDU CRS": {
#             "Name": "ST_WGS84_UTM31N_P32631",
#             "id": "npequinor-dev:reference-data--CoordinateReferenceSystem:Projected:EPSG::32631",
#             "Matching prob": 100
#         }
#     }
# ]

# %%
"""
Let's see which are the found and non-found crs's within OSDU.
"""
crs_found2 = [i for i in crs_mapping_list2 if i.get("OSDU CRS").get("Name") != None]
crs_non_found2 = [i for i in crs_mapping_list2 if i.get("OSDU CRS").get("Name") == None]

print(f"""
      Total unique crs's: {len(unique_crs2)}
      Crs's found in OSDU: {len(crs_found2)}
      Crs's not found in OSDU: {len(crs_non_found2)}
      """)
# Out:
#       Total unique crs's: 105
#       Crs's found in OSDU: 62
#       Crs's not found in OSDU: 43

# %%
"""
Let's see how many bingrids crs's,
crs of which can be referenced based on current osdu crs data.
"""

geo_cubes_with_ref_crs2 = 0
geo_cubes_with_no_ref_crs2 = 0
for binsetgrid in source_records:
    if binsetgrid["originalCRS"] in [i.get('SDB CRS') for i in crs_mapping_list2 if i.get("OSDU CRS").get("Name") != None]:
        geo_cubes_with_ref_crs2 += 1
    else:
        geo_cubes_with_no_ref_crs2 += 1
        
print(f"""
      Total binsetgrids: {len(source_records)}
      Records with referenced crs in osdu: {geo_cubes_with_ref_crs2}
      Records with NO referenced crs in osdu: {geo_cubes_with_no_ref_crs2}
      """)
# Out:
#       Total binsetgrids: 500
#       Records with referenced crs in osdu: 370
#       Records with NO referenced crs in osdu: 130
